# %% [markdown]
# # Import

# %%
from collections import defaultdict
from math import log, sqrt
import re
import numpy as np
import sys
from copy import deepcopy
import pandas as pd
import numpy as np
import csv
import json
from itertools import islice
from collections import OrderedDict
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import nltk
from glob import glob
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from tqdm import tqdm
import pickle
import math
import re
from sklearn.model_selection import train_test_split
import operator
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import datetime
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('corpus')
! pip install git+https://github.com/LIAAD/yake
import yake
! pip install multi_rake
from multi_rake import Rake
! pip install summa
from summa import keywords as summa_keywords
! pip install keybert
from keybert import KeyBERT
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Error loading corpus: Package 'corpus' not found in index
# Collecting git+https://github.com/LIAAD/yake
#   Cloning https://github.com/LIAAD/yake to /tmp/pip-req-build-cimdzw6k
#   Running command git clone -q https://github.com/LIAAD/yake /tmp/pip-req-build-cimdzw6k
# Requirement already satisfied: tabulate in /usr/local/lib/python3.7/dist-packages (from yake==0.4.8) (0.8.9)
# Requirement already satisfied: click>=6.0 in /usr/local/lib/python3.7/dist-packages (from yake==0.4.8) (7.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from yake==0.4.8) (1.21.6)
# Collecting segtok
#   Downloading segtok-1.5.11-py3-none-any.whl (24 kB)
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (from yake==0.4.8) (2.6.3)
# Collecting jellyfish
#   Downloading jellyfish-0.9.0.tar.gz (132 kB)
#      |████████████████████████████████| 132 kB 14.3 MB/s
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from segtok->yake==0.4.8) (2019.12.20)
# Building wheels for collected packages: yake, jellyfish
#   Building wheel for yake (setup.py) ... done
#   Created wheel for yake: filename=yake-0.4.8-py2.py3-none-any.whl size=62565 sha256=cf5fa07afaba06b5eaefd9cb1b1138133ffff283f2c4d1dbe6e8ef4daa667170
#   Stored in directory: /tmp/pip-ephem-wheel-cache-8o25x6sa/wheels/52/79/f4/dae9309f60266aa3767a4381405002b6f2955fbcf038d804da
#   Building wheel for jellyfish (setup.py) ... done
#   Created wheel for jellyfish: filename=jellyfish-0.9.0-cp37-cp37m-linux_x86_64.whl size=73973 sha256=80e7397b3746220185f293562c526155622450c3ef2084c91da3f12a0a0d6f08
#   Stored in directory: /root/.cache/pip/wheels/fe/99/4e/646ce766df0d070b0ef04db27aa11543e2767fda3075aec31b
# Successfully built yake jellyfish
# Installing collected packages: segtok, jellyfish, yake
# Successfully installed jellyfish-0.9.0 segtok-1.5.11 yake-0.4.8
# Collecting multi_rake
#   Downloading multi_rake-0.0.2-py3-none-any.whl (31 kB)
# Requirement already satisfied: regex>=2018.6.6 in /usr/local/lib/python3.7/dist-packages (from multi_rake) (2019.12.20)
# Collecting pycld2>=0.41
#   Downloading pycld2-0.41.tar.gz (41.4 MB)
#      |████████████████████████████████| 41.4 MB 1.8 MB/s
# Requirement already satisfied: numpy>=1.14.4 in /usr/local/lib/python3.7/dist-packages (from multi_rake) (1.21.6)
# Requirement already satisfied: pyrsistent>=0.14.2 in /usr/local/lib/python3.7/dist-packages (from multi_rake) (0.18.1)
# Building wheels for collected packages: pycld2
#   Building wheel for pycld2 (setup.py) ... done
#   Created wheel for pycld2: filename=pycld2-0.41-cp37-cp37m-linux_x86_64.whl size=9834334 sha256=dfc113baa48744f484955b14995d322fec63ced9bc0a5f239edcc047c7ada9be
#   Stored in directory: /root/.cache/pip/wheels/ed/e4/58/ed2e9f43c07d617cc81fe7aff0fc6e42b16c9cf6afe960b614
# Successfully built pycld2
# Installing collected packages: pycld2, multi-rake
# Successfully installed multi-rake-0.0.2 pycld2-0.41
# Collecting summa
#   Downloading summa-1.2.0.tar.gz (54 kB)
#      |████████████████████████████████| 54 kB 2.3 MB/s
# Requirement already satisfied: scipy>=0.19 in /usr/local/lib/python3.7/dist-packages (from summa) (1.4.1)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from scipy>=0.19->summa) (1.21.6)
# Building wheels for collected packages: summa
#   Building wheel for summa (setup.py) ... done
#   Created wheel for summa: filename=summa-1.2.0-py3-none-any.whl size=54412 sha256=00cf73d1de9fb878134e7a196766a91fe280eb66b59fa81b5b3aadd019aceaf2
#   Stored in directory: /root/.cache/pip/wheels/29/64/ac/7b443477588d365ef37ada30d456bdf5f07dc5be9f6324cb6e
# Successfully built summa
# Installing collected packages: summa
# Successfully installed summa-1.2.0
# Collecting keybert
#   Downloading keybert-0.5.1.tar.gz (19 kB)
# Collecting sentence-transformers>=0.3.8
#   Downloading sentence-transformers-2.2.0.tar.gz (79 kB)
#      |████████████████████████████████| 79 kB 5.5 MB/s
# Requirement already satisfied: scikit-learn>=0.22.2 in /usr/local/lib/python3.7/dist-packages (from keybert) (1.0.2)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.7/dist-packages (from keybert) (1.21.6)
# Collecting rich>=10.4.0
#   Downloading rich-12.3.0-py3-none-any.whl (232 kB)
#      |████████████████████████████████| 232 kB 40.7 MB/s
# Requirement already satisfied: typing-extensions<5.0,>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from rich>=10.4.0->keybert) (4.2.0)
# Collecting commonmark<0.10.0,>=0.9.0
#   Downloading commonmark-0.9.1-py2.py3-none-any.whl (51 kB)
#      |████████████████████████████████| 51 kB 5.4 MB/s
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /usr/local/lib/python3.7/dist-packages (from rich>=10.4.0->keybert) (2.6.1)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.22.2->keybert) (1.4.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.22.2->keybert) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.22.2->keybert) (1.1.0)
# Collecting transformers<5.0.0,>=4.6.0
#   Downloading transformers-4.18.0-py3-none-any.whl (4.0 MB)
#      |████████████████████████████████| 4.0 MB 67.8 MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from sentence-transformers>=0.3.8->keybert) (4.64.0)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from sentence-transformers>=0.3.8->keybert) (1.11.0+cu113)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from sentence-transformers>=0.3.8->keybert) (0.12.0+cu113)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from sentence-transformers>=0.3.8->keybert) (3.2.5)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 41.3 MB/s
# Collecting huggingface-hub
#   Downloading huggingface_hub-0.5.1-py3-none-any.whl (77 kB)
#      |████████████████████████████████| 77 kB 5.5 MB/s
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (21.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (3.6.0)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 44.5 MB/s
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 58.3 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (2.23.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (2019.12.20)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (4.11.3)
# Collecting sacremoses
#   Downloading sacremoses-0.0.49-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 60.6 MB/s
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (3.0.8)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (3.8.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk->sentence-transformers>=0.3.8->keybert) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (2.10)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (7.1.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->sentence-transformers>=0.3.8->keybert) (7.1.2)
# Building wheels for collected packages: keybert, sentence-transformers
#   Building wheel for keybert (setup.py) ... done
#   Created wheel for keybert: filename=keybert-0.5.1-py3-none-any.whl size=21332 sha256=8d5f21b7f34adfbe3c07f0f121c6afd346b73ca1db50f15061b2199ca169b31e
#   Stored in directory: /root/.cache/pip/wheels/8e/95/c5/f5ceed2a9f9e80bc1a706a10a6fb03d726df7a3dd11800a58b
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.0-py3-none-any.whl size=120747 sha256=efb24482f9e9dcb15b6eb35c9e2559977630c3239878f2101fb676348591ac10
#   Stored in directory: /root/.cache/pip/wheels/83/c0/df/b6873ab7aac3f2465aa9144b6b4c41c4391cfecc027c8b07e7
# Successfully built keybert sentence-transformers
# Installing collected packages: pyyaml, tokenizers, sacremoses, huggingface-hub, transformers, sentencepiece, commonmark, sentence-transformers, rich, keybert
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed commonmark-0.9.1 huggingface-hub-0.5.1 keybert-0.5.1 pyyaml-6.0 rich-12.3.0 sacremoses-0.0.49 sentence-transformers-2.2.0 sentencepiece-0.1.96 tokenizers-0.12.1 transformers-4.18.0

# %%
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file1 = open("/content/drive/MyDrive/Tweelink_Dataset/twitter_base_preprocessed.pkl", "rb")
df = pickle.load(file1)
file1.close()

# %% [markdown]
# # Input

# %%
u_base_hashtag = input("Enter base hashtag: ")
u_time = input("Enter time: ")
u_location = input("Enter Location: ")
# Out:
# Enter base hashtag: hijab
# Enter time: 2022-02-19
# Enter Location: india

# %% [markdown]
# # Processing

# %%
def keyword_extractor(dataset):
  preprocessed_vocabulary = dict()

  #Converting to lowercase
  def to_lower_case(text):
    text = text.lower()
    return text

  def remove_at_word(text):
    data = text.split()
    data = [d for d in data if d[0]!='@']
    text = ' '.join(data)
    return text

  def remove_hashtag(text):
    data = text.split()
    data = [d if (d[0]!='#' or len(d) == 1) else d[1:] for d in data]
    data = [d for d in data if d[0]!='#']
    text = ' '.join(data)
    return text

  def remove_URL(text):
    text = re.sub(r"http\S+", "", text)
    text = re.sub(r'bit.ly\S+', '', text, flags=re.MULTILINE)
    return text

  #Removing stopwords
  def remove_stopwords(text):
    stopword = stopwords.words('english')
    new_list = [x for x in text.split() if x not in stopword]
    return ' '.join(new_list)

  #Removing punctuations
  def remove_punctuations(text):
    punctuations = '''!()-[|]`{};:'"\,<>./?@#$=+%^&*_~'''
    new_list = ['' if x in punctuations else x for x in text.split()]
    new_list_final = []
    for token in new_list:
      new_token=""
      for char in token:
        if(char not in punctuations):
          new_token+=char
      if(len(new_token)!=0):
        new_list_final.append(new_token)
    return ' '.join(new_list_final)

  #Tokenization
  def tokenization(text):
    return word_tokenize(text)

  def pre_process(text):
    text = to_lower_case(text)
    text = remove_at_word(text)
    text = remove_hashtag(text)
    text = remove_URL(text)
    text = remove_stopwords(text)
    text = remove_punctuations(text)
    text = tokenization(text)
    for token in text:
      if token in preprocessed_vocabulary.keys():
        preprocessed_vocabulary[token] += 1
      else:
        preprocessed_vocabulary[token] = 1
    return text
  
  preprocessed_data = [pre_process(text) for text in dataset]

  #print(preprocessed_vocabulary)
  AOF_coefficient = 0
  if len(preprocessed_vocabulary) > 0:
      AOF_coefficient = sum(preprocessed_vocabulary.values())/len(preprocessed_vocabulary)
  vocabulary = {token.strip():preprocessed_vocabulary[token] for token in preprocessed_vocabulary.keys() if preprocessed_vocabulary[token] > AOF_coefficient and len(token.strip())}

  #print(vocabulary)

  final_tokens_per_tweet = []
  for data in preprocessed_data:
    final_tokens_per_tweet.append([token for token in data if token in vocabulary.keys()])

  #print(preprocessed_data)
  #print(final_tokens_per_tweet)

  word2id = dict()
  id2word = dict()
  vocabulary_size = len(vocabulary)
  count = 0
  for token in vocabulary.keys():
    word2id[token] = count
    id2word[count] = token
    count += 1

  #print(word2id)
  #print(id2word)

  directed_graph_adjacency_matrix = np.zeros((vocabulary_size, vocabulary_size))
  edge_weight_matrix = np.zeros((vocabulary_size, vocabulary_size))
  first_frequency = dict()
  last_frequency = dict()
  term_frequency = vocabulary
  strength = dict()
  degree = dict()
  selective_centraility = dict()


  for tweet in final_tokens_per_tweet:
    if len(tweet)<1:
      continue

    if tweet[0] in first_frequency.keys():
      first_frequency[tweet[0]] += 1
    else:
      first_frequency[tweet[0]] = 1

    if tweet[-1] in last_frequency.keys():
      last_frequency[tweet[-1]] += 1
    else:
      last_frequency[tweet[-1]] = 1
    


    for i in range(len(tweet)-1):
      if tweet[i] == tweet[i+1]:
        continue
      x = word2id[tweet[i]]
      y = word2id[tweet[i+1]]
      directed_graph_adjacency_matrix[x][y] += 1

  for tweet in final_tokens_per_tweet:
    for i in range(len(tweet)-1):


      if tweet[i] == tweet[i+1]:
        continue
      x = word2id[tweet[i]]
      y = word2id[tweet[i+1]]

    # Updating degree..
      if tweet[i] in degree.keys():
        degree[tweet[i]] += 1
      else:
        degree[tweet[i]] = 1
        
      if tweet[i+1] in degree.keys():
        degree[tweet[i+1]] += 1
      else:
        degree[tweet[i+1]] = 1

      edge_weight_matrix[x][y] = directed_graph_adjacency_matrix[x][y]/(vocabulary[tweet[i]] + vocabulary[tweet[i+1]] - directed_graph_adjacency_matrix[x][y])

      if tweet[i] in strength.keys():
        strength[tweet[i]] += edge_weight_matrix[x][y]
      else:
        strength[tweet[i]] = edge_weight_matrix[x][y]




  first_frequency = {token:(first_frequency[token]/vocabulary[token] if token in first_frequency else 0) for token in vocabulary.keys()}
  last_frequency = {token:(last_frequency[token]/vocabulary[token] if token in last_frequency else 0) for token in vocabulary.keys()}
  degree = {token:(degree[token] if token in degree else 0) for token in vocabulary.keys()}
  strength = {token:(strength[token] if token in strength else 0) for token in vocabulary.keys()}
  selective_centraility = {token:(strength[token]/degree[token] if degree[token]!=0 else 0) for token in vocabulary.keys()}

  #print(degree)
  #print(vocabulary)

  maxdegree = max(degree.items(), key=lambda x: x[1])[1]
  max_degree_nodes_with_freq = {key:term_frequency[key] for key in degree.keys() if degree[key] == maxdegree}
  maxfreq = max(max_degree_nodes_with_freq.items(), key=lambda x: x[1])[1]
  central_node_name = [key for key in max_degree_nodes_with_freq.keys() if max_degree_nodes_with_freq[key] == maxfreq][0]
  #print("central node: ", central_node_name)

  # bfs
  distance_from_central_node = dict()
  central_node_id = word2id[central_node_name]
  q = [(central_node_id, 0)]

  # Set source as visited
  distance_from_central_node[central_node_name] = 0

  while q:
      vis = q[0]
      # Print current node
      #print(id2word[vis[0]], vis[1])
      q.pop(0)
        
      # For every adjacent vertex to
      # the current vertex
      for i in range(len(directed_graph_adjacency_matrix[vis[0]])):
          if (directed_graph_adjacency_matrix[vis[0]][i] == 1 and (id2word[i] not in distance_from_central_node.keys())):
              # Push the adjacent node
              # in the queue
              q.append((i, vis[1]+1))
              distance_from_central_node[id2word[i]] = vis[1]+1

  #print(distance_from_central_node)
  inverse_distance_from_central_node = {token:(1/distance_from_central_node[token] if token in distance_from_central_node and token != central_node_name else 0) for token in vocabulary.keys()}
  inverse_distance_from_central_node[central_node_name] = 1.0
  #print(inverse_distance_from_central_node)

  neighbour_importance = dict()

  for i in range(len(directed_graph_adjacency_matrix)):
    neighbours = set()

    # traversing outgoing edges
    for j in range(len(directed_graph_adjacency_matrix)):
      if i == j:
        continue
      if directed_graph_adjacency_matrix[i][j] > 0:
        neighbours.add(j)
    for j in range(len(directed_graph_adjacency_matrix)):
      if i == j:
        continue
      if directed_graph_adjacency_matrix[j][i] > 0:
          neighbours.add(j)
    if len(neighbours) != 0:
      neighbour_importance[id2word[i]] = sum([strength[id2word[j]] for j in neighbours])/len(neighbours)
    else:
      neighbour_importance[id2word[i]] = 0
      
  #print(neighbour_importance)

  unnormalized_node_weight = {node: (first_frequency[node] + last_frequency[node] + term_frequency[node] + selective_centraility[node] + inverse_distance_from_central_node[node] + neighbour_importance[node]) for node in vocabulary.keys()}
  max_node_weight = max(unnormalized_node_weight.items(), key=lambda x: x[1])[1]
  min_node_weight = min(unnormalized_node_weight.items(), key=lambda x: x[1])[1]
  #print("max node weight: ", max_node_weight, "min node weight: ", min_node_weight)
  normalized_node_weight = {node: ((unnormalized_node_weight[node] - min_node_weight)/(max_node_weight - min_node_weight) if max_node_weight != min_node_weight else unnormalized_node_weight[node]) for node in unnormalized_node_weight.keys()}
  #print("Unnormalized score: ", unnormalized_node_weight)
  #print("Normalized score: ", normalized_node_weight)

  damping_factor = 0.85
  relevance_of_node = {node: np.random.uniform(0,1,1)[0] for node in vocabulary.keys()}
  threshold = 0.000000001


  #print(relevance_of_node)

  count = 0
  while True:
    count += 1
    current_relevance_of_node = dict()
    for node in vocabulary.keys():
      outer_sum = 0
      node_idx = word2id[node]
      for j in range(len(directed_graph_adjacency_matrix)):
        if j == node_idx:
          continue
        if directed_graph_adjacency_matrix[j][node_idx] > 0:
          den_sum = 0
          for k in range(len(directed_graph_adjacency_matrix)):
            if k == j:
              continue
            den_sum += directed_graph_adjacency_matrix[j][k]
          outer_sum += ((directed_graph_adjacency_matrix[j][node_idx]/den_sum) * relevance_of_node[id2word[j]])
      current_relevance_of_node[node] = (1-damping_factor)*normalized_node_weight[node] + damping_factor*normalized_node_weight[node]*outer_sum
    

    # checking convergence..
    sq_error = sum([(current_relevance_of_node[node] - relevance_of_node[node])**2 for node in vocabulary.keys()])
    relevance_of_node = current_relevance_of_node
    if sq_error < threshold:
      break

  #print(relevance_of_node)
  #print(count)

  degree_centrality  = {node: 0 for node in vocabulary.keys()}

  if len(directed_graph_adjacency_matrix) > 1:
    for i in range(len(directed_graph_adjacency_matrix)):
      count = 0
      for j in range(len(directed_graph_adjacency_matrix)):
        if i == j:
          continue
        if directed_graph_adjacency_matrix[j][i] > 0:
          count += 1
      degree_centrality[id2word[i]] = count / (len(directed_graph_adjacency_matrix)-1)

  #print(degree_centrality)

  final_keyword_rank = [{'node': node, 'NE_rank': relevance_of_node[node], 'Degree': degree_centrality[node]} for node in vocabulary.keys()]

  #print("-----------")
  final_keyword_rank = sorted(final_keyword_rank, key = lambda i: (i['NE_rank'], i['Degree']), reverse = True)

  final_keywords = [keyword['node'] for keyword in final_keyword_rank]

  return final_keywords

# %%
# ## Import the data and create the inverted index

def import_dataset():
    """
    This function import all the articles in the TIME corpus,
    returning list of lists where each sub-list contains all the
    terms present in the document as a string.
    """
    # articles = []
    # with open('TIME.ALL', 'r') as f:
    #     tmp = []
    #     for row in f:
    #         if row.startswith("*TEXT"):
    #             if tmp != []:
    #                 articles.append(tmp)
    #             tmp = []
    #         else:
    #             row = re.sub(r'[^a-zA-Z\s]+', '', row)
    #             tmp += row.split()
    # return articles

    docs_preprocessed_metrics = []
    docs_preprocessed = []
    docs_preprocessed_with_names = []
    path = '/content/drive/MyDrive/Tweelink_Dataset/Tweelink_Articles_Processed'
    for filename in glob(os.path.join(path, '*')):
      with open(os.path.join(os.getcwd(), filename), 'r', encoding = 'utf-8',errors = 'ignore') as f:
        filename = os.path.basename(f.name)
        data = json.load(f)
        d_date = data["Date"]
        if(d_date=="" or d_date=="Date"):
          continue
        format = '%Y-%m-%d'
    
        try:
          d_present_date = datetime.datetime.strptime(d_date, format)
        except:
          continue
    
        if(str(d_present_date.date()) not in [str(u_present_date.date()), str(u_prev_date.date()), str(u_next_date.date())]):
          continue
        docs_preprocessed_metrics.append({'Name':filename, 'Data':data})
        docs_preprocessed.append(data['Body_processed'])
        docs_preprocessed_with_names.append(filename)

    return docs_preprocessed, docs_preprocessed_with_names, docs_preprocessed_metrics




# def remove_stop_words(corpus):
#    '''
#    This function removes from the corpus all the stop words present in the file TIME.STP
#    '''
#    stop_w = [line.rstrip('\n') for line in open('TIME.STP')]
#    stop_w=list(filter(None, stop_w))
#    for i in range(0,len(corpus)):
#        corpus[i] = [x for x in corpus[i] if x not in stop_w]
#    return corpus 


def make_inverted_index(corpus):
    """
    This function builds an inverted index as an hash table (dictionary)
    where the keys are the terms and the values are ordered lists of
    docIDs containing the term.
    """
    # corpus = remove_stop_words(corpus)
    index = defaultdict(set)
    for docid, article in enumerate(corpus):
        for term in article:
            index[term].add(docid)
    return index


# ### Union of two posting lists


def posting_lists_union(pl1, pl2):
        """
        Returns a new posting list resulting from the union of the
        two lists passed as arguments.
        """
        pl1 = sorted(list(pl1))
        pl2 = sorted(list(pl2))
        union = []
        i = 0
        j = 0
        while (i < len(pl1) and j < len(pl2)):
            if (pl1[i] == pl2[j]):
                union.append(pl1[i])
                i += 1
                j += 1
            elif (pl1[i] < pl2[j]):
                union.append(pl1[i])
                i += 1
            else:
                union.append(pl2[j])
                j += 1
        for k in range(i, len(pl1)):
            union.append(pl1[k])
        for k in range(j, len(pl2)):
            union.append(pl2[k])
        return union


# ## Precomputing weights


def DF(term, index):
    '''
    Function computing Document Frequency for a term.
    '''
    return len(index[term])


def IDF(term, index, corpus):
    '''
    Function computing Inverse Document Frequency for a term.
    '''
    return log(len(corpus)/DF(term, index))


def RSV_weights(corpus,index):
    '''
    This function precomputes the Retrieval Status Value weights
    for each term in the index
    '''
    N = len(corpus)
    w = {}
    for term in index.keys():
        p = DF(term, index)/(N+0.5)  
        w[term] = IDF(term, index, corpus) + log(p/(1-p))
    return w
    


# ## BIM Class


class BIM():
    '''
    Binary Independence Model class
    '''
    
    def __init__(self, corpus, articles_with_name, docs_preprocessed_metrics):
        self.original_corpus = deepcopy(corpus)
        self.articles_with_name = articles_with_name
        self.articles = corpus
        self.docs_preprocessed_metrics = docs_preprocessed_metrics
        self.index = make_inverted_index(self.articles)
        self.weights = RSV_weights(self.articles, self.index)
        self.ranked = []
        self.query_text = ''
        self.N_retrieved = 0
    
        
    def RSV_doc_query(self, doc_id, query):
        '''
        This function computes the Retrieval Status Value for a given couple document - query
        using the precomputed weights
        '''
        score = 0
        doc = self.articles[doc_id]
        for term in doc:
            if term in query:
                score += self.weights[term]     
        return score

    
        
    def ranking(self, query):
        '''
        Auxiliary function for the function answer_query. Computes the score only for documents
        that are in the posting list of al least one term in the query
        '''

        docs = []
        for term in self.index: 
            if term in query:
                docs = posting_lists_union(docs, self.index[term])

        scores = []
        for doc in docs:
            scores.append((doc, self.RSV_doc_query(doc, query)))
        
        self.ranked = sorted(scores, key=lambda x: x[1], reverse = True)
        return self.ranked
    
    
    
    def recompute_weights(self, relevant_idx, query):
        '''
        Auxiliary function for relevance_feedback function and
        for the pseudo relevance feedback in answer_query function.
        Recomputes the weights, only for the terms in the query
        based on a set of relevant documents.
        '''
        
        relevant_docs = []
        for idx in relevant_idx:
          try:
            doc_id = self.ranked[idx-1][0]
            relevant_docs.append(self.articles[doc_id])
          except:
            continue
        
        N = len(self.articles)
        N_rel = len(relevant_idx)
        
        for term in query:
            if term in self.weights.keys():
                vri = 0
                for doc in relevant_docs:
                    if term in doc:
                        vri += 1
                p = (vri + 0.5) /( N_rel + 1)
                u = (DF(term, self.index) - vri + 0.5) / (N - N_rel +1)
                self.weights[term] = log((1-u)/u) + log(p/(1-p))

            
    
    def answer_query(self, query_text):
        '''
        Function to answer a free text query. Shows the first 30 words of the
        15 most relevant documents. 
        Also implements the pseudo relevance feedback with k = 5
        '''
        
        self.query_text = query_text
        query =  query_text.lower().split()
        ranking = self.ranking(query)

        ## pseudo relevance feedback 
        i = 0
        new_ranking=[]
        while i<10 and ranking != new_ranking:
            self.recompute_weights([1,2,3,4,5], query)
            new_ranking = self.ranking(query)
            i+=1


        ranking = new_ranking
        
        self.N_retrieved = 20
        
        ## print retrieved documents
        ret_list = []
        for i in range(0, min(len(ranking), self.N_retrieved)):
            article = self.original_corpus[ranking[i][0]]
            text = " ".join(article)
            #print(f"Article {self.articles_with_name[self.ranked[i][0]]}, score: {ranking[i][1]}")
            for myDoc in self.docs_preprocessed_metrics:
              if(self.articles_with_name[self.ranked[i][0]]==myDoc['Name']):
                ret_list.append((self.articles_with_name[self.ranked[i][0]], ranking[i][1], myDoc['Data']['Date'], myDoc['Data']['Location'].lower(), myDoc['Data']['Link']))
            #ret_list.append((self.articles_with_name[self.ranked[i][0]], ranking[i][1]))
            # print(text, '\n')

        self.weights = RSV_weights(self.articles, self.index)
        
        # priortitize location
        location_relevant = []
        location_irrelevant = []
        for x in ret_list:
          if u_location.lower() in x[3]:
            location_relevant.append(x)
          else:
            location_irrelevant.append(x)
        ret_list = location_relevant + location_irrelevant
        return ret_list


            
    def relevance_feedback(self, *args):
        '''
        Function that implements relevance feedback for the last query formulated.
        The set of relevant documents is given by the user through a set of indexes
        '''
        if(self.query_text == ''):
            print('Cannot get feedback before a query is formulated.')
            return
        
        relevant_idx = list(args)
        
        if(isinstance(relevant_idx[0], list)):
            relevant_idx = relevant_idx[0]
        
        query = self.query_text.upper().split()
        self.recompute_weights(relevant_idx,query)
        
        self.answer_query(self.query_text)
    
    
    def read_document(self,rank_num):
        '''
        Function that allows the user to select a document among the ones returned 
        by answer_query and read the whole text
        '''
        if(self.query_text == ''):
            print('Cannot select a document before a query is formulated.')
            return
            
        article = self.original_corpus[self.ranked[rank_num - 1][0]]
        text = " ".join(article)
        print(f"Article {rank_num}, score: {self.ranked[rank_num][1]}")
        print(text, '\n')
        
        
    def show_more(self):
        '''
        Function that allows the user to see more 10 retrieved documents
        '''
        
        if(self.N_retrieved + 10 > len(self.ranked)):
            print('No more documents available')
            return 
        
        for i in range(self.N_retrieved, self.N_retrieved+10):
            article = self.original_corpus[self.ranked[i][0]]
            if (len(article) > 30):
                article = article[0:30]
            text = " ".join(article)
            print(f"Article {self.articles_with_name[self.ranked[i][0]]}, score: {self.ranked[i][1]}")
            print(text, '\n')
        
        self.N_retrieved += 10 
        



# Example of usage

# articles, articles_with_name = import_dataset()
# bim  = BIM(articles, articles_with_name)
# bim.answer_query('Italy and Great Britain fight the enemy')
# bim.relevance_feedback(5,6,8)
# bim.show_more()
# bim.read_document(2)

# %%
tweet_query = []
format = '%Y-%m-%d'
u_present_date = datetime.datetime.strptime(u_time, format)
u_prev_date = u_present_date - datetime.timedelta(days=1)
u_next_date = u_present_date + datetime.timedelta(days=1)
df_query = df.loc[df['hashtags'].str.contains(u_base_hashtag) & df['Date_Only'].isin([str(u_present_date.date()), str(u_prev_date.date()), str(u_next_date.date())])]
print(df_query.shape[0])
if df_query.shape[0]<50:
  df_query = df.loc[df['Date_Only'].isin([str(u_present_date.date()), str(u_prev_date.date()), str(u_next_date.date())])]
  df_query = df.iloc[:min(df_query.shape[0],1000),:]
# Out:
# 264

# %%
for tweet in df_query['Preprocessed_Data']:
  tweet_query.extend(tweet)

# %%
def get_keyword_keywordextractor(df_query):
  keyword_dataset = df_query['tweet'].tolist()
  tweet_query_keyword_extractor = keyword_extractor(keyword_dataset)
  return tweet_query_keyword_extractor

# %%
def get_yake_keywords(tweet_query):
  tweet_keywords_yake = []
  kw_extractor = yake.KeywordExtractor(top=20, stopwords=None)
  keywords = kw_extractor.extract_keywords(' '.join(tweet_query))
  #keywords = kw_extractor.extract_keywords(' '.join(df_query['tweet'].tolist()))
  for kw, v in keywords:
    #print("Keyphrase: ",kw, ": score", v)
    for key in kw.split():
      if(key.lower() not in tweet_keywords_yake):
        tweet_keywords_yake.append(key.lower())
  return tweet_keywords_yake

# %%
def get_rake_keywords(tweet_query):
  tweet_keywords_rake = []
  rake = Rake()
  rake_keywords = rake.apply(' '.join(tweet_query).encode('ascii', 'ignore').decode())
  for kw,score in rake_keywords[:20]:
    for key in kw.split():
      if(key.lower() not in tweet_keywords_rake):
        tweet_keywords_rake.append(key.lower())
  return tweet_keywords_rake

# %%
def get_text_rank_keywords(tweet_query):
  tweet_keywords_text_rank = []
  TR_keywords = summa_keywords.keywords(' '.join(tweet_query), scores=True)
  for kw,score in TR_keywords[:20]:
    for key in kw.split():
      if(key.lower() not in tweet_keywords_text_rank):
        tweet_keywords_text_rank.append(key.lower())
  return tweet_keywords_text_rank

# %%
def get_keybert_keywords(tweet_query):
  # uncomment later
  keybert_model = KeyBERT(model='all-mpnet-base-v2')
  keybert_keywords = keybert_model.extract_keywords(' '.join(tweet_query), keyphrase_ngram_range=(1,1), stop_words='english', highlight=False, top_n=20)
  tweet_keywords_keybert = list(dict(keybert_keywords).keys())
  # print(tweet_keywords_keybert)
  return tweet_keywords_keybert

# %%
# Example of usage
articles, articles_with_name, docs_preprocessed_metrics = import_dataset()

# %% [markdown]
# # Helpful Functions

# %%
def get_relevant_docs_list_for_base_hashtag(base_hashtag, base_date, docs_preprocessed_metrics):
  relevant_docs_list = []
  for doc in docs_preprocessed_metrics:
    if doc['Data']['Base Hashtag']==base_hashtag:
      current_date = datetime.datetime.strptime(base_date, format)
      prev_date = current_date - datetime.timedelta(days=1)
      next_date = current_date + datetime.timedelta(days=1)
      #if(doc['Data']['Date'] in [str(prev_date.date()), str(current_date.date()), str(next_date.date())]):
      #  relevant_docs_list.append((doc['Name'], doc['Data']['Location'].lower()))
      if(doc['Data']['Date']==str(str(current_date.date()))):
        relevant_docs_list.append((doc['Name'], doc['Data']['Location'].lower(), 1.0))
      elif(doc['Data']['Date'] in [str(prev_date.date()), str(next_date.date())]):
        relevant_docs_list.append((doc['Name'], doc['Data']['Location'].lower(), 0.5))
  
  # prioritize location
  location_relevant = []
  location_irrelevant = []
  for x in relevant_docs_list:
    if u_location.lower() in x[1]:
      location_relevant.append(x)
    else:
      location_irrelevant.append(x)
  relevant_docs_list = location_relevant + location_irrelevant
  return relevant_docs_list

# %%
def nDCG(base_hashtag, base_date, prediction_list, docs_preprocessed_metrics):
  ground_truth = get_relevant_docs_list_for_base_hashtag(base_hashtag, base_date, docs_preprocessed_metrics)
  ground_truth_scores = {}
  ground_truth_scores_list = []
  prediction_list_scores = []
  for gt in ground_truth:
    ground_truth_scores[gt[0]] = gt[2]
    ground_truth_scores_list.append(gt[2])
  for x in prediction_list:
    if x[0] in ground_truth_scores.keys():
      prediction_list_scores.append(ground_truth_scores[x[0]])
    else:
      prediction_list_scores.append(0.0)
  
  DCG = prediction_list_scores[0] + sum([prediction_list_scores[i]/np.log2(i+1) for i in range(1,len(prediction_list_scores))])
  ideal_DCG = ground_truth_scores_list[0] + sum([ground_truth_scores_list[i]/np.log2(i+1) for i in range(1,len(ground_truth_scores_list))])
  if ideal_DCG==0:
    return DCG
  return DCG/ideal_DCG

# %%
def precision_at_k(k, base_hashtag, base_date, prediction_list, docs_preprocessed_metrics):
  relevant_docs_list = get_relevant_docs_list_for_base_hashtag(base_hashtag, base_date, docs_preprocessed_metrics)
  num_of_relevant_results=0
  list_of_rel_doc_names = []
  for x in relevant_docs_list:
    list_of_rel_doc_names.append(x[0])
  for itr in range(min(len(prediction_list), k)):
    if (prediction_list[itr][0] in list_of_rel_doc_names):
      num_of_relevant_results+=1
  return num_of_relevant_results/k

# %%
def mean_average_precision(max_k, base_hashtag, base_date, relevant_docs, docs_preprocessed_metrics):
  average_precision=0
  ctr=0
  relevant_docs_list = get_relevant_docs_list_for_base_hashtag(base_hashtag, base_date, docs_preprocessed_metrics)
  for k_val in range(1,len(relevant_docs_list)+1):
    ctr+=1
    if k_val>len(relevant_docs_list):
      break
    precision_at_k_val = precision_at_k(k_val, base_hashtag, base_date, relevant_docs, docs_preprocessed_metrics)
    #print('Hashtag: {}   Precision@{}: {}'.format(base_hashtag, k_val, precision_at_k_val))
    average_precision += precision_at_k_val
  return average_precision/ctr

# %%
def recall_at_k(k, base_hashtag, base_date, prediction_list, docs_preprocessed_metrics):
  relevant_docs_list = get_relevant_docs_list_for_base_hashtag(base_hashtag, base_date, docs_preprocessed_metrics)
  current_num_of_relevant_results=0
  list_of_rel_doc_names = []
  for x in relevant_docs_list:
    list_of_rel_doc_names.append(x[0])
  for itr in range(min(len(prediction_list),k)):
    if (prediction_list[itr][0] in list_of_rel_doc_names):
      current_num_of_relevant_results+=1
  if(len(relevant_docs_list)==0):
    return 0
  return current_num_of_relevant_results/len(relevant_docs_list)

# %%
def mean_average_recall(max_k, base_hashtag, base_date, relevant_docs, docs_preprocessed_metrics):
  average_recall=0
  ctr=0
  relevant_docs_list = get_relevant_docs_list_for_base_hashtag(base_hashtag, base_date, docs_preprocessed_metrics)
  print(len(relevant_docs_list))
  for k_val in range(1,len(relevant_docs_list)+1):
    ctr+=1
    if k_val>len(relevant_docs_list):
      break
    recall_at_k_val = recall_at_k(k_val, base_hashtag, base_date, relevant_docs, docs_preprocessed_metrics)
    #print('Hashtag: {}   Recall@{}: {}'.format(base_hashtag, k_val, recall_at_k_val))
    average_recall += recall_at_k_val
  return average_recall/ctr

# %% [markdown]
# # Plain Model (Binary Independence Model)

# %%
print(articles)
# Out:
# [['lebron', 'james', 'hit', 'thunder', 'gm', 'sam', 'presti', 'ultimate', 'praise', 'oklahoma', 'city', 'thunder', 'gm', 'sam', 'presti', 'wellknown', 'around', 'nba', 'ability', 'rack', 'draft', 'pick', 'build', 'franchise', 'future', 'aside', 'that', 'presti', 'also', 'draft', 'numerous', 'talented', 'player', 'year', 'turn', 'legitimate', 'superstar', 'include', 'kevin', 'durant', 'russell', 'westbrook', 'saturday', 'allstar', 'weekend', 'los', 'angeles', 'lakers', 'star', 'lebron', 'james', 'ask', 'question', 'thunder', 'rookie', 'josh', 'giddey', 'king', 'turn', 'opportunity', 'praise', 'presti', 'phenomenal', 'front', 'office', 'work', 'year', 'via', 'espns', 'dave', 'mcmenamin', 'the', 'mvp', 'sam', 'presti', 'he', 'mvp', 'james', 'say', '44yearold', 'front', 'office', 'executive', 'hold', 'post', 'since', '2007', 'i', 'mean', 'josh', 'giddey', 'great', 'sam', 'presti', 'dont', 'understand', 'guy', 'eye', 'talent', 'draft', 'kevin', 'durant', 'rus', 'westbrook', 'jeff', 'green', 'serge', 'ibaka', 'reggie', 'jackson', 'josh', 'giddey', 'list', 'go', 'on', 'guy', 'pretty', 'damn', 'good', 'presti', 'clearly', 'idea', 'he', 'do', 'thunder', 'rather', 'awful', 'right', 'now', 'whop', '38', 'pick', 'across', 'next', 'seven', 'year', '2022', 'okc', 'posse', 'three', 'firstround', 'selection', 'lone', 'secondround', 'pick', 'thunder', 'already', 'intrigue', 'talent', 'helm', 'budding', 'superstar', 'shai', 'gilgeousalexander', 'lu', 'dort', 'giddey', 'already', 'making', 'presence', 'felt', 'every', 'way', 'possible', 'year', 'one', 'lebron', 'realize', 'prestis', 'plan', 'it', 'great', 'good', 'four', 'five', 'year', 'thunder', 'could', 'scary'], ['giant', 'mock', 'offseason', 'propose', 'trade', 'cap', 'cut', 'minimock', 'draft', 'joe', 'schoen', 'big', 'job', 'offseason', 'new', 'gm', 'new', 'york', 'giant', 'clear', '40', 'million', 'cap', 'space', 'figure', 'giant', 'unrestricted', 'free', 'agent', 'want', 'bring', 'back', 'dive', 'free', 'agency', 'see', 'find', 'affordable', 'help', 'prepare', 'run', 'firstever', 'nfl', 'draft', 'figure', 'joe', 'need', 'little', 'help', 'cant', 'let', 'tim', 'mcdonnell', 'chris', 'pettit', 'chris', 'mara', 'brandon', 'brown', 'fun', 'im', 'joe', 'can', 'it', 'fun', 'way', 'spend', 'part', 'friday', 'afternoon', 'use', 'fanspeak', 'ultimate', 'gm', 'tool', 'run', 'mock', 'offseason', 'now', 'thing', 'fanspeak', 'tool', 'arent', 'perfect', 'example', 'could', 'restructure', 'player', 'couldnt', 'figure', 'actually', 'calculate', 'restructure', 'plod', 'ahead', 'anyway', 'thing', 'go', 'down', 'joe', 'ill', 'expect', 'thank', 'you', 'email', 'time', 'now', 'bye', 'bye', 'bradberry', 'first', 'move', 'make', 'trade', 'cornerback', 'james', 'bradberry', 'la', 'vega', 'raider', 'reunite', 'defensive', 'coordinator', 'patrick', 'graham', 'save', '12136', 'million', 'cap', 'space', 'could', 'wait', 'make', 'bradberry', 'postjune', '1', 'cuttrade', 'increase', 'saving', '135', 'million', 'want', 'money', 'available', 'immediately', 'though', 'make', 'move', 'return', 'bradberry', 'raider', 'pick', 'round', '3', '5', '22nd', 'overall', 'round', 'thought', 'fair', 'cap', 'move', 'slash', 'wide', 'receiver', 'sterling', 'shepard', 'tight', 'end', 'kyle', 'rudolph', 'punter', 'riley', 'dixon', 'center', 'nick', 'gate', 'sadly', 'edge', 'defender', 'oshane', 'ximines', 'linebacker', 'tj', 'brunson', 'restructure', 'blake', 'martinez', 'scenario', 'sat', 'free', 'agency', 'exception', 'bringing', 'back', 'edge', 'defender', 'lorenzo', 'carter', 'oneyear', '5', 'million', 'deal', 'make', 'nick', 'falato', 'happy', 'importantly', 'give', 'giant', 'flexibility', 'really', 'worry', 'edge', 'kayvon', 'thibodeaux', 'aidan', 'hutchinson', 'fall', 'lap', 'draft', 'below', 'cap', 'situation', 'maybe', 'quite', 'healthy', 'would', 'like', 'bad', 'move', 'could', 'make', 'save', 'room', 'hold', 'off', 'draft', 'two', 'thing', 'know', 'draft', 'big', 'board', 'choose', 'come', 'draft', 'diamond', 'use', 'mostly' ...

# %%
#results with normal query
bim  = BIM(articles, articles_with_name, docs_preprocessed_metrics)
relevant_docs_bim_plain = bim.answer_query(" ".join(tweet_query))

# bim.relevance_feedback(5,6,8)
# bim.show_more()
# bim.read_document(2)

for rank, doc in enumerate(relevant_docs_bim_plain):
  print('Rank: {} Relevant Document: {}'.format(rank+1,doc))

print()

mean_average_precision_hashtag_bim_plain = mean_average_precision(20, u_base_hashtag, u_time, relevant_docs_bim_plain, docs_preprocessed_metrics)
print('Mean Average Precision Plain Model (BIM) : {}'.format(mean_average_precision_hashtag_bim_plain))

mean_average_recall_hashtag_bim_plain = mean_average_recall(20, u_base_hashtag, u_time, relevant_docs_bim_plain, docs_preprocessed_metrics)
print('Mean Average Recall Plain Model (BIM) : {}'.format(mean_average_recall_hashtag_bim_plain))

nDCG_hashtag_bim_plain = nDCG(u_base_hashtag, u_time, relevant_docs_bim_plain, docs_preprocessed_metrics)
print('nDCG Plain Model (Binary Independence Model) : {}'.format(nDCG_hashtag_bim_plain))
# Out:
# Rank: 1 Relevant Document: ('PunjabElections2022_2357.json', 2078.0102493264662, '2022-02-20', 'punjab india', 'https://www.tribuneindia.com/news/punjab/punjab-votes-polling-begins-for-117-constituencies-cm-channi-navjot-sidhu-sukhbir-badal-bhagwant-mann-capt-amarinder-in-fray-371448')
# Rank: 2 Relevant Document: ('PunjabElections2022_2360.json', 1946.9153066493277, '2022-02-20', 'punjab india', 'https://indianexpress.com/elections/assembly-elections-2022-live-updates-punjab-up-uttarakhand-manipur-goa-7783132/')
# Rank: 3 Relevant Document: ('WriddhimanSaha_2366.json', 1255.6008791818638, '2022-02-20', 'india', 'https://www.espncricinfo.com/story/ind-vs-sl-test-series-wriddhiman-saha-being-indirectly-told-to-retire-1302005')
# Rank: 4 Relevant Document: ('InternalAssessmentForAll2022_1708.json', 953.1007484064185, '2022-02-19', 'india', 'https://www.ecb.europa.eu/press/key/date/2022/html/ecb.sp220218~c55e646426.en.html')
# Rank: 5 Relevant Document: ('kejriwalvsall_1655.json', 622.7212955144444, '2022-02-18', 'india', 'https://www.ndtv.com/opinion/it-could-be-kejriwal-vs-adityanath-in-2029-by-sagarika-ghose-2814030')
# Rank: 6 Relevant Document: ('UkraineRussiaCrisis_314.json', 2393.2232787380285, '2022-02-20', 'washington, united states of america', 'https://edition.cnn.com/europe/live-news/ukraine-russia-news-02-20-22-intl/index.html')
# Rank: 7 Relevant Document: ('UkraineRussiaCrisis_315.json', 1961.4583245632846, '2022-02-20', 'london, united kingdom', 'https://fivebooks.com/best-books/russia-ukraine-serhii-plokhy/')
# Rank: 8 Relevant Document: ('UkraineRussiaCrisis_319.json', 1668.1329529464513, '2022-02-20', 'new york, united states of america', 'https://www.bloomberg.com/news/articles/2022-04-16/ukraine-update-un-calls-for-unimpeded-access-to-besieged-cities')
# Rank: 9 Relevant Document: ('zeynep_1627.json', 1389.7657162985395, '2022-02-18', 'united states of america', 'https://www.nytimes.com/2022/03/11/opinion/covid-health-pandemic.html')
# Rank: 10 Relevant Document: ('UkraineRussiaCrisis_318.json', 915.4811931155648, '2022-02-20', 'ukraine', 'https://www.cbsnews.com/news/ukraine-russia-60-minutes-2022-02-20/')
# Rank: 11 Relevant Document: ('hijab_334.json', 873.4452373280301, '2022-02-20', 'massachusetts, united states of america', 'https://scroll.in/article/1017784/why-urbane-educated-muslim-women-are-wearing-the-hijab-in-india')
# Rank: 12 Relevant Document: ('UkraineRussiaCrisis_212.json', 732.4946428874464, '2022-02-18', 'dubai, uae', 'https://www.wilsoncenter.org/article/ukraine-russia-and-arabs')
# Rank: 13 Relevant Document: ('UFCVegas48_1025.json', 708.2638887295416, '2022-02-20', 'united states of america', 'https://www.bloodyelbow.com/2022/2/20/22943543/ufc-vegas-48-johnny-walker-vs-jamahal-hill-unofficial-awards-mma-news-editorial')
# Rank: 14 Relevant Document: ('UFCVegas48_1681.json', 706.9304541405136, '2022-02-19', 'united states of america', 'https://www.bloodyelbow.com/2022/2/20/22943543/ufc-vegas-48-johnny-walker-vs-jamahal-hill-unofficial-awards-mma-news-editorial')
# Rank: 15 Relevant Document: ('MCITOT_1769.json', 674.4505332181395, '2022-02-20', 'united kingdom', 'https://www.thescore.com/eng_fed/news/2301408')
# Rank: 16 Relevant Document: ('freedomconvoy22_2327.json', 652.1302723867092, '2022-02-18', 'doha, qatar', 'https://www.aljazeera.com/news/2022/2/19/canada-freedom-convoy-ending-but-issue-not-going-away')
# Rank: 17 Relevant Document: ('CallTheMidwife_989.json', 648.6247261418208, '2022-02-20', 'london, uk', 'https://www.digitalspy.com/tv/a39161489/call-the-midwife-season-12-release-date/')
# Rank: 18 Relevant Document: ('UkraineRussiaCrisis_261.json', 646.782494951244, '2022-02-19', 'belarus, ukraine', 'https://www.theguardian.com/world/2022/feb/19/ukraine-russia-crisis-whos-winning-the-international-influence-war-russia-putin')
# Rank: 19 Relevant Document: ('UkraineRussiaCrisis_220.json', 631.39941093163, '2022-02-18', 'washinton, united states of america', 'https://www.whitehouse.gov/briefing-room/speeches-remarks/2022/02/18/remarks-by-president-biden-providing-an-update-on-russia-and-ukraine-2/')
# Rank: 20 Relevant Document: ('UkraineRussiaCrisis_213.json', 605.2119498042539, '2022-02-18', 'ukraine', 'https://apnews.com/article/russia-ukraine-joe-biden-united-states-europe-vladimir-putin-e9e56b0091c4a2541609ae35661643c9')
#
# Mean Average Precision Plain Model (BIM) : 0.0334385701587714
# 20
# Mean Average Recall Plain Model (BIM) : 0.024999999999999998
# nDCG Plain Model (Binary Independence Model) : 0.023851650468170834

# %% [markdown]
# # Model with Keyword Extractor (Binary Independence Model)

# %%
# results with top k keywords
bim  = BIM(articles, articles_with_name, docs_preprocessed_metrics)
tweet_query_keyword_extractor = get_keyword_keywordextractor(df_query)
relevant_docs_bim_keyword_extractor = bim.answer_query(" ".join(tweet_query_keyword_extractor[:20]))

# bim.relevance_feedback(5,6,8)
# bim.show_more()
# bim.read_document(2)

for rank, doc in enumerate(relevant_docs_bim_keyword_extractor):
  print('Rank: {} Relevant Document: {}'.format(rank+1,doc))

print()

mean_average_precision_hashtag_bim_keyword_extractor = mean_average_precision(20, u_base_hashtag, u_time, relevant_docs_bim_keyword_extractor, docs_preprocessed_metrics)
print('Mean Average Precision Keyword Extractor Model (BIM) : {}'.format(mean_average_precision_hashtag_bim_keyword_extractor))

mean_average_recall_hashtag_bim_keyword_extractor = mean_average_recall(20, u_base_hashtag, u_time, relevant_docs_bim_keyword_extractor, docs_preprocessed_metrics)
print('Mean Average Recall Keyword Extractor Model (BIM) : {}'.format(mean_average_recall_hashtag_bim_keyword_extractor))

nDCG_hashtag_bim_keyword_extractor = nDCG(u_base_hashtag, u_time, relevant_docs_bim_keyword_extractor, docs_preprocessed_metrics)
print('nDCG Keyword Extractor Model (Binary Independence Model) : {}'.format(nDCG_hashtag_bim_keyword_extractor))
# Out:
# Rank: 1 Relevant Document: ('hijab_285.json', 201.97408372038728, '2022-02-19', 'new delhi, india', 'https://news.abplive.com/karnataka/karnataka-hijab-row-govt-order-dated-feb-5-does-not-ban-hijab-ag-tells-high-court-1514213')
# Rank: 2 Relevant Document: ('hijab_338.json', 197.2945433842324, '2022-02-20', 'new delhi, india', 'https://news.abplive.com/karnataka/hijab-row-conspiracy-of-bjp-against-muslim-girls-former-k-taka-cm-siddaramaiah-1514360')
# Rank: 3 Relevant Document: ('hijab_332.json', 176.3292941798442, '2022-02-20', 'new delhi, india', 'https://thewire.in/communalism/karnataka-muslim-women-students-face-case-suspension-for-wearing-hijab-protesting')
# Rank: 4 Relevant Document: ('hijab_340.json', 135.5616591264769, '2022-02-20', 'hyderabad, india', 'https://www.siasat.com/hijab-row-bangladesh-stands-in-solidarity-with-muslim-women-2279139/')
# Rank: 5 Relevant Document: ('hijab_283.json', 121.16898761709544, '2022-02-19', 'new delhi, india', 'https://www.newindianexpress.com/nation/2022/feb/19/education-more-important-than-hijab-rss-linked-muslim-rashtriya-manch-to-community-2421449.html')
# Rank: 6 Relevant Document: ('hijab_333.json', 108.42863957959138, '2022-02-20', 'kerala, india', 'https://www.theweek.in/news/entertainment/2022/02/20/hijab-not-a-choice-but-an-obligation-in-islam-says-zaira-wasim.html')
# Rank: 7 Relevant Document: ('InternalAssessmentForAll2022_1707.json', 58.89643672517892, '2022-02-19', 'india', 'https://indianexpress.com/article/cities/delhi/haryana-board-exams-class-8-students-parents-protest-7782756/')
# Rank: 8 Relevant Document: ('hijab_339.json', 359.15771730071293, '2022-02-20', 'aluva, kerala', 'https://thefederal.com/states/south/tamil-nadu/discrimination-violence-drove-40-dalits-in-tn-village-to-embrace-islam/')
# Rank: 9 Relevant Document: ('hijab_334.json', 353.4949830403285, '2022-02-20', 'massachusetts, united states of america', 'https://scroll.in/article/1017784/why-urbane-educated-muslim-women-are-wearing-the-hijab-in-india')
# Rank: 10 Relevant Document: ('hijab_286.json', 213.99223091959445, '2022-02-19', 'bangalore, karnataka', 'https://thefederal.com/states/south/karnataka/uneasy-bjp-central-command-wants-to-wind-down-hijab-row-in-karnataka/')
# Rank: 11 Relevant Document: ('hijab_331.json', 206.85034486327797, '2022-02-20', 'chennai, tamil nadu', 'https://www.thehindu.com/data/data-hijab-row-why-the-ban-is-a-double-blow-for-muslim-girl-students/article65066546.ece')
# Rank: 12 Relevant Document: ('hijab_288.json', 180.15037328838937, '2022-02-19', 'mysore', 'https://thekashmirwalla.com/mysuru-college-cancels-uniform-order-allows-students-to-wear-hijab/')
# Rank: 13 Relevant Document: ('hijab_281.json', 158.913607787266, '2022-02-19', 'bangalore, karnataka', 'https://www.thehindu.com/news/national/karnataka/hijab-row-polarises-classrooms-breaks-friendships/article65063188.ece')
# Rank: 14 Relevant Document: ('hijab_336.json', 157.96194599392047, '2022-02-20', 'mumbai, maharashtra', 'https://www.indiatoday.in/movies/celebrities/story/hijab-isn-t-a-choice-but-an-obligation-in-islam-says-zaira-wasim-1915351-2022-02-20')
# Rank: 15 Relevant Document: ('hijab_282.json', 150.93883831767894, '2022-02-19', 'bangalore, karnataka', 'https://www.hindustantimes.com/entertainment/bollywood/zaira-wasim-reacts-to-hijab-row-i-as-a-woman-who-wears-hijab-resent-this-entire-system-101645288361058.html')
# Rank: 16 Relevant Document: ('hijab_290.json', 137.94075189841263, '2022-02-19', 'bangalore, karnataka', 'https://english.varthabharati.in/karnataka/hijab-row-feb-5-government-order-doesnt-ban-hijab-insists-ag-in-karnataka-hc')
# Rank: 17 Relevant Document: ('hijab_287.json', 124.80864142789012, '2022-02-19', 'shivamogga', 'https://www.outlookindia.com/national/karnataka-hijab-row-58-students-suspended-in-shivamogga-for-wearing-headscarves-holding-protest-news-183162')
# Rank: 18 Relevant Document: ('hijab_284.json', 115.22318138850582, '2022-02-19', 'bangalore, karnataka', 'https://www.sundayguardianlive.com/news/hijab-controversy-manufactured-create-anarchy')
# Rank: 19 Relevant Document: ('hijab_335.json', 69.1210883265995, '2022-02-20', 'bangalore, karnataka', 'https://indianexpress.com/article/cities/bangalore/karnataka-bengaluru-live-updates-hijab-row-protests-court-hearing-covid-7765244/')
# Rank: 20 Relevant Document: ('hijab_289.json', 68.81854785989508, '2022-02-19', 'karnataka', 'https://www.freepressjournal.in/india/karnataka-hijab-row-seen-to-be-soft-cm-basavaraj-bommaiturns-heat-on-hijab-protesters')
#
# Mean Average Precision Keyword Extractor Model (BIM) : 0.9426130171428155
# 20
# Mean Average Recall Keyword Extractor Model (BIM) : 0.48999999999999994
# nDCG Keyword Extractor Model (Binary Independence Model) : 0.9042680757114674

# %% [markdown]
# # Model with YAKE (Binary Independence Model)

# %%
# results with top k keywords
bim  = BIM(articles, articles_with_name, docs_preprocessed_metrics)
tweet_keywords_yake = get_yake_keywords(tweet_query)
relevant_docs_bim_yake = bim.answer_query(" ".join(tweet_keywords_yake))

# bim.relevance_feedback(5,6,8)
# bim.show_more()
# bim.read_document(2)

for rank, doc in enumerate(relevant_docs_bim_yake):
  print('Rank: {} Relevant Document: {}'.format(rank+1,doc))

print()

mean_average_precision_hashtag_bim_yake = mean_average_precision(20, u_base_hashtag, u_time, relevant_docs_bim_yake, docs_preprocessed_metrics)
print('Mean Average Precision YAKE Model (BIM) : {}'.format(mean_average_precision_hashtag_bim_yake))

mean_average_recall_hashtag_bim_yake = mean_average_recall(20, u_base_hashtag, u_time, relevant_docs_bim_yake, docs_preprocessed_metrics)
print('Mean Average Recall YAKE Model (BIM) : {}'.format(mean_average_recall_hashtag_bim_yake))

nDCG_hashtag_bim_yake = nDCG(u_base_hashtag, u_time, relevant_docs_bim_yake, docs_preprocessed_metrics)
print('nDCG YAKE Model (Binary Independence Model) : {}'.format(nDCG_hashtag_bim_yake))
# Out:
# Rank: 1 Relevant Document: ('hijab_338.json', 187.47847059670258, '2022-02-20', 'new delhi, india', 'https://news.abplive.com/karnataka/hijab-row-conspiracy-of-bjp-against-muslim-girls-former-k-taka-cm-siddaramaiah-1514360')
# Rank: 2 Relevant Document: ('hijab_332.json', 171.4212577860793, '2022-02-20', 'new delhi, india', 'https://thewire.in/communalism/karnataka-muslim-women-students-face-case-suspension-for-wearing-hijab-protesting')
# Rank: 3 Relevant Document: ('hijab_285.json', 165.846718652571, '2022-02-19', 'new delhi, india', 'https://news.abplive.com/karnataka/karnataka-hijab-row-govt-order-dated-feb-5-does-not-ban-hijab-ag-tells-high-court-1514213')
# Rank: 4 Relevant Document: ('hijab_340.json', 135.273968284136, '2022-02-20', 'hyderabad, india', 'https://www.siasat.com/hijab-row-bangladesh-stands-in-solidarity-with-muslim-women-2279139/')
# Rank: 5 Relevant Document: ('hijab_283.json', 116.26095122333052, '2022-02-19', 'new delhi, india', 'https://www.newindianexpress.com/nation/2022/feb/19/education-more-important-than-hijab-rss-linked-muslim-rashtriya-manch-to-community-2421449.html')
# Rank: 6 Relevant Document: ('hijab_333.json', 102.93023308200584, '2022-02-20', 'kerala, india', 'https://www.theweek.in/news/entertainment/2022/02/20/hijab-not-a-choice-but-an-obligation-in-islam-says-zaira-wasim.html')
# Rank: 7 Relevant Document: ('hijab_334.json', 340.77408410470696, '2022-02-20', 'massachusetts, united states of america', 'https://scroll.in/article/1017784/why-urbane-educated-muslim-women-are-wearing-the-hijab-in-india')
# Rank: 8 Relevant Document: ('hijab_339.json', 327.23092474202076, '2022-02-20', 'aluva, kerala', 'https://thefederal.com/states/south/tamil-nadu/discrimination-violence-drove-40-dalits-in-tn-village-to-embrace-islam/')
# Rank: 9 Relevant Document: ('hijab_286.json', 187.85153570082872, '2022-02-19', 'bangalore, karnataka', 'https://thefederal.com/states/south/karnataka/uneasy-bjp-central-command-wants-to-wind-down-hijab-row-in-karnataka/')
# Rank: 10 Relevant Document: ('hijab_288.json', 153.83908100810294, '2022-02-19', 'mysore', 'https://thekashmirwalla.com/mysuru-college-cancels-uniform-order-allows-students-to-wear-hijab/')
# Rank: 11 Relevant Document: ('hijab_281.json', 147.49702174979504, '2022-02-19', 'bangalore, karnataka', 'https://www.thehindu.com/news/national/karnataka/hijab-row-polarises-classrooms-breaks-friendships/article65063188.ece')
# Rank: 12 Relevant Document: ('hijab_331.json', 146.77316793045776, '2022-02-20', 'chennai, tamil nadu', 'https://www.thehindu.com/data/data-hijab-row-why-the-ban-is-a-double-blow-for-muslim-girl-students/article65066546.ece')
# Rank: 13 Relevant Document: ('hijab_336.json', 142.0570966049845, '2022-02-20', 'mumbai, maharashtra', 'https://www.indiatoday.in/movies/celebrities/story/hijab-isn-t-a-choice-but-an-obligation-in-islam-says-zaira-wasim-1915351-2022-02-20')
# Rank: 14 Relevant Document: ('hijab_282.json', 135.03398892874296, '2022-02-19', 'bangalore, karnataka', 'https://www.hindustantimes.com/entertainment/bollywood/zaira-wasim-reacts-to-hijab-row-i-as-a-woman-who-wears-hijab-resent-this-entire-system-101645288361058.html')
# Rank: 15 Relevant Document: ('hijab_287.json', 119.9006050341252, '2022-02-19', 'shivamogga', 'https://www.outlookindia.com/national/karnataka-hijab-row-58-students-suspended-in-shivamogga-for-wearing-headscarves-holding-protest-news-183162')
# Rank: 16 Relevant Document: ('hijab_290.json', 106.7214232243613, '2022-02-19', 'bangalore, karnataka', 'https://english.varthabharati.in/karnataka/hijab-row-feb-5-government-order-doesnt-ban-hijab-insists-ag-in-karnataka-hc')
# Rank: 17 Relevant Document: ('hijab_284.json', 106.69434545255866, '2022-02-19', 'bangalore, karnataka', 'https://www.sundayguardianlive.com/news/hijab-controversy-manufactured-create-anarchy')
# Rank: 18 Relevant Document: ('hijab_335.json', 69.1210883265995, '2022-02-20', 'bangalore, karnataka', 'https://indianexpress.com/article/cities/bangalore/karnataka-bengaluru-live-updates-hijab-row-protests-court-hearing-covid-7765244/')
# Rank: 19 Relevant Document: ('hijab_289.json', 63.91051146613017, '2022-02-19', 'karnataka', 'https://www.freepressjournal.in/india/karnataka-hijab-row-seen-to-be-soft-cm-basavaraj-bommaiturns-heat-on-hijab-protesters')
# Rank: 20 Relevant Document: ('BJPwinningUP_2524.json', 37.61777596083726, '2022-02-18', 'banaras, up', 'https://theprint.in/opinion/bjps-2ab-factor-thats-missing-from-sp-bsp-congress-in-up-elections/836455/')
#
# Mean Average Precision YAKE Model (BIM) : 0.9974999999999999
# 20
# Mean Average Recall YAKE Model (BIM) : 0.5224999999999999
# nDCG YAKE Model (Binary Independence Model) : 0.8908988901562694

# %% [markdown]
# # Model with RAKE (Binary Independence Model)

# %%
# results with top k keywords
bim  = BIM(articles, articles_with_name, docs_preprocessed_metrics)
tweet_keywords_rake = get_rake_keywords(tweet_query)
relevant_docs_bim_rake = bim.answer_query(" ".join(tweet_keywords_rake))

# bim.relevance_feedback(5,6,8)
# bim.show_more()
# bim.read_document(2)

for rank, doc in enumerate(relevant_docs_bim_rake):
  print('Rank: {} Relevant Document: {}'.format(rank+1,doc))

print()

mean_average_precision_hashtag_bim_rake = mean_average_precision(20, u_base_hashtag, u_time, relevant_docs_bim_rake, docs_preprocessed_metrics)
print('Mean Average Precision RAKE Model (BIM) : {}'.format(mean_average_precision_hashtag_bim_rake))

mean_average_recall_hashtag_bim_rake = mean_average_recall(20, u_base_hashtag, u_time, relevant_docs_bim_rake, docs_preprocessed_metrics)
print('Mean Average Recall RAKE Model (BIM) : {}'.format(mean_average_recall_hashtag_bim_rake))

nDCG_hashtag_bim_rake = nDCG(u_base_hashtag, u_time, relevant_docs_bim_rake, docs_preprocessed_metrics)
print('nDCG RAKE Model (Binary Independence Model) : {}'.format(nDCG_hashtag_bim_rake))
# Out:
# Rank: 1 Relevant Document: ('PunjabElections2022_2360.json', 184.45969360431474, '2022-02-20', 'punjab india', 'https://indianexpress.com/elections/assembly-elections-2022-live-updates-punjab-up-uttarakhand-manipur-goa-7783132/')
# Rank: 2 Relevant Document: ('PunjabElections2022_2357.json', 164.9801869372841, '2022-02-20', 'punjab india', 'https://www.tribuneindia.com/news/punjab/punjab-votes-polling-begins-for-117-constituencies-cm-channi-navjot-sidhu-sukhbir-badal-bhagwant-mann-capt-amarinder-in-fray-371448')
# Rank: 3 Relevant Document: ('kejriwalvsall_1655.json', 87.37772668411331, '2022-02-18', 'india', 'https://www.ndtv.com/opinion/it-could-be-kejriwal-vs-adityanath-in-2029-by-sagarika-ghose-2814030')
# Rank: 4 Relevant Document: ('kejriwalvsall_1661.json', 52.06436178857196, '2022-02-18', 'india', 'https://www.hindustantimes.com/cities/delhi-news/is-kejriwal-for-municipal-reforms-or-not-bjp-asks-as-unification-of-mcds-imminent-101646853880629.html')
# Rank: 5 Relevant Document: ('hijab_285.json', 49.97071194336594, '2022-02-19', 'new delhi, india', 'https://news.abplive.com/karnataka/karnataka-hijab-row-govt-order-dated-feb-5-does-not-ban-hijab-ag-tells-high-court-1514213')
# Rank: 6 Relevant Document: ('zeynep_1627.json', 93.5909328352406, '2022-02-18', 'united states of america', 'https://www.nytimes.com/2022/03/11/opinion/covid-health-pandemic.html')
# Rank: 7 Relevant Document: ('UkraineRussiaCrisis_315.json', 91.0464373394977, '2022-02-20', 'london, united kingdom', 'https://fivebooks.com/best-books/russia-ukraine-serhii-plokhy/')
# Rank: 8 Relevant Document: ('hijab_286.json', 76.99832516889883, '2022-02-19', 'bangalore, karnataka', 'https://thefederal.com/states/south/karnataka/uneasy-bjp-central-command-wants-to-wind-down-hijab-row-in-karnataka/')
# Rank: 9 Relevant Document: ('BJPwinningUP_2524.json', 65.52797113005268, '2022-02-18', 'banaras, up', 'https://theprint.in/opinion/bjps-2ab-factor-thats-missing-from-sp-bsp-congress-in-up-elections/836455/')
# Rank: 10 Relevant Document: ('narendramodi_305.json', 64.5579530580163, '2022-02-20', 'hardoi, uttar pradesh', 'https://www.indiatoday.in/elections/uttar-pradesh-assembly-polls-2022/story/pm-modi-addresses-rally-up-hardoi-1915489-2022-02-20')
# Rank: 11 Relevant Document: ('hijab_339.json', 62.187838395316234, '2022-02-20', 'aluva, kerala', 'https://thefederal.com/states/south/tamil-nadu/discrimination-violence-drove-40-dalits-in-tn-village-to-embrace-islam/')
# Rank: 12 Relevant Document: ('UkraineRussiaCrisis_319.json', 57.327399392829335, '2022-02-20', 'new york, united states of america', 'https://www.bloomberg.com/news/articles/2022-04-16/ukraine-update-un-calls-for-unimpeded-access-to-besieged-cities')
# Rank: 13 Relevant Document: ('OperationDudula_999.json', 54.71169967258995, '2022-02-20', 'johannesburg, south africa', 'https://www.dailymaverick.co.za/article/2022-02-21-xenophobia-accused-operation-dudula-returns-to-hillbrow/')
# Rank: 14 Relevant Document: ('narendramodi_304.json', 50.63224738800481, '2022-02-20', 'hardoi, uttar pradesh', 'https://indianexpress.com/elections/pm-narendra-modi-uttar-pradesh-polls-hardoi-7782343/')
# Rank: 15 Relevant Document: ('UkraineRussiaCrisis_314.json', 49.97289318803954, '2022-02-20', 'washington, united states of america', 'https://edition.cnn.com/europe/live-news/ukraine-russia-news-02-20-22-intl/index.html')
# Rank: 16 Relevant Document: ('hijab_334.json', 49.91670642740691, '2022-02-20', 'massachusetts, united states of america', 'https://scroll.in/article/1017784/why-urbane-educated-muslim-women-are-wearing-the-hijab-in-india')
# Rank: 17 Relevant Document: ('narendramodi_310.json', 49.085709330771806, '2022-02-20', 'amritsar, punjab', 'https://www.aljazeera.com/news/2022/2/20/farmer-anger-will-test-modi-as-indias-grain-bowl-votes')
# Rank: 18 Relevant Document: ('freedomconvoy22_2327.json', 48.97852006583021, '2022-02-18', 'doha, qatar', 'https://www.aljazeera.com/news/2022/2/19/canada-freedom-convoy-ending-but-issue-not-going-away')
# Rank: 19 Relevant Document: ('TaylorSwift_235.json', 40.39163826586817, '2022-02-18', 'united states of america', 'https://qr.ae/pG0O7P')
# Rank: 20 Relevant Document: ('zeynep_1630.json', 38.02570009463241, '2022-02-18', 'united states of america', 'https://blogs.lse.ac.uk/usappblog/2022/02/27/book-review-politics-and-expertise-how-to-use-science-in-a-democratic-society-by-zeynep-pamuk/')
#
# Mean Average Precision RAKE Model (BIM) : 0.17337854525935023
# 20
# Mean Average Recall RAKE Model (BIM) : 0.10999999999999999
# nDCG RAKE Model (Binary Independence Model) : 0.170561670242497

# %% [markdown]
# # Model with TextRank

# %%
# results with top k keywords
bim  = BIM(articles, articles_with_name, docs_preprocessed_metrics)
tweet_keywords_text_rank = get_yake_keywords(tweet_query)
relevant_docs_bim_text_rank = bim.answer_query(" ".join(tweet_keywords_text_rank))

# bim.relevance_feedback(5,6,8)
# bim.show_more()
# bim.read_document(2)

for rank, doc in enumerate(relevant_docs_bim_text_rank):
  print('Rank: {} Relevant Document: {}'.format(rank+1,doc))

print()

mean_average_precision_hashtag_bim_text_rank = mean_average_precision(20, u_base_hashtag, u_time, relevant_docs_bim_text_rank, docs_preprocessed_metrics)
print('Mean Average Precision TextRank Model (BIM) : {}'.format(mean_average_precision_hashtag_bim_text_rank))

mean_average_recall_hashtag_bim_text_rank = mean_average_recall(20, u_base_hashtag, u_time, relevant_docs_bim_text_rank, docs_preprocessed_metrics)
print('Mean Average Recall TextRank Model (BIM) : {}'.format(mean_average_recall_hashtag_bim_text_rank))

nDCG_hashtag_bim_text_rank = nDCG(u_base_hashtag, u_time, relevant_docs_bim_text_rank, docs_preprocessed_metrics)
print('nDCG TextRank Model (Binary Independence Model) : {}'.format(nDCG_hashtag_bim_text_rank))
# Out:
# Rank: 1 Relevant Document: ('hijab_338.json', 187.47847059670258, '2022-02-20', 'new delhi, india', 'https://news.abplive.com/karnataka/hijab-row-conspiracy-of-bjp-against-muslim-girls-former-k-taka-cm-siddaramaiah-1514360')
# Rank: 2 Relevant Document: ('hijab_332.json', 171.4212577860793, '2022-02-20', 'new delhi, india', 'https://thewire.in/communalism/karnataka-muslim-women-students-face-case-suspension-for-wearing-hijab-protesting')
# Rank: 3 Relevant Document: ('hijab_285.json', 165.846718652571, '2022-02-19', 'new delhi, india', 'https://news.abplive.com/karnataka/karnataka-hijab-row-govt-order-dated-feb-5-does-not-ban-hijab-ag-tells-high-court-1514213')
# Rank: 4 Relevant Document: ('hijab_340.json', 135.273968284136, '2022-02-20', 'hyderabad, india', 'https://www.siasat.com/hijab-row-bangladesh-stands-in-solidarity-with-muslim-women-2279139/')
# Rank: 5 Relevant Document: ('hijab_283.json', 116.26095122333052, '2022-02-19', 'new delhi, india', 'https://www.newindianexpress.com/nation/2022/feb/19/education-more-important-than-hijab-rss-linked-muslim-rashtriya-manch-to-community-2421449.html')
# Rank: 6 Relevant Document: ('hijab_333.json', 102.93023308200584, '2022-02-20', 'kerala, india', 'https://www.theweek.in/news/entertainment/2022/02/20/hijab-not-a-choice-but-an-obligation-in-islam-says-zaira-wasim.html')
# Rank: 7 Relevant Document: ('hijab_334.json', 340.77408410470696, '2022-02-20', 'massachusetts, united states of america', 'https://scroll.in/article/1017784/why-urbane-educated-muslim-women-are-wearing-the-hijab-in-india')
# Rank: 8 Relevant Document: ('hijab_339.json', 327.23092474202076, '2022-02-20', 'aluva, kerala', 'https://thefederal.com/states/south/tamil-nadu/discrimination-violence-drove-40-dalits-in-tn-village-to-embrace-islam/')
# Rank: 9 Relevant Document: ('hijab_286.json', 187.85153570082872, '2022-02-19', 'bangalore, karnataka', 'https://thefederal.com/states/south/karnataka/uneasy-bjp-central-command-wants-to-wind-down-hijab-row-in-karnataka/')
# Rank: 10 Relevant Document: ('hijab_288.json', 153.83908100810294, '2022-02-19', 'mysore', 'https://thekashmirwalla.com/mysuru-college-cancels-uniform-order-allows-students-to-wear-hijab/')
# Rank: 11 Relevant Document: ('hijab_281.json', 147.49702174979504, '2022-02-19', 'bangalore, karnataka', 'https://www.thehindu.com/news/national/karnataka/hijab-row-polarises-classrooms-breaks-friendships/article65063188.ece')
# Rank: 12 Relevant Document: ('hijab_331.json', 146.77316793045776, '2022-02-20', 'chennai, tamil nadu', 'https://www.thehindu.com/data/data-hijab-row-why-the-ban-is-a-double-blow-for-muslim-girl-students/article65066546.ece')
# Rank: 13 Relevant Document: ('hijab_336.json', 142.0570966049845, '2022-02-20', 'mumbai, maharashtra', 'https://www.indiatoday.in/movies/celebrities/story/hijab-isn-t-a-choice-but-an-obligation-in-islam-says-zaira-wasim-1915351-2022-02-20')
# Rank: 14 Relevant Document: ('hijab_282.json', 135.03398892874296, '2022-02-19', 'bangalore, karnataka', 'https://www.hindustantimes.com/entertainment/bollywood/zaira-wasim-reacts-to-hijab-row-i-as-a-woman-who-wears-hijab-resent-this-entire-system-101645288361058.html')
# Rank: 15 Relevant Document: ('hijab_287.json', 119.9006050341252, '2022-02-19', 'shivamogga', 'https://www.outlookindia.com/national/karnataka-hijab-row-58-students-suspended-in-shivamogga-for-wearing-headscarves-holding-protest-news-183162')
# Rank: 16 Relevant Document: ('hijab_290.json', 106.7214232243613, '2022-02-19', 'bangalore, karnataka', 'https://english.varthabharati.in/karnataka/hijab-row-feb-5-government-order-doesnt-ban-hijab-insists-ag-in-karnataka-hc')
# Rank: 17 Relevant Document: ('hijab_284.json', 106.69434545255866, '2022-02-19', 'bangalore, karnataka', 'https://www.sundayguardianlive.com/news/hijab-controversy-manufactured-create-anarchy')
# Rank: 18 Relevant Document: ('hijab_335.json', 69.1210883265995, '2022-02-20', 'bangalore, karnataka', 'https://indianexpress.com/article/cities/bangalore/karnataka-bengaluru-live-updates-hijab-row-protests-court-hearing-covid-7765244/')
# Rank: 19 Relevant Document: ('hijab_289.json', 63.91051146613017, '2022-02-19', 'karnataka', 'https://www.freepressjournal.in/india/karnataka-hijab-row-seen-to-be-soft-cm-basavaraj-bommaiturns-heat-on-hijab-protesters')
# Rank: 20 Relevant Document: ('BJPwinningUP_2524.json', 37.61777596083726, '2022-02-18', 'banaras, up', 'https://theprint.in/opinion/bjps-2ab-factor-thats-missing-from-sp-bsp-congress-in-up-elections/836455/')
#
# Mean Average Precision TextRank Model (BIM) : 0.9974999999999999
# 20
# Mean Average Recall TextRank Model (BIM) : 0.5224999999999999
# nDCG TextRank Model (Binary Independence Model) : 0.8908988901562694

# %% [markdown]
# # Model with KeyBert

# %%
# results with top k keywords
bim  = BIM(articles, articles_with_name, docs_preprocessed_metrics)
tweet_keywords_keybert = get_keybert_keywords(tweet_query)
relevant_docs_bim_keybert = bim.answer_query(" ".join(tweet_keywords_keybert))

# bim.relevance_feedback(5,6,8)
# bim.show_more()
# bim.read_document(2)

for rank, doc in enumerate(relevant_docs_bim_keybert):
  print('Rank: {} Relevant Document: {}'.format(rank+1,doc))

print()

mean_average_precision_hashtag_bim_keybert = mean_average_precision(20, u_base_hashtag, u_time, relevant_docs_bim_keybert, docs_preprocessed_metrics)
print('Mean Average Precision KeyBERT Model (BIM) : {}'.format(mean_average_precision_hashtag_bim_keybert))

mean_average_recall_hashtag_bim_keybert = mean_average_recall(20, u_base_hashtag, u_time, relevant_docs_bim_keybert, docs_preprocessed_metrics)
print('Mean Average Recall KeyBERT Model (BIM) : {}'.format(mean_average_recall_hashtag_bim_keybert))

nDCG_hashtag_bim_keybert = nDCG(u_base_hashtag, u_time, relevant_docs_bim_keybert, docs_preprocessed_metrics)
print('nDCG KeyBERT Model (Binary Independence Model) : {}'.format(nDCG_hashtag_bim_keybert))
# Out:
# Downloading:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/10.1k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/571 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/349 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/363 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/13.1k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Rank: 1 Relevant Document: ('hijab_332.json', 81.73349189273124, '2022-02-20', 'new delhi, india', 'https://thewire.in/communalism/karnataka-muslim-women-students-face-case-suspension-for-wearing-hijab-protesting')
# Rank: 2 Relevant Document: ('hijab_338.json', 70.0572787651982, '2022-02-20', 'new delhi, india', 'https://news.abplive.com/karnataka/hijab-row-conspiracy-of-bjp-against-muslim-girls-former-k-taka-cm-siddaramaiah-1514360')
# Rank: 3 Relevant Document: ('hijab_285.json', 64.21917220143169, '2022-02-19', 'new delhi, india', 'https://news.abplive.com/karnataka/karnataka-hijab-row-govt-order-dated-feb-5-does-not-ban-hijab-ag-tells-high-court-1514213')
# Rank: 4 Relevant Document: ('hijab_340.json', 64.21917220143169, '2022-02-20', 'hyderabad, india', 'https://www.siasat.com/hijab-row-bangladesh-stands-in-solidarity-with-muslim-women-2279139/')
# Rank: 5 Relevant Document: ('hijab_333.json', 58.381065637665166, '2022-02-20', 'kerala, india', 'https://www.theweek.in/news/entertainment/2022/02/20/hijab-not-a-choice-but-an-obligation-in-islam-says-zaira-wasim.html')
# Rank: 6 Relevant Document: ('hijab_283.json', 29.190532818832587, '2022-02-19', 'new delhi, india', 'https://www.newindianexpress.com/nation/2022/feb/19/education-more-important-than-hijab-rss-linked-muslim-rashtriya-manch-to-community-2421449.html')
# Rank: 7 Relevant Document: ('hijab_337.json', 5.838106563766518, '2022-02-20', 'new delhi, india', 'https://www.hindustantimes.com/opinion/hijab-row-restriction-on-clothing-is-political-101645367225790.html')
# Rank: 8 Relevant Document: ('hijab_339.json', 116.76213127533033, '2022-02-20', 'aluva, kerala', 'https://thefederal.com/states/south/tamil-nadu/discrimination-violence-drove-40-dalits-in-tn-village-to-embrace-islam/')
# Rank: 9 Relevant Document: ('hijab_334.json', 105.0859181477973, '2022-02-20', 'massachusetts, united states of america', 'https://scroll.in/article/1017784/why-urbane-educated-muslim-women-are-wearing-the-hijab-in-india')
# Rank: 10 Relevant Document: ('hijab_336.json', 81.73349189273124, '2022-02-20', 'mumbai, maharashtra', 'https://www.indiatoday.in/movies/celebrities/story/hijab-isn-t-a-choice-but-an-obligation-in-islam-says-zaira-wasim-1915351-2022-02-20')
# Rank: 11 Relevant Document: ('hijab_286.json', 75.89538532896472, '2022-02-19', 'bangalore, karnataka', 'https://thefederal.com/states/south/karnataka/uneasy-bjp-central-command-wants-to-wind-down-hijab-row-in-karnataka/')
# Rank: 12 Relevant Document: ('hijab_282.json', 70.0572787651982, '2022-02-19', 'bangalore, karnataka', 'https://www.hindustantimes.com/entertainment/bollywood/zaira-wasim-reacts-to-hijab-row-i-as-a-woman-who-wears-hijab-resent-this-entire-system-101645288361058.html')
# Rank: 13 Relevant Document: ('hijab_281.json', 64.21917220143169, '2022-02-19', 'bangalore, karnataka', 'https://www.thehindu.com/news/national/karnataka/hijab-row-polarises-classrooms-breaks-friendships/article65063188.ece')
# Rank: 14 Relevant Document: ('hijab_287.json', 58.381065637665166, '2022-02-19', 'shivamogga', 'https://www.outlookindia.com/national/karnataka-hijab-row-58-students-suspended-in-shivamogga-for-wearing-headscarves-holding-protest-news-183162')
# Rank: 15 Relevant Document: ('hijab_288.json', 58.381065637665166, '2022-02-19', 'mysore', 'https://thekashmirwalla.com/mysuru-college-cancels-uniform-order-allows-students-to-wear-hijab/')
# Rank: 16 Relevant Document: ('hijab_289.json', 52.54295907389865, '2022-02-19', 'karnataka', 'https://www.freepressjournal.in/india/karnataka-hijab-row-seen-to-be-soft-cm-basavaraj-bommaiturns-heat-on-hijab-protesters')
# Rank: 17 Relevant Document: ('hijab_290.json', 52.54295907389865, '2022-02-19', 'bangalore, karnataka', 'https://english.varthabharati.in/karnataka/hijab-row-feb-5-government-order-doesnt-ban-hijab-insists-ag-in-karnataka-hc')
# Rank: 18 Relevant Document: ('hijab_331.json', 40.86674594636562, '2022-02-20', 'chennai, tamil nadu', 'https://www.thehindu.com/data/data-hijab-row-why-the-ban-is-a-double-blow-for-muslim-girl-students/article65066546.ece')
# Rank: 19 Relevant Document: ('hijab_284.json', 35.0286393825991, '2022-02-19', 'bangalore, karnataka', 'https://www.sundayguardianlive.com/news/hijab-controversy-manufactured-create-anarchy')
# Rank: 20 Relevant Document: ('hijab_335.json', 29.190532818832587, '2022-02-20', 'bangalore, karnataka', 'https://indianexpress.com/article/cities/bangalore/karnataka-bengaluru-live-updates-hijab-row-protests-court-hearing-covid-7765244/')
#
# Mean Average Precision KeyBERT Model (BIM) : 1.0
# 20
# Mean Average Recall KeyBERT Model (BIM) : 0.5249999999999999
# nDCG KeyBERT Model (Binary Independence Model) : 0.9008203286974528

# %% [markdown]
# # Across all hashtags

# %%
global_list =[['IPL', '2022-02-25', 'india'], ['IPL', '2022-02-16', 'india'], ['Drishyam2', '2022-02-17', 'india'], ['elections', '2022-02-27', 'imphal'], ['elections', '2022-02-27', 'new delhi'], ['elections', '2022-02-27', 'uttar pradesh'], ['nursesstrike', '2022-02-15', 'australia'], ['Djokovic', '2022-02-15', 'australia'],['hijab', '2022-02-19', 'india'], ['msdtrong', '2022-02-14', 'Florida'], ['ottawaoccupied', '2022-02-14', 'Ottawa'], ['Boycott_ChennaiSuperKings', '2022-02-14', 'chennai'], ['GlanceJio', '2022-02-14', 'New Delhi'], ['ArabicKuthu', '2022-02-14', 'CHENNAI'], ['Djokovic', '2022-02-15', 'AUSTRALIA'], ['Real Madrid', '2022-02-15', 'Madrid'], ['bighit', '2022-02-15', 'ASSAM'], ['Maxwell', '2022-02-15', 'india'], ['mafsau', '2022-02-16', 'australia'], ['channi', '2022-02-16', 'punjab'], ['ayalaan', '2022-02-16', 'tamil nadu'], ['jkbose', '2022-02-16', 'srinagar'], ['happybirthdayjhope', '2022-02-17', 'new delhi'], ['mohsinbaig', '2022-02-17', 'islamabad'],  ['ShivajiJayanti', '2022-02-18', 'maharashtra'], ['OperationDudula', '2022-02-20', 'South Africa'], ['UFCVegas48', '2022-02-20', 'india'], ['FCNPSG', '2022-02-20', 'PARIS'], ['shivamogga', '2022-02-21', 'KARNATAKA'],  ['StayAlive_CHAKHO', '2022-02-22', 'seoul'], ['KaranSinghGrover', '2022-02-22', 'india'], ['NationalMargaritaDay', '2022-02-22', 'United States of America'], ['dontsaygay', '2022-02-22', 'New York'], ['RIPRikyRick', '2022-02-23', 'South Africa'], ['budget2022', '2022-02-23', 'Cape Town'], ['CottonFest2022', '2022-02-23', 'nigeria'], ['NationalChiliDay', '2022-02-24', 'Ohio'], ['stockmarketcrash', '2022-02-24', 'mumbai'], ['BidenisaFailure', '2022-02-24', 'United States of America']]
print(len(global_list))
global_list = global_list[:30]
# Out:
# 39

# %%
global_average_mean_average_precision_plain = []
global_mean_average_recall_plain = []
global_mean_average_ndcg_plain = []

global_average_mean_average_precision_keyword_extractor = []
global_mean_average_recall_keyword_extractor = []
global_mean_average_ndcg_keyword_exractor = []

global_average_mean_average_precision_rake = []
global_mean_average_recall_rake = []
global_mean_average_ndcg_rake = []

global_average_mean_average_precision_yake = []
global_mean_average_recall_yake = []
global_mean_average_ndcg_yake = []

global_average_mean_average_precision_text_rank = []
global_mean_average_recall_text_rank = []
global_mean_average_ndcg_text_rank = []


global_average_mean_average_precision_keybert = []
global_mean_average_recall_keybert = []
global_mean_average_ndcg_keybert = []

for iter in tqdm(range(len(global_list))):
  u_base_hashtag = global_list[iter][0]
  u_time = global_list[iter][1]
  u_location = global_list[iter][2]
  tweet_query = []
  format = '%Y-%m-%d'
  u_present_date = datetime.datetime.strptime(u_time, format)
  u_prev_date = u_present_date - datetime.timedelta(days=1)
  u_next_date = u_present_date + datetime.timedelta(days=1)
  df_query = df.loc[df['hashtags'].str.contains(u_base_hashtag) & df['Date_Only'].isin([str(u_present_date.date()), str(u_prev_date.date()), str(u_next_date.date())])]

  for tweet in df_query['Preprocessed_Data']:
    tweet_query.extend(tweet)
  
  tweet_keywords = []
  kw_extractor = yake.KeywordExtractor(top=20, stopwords=None)
  keywords = kw_extractor.extract_keywords(' '.join(tweet_query))
  for kw, v in keywords:
    #print("Keyphrase: ",kw, ": score", v)
    for key in kw.split():
      if(key not in tweet_keywords):
        tweet_keywords.append(key)
  
  docs_preprocessed = []

  total_documents = 0
  path = '/content/drive/MyDrive/Tweelink_Dataset/Tweelink_Articles_Processed'
  for filename in glob(os.path.join(path, '*')):
    with open(os.path.join(os.getcwd(), filename), 'r', encoding = 'utf-8',errors = 'ignore') as f:
      filename = os.path.basename(f.name)
      data = json.load(f)
      d_date = data["Date"]
      if(d_date=="" or d_date=="Date"):
        continue
      format = '%Y-%m-%d'
  
      d_present_date = datetime.datetime.strptime(d_date, format)
  
      if(str(d_present_date.date()) not in [str(u_present_date.date()), str(u_prev_date.date()), str(u_next_date.date())]):
        continue
    
      docs_preprocessed.append({'Name':filename, 'Data':data})
      total_documents+=1
  
  # Plain
  articles, articles_with_name, docs_preprocessed_metrics = import_dataset()
  bim  = BIM(articles, articles_with_name,docs_preprocessed_metrics)
  relevant_articles_list_plain = bim.answer_query(" ".join(tweet_query))
  mean_average_precision_hashtag_plain = mean_average_precision(20, u_base_hashtag, u_time, relevant_articles_list_plain, docs_preprocessed_metrics)
  global_average_mean_average_precision_plain.append(mean_average_precision_hashtag_plain)
  mean_average_recall_hashtag_plain = mean_average_recall(20, u_base_hashtag, u_time, relevant_articles_list_plain, docs_preprocessed_metrics)
  global_mean_average_recall_plain.append(mean_average_recall_hashtag_plain)
  nDCG_hashtag_plain = nDCG(u_base_hashtag, u_time, relevant_articles_list_plain, docs_preprocessed)
  global_mean_average_ndcg_plain.append(nDCG_hashtag_plain)

  # keyword extractor
  bim  = BIM(articles, articles_with_name, docs_preprocessed_metrics)
  tweet_query_keyword_extractor = get_keyword_keywordextractor(df_query)
  relevant_articles_list_keyword_extractor = bim.answer_query(" ".join(tweet_query_keyword_extractor[:20]))
  mean_average_precision_hashtag_keyword_extractor = mean_average_precision(20, u_base_hashtag, u_time, relevant_articles_list_keyword_extractor, docs_preprocessed_metrics)
  global_average_mean_average_precision_keyword_extractor.append(mean_average_precision_hashtag_keyword_extractor)
  mean_average_recall_hashtag_keyword_extractor = mean_average_recall(20, u_base_hashtag, u_time, relevant_articles_list_keyword_extractor, docs_preprocessed_metrics)
  global_mean_average_recall_keyword_extractor.append(mean_average_recall_hashtag_keyword_extractor)
  nDCG_hashtag_keyword_extractor = nDCG(u_base_hashtag, u_time, relevant_articles_list_keyword_extractor, docs_preprocessed)
  global_mean_average_ndcg_keyword_exractor.append(nDCG_hashtag_keyword_extractor)

  # Rake
  bim  = BIM(articles, articles_with_name, docs_preprocessed_metrics)
  tweet_query_rake = get_rake_keywords(tweet_query)
  relevant_articles_list_rake = bim.answer_query(" ".join(tweet_query_rake))
  mean_average_precision_hashtag_rake = mean_average_precision(20, u_base_hashtag, u_time, relevant_articles_list_rake, docs_preprocessed_metrics)
  global_average_mean_average_precision_rake.append(mean_average_precision_hashtag_rake)
  mean_average_recall_hashtag_rake = mean_average_recall(20, u_base_hashtag, u_time, relevant_articles_list_rake, docs_preprocessed_metrics)
  global_mean_average_recall_rake.append(mean_average_recall_hashtag_rake)
  nDCG_hashtag_rake = nDCG(u_base_hashtag, u_time,  relevant_articles_list_rake, docs_preprocessed)
  global_mean_average_ndcg_rake.append(nDCG_hashtag_rake)

  # Yake
  bim  = BIM(articles, articles_with_name, docs_preprocessed_metrics)
  tweet_query_yake = get_yake_keywords(tweet_query)
  relevant_articles_list_yake = bim.answer_query(" ".join(tweet_query_yake))
  mean_average_precision_hashtag_yake = mean_average_precision(20, u_base_hashtag, u_time, relevant_articles_list_yake, docs_preprocessed_metrics)
  global_average_mean_average_precision_yake.append(mean_average_precision_hashtag_yake)
  mean_average_recall_hashtag_yake = mean_average_recall(20, u_base_hashtag, u_time, relevant_articles_list_yake, docs_preprocessed_metrics)
  global_mean_average_recall_yake.append(mean_average_recall_hashtag_yake)
  nDCG_hashtag_yake = nDCG(u_base_hashtag, u_time, relevant_articles_list_yake, docs_preprocessed)
  global_mean_average_ndcg_yake.append(nDCG_hashtag_yake)

  # Text Rank
  bim  = BIM(articles, articles_with_name, docs_preprocessed_metrics)
  tweet_query_text_rank = get_text_rank_keywords(tweet_query)
  relevant_articles_list_text_rank = bim.answer_query(" ".join(tweet_query_text_rank))
  mean_average_precision_hashtag_text_rank = mean_average_precision(20, u_base_hashtag, u_time, relevant_articles_list_text_rank, docs_preprocessed_metrics)
  global_average_mean_average_precision_text_rank.append(mean_average_precision_hashtag_text_rank)
  mean_average_recall_hashtag_text_rank = mean_average_recall(20, u_base_hashtag, u_time, relevant_articles_list_text_rank, docs_preprocessed_metrics)
  global_mean_average_recall_text_rank.append(mean_average_recall_hashtag_text_rank)
  nDCG_hashtag_text_rank = nDCG(u_base_hashtag, u_time, relevant_articles_list_text_rank, docs_preprocessed)
  global_mean_average_ndcg_text_rank.append(nDCG_hashtag_text_rank)
  
  
  # Keybert
  bim  = BIM(articles, articles_with_name, docs_preprocessed_metrics)
  tweet_query_keybert = get_keybert_keywords(tweet_query)
  relevant_articles_list_keybert = bim.answer_query(" ".join(tweet_query_keybert))
  mean_average_precision_hashtag_keybert = mean_average_precision(20, u_base_hashtag, u_time, relevant_articles_list_keybert, docs_preprocessed_metrics)
  global_average_mean_average_precision_keybert.append(mean_average_precision_hashtag_keybert)
  mean_average_recall_hashtag_keybert = mean_average_recall(20, u_base_hashtag, u_time, relevant_articles_list_keybert, docs_preprocessed_metrics)
  global_mean_average_recall_keybert.append(mean_average_recall_hashtag_keybert)
  nDCG_hashtag_keybert = nDCG(u_base_hashtag, u_time, relevant_articles_list_keybert, docs_preprocessed)
  global_mean_average_ndcg_keybert.append(nDCG_hashtag_keybert)
# Out:
#   0%|          | 0/30 [00:07<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-42-d7da03ec21b7> in <module>()
#      69
#      70   # Plain
# ---> 71   articles, articles_with_name, docs_preprocessed_metrics = import_dataset()
#      72   bim  = BIM(articles, articles_with_name,docs_preprocessed_metrics)
#      73   relevant_articles_list_plain = bim.answer_query(" ".join(tweet_query))
#
# <ipython-input-8-170944198d14> in import_dataset()
#      25     path = '/content/drive/MyDrive/Tweelink_Dataset/Tweelink_Articles_Processed'
#      26     for filename in glob(os.path.join(path, '*')):
# ---> 27       with open(os.path.join(os.getcwd(), filename), 'r', encoding = 'utf-8',errors = 'ignore') as f:
#      28         filename = os.path.basename(f.name)
#      29         data = json.load(f)
#
# KeyboardInterrupt:

# %%
overall_average_mean_average_precision_plain = sum(global_average_mean_average_precision_plain)/len(global_average_mean_average_precision_plain)
print(overall_average_mean_average_precision_plain)

overall_mean_average_recall_plain = sum(global_mean_average_recall_plain)/len(global_mean_average_recall_plain)
print(overall_mean_average_recall_plain)

overall_mean_average_ndcg_plain = sum(global_mean_average_ndcg_plain)/len(global_mean_average_ndcg_plain)
print(overall_mean_average_ndcg_plain)
# Out:
# 0.0
# 0.0
# 0.0

# %%
overall_average_mean_average_precision_keyword_extractor = sum(global_average_mean_average_precision_keyword_extractor)/len(global_average_mean_average_precision_keyword_extractor)
print(overall_average_mean_average_precision_keyword_extractor)

overall_mean_average_recall_keyword_extractor = sum(global_mean_average_recall_keyword_extractor)/len(global_mean_average_recall_keyword_extractor)
print(overall_mean_average_recall_keyword_extractor)

overall_mean_average_ndcg_keyword_extractor = sum(global_mean_average_ndcg_keyword_exractor)/len(global_mean_average_ndcg_keyword_exractor)
print(overall_mean_average_ndcg_keyword_extractor)
# Out:
# 0.7195254113052709
# 0.36277777777777775
# 0.6990366407981631

# %%
overall_average_mean_average_precision_rake = sum(global_average_mean_average_precision_rake)/len(global_average_mean_average_precision_rake)
print(overall_average_mean_average_precision_rake)

overall_mean_average_recall_rake = sum(global_mean_average_recall_rake)/len(global_mean_average_recall_rake)
print(overall_mean_average_recall_rake)

overall_mean_average_ndcg_rake = sum(global_mean_average_ndcg_rake)/len(global_mean_average_ndcg_rake)
print(overall_mean_average_ndcg_rake)
# Out:
# 0.0
# 0.0
# 0.0

# %%
overall_average_mean_average_precision_yake = sum(global_average_mean_average_precision_yake)/len(global_average_mean_average_precision_yake)
print(overall_average_mean_average_precision_yake)

overall_mean_average_recall_yake = sum(global_mean_average_recall_yake)/len(global_mean_average_recall_yake)
print(overall_mean_average_recall_yake)

overall_mean_average_ndcg_yake = sum(global_mean_average_ndcg_yake)/len(global_mean_average_ndcg_yake)
print(overall_mean_average_ndcg_yake)
# Out:
# 0.7516894008083441
# 0.37111111111111106
# 0.7328856581382406

# %%
overall_average_mean_average_precision_text_rank = sum(global_average_mean_average_precision_text_rank)/len(global_average_mean_average_precision_text_rank)
print(overall_average_mean_average_precision_text_rank)

overall_mean_average_recall_text_rank = sum(global_mean_average_recall_text_rank)/len(global_mean_average_recall_text_rank)
print(overall_mean_average_recall_text_rank)


overall_mean_average_ndcg_text_rank = sum(global_mean_average_ndcg_text_rank)/len(global_mean_average_ndcg_text_rank)
print(overall_mean_average_ndcg_text_rank)
# Out:
# 0.7291639440688037
# 0.36444444444444446
# 0.7398200931115673

# %%
overall_average_mean_average_precision_keybert = sum(global_average_mean_average_precision_keybert)/len(global_average_mean_average_precision_keybert)
print(overall_average_mean_average_precision_keybert)

overall_mean_average_recall_keybert = sum(global_mean_average_recall_keybert)/len(global_mean_average_recall_keybert)
print(overall_mean_average_recall_keybert)

overall_mean_average_ndcg_keybert = sum(global_mean_average_ndcg_keybert)/len(global_mean_average_ndcg_keybert)
print(overall_mean_average_ndcg_keybert)
# Out:
# 0.4657491579255698
# 0.2277777777777777
# 0.9460995457893934
