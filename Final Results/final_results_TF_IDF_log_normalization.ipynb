# %% [markdown]
# # Import Statements

# %%
#Importing essential libraries
import pandas as pd
import numpy as np
import csv
import json
from itertools import islice
from collections import OrderedDict
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import nltk
from glob import glob
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from tqdm import tqdm
import pickle
import math
import re
from sklearn.model_selection import train_test_split
import operator
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('corpus')
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from scipy import stats
! pip install git+https://github.com/LIAAD/yake
import yake
! pip install multi_rake
from multi_rake import Rake
! pip install summa
from summa import keywords as summa_keywords
! pip install keybert
from keybert import KeyBERT
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Error loading corpus: Package 'corpus' not found in index
# Collecting git+https://github.com/LIAAD/yake
#   Cloning https://github.com/LIAAD/yake to /tmp/pip-req-build-t4gr_am1
#   Running command git clone -q https://github.com/LIAAD/yake /tmp/pip-req-build-t4gr_am1
# Requirement already satisfied: tabulate in /usr/local/lib/python3.7/dist-packages (from yake==0.4.8) (0.8.9)
# Requirement already satisfied: click>=6.0 in /usr/local/lib/python3.7/dist-packages (from yake==0.4.8) (7.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from yake==0.4.8) (1.21.6)
# Collecting segtok
#   Downloading segtok-1.5.11-py3-none-any.whl (24 kB)
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (from yake==0.4.8) (2.6.3)
# Collecting jellyfish
#   Downloading jellyfish-0.9.0.tar.gz (132 kB)
#      |████████████████████████████████| 132 kB 5.8 MB/s
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from segtok->yake==0.4.8) (2019.12.20)
# Building wheels for collected packages: yake, jellyfish
#   Building wheel for yake (setup.py) ... done
#   Created wheel for yake: filename=yake-0.4.8-py2.py3-none-any.whl size=62565 sha256=624566c55c7a0a4f1fcc5eed701554a951b46f47442c581625e6f88c3d120c0f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ltucijok/wheels/52/79/f4/dae9309f60266aa3767a4381405002b6f2955fbcf038d804da
#   Building wheel for jellyfish (setup.py) ... done
#   Created wheel for jellyfish: filename=jellyfish-0.9.0-cp37-cp37m-linux_x86_64.whl size=74021 sha256=a6c388c94e0dbd09277a0f0b9950d8cd5466286055f9825be5ab0295ea736210
#   Stored in directory: /root/.cache/pip/wheels/fe/99/4e/646ce766df0d070b0ef04db27aa11543e2767fda3075aec31b
# Successfully built yake jellyfish
# Installing collected packages: segtok, jellyfish, yake
# Successfully installed jellyfish-0.9.0 segtok-1.5.11 yake-0.4.8
# Collecting multi_rake
#   Downloading multi_rake-0.0.2-py3-none-any.whl (31 kB)
# Requirement already satisfied: pyrsistent>=0.14.2 in /usr/local/lib/python3.7/dist-packages (from multi_rake) (0.18.1)
# Collecting pycld2>=0.41
#   Downloading pycld2-0.41.tar.gz (41.4 MB)
#      |████████████████████████████████| 41.4 MB 3.8 MB/s
# Requirement already satisfied: numpy>=1.14.4 in /usr/local/lib/python3.7/dist-packages (from multi_rake) (1.21.6)
# Requirement already satisfied: regex>=2018.6.6 in /usr/local/lib/python3.7/dist-packages (from multi_rake) (2019.12.20)
# Building wheels for collected packages: pycld2
#   Building wheel for pycld2 (setup.py) ... done
#   Created wheel for pycld2: filename=pycld2-0.41-cp37-cp37m-linux_x86_64.whl size=9834281 sha256=7307bb8d055688be564e1ef3a09aef532f30466d1ef0708d94830a1ba2f09647
#   Stored in directory: /root/.cache/pip/wheels/ed/e4/58/ed2e9f43c07d617cc81fe7aff0fc6e42b16c9cf6afe960b614
# Successfully built pycld2
# Installing collected packages: pycld2, multi-rake
# Successfully installed multi-rake-0.0.2 pycld2-0.41
# Collecting summa
#   Downloading summa-1.2.0.tar.gz (54 kB)
#      |████████████████████████████████| 54 kB 1.8 MB/s
# Requirement already satisfied: scipy>=0.19 in /usr/local/lib/python3.7/dist-packages (from summa) (1.4.1)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from scipy>=0.19->summa) (1.21.6)
# Building wheels for collected packages: summa
#   Building wheel for summa (setup.py) ... done
#   Created wheel for summa: filename=summa-1.2.0-py3-none-any.whl size=54412 sha256=1b27a48979cc4fcd98d72d78bde36f78d6be81facdc88c6840e430785ae1e381
#   Stored in directory: /root/.cache/pip/wheels/29/64/ac/7b443477588d365ef37ada30d456bdf5f07dc5be9f6324cb6e
# Successfully built summa
# Installing collected packages: summa
# Successfully installed summa-1.2.0
# Collecting keybert
#   Downloading keybert-0.5.1.tar.gz (19 kB)
# Collecting sentence-transformers>=0.3.8
#   Downloading sentence-transformers-2.2.0.tar.gz (79 kB)
#      |████████████████████████████████| 79 kB 3.2 MB/s
# Requirement already satisfied: scikit-learn>=0.22.2 in /usr/local/lib/python3.7/dist-packages (from keybert) (1.0.2)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.7/dist-packages (from keybert) (1.21.6)
# Collecting rich>=10.4.0
#   Downloading rich-12.3.0-py3-none-any.whl (232 kB)
#      |████████████████████████████████| 232 kB 8.7 MB/s
# Requirement already satisfied: typing-extensions<5.0,>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from rich>=10.4.0->keybert) (4.2.0)
# Collecting commonmark<0.10.0,>=0.9.0
#   Downloading commonmark-0.9.1-py2.py3-none-any.whl (51 kB)
#      |████████████████████████████████| 51 kB 4.9 MB/s
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /usr/local/lib/python3.7/dist-packages (from rich>=10.4.0->keybert) (2.6.1)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.22.2->keybert) (1.4.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.22.2->keybert) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.22.2->keybert) (1.1.0)
# Collecting transformers<5.0.0,>=4.6.0
#   Downloading transformers-4.18.0-py3-none-any.whl (4.0 MB)
#      |████████████████████████████████| 4.0 MB 51.0 MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from sentence-transformers>=0.3.8->keybert) (4.64.0)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from sentence-transformers>=0.3.8->keybert) (1.11.0+cu113)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from sentence-transformers>=0.3.8->keybert) (0.12.0+cu113)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from sentence-transformers>=0.3.8->keybert) (3.2.5)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 40.3 MB/s
# Collecting huggingface-hub
#   Downloading huggingface_hub-0.5.1-py3-none-any.whl (77 kB)
#      |████████████████████████████████| 77 kB 5.5 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (2019.12.20)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (2.23.0)
# Collecting sacremoses
#   Downloading sacremoses-0.0.49-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 63.0 MB/s
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 52.7 MB/s
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 43.5 MB/s
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (21.3)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (4.11.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (3.6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (3.0.8)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (3.8.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk->sentence-transformers>=0.3.8->keybert) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (1.24.3)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert) (7.1.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->sentence-transformers>=0.3.8->keybert) (7.1.2)
# Building wheels for collected packages: keybert, sentence-transformers
#   Building wheel for keybert (setup.py) ... done
#   Created wheel for keybert: filename=keybert-0.5.1-py3-none-any.whl size=21332 sha256=b07b75e4925ae7f58f11cca3ed92a9be28d8e49cb5ce2c3956325e6b07b2075d
#   Stored in directory: /root/.cache/pip/wheels/8e/95/c5/f5ceed2a9f9e80bc1a706a10a6fb03d726df7a3dd11800a58b
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.0-py3-none-any.whl size=120747 sha256=33f5a43a0effe1736c69b782584c82ea9d1e5ae52e14050a955e54cc66f9dd7f
#   Stored in directory: /root/.cache/pip/wheels/83/c0/df/b6873ab7aac3f2465aa9144b6b4c41c4391cfecc027c8b07e7
# Successfully built keybert sentence-transformers
# Installing collected packages: pyyaml, tokenizers, sacremoses, huggingface-hub, transformers, sentencepiece, commonmark, sentence-transformers, rich, keybert
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed commonmark-0.9.1 huggingface-hub-0.5.1 keybert-0.5.1 pyyaml-6.0 rich-12.3.0 sacremoses-0.0.49 sentence-transformers-2.2.0 sentencepiece-0.1.96 tokenizers-0.12.1 transformers-4.18.0

# %%
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file1 = open("/content/drive/MyDrive/Tweelink_Dataset/twitter_base_preprocessed.pkl", "rb")
df = pickle.load(file1)
file1.close()

# %% [markdown]
# # Input

# %%
u_base_hashtag = input("Enter base hashtag: ")
u_time = input("Enter time: ")
u_location = input("Enter Location: ")
# Out:
# Enter base hashtag: hijab
# Enter time: 2022-02-19
# Enter Location: india

# %% [markdown]
# # Processing

# %%
import datetime
tweet_query = []
format = '%Y-%m-%d'
u_present_date = datetime.datetime.strptime(u_time, format)
u_prev_date = u_present_date - datetime.timedelta(days=1)
u_next_date = u_present_date + datetime.timedelta(days=1)
df_query = df.loc[df['hashtags'].str.contains(u_base_hashtag) & df['Date_Only'].isin([str(u_present_date.date()), str(u_prev_date.date()), str(u_next_date.date())])]
print(df_query.shape[0])
if df_query.shape[0]<50:
  df_query = df.loc[df['Date_Only'].isin([str(u_present_date.date()), str(u_prev_date.date()), str(u_next_date.date())])]
  df_query = df.iloc[:min(df_query.shape[0],1000),:]
# Out:
# 264

# %%
def keyword_extractor(dataset):
  preprocessed_vocabulary = dict()

  #Converting to lowercase
  def to_lower_case(text):
    text = text.lower()
    return text

  def remove_at_word(text):
    data = text.split()
    data = [d for d in data if d[0]!='@']
    text = ' '.join(data)
    return text

  def remove_hashtag(text):
    data = text.split()
    data = [d if (d[0]!='#' or len(d) == 1) else d[1:] for d in data]
    data = [d for d in data if d[0]!='#']
    text = ' '.join(data)
    return text

  def remove_URL(text):
    text = re.sub(r"http\S+", "", text)
    text = re.sub(r'bit.ly\S+', '', text, flags=re.MULTILINE)
    return text

  #Removing stopwords
  def remove_stopwords(text):
    stopword = stopwords.words('english')
    new_list = [x for x in text.split() if x not in stopword]
    return ' '.join(new_list)

  #Removing punctuations
  def remove_punctuations(text):
    punctuations = '''!()-[|]`{};:'"\,<>./?@#$=+%^&*_~'''
    new_list = ['' if x in punctuations else x for x in text.split()]
    new_list_final = []
    for token in new_list:
      new_token=""
      for char in token:
        if(char not in punctuations):
          new_token+=char
      if(len(new_token)!=0):
        new_list_final.append(new_token)
    return ' '.join(new_list_final)

  #Tokenization
  def tokenization(text):
    return word_tokenize(text)

  def pre_process(text):
    text = to_lower_case(text)
    text = remove_at_word(text)
    text = remove_hashtag(text)
    text = remove_URL(text)
    text = remove_stopwords(text)
    text = remove_punctuations(text)
    text = tokenization(text)
    for token in text:
      if token in preprocessed_vocabulary.keys():
        preprocessed_vocabulary[token] += 1
      else:
        preprocessed_vocabulary[token] = 1
    return text
  
  preprocessed_data = [pre_process(text) for text in dataset]

  #print(preprocessed_vocabulary)

  AOF_coefficient = sum(preprocessed_vocabulary.values())/len(preprocessed_vocabulary)
  vocabulary = {token.strip():preprocessed_vocabulary[token] for token in preprocessed_vocabulary.keys() if preprocessed_vocabulary[token] > AOF_coefficient and len(token.strip())}

  #print(vocabulary)

  final_tokens_per_tweet = []
  for data in preprocessed_data:
    final_tokens_per_tweet.append([token for token in data if token in vocabulary.keys()])

  #print(preprocessed_data)
  #print(final_tokens_per_tweet)

  word2id = dict()
  id2word = dict()
  vocabulary_size = len(vocabulary)
  count = 0
  for token in vocabulary.keys():
    word2id[token] = count
    id2word[count] = token
    count += 1

  #print(word2id)
  #print(id2word)

  directed_graph_adjacency_matrix = np.zeros((vocabulary_size, vocabulary_size))
  edge_weight_matrix = np.zeros((vocabulary_size, vocabulary_size))
  first_frequency = dict()
  last_frequency = dict()
  term_frequency = vocabulary
  strength = dict()
  degree = dict()
  selective_centraility = dict()


  for tweet in final_tokens_per_tweet:
    if len(tweet)<1:
      continue

    if tweet[0] in first_frequency.keys():
      first_frequency[tweet[0]] += 1
    else:
      first_frequency[tweet[0]] = 1

    if tweet[-1] in last_frequency.keys():
      last_frequency[tweet[-1]] += 1
    else:
      last_frequency[tweet[-1]] = 1
    


    for i in range(len(tweet)-1):
      if tweet[i] == tweet[i+1]:
        continue
      x = word2id[tweet[i]]
      y = word2id[tweet[i+1]]
      directed_graph_adjacency_matrix[x][y] += 1

  for tweet in final_tokens_per_tweet:
    for i in range(len(tweet)-1):


      if tweet[i] == tweet[i+1]:
        continue
      x = word2id[tweet[i]]
      y = word2id[tweet[i+1]]

    # Updating degree..
      if tweet[i] in degree.keys():
        degree[tweet[i]] += 1
      else:
        degree[tweet[i]] = 1
        
      if tweet[i+1] in degree.keys():
        degree[tweet[i+1]] += 1
      else:
        degree[tweet[i+1]] = 1

      edge_weight_matrix[x][y] = directed_graph_adjacency_matrix[x][y]/(vocabulary[tweet[i]] + vocabulary[tweet[i+1]] - directed_graph_adjacency_matrix[x][y])

      if tweet[i] in strength.keys():
        strength[tweet[i]] += edge_weight_matrix[x][y]
      else:
        strength[tweet[i]] = edge_weight_matrix[x][y]




  first_frequency = {token:(first_frequency[token]/vocabulary[token] if token in first_frequency else 0) for token in vocabulary.keys()}
  last_frequency = {token:(last_frequency[token]/vocabulary[token] if token in last_frequency else 0) for token in vocabulary.keys()}
  degree = {token:(degree[token] if token in degree else 0) for token in vocabulary.keys()}
  strength = {token:(strength[token] if token in strength else 0) for token in vocabulary.keys()}
  selective_centraility = {token:(strength[token]/degree[token] if degree[token]!=0 else 0) for token in vocabulary.keys()}

  #print(degree)
  #print(vocabulary)

  maxdegree = max(degree.items(), key=lambda x: x[1])[1]
  max_degree_nodes_with_freq = {key:term_frequency[key] for key in degree.keys() if degree[key] == maxdegree}
  maxfreq = max(max_degree_nodes_with_freq.items(), key=lambda x: x[1])[1]
  central_node_name = [key for key in max_degree_nodes_with_freq.keys() if max_degree_nodes_with_freq[key] == maxfreq][0]
  #print("central node: ", central_node_name)

  # bfs
  distance_from_central_node = dict()
  central_node_id = word2id[central_node_name]
  q = [(central_node_id, 0)]

  # Set source as visited
  distance_from_central_node[central_node_name] = 0

  while q:
      vis = q[0]
      # Print current node
      #print(id2word[vis[0]], vis[1])
      q.pop(0)
        
      # For every adjacent vertex to
      # the current vertex
      for i in range(len(directed_graph_adjacency_matrix[vis[0]])):
          if (directed_graph_adjacency_matrix[vis[0]][i] == 1 and (id2word[i] not in distance_from_central_node.keys())):
              # Push the adjacent node
              # in the queue
              q.append((i, vis[1]+1))
              distance_from_central_node[id2word[i]] = vis[1]+1

  #print(distance_from_central_node)
  inverse_distance_from_central_node = {token:(1/distance_from_central_node[token] if token in distance_from_central_node and token != central_node_name else 0) for token in vocabulary.keys()}
  inverse_distance_from_central_node[central_node_name] = 1.0
  #print(inverse_distance_from_central_node)

  neighbour_importance = dict()

  for i in range(len(directed_graph_adjacency_matrix)):
    neighbours = set()

    # traversing outgoing edges
    for j in range(len(directed_graph_adjacency_matrix)):
      if i == j:
        continue
      if directed_graph_adjacency_matrix[i][j] > 0:
        neighbours.add(j)
    for j in range(len(directed_graph_adjacency_matrix)):
      if i == j:
        continue
      if directed_graph_adjacency_matrix[j][i] > 0:
          neighbours.add(j)
    if len(neighbours) != 0:
      neighbour_importance[id2word[i]] = sum([strength[id2word[j]] for j in neighbours])/len(neighbours)
    else:
      neighbour_importance[id2word[i]] = 0
      
  #print(neighbour_importance)

  unnormalized_node_weight = {node: (first_frequency[node] + last_frequency[node] + term_frequency[node] + selective_centraility[node] + inverse_distance_from_central_node[node] + neighbour_importance[node]) for node in vocabulary.keys()}
  max_node_weight = max(unnormalized_node_weight.items(), key=lambda x: x[1])[1]
  min_node_weight = min(unnormalized_node_weight.items(), key=lambda x: x[1])[1]
  #print("max node weight: ", max_node_weight, "min node weight: ", min_node_weight)
  normalized_node_weight = {node: ((unnormalized_node_weight[node] - min_node_weight)/(max_node_weight - min_node_weight) if max_node_weight != min_node_weight else unnormalized_node_weight[node]) for node in unnormalized_node_weight.keys()}
  #print("Unnormalized score: ", unnormalized_node_weight)
  #print("Normalized score: ", normalized_node_weight)

  damping_factor = 0.85
  relevance_of_node = {node: np.random.uniform(0,1,1)[0] for node in vocabulary.keys()}
  threshold = 0.000000001


  #print(relevance_of_node)

  count = 0
  while True:
    count += 1
    current_relevance_of_node = dict()
    for node in vocabulary.keys():
      outer_sum = 0
      node_idx = word2id[node]
      for j in range(len(directed_graph_adjacency_matrix)):
        if j == node_idx:
          continue
        if directed_graph_adjacency_matrix[j][node_idx] > 0:
          den_sum = 0
          for k in range(len(directed_graph_adjacency_matrix)):
            if k == j:
              continue
            den_sum += directed_graph_adjacency_matrix[j][k]
          outer_sum += ((directed_graph_adjacency_matrix[j][node_idx]/den_sum) * relevance_of_node[id2word[j]])
      current_relevance_of_node[node] = (1-damping_factor)*normalized_node_weight[node] + damping_factor*normalized_node_weight[node]*outer_sum
    

    # checking convergence..
    sq_error = sum([(current_relevance_of_node[node] - relevance_of_node[node])**2 for node in vocabulary.keys()])
    relevance_of_node = current_relevance_of_node
    if sq_error < threshold:
      break

  #print(relevance_of_node)
  #print(count)

  degree_centrality  = {node: 0 for node in vocabulary.keys()}

  if len(directed_graph_adjacency_matrix) > 1:
    for i in range(len(directed_graph_adjacency_matrix)):
      count = 0
      for j in range(len(directed_graph_adjacency_matrix)):
        if i == j:
          continue
        if directed_graph_adjacency_matrix[j][i] > 0:
          count += 1
      degree_centrality[id2word[i]] = count / (len(directed_graph_adjacency_matrix)-1)

  #print(degree_centrality)

  final_keyword_rank = [{'node': node, 'NE_rank': relevance_of_node[node], 'Degree': degree_centrality[node]} for node in vocabulary.keys()]

  #print("-----------")
  final_keyword_rank = sorted(final_keyword_rank, key = lambda i: (i['NE_rank'], i['Degree']), reverse = True)

  final_keywords = [keyword['node'] for keyword in final_keyword_rank]

  return final_keywords

# %%
for tweet in df_query['Preprocessed_Data']:
  tweet_query.extend(tweet)

# %%
keyword_dataset = df_query['tweet'].tolist()
tweet_query_keyword_extractor = keyword_extractor(keyword_dataset)

# %%
tweet_keywords_yake = []
kw_extractor = yake.KeywordExtractor(top=20, stopwords=None)
keywords = kw_extractor.extract_keywords(' '.join(tweet_query))
#keywords = kw_extractor.extract_keywords(' '.join(df_query['tweet'].tolist()))
for kw, v in keywords:
  print("Keyphrase: ",kw, ": score", v)
  for key in kw.split():
    if(key.lower() not in tweet_keywords_yake):
      tweet_keywords_yake.append(key.lower())
# Out:
# Keyphrase:  hijab hijab hijab : score 7.93098251569731e-07
# Keyphrase:  hijab karnataka india : score 1.5697747232782718e-06
# Keyphrase:  muslims hijab started : score 1.6442080038241414e-06
# Keyphrase:  persecution muslims hijab : score 1.8404918384483932e-06
# Keyphrase:  muslims islam muslim : score 1.917070007737707e-06
# Keyphrase:  hijab started india : score 2.0983196417080144e-06
# Keyphrase:  india muslim world : score 2.278438414831808e-06
# Keyphrase:  wear hijab hijab : score 2.381368646009185e-06
# Keyphrase:  started india muslim : score 2.6379691133901388e-06
# Keyphrase:  wear hijab schools : score 2.6722056209623396e-06
# Keyphrase:  muslims hijab hijab : score 2.9907514385679128e-06
# Keyphrase:  hijab hijabisfundamentalright india : score 3.092358441392823e-06
# Keyphrase:  wearing hijab hijab : score 3.2729984537171845e-06
# Keyphrase:  hijab schools colleges : score 3.3492161131480414e-06
# Keyphrase:  islam muslim allah : score 3.642941755792867e-06
# Keyphrase:  hijab abaya muslim : score 4.0776510485973575e-06
# Keyphrase:  muslim women india : score 4.122753760151645e-06
# Keyphrase:  muslims india hijab : score 4.796942600854159e-06
# Keyphrase:  hijab muslims india : score 4.796942600854159e-06
# Keyphrase:  girls wear hijab : score 5.01291274452287e-06

# %%
tweet_keywords_rake = []
rake = Rake()
rake_keywords = rake.apply(' '.join(tweet_query).encode('ascii', 'ignore').decode())
for kw,score in rake_keywords[:20]:
  for key in kw.split():
    if(key.lower() not in tweet_keywords_yake):
      tweet_keywords_rake.append(key.lower())

# %%
tweet_keywords_text_rank = []
TR_keywords = summa_keywords.keywords(' '.join(tweet_query), scores=True)
for kw,score in TR_keywords[:20]:
  for key in kw.split():
    if(key.lower() not in tweet_keywords_text_rank):
      tweet_keywords_text_rank.append(key.lower())
print(tweet_keywords_text_rank)
# Out:
# ['hijabers', 'hijabs', 'hijab', 'hate', 'womens', 'india', 'voice', 'muslim', 'women', 'wearing', 'wears', 'schools', 'indias', 'islamic', 'amp', 'like', 'likes', 'karnatakas', 'protest', 'local', 'dallas', 'muslims', 'girl', 'posts', 'hijabrow', 'educated', 'girls', 'suddenly', 'wanted', 'bans']

# %%
# uncomment later
keybert_model = KeyBERT(model='all-mpnet-base-v2')
keybert_keywords = keybert_model.extract_keywords(' '.join(tweet_query), keyphrase_ngram_range=(1,1), stop_words='english', highlight=False, top_n=20)
tweet_keywords_keybert = list(dict(keybert_keywords).keys())
print(tweet_keywords_keybert)
# Out:
# Downloading:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/10.1k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/571 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/349 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/363 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/13.1k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# ['hijabsexandthecity', 'hijabvalentinedaybanhijabliveorleave', 'hijabcontroversyfaultlinesindiahijabarticle19constitutionguaranteesfreedomspeechexpression', 'hijabrowburqahijab', 'hijabcanadafreedomconvoyblm', 'hijabkashmirelections', 'hijabrowbangladeshdhakaindianmuslimhijab', 'hijabs', 'hijabburqaniqabbangladeshkatnatakabharathinduwomen', 'hijabisfundamentalright', 'hijabuttarakhandelections2022', 'hijabifashion', 'hijabsharia', 'hijabers', 'hijabhijabisourrightmuslimgirls', 'hijabisourrighthijabisourpridehijabisfundamentalrighthijabkarnatakahijabrowislamophobiainindia', 'hijabplothijabkarnatakahijabcontroversyhijabrow', 'hijabkarnatakaindia', 'hijabrowhijab', 'hijab']

# %% [markdown]
# # Helpful Functions

# %%
docs_preprocessed = []

# %%
#Storing file name and data
total_documents = 0
path = '/content/drive/MyDrive/Tweelink_Dataset/Tweelink_Articles_Processed'
for filename in glob(os.path.join(path, '*')):
   with open(os.path.join(os.getcwd(), filename), 'r', encoding = 'utf-8',errors = 'ignore') as f:
     filename = os.path.basename(f.name)
     data = json.load(f)
     d_date = data["Date"]
     if(d_date=="" or d_date=="Date"):
       continue
     format = '%Y-%m-%d'
 
     try:
       d_present_date = datetime.datetime.strptime(d_date, format)
     except:
       continue
 
     if(str(d_present_date.date()) not in [str(u_present_date.date()), str(u_prev_date.date()), str(u_next_date.date())]):
       continue
   
     docs_preprocessed.append({'Name':filename, 'Data':data})
     total_documents+=1
print(total_documents)
# Out:
# 503

# %%
def get_relevant_docs_list_for_base_hashtag(base_hashtag, base_date, docs_preprocessed):
  relevant_docs_list = []
  for doc in docs_preprocessed:
    if doc['Data']['Base Hashtag']==base_hashtag:
      current_date = datetime.datetime.strptime(base_date, format)
      prev_date = current_date - datetime.timedelta(days=1)
      next_date = current_date + datetime.timedelta(days=1)
      #if(doc['Data']['Date'] in [str(prev_date.date()), str(current_date.date()), str(next_date.date())]):
      #  relevant_docs_list.append((doc['Name'], doc['Data']['Location'].lower()))
      if(doc['Data']['Date']==str(str(current_date.date()))):
        relevant_docs_list.append((doc['Name'], doc['Data']['Location'].lower(), 1.0))
      elif(doc['Data']['Date'] in [str(prev_date.date()), str(next_date.date())]):
        relevant_docs_list.append((doc['Name'], doc['Data']['Location'].lower(), 0.5))
  
  # prioritize location
  location_relevant = []
  location_irrelevant = []
  for x in relevant_docs_list:
    if u_location.lower() in x[1]:
      location_relevant.append(x)
    else:
      location_irrelevant.append(x)
  relevant_docs_list = location_relevant + location_irrelevant
  return relevant_docs_list

# %%
def nDCG(base_hashtag, base_date, prediction_list, docs_preprocessed):
  ground_truth = get_relevant_docs_list_for_base_hashtag(base_hashtag, base_date, docs_preprocessed)
  ground_truth_scores = {}
  ground_truth_scores_list = []
  prediction_list_scores = []
  for gt in ground_truth:
    ground_truth_scores[gt[0]] = gt[2]
    ground_truth_scores_list.append(gt[2])
  for x in prediction_list:
    if x[0] in ground_truth_scores.keys():
      prediction_list_scores.append(ground_truth_scores[x[0]])
    else:
      prediction_list_scores.append(0.0)
  
  DCG = prediction_list_scores[0] + sum([prediction_list_scores[i]/np.log2(i+1) for i in range(1,len(prediction_list_scores))])
  ideal_DCG = ground_truth_scores_list[0] + sum([ground_truth_scores_list[i]/np.log2(i+1) for i in range(1,len(ground_truth_scores_list))])
  if ideal_DCG==0:
    return DCG
  return DCG/ideal_DCG

# %%
def precision_at_k(k, base_hashtag, base_date, prediction_list, docs_preprocessed):
  relevant_docs_list = get_relevant_docs_list_for_base_hashtag(base_hashtag, base_date, docs_preprocessed)
  num_of_relevant_results=0
  list_of_rel_doc_names = []
  for x in relevant_docs_list:
    list_of_rel_doc_names.append(x[0])
  for itr in range(k):
    if (prediction_list[itr][0] in list_of_rel_doc_names):
      num_of_relevant_results+=1
  return num_of_relevant_results/k

# %%
def mean_average_precision(max_k, base_hashtag, base_date, relevant_docs, docs_preprocessed):
  average_precision=0
  ctr=0
  relevant_docs_list = get_relevant_docs_list_for_base_hashtag(base_hashtag, base_date, docs_preprocessed)
  print(len(relevant_docs_list))
  for k_val in range(1,len(relevant_docs_list)+1):
    ctr+=1
    if k_val>len(relevant_docs_list):
      break
    precision_at_k_val = precision_at_k(k_val, base_hashtag, base_date, relevant_docs, docs_preprocessed)
    #print('Hashtag: {}   Precision@{}: {}'.format(base_hashtag, k_val, precision_at_k_val))
    average_precision += precision_at_k_val
  return average_precision/ctr

# %%
def recall_at_k(k, base_hashtag, base_date, prediction_list, docs_preprocessed):
  relevant_docs_list = get_relevant_docs_list_for_base_hashtag(base_hashtag, base_date, docs_preprocessed)
  current_num_of_relevant_results=0
  list_of_rel_doc_names = []
  for x in relevant_docs_list:
    list_of_rel_doc_names.append(x[0])
  for itr in range(k):
    if (prediction_list[itr][0] in list_of_rel_doc_names):
      current_num_of_relevant_results+=1
  if(len(relevant_docs_list)==0):
    return 0
  return current_num_of_relevant_results/len(relevant_docs_list)

# %%
def mean_average_recall(max_k, base_hashtag, base_date, relevant_docs, docs_preprocessed):
  average_recall=0
  ctr=0
  relevant_docs_list = get_relevant_docs_list_for_base_hashtag(base_hashtag, base_date, docs_preprocessed)
  print(len(relevant_docs_list))
  for k_val in range(1,len(relevant_docs_list)+1):
    ctr+=1
    if k_val>len(relevant_docs_list):
      break
    recall_at_k_val = recall_at_k(k_val, base_hashtag, base_date, relevant_docs, docs_preprocessed)
    #print('Hashtag: {}   Recall@{}: {}'.format(base_hashtag, k_val, recall_at_k_val))
    average_recall += recall_at_k_val
  return average_recall/ctr

# %% [markdown]
# # TF-IDF Log Normalization

# %%
#Finding vocabulary of our dataset
all_words = []
for doc in docs_preprocessed:
  #print(doc)
  tokens = doc['Data']['Body_processed']
  all_words.extend(tokens)

# finding all distinct words in dataset
vocabulary = list(set(all_words))
word2id = {}
id2word = {}

k = 0
for word in vocabulary: 
  word2id[word] = k
  k += 1
for word in word2id.keys():
  id2word[word2id[word]] = word

# %%
# Word-doc matrix (for storing frequency of each word of vocabulary in document)
inverted_index = {}
total_words_in_doc = []
word_doc_matrix = np.zeros((total_documents, len(vocabulary)), dtype=float)
for i in tqdm(range(len(docs_preprocessed))):
  # total_words_in_doc.append(len(docs_preprocessed[i]['Text']))
  for j, word in enumerate(docs_preprocessed[i]['Data']['Body_processed']):
    if(word not in inverted_index):
        inverted_index[word] = [i]
    else:
      if inverted_index[word][-1]!=i:
        inverted_index[word].append(i)
    word_doc_matrix[i][word2id[word]] += 1
  total_words_in_doc.append(sum(word_doc_matrix[i]))
# Out:
# 100%|██████████| 503/503 [00:01<00:00, 346.66it/s]

# %%
max_freq_word_in_doc = []
for words_in_doc in word_doc_matrix:
  max_freq_word_in_doc.append(np.max(words_in_doc))

# %%
IDF = {}
inverted_index_final = {}
for key in inverted_index:
  inverted_index_final[key] = {"Frequency": len(inverted_index[key]), "doc_id":inverted_index[key]}
  IDF[key] = np.log10(total_documents/(len(inverted_index[key]) +1))

#  sorting according to words
inverted_index_final = dict(sorted(inverted_index_final.items()))

# %%
def Log_Normalization_tf_idf_scheme(word_doc_matrix):
  return np.log10(1+word_doc_matrix)

# %%
Log_Normalization_tf_idf = Log_Normalization_tf_idf_scheme(np.copy(word_doc_matrix))

# %%
for i in tqdm(range(len(vocabulary))):
  IDF_factor = IDF[id2word[i]]
  Log_Normalization_tf_idf[:, i] *= IDF_factor
# Out:
# 100%|██████████| 17544/17544 [00:00<00:00, 158021.04it/s]

# %%
def find_relevant_documents_tfidf_log_normalization(isPlain, docs_preprocessed, processed_query):
  max_list_size = len(get_relevant_docs_list_for_base_hashtag(u_base_hashtag, u_time, docs_preprocessed))
  
  query_frequency = dict()
  for query_token in processed_query:
      if query_token in query_frequency:
          query_frequency[query_token] += 1
      else:
        query_frequency[query_token] = 1

  query_frequency_vector = np.zeros((len(vocabulary),))

  for token in query_frequency.keys():
    if token in vocabulary:
      query_frequency_vector[word2id[token]] = query_frequency[token]

  max_freq_token = query_frequency[max(query_frequency, key=query_frequency.get)]
  total_tokens = len(processed_query)

  f = query_frequency_vector
  query_log_normalization = Log_Normalization_tf_idf_scheme(np.copy(query_frequency_vector))

  for i in tqdm(range(len(vocabulary))):
    IDF_factor = IDF[id2word[i]]
    query_log_normalization[i] *= IDF_factor

  if isPlain:
    query_log_normalization = np.where(query_log_normalization >= np.sort(query_log_normalization)[-10], query_log_normalization, 0)
  
  Log_Normalization_tf_idf_score = np.dot(Log_Normalization_tf_idf, query_log_normalization)
  Log_Normalization_tf_idf_score = {docs_preprocessed[i]['Name']:Log_Normalization_tf_idf_score[i] for i in range(len(Log_Normalization_tf_idf_score))}
  Log_Normalization_relevant_docs = list(sorted(Log_Normalization_tf_idf_score.items(), key=operator.itemgetter(1),reverse=True))[:max_list_size]

  for i in range(len(Log_Normalization_relevant_docs)):
    for j in range(len(docs_preprocessed)):
      if(Log_Normalization_relevant_docs[i][0] == docs_preprocessed[j]['Name']):
        Log_Normalization_relevant_docs[i] = (Log_Normalization_relevant_docs[i][0], Log_Normalization_relevant_docs[i][1], docs_preprocessed[j]['Data']['Date'], docs_preprocessed[j]['Data']['Location'].lower(), docs_preprocessed[j]['Data']['Link'])

  # prioritize location
  location_relevant = []
  location_irrelevant = []
  for x in Log_Normalization_relevant_docs:
    if u_location.lower() in x[3]:
      location_relevant.append(x)
    else:
      location_irrelevant.append(x) 
  Log_Normalization_relevant_docs = location_relevant + location_irrelevant
  return Log_Normalization_relevant_docs

# %% [markdown]
# # Plain Model (TF-IDF Log Normalization)

# %%
relevant_docs_tfidf_log_normalization_plain = find_relevant_documents_tfidf_log_normalization(True, docs_preprocessed, tweet_query)

for rank, doc in enumerate(relevant_docs_tfidf_log_normalization_plain):
  print('Rank: {} Relevant Document: {}'.format(rank+1,doc))

print()

mean_average_precision_hashtag_tfidf_log_normalization_plain = mean_average_precision(20, u_base_hashtag, u_time, relevant_docs_tfidf_log_normalization_plain, docs_preprocessed)
print('Mean Average Precision Plain Model (TF-IDF Log Normalization) : {}'.format(mean_average_precision_hashtag_tfidf_log_normalization_plain))

mean_average_recall_hashtag_tfidf_log_normalization_plain = mean_average_recall(20, u_base_hashtag, u_time, relevant_docs_tfidf_log_normalization_plain, docs_preprocessed)
print('Mean Average Recall Plain Model (TF-IDF Log Normalization) : {}'.format(mean_average_recall_hashtag_tfidf_log_normalization_plain))

nDCG_hashtag_tfidf_log_normalization_plain = nDCG(u_base_hashtag, u_time, relevant_docs_tfidf_log_normalization_plain, docs_preprocessed)
print('nDCG Plain Model (TF-IDF Log Normalization) : {}'.format(nDCG_hashtag_tfidf_log_normalization_plain))
# Out:
# 100%|██████████| 17544/17544 [00:00<00:00, 526565.31it/s]
# Rank: 1 Relevant Document: ('hijab_338.json', 14.880589401746779, '2022-02-20', 'new delhi, india', 'https://news.abplive.com/karnataka/hijab-row-conspiracy-of-bjp-against-muslim-girls-former-k-taka-cm-siddaramaiah-1514360')
# Rank: 2 Relevant Document: ('hijab_285.json', 12.956943796918976, '2022-02-19', 'new delhi, india', 'https://news.abplive.com/karnataka/karnataka-hijab-row-govt-order-dated-feb-5-does-not-ban-hijab-ag-tells-high-court-1514213')
# Rank: 3 Relevant Document: ('hijab_340.json', 12.564654546990996, '2022-02-20', 'hyderabad, india', 'https://www.siasat.com/hijab-row-bangladesh-stands-in-solidarity-with-muslim-women-2279139/')
# Rank: 4 Relevant Document: ('hijab_333.json', 11.769164914462921, '2022-02-20', 'kerala, india', 'https://www.theweek.in/news/entertainment/2022/02/20/hijab-not-a-choice-but-an-obligation-in-islam-says-zaira-wasim.html')
# Rank: 5 Relevant Document: ('hijab_332.json', 11.549907487143098, '2022-02-20', 'new delhi, india', 'https://thewire.in/communalism/karnataka-muslim-women-students-face-case-suspension-for-wearing-hijab-protesting')
# Rank: 6 Relevant Document: ('hijab_283.json', 7.563857454440864, '2022-02-19', 'new delhi, india', 'https://www.newindianexpress.com/nation/2022/feb/19/education-more-important-than-hijab-rss-linked-muslim-rashtriya-manch-to-community-2421449.html')
# Rank: 7 Relevant Document: ('hijab_339.json', 15.397491942600642, '2022-02-20', 'aluva, kerala', 'https://thefederal.com/states/south/tamil-nadu/discrimination-violence-drove-40-dalits-in-tn-village-to-embrace-islam/')
# Rank: 8 Relevant Document: ('hijab_334.json', 14.374245895096097, '2022-02-20', 'massachusetts, united states of america', 'https://scroll.in/article/1017784/why-urbane-educated-muslim-women-are-wearing-the-hijab-in-india')
# Rank: 9 Relevant Document: ('hijab_336.json', 13.065907843823029, '2022-02-20', 'mumbai, maharashtra', 'https://www.indiatoday.in/movies/celebrities/story/hijab-isn-t-a-choice-but-an-obligation-in-islam-says-zaira-wasim-1915351-2022-02-20')
# Rank: 10 Relevant Document: ('hijab_286.json', 11.74377265272258, '2022-02-19', 'bangalore, karnataka', 'https://thefederal.com/states/south/karnataka/uneasy-bjp-central-command-wants-to-wind-down-hijab-row-in-karnataka/')
# Rank: 11 Relevant Document: ('hijab_288.json', 11.262583071074577, '2022-02-19', 'mysore', 'https://thekashmirwalla.com/mysuru-college-cancels-uniform-order-allows-students-to-wear-hijab/')
# Rank: 12 Relevant Document: ('hijab_290.json', 10.845110579848605, '2022-02-19', 'bangalore, karnataka', 'https://english.varthabharati.in/karnataka/hijab-row-feb-5-government-order-doesnt-ban-hijab-insists-ag-in-karnataka-hc')
# Rank: 13 Relevant Document: ('hijab_282.json', 10.68655730408254, '2022-02-19', 'bangalore, karnataka', 'https://www.hindustantimes.com/entertainment/bollywood/zaira-wasim-reacts-to-hijab-row-i-as-a-woman-who-wears-hijab-resent-this-entire-system-101645288361058.html')
# Rank: 14 Relevant Document: ('hijab_331.json', 10.623049477645809, '2022-02-20', 'chennai, tamil nadu', 'https://www.thehindu.com/data/data-hijab-row-why-the-ban-is-a-double-blow-for-muslim-girl-students/article65066546.ece')
# Rank: 15 Relevant Document: ('hijab_281.json', 10.412152007957552, '2022-02-19', 'bangalore, karnataka', 'https://www.thehindu.com/news/national/karnataka/hijab-row-polarises-classrooms-breaks-friendships/article65063188.ece')
# Rank: 16 Relevant Document: ('hijab_287.json', 8.73670014324067, '2022-02-19', 'shivamogga', 'https://www.outlookindia.com/national/karnataka-hijab-row-58-students-suspended-in-shivamogga-for-wearing-headscarves-holding-protest-news-183162')
# Rank: 17 Relevant Document: ('hijab_284.json', 8.621852842126664, '2022-02-19', 'bangalore, karnataka', 'https://www.sundayguardianlive.com/news/hijab-controversy-manufactured-create-anarchy')
# Rank: 18 Relevant Document: ('hijab_335.json', 6.094651785720227, '2022-02-20', 'bangalore, karnataka', 'https://indianexpress.com/article/cities/bangalore/karnataka-bengaluru-live-updates-hijab-row-protests-court-hearing-covid-7765244/')
# Rank: 19 Relevant Document: ('hijab_289.json', 5.771386282935697, '2022-02-19', 'karnataka', 'https://www.freepressjournal.in/india/karnataka-hijab-row-seen-to-be-soft-cm-basavaraj-bommaiturns-heat-on-hijab-protesters')
# Rank: 20 Relevant Document: ('BJPwinningUP_2524.json', 2.6499268527002235, '2022-02-18', 'banaras, up', 'https://theprint.in/opinion/bjps-2ab-factor-thats-missing-from-sp-bsp-congress-in-up-elections/836455/')
#
# 20
# Mean Average Precision Plain Model (TF-IDF Log Normalization) : 0.9974999999999999
# 20
# Mean Average Recall Plain Model (TF-IDF Log Normalization) : 0.5224999999999999
# nDCG Plain Model (TF-IDF Log Normalization) : 0.9153486254637909

# %% [markdown]
# # Model with Keyword Extractor (TF-IDF Log Normalization)

# %%
relevant_docs_tfidf_log_normalization_keyword_extractor = find_relevant_documents_tfidf_log_normalization(False, docs_preprocessed, tweet_query_keyword_extractor[:20])

for rank, doc in enumerate(relevant_docs_tfidf_log_normalization_keyword_extractor):
  print('Rank: {} Relevant Document: {}'.format(rank+1,doc))

print()

mean_average_precision_hashtag_tfidf_log_normalization_keyword_extractor = mean_average_precision(20, u_base_hashtag, u_time, relevant_docs_tfidf_log_normalization_keyword_extractor, docs_preprocessed)
print('Mean Average Precision Keyword Extractor Model (TF-IDF Log Normalization) : {}'.format(mean_average_precision_hashtag_tfidf_log_normalization_keyword_extractor))

mean_average_recall_hashtag_tfidf_log_normalization_keyword_extractor = mean_average_recall(20, u_base_hashtag, u_time, relevant_docs_tfidf_log_normalization_keyword_extractor, docs_preprocessed)
print('Mean Average Recall Keyword Extractor Model (TF-IDF Log Normalization) : {}'.format(mean_average_recall_hashtag_tfidf_log_normalization_keyword_extractor))

nDCG_hashtag_tfidf_log_normalization_keyword_extractor = nDCG(u_base_hashtag, u_time, relevant_docs_tfidf_log_normalization_keyword_extractor, docs_preprocessed)
print('nDCG Keyword Extractor Model (TF-IDF Log Normalization) : {}'.format(nDCG_hashtag_tfidf_log_normalization_keyword_extractor))
# Out:
# 100%|██████████| 17544/17544 [00:00<00:00, 717075.65it/s]
# Rank: 1 Relevant Document: ('hijab_285.json', 2.9941226175587343, '2022-02-19', 'new delhi, india', 'https://news.abplive.com/karnataka/karnataka-hijab-row-govt-order-dated-feb-5-does-not-ban-hijab-ag-tells-high-court-1514213')
# Rank: 2 Relevant Document: ('hijab_338.json', 2.7019188494724653, '2022-02-20', 'new delhi, india', 'https://news.abplive.com/karnataka/hijab-row-conspiracy-of-bjp-against-muslim-girls-former-k-taka-cm-siddaramaiah-1514360')
# Rank: 3 Relevant Document: ('hijab_332.json', 2.2910771169176156, '2022-02-20', 'new delhi, india', 'https://thewire.in/communalism/karnataka-muslim-women-students-face-case-suspension-for-wearing-hijab-protesting')
# Rank: 4 Relevant Document: ('hijab_333.json', 2.0235659069563106, '2022-02-20', 'kerala, india', 'https://www.theweek.in/news/entertainment/2022/02/20/hijab-not-a-choice-but-an-obligation-in-islam-says-zaira-wasim.html')
# Rank: 5 Relevant Document: ('hijab_340.json', 1.7330585812892996, '2022-02-20', 'hyderabad, india', 'https://www.siasat.com/hijab-row-bangladesh-stands-in-solidarity-with-muslim-women-2279139/')
# Rank: 6 Relevant Document: ('hijab_283.json', 1.3918350875234533, '2022-02-19', 'new delhi, india', 'https://www.newindianexpress.com/nation/2022/feb/19/education-more-important-than-hijab-rss-linked-muslim-rashtriya-manch-to-community-2421449.html')
# Rank: 7 Relevant Document: ('hijab_339.json', 3.5050478038525155, '2022-02-20', 'aluva, kerala', 'https://thefederal.com/states/south/tamil-nadu/discrimination-violence-drove-40-dalits-in-tn-village-to-embrace-islam/')
# Rank: 8 Relevant Document: ('hijab_334.json', 3.076808325240185, '2022-02-20', 'massachusetts, united states of america', 'https://scroll.in/article/1017784/why-urbane-educated-muslim-women-are-wearing-the-hijab-in-india')
# Rank: 9 Relevant Document: ('hijab_288.json', 2.604167607871961, '2022-02-19', 'mysore', 'https://thekashmirwalla.com/mysuru-college-cancels-uniform-order-allows-students-to-wear-hijab/')
# Rank: 10 Relevant Document: ('hijab_331.json', 2.545460336717875, '2022-02-20', 'chennai, tamil nadu', 'https://www.thehindu.com/data/data-hijab-row-why-the-ban-is-a-double-blow-for-muslim-girl-students/article65066546.ece')
# Rank: 11 Relevant Document: ('hijab_286.json', 2.506292008669067, '2022-02-19', 'bangalore, karnataka', 'https://thefederal.com/states/south/karnataka/uneasy-bjp-central-command-wants-to-wind-down-hijab-row-in-karnataka/')
# Rank: 12 Relevant Document: ('hijab_336.json', 2.408517562229951, '2022-02-20', 'mumbai, maharashtra', 'https://www.indiatoday.in/movies/celebrities/story/hijab-isn-t-a-choice-but-an-obligation-in-islam-says-zaira-wasim-1915351-2022-02-20')
# Rank: 13 Relevant Document: ('hijab_290.json', 2.3359512267332243, '2022-02-19', 'bangalore, karnataka', 'https://english.varthabharati.in/karnataka/hijab-row-feb-5-government-order-doesnt-ban-hijab-insists-ag-in-karnataka-hc')
# Rank: 14 Relevant Document: ('hijab_281.json', 2.218371973752323, '2022-02-19', 'bangalore, karnataka', 'https://www.thehindu.com/news/national/karnataka/hijab-row-polarises-classrooms-breaks-friendships/article65063188.ece')
# Rank: 15 Relevant Document: ('hijab_282.json', 2.184135142949383, '2022-02-19', 'bangalore, karnataka', 'https://www.hindustantimes.com/entertainment/bollywood/zaira-wasim-reacts-to-hijab-row-i-as-a-woman-who-wears-hijab-resent-this-entire-system-101645288361058.html')
# Rank: 16 Relevant Document: ('hijab_287.json', 1.81193804769452, '2022-02-19', 'shivamogga', 'https://www.outlookindia.com/national/karnataka-hijab-row-58-students-suspended-in-shivamogga-for-wearing-headscarves-holding-protest-news-183162')
# Rank: 17 Relevant Document: ('hijab_284.json', 1.8039512202364008, '2022-02-19', 'bangalore, karnataka', 'https://www.sundayguardianlive.com/news/hijab-controversy-manufactured-create-anarchy')
# Rank: 18 Relevant Document: ('hijab_335.json', 1.0605895506602931, '2022-02-20', 'bangalore, karnataka', 'https://indianexpress.com/article/cities/bangalore/karnataka-bengaluru-live-updates-hijab-row-protests-court-hearing-covid-7765244/')
# Rank: 19 Relevant Document: ('hijab_289.json', 0.9970182099443061, '2022-02-19', 'karnataka', 'https://www.freepressjournal.in/india/karnataka-hijab-row-seen-to-be-soft-cm-basavaraj-bommaiturns-heat-on-hijab-protesters')
# Rank: 20 Relevant Document: ('BJPwinningUP_2527.json', 0.6321120683701362, '2022-02-18', 'lucknow, uttar pradesh', 'https://www.ndtv.com/india-news/up-assembly-election-second-hate-speech-video-by-bjp-mla-emerges-amid-uttar-pradesh-election-2775119')
#
# 20
# Mean Average Precision Keyword Extractor Model (TF-IDF Log Normalization) : 0.9974999999999999
# 20
# Mean Average Recall Keyword Extractor Model (TF-IDF Log Normalization) : 0.5224999999999999
# nDCG Keyword Extractor Model (TF-IDF Log Normalization) : 0.9151952723339857

# %% [markdown]
# # Model with YAKE (TF-IDF Log Normalization)

# %%
relevant_docs_tfidf_log_normalization_yake = find_relevant_documents_tfidf_log_normalization(False, docs_preprocessed, tweet_keywords_yake)

for rank, doc in enumerate(relevant_docs_tfidf_log_normalization_yake):
  print('Rank: {} Relevant Document: {}'.format(rank+1,doc))

print()

mean_average_precision_hashtag_tfidf_log_normalization_yake = mean_average_precision(20, u_base_hashtag, u_time, relevant_docs_tfidf_log_normalization_yake, docs_preprocessed)
print('Mean Average Precision Keyword YAKE Model (TF-IDF Log Normalization) : {}'.format(mean_average_precision_hashtag_tfidf_log_normalization_yake))

mean_average_recall_hashtag_tfidf_log_normalization_yake = mean_average_recall(20, u_base_hashtag, u_time, relevant_docs_tfidf_log_normalization_yake, docs_preprocessed)
print('Mean Average Recall Keyword YAKE Model (TF-IDF Log Normalization) : {}'.format(mean_average_recall_hashtag_tfidf_log_normalization_yake))

nDCG_hashtag_tfidf_log_normalization_yake = nDCG(u_base_hashtag, u_time, relevant_docs_tfidf_log_normalization_yake, docs_preprocessed)
print('nDCG Keyword YAKE Model (TF-IDF Log Normalization) : {}'.format(nDCG_hashtag_tfidf_log_normalization_yake))
# Out:
# 100%|██████████| 17544/17544 [00:00<00:00, 586305.59it/s]
# Rank: 1 Relevant Document: ('hijab_338.json', 2.538062987215159, '2022-02-20', 'new delhi, india', 'https://news.abplive.com/karnataka/hijab-row-conspiracy-of-bjp-against-muslim-girls-former-k-taka-cm-siddaramaiah-1514360')
# Rank: 2 Relevant Document: ('hijab_285.json', 2.4616651403172507, '2022-02-19', 'new delhi, india', 'https://news.abplive.com/karnataka/karnataka-hijab-row-govt-order-dated-feb-5-does-not-ban-hijab-ag-tells-high-court-1514213')
# Rank: 3 Relevant Document: ('hijab_332.json', 2.1876955781223746, '2022-02-20', 'new delhi, india', 'https://thewire.in/communalism/karnataka-muslim-women-students-face-case-suspension-for-wearing-hijab-protesting')
# Rank: 4 Relevant Document: ('hijab_333.json', 1.8773594180462478, '2022-02-20', 'kerala, india', 'https://www.theweek.in/news/entertainment/2022/02/20/hijab-not-a-choice-but-an-obligation-in-islam-says-zaira-wasim.html')
# Rank: 5 Relevant Document: ('hijab_340.json', 1.744314353688507, '2022-02-20', 'hyderabad, india', 'https://www.siasat.com/hijab-row-bangladesh-stands-in-solidarity-with-muslim-women-2279139/')
# Rank: 6 Relevant Document: ('hijab_283.json', 1.2884535487282123, '2022-02-19', 'new delhi, india', 'https://www.newindianexpress.com/nation/2022/feb/19/education-more-important-than-hijab-rss-linked-muslim-rashtriya-manch-to-community-2421449.html')
# Rank: 7 Relevant Document: ('narendramodi_253.json', 0.7190127762377707, '2022-02-19', 'new delhi, india', 'https://www.newindianexpress.com/nation/2022/feb/19/india-is-your-home-pm-narendra-modi-meets-afghan-sikh-hindu-delegation-2421442.html')
# Rank: 8 Relevant Document: ('hijab_339.json', 3.033014152792802, '2022-02-20', 'aluva, kerala', 'https://thefederal.com/states/south/tamil-nadu/discrimination-violence-drove-40-dalits-in-tn-village-to-embrace-islam/')
# Rank: 9 Relevant Document: ('hijab_334.json', 2.80302168917953, '2022-02-20', 'massachusetts, united states of america', 'https://scroll.in/article/1017784/why-urbane-educated-muslim-women-are-wearing-the-hijab-in-india')
# Rank: 10 Relevant Document: ('hijab_288.json', 2.1478987677945294, '2022-02-19', 'mysore', 'https://thekashmirwalla.com/mysuru-college-cancels-uniform-order-allows-students-to-wear-hijab/')
# Rank: 11 Relevant Document: ('hijab_286.json', 2.100359208702171, '2022-02-19', 'bangalore, karnataka', 'https://thefederal.com/states/south/karnataka/uneasy-bjp-central-command-wants-to-wind-down-hijab-row-in-karnataka/')
# Rank: 12 Relevant Document: ('hijab_336.json', 2.073404221150157, '2022-02-20', 'mumbai, maharashtra', 'https://www.indiatoday.in/movies/celebrities/story/hijab-isn-t-a-choice-but-an-obligation-in-islam-says-zaira-wasim-1915351-2022-02-20')
# Rank: 13 Relevant Document: ('hijab_331.json', 1.956087170341687, '2022-02-20', 'chennai, tamil nadu', 'https://www.thehindu.com/data/data-hijab-row-why-the-ban-is-a-double-blow-for-muslim-girl-students/article65066546.ece')
# Rank: 14 Relevant Document: ('hijab_281.json', 1.9491021344115447, '2022-02-19', 'bangalore, karnataka', 'https://www.thehindu.com/news/national/karnataka/hijab-row-polarises-classrooms-breaks-friendships/article65063188.ece')
# Rank: 15 Relevant Document: ('hijab_282.json', 1.8490218018695892, '2022-02-19', 'bangalore, karnataka', 'https://www.hindustantimes.com/entertainment/bollywood/zaira-wasim-reacts-to-hijab-row-i-as-a-woman-who-wears-hijab-resent-this-entire-system-101645288361058.html')
# Rank: 16 Relevant Document: ('hijab_290.json', 1.8367751713226168, '2022-02-19', 'bangalore, karnataka', 'https://english.varthabharati.in/karnataka/hijab-row-feb-5-government-order-doesnt-ban-hijab-insists-ag-in-karnataka-hc')
# Rank: 17 Relevant Document: ('hijab_287.json', 1.7085565088992791, '2022-02-19', 'shivamogga', 'https://www.outlookindia.com/national/karnataka-hijab-row-58-students-suspended-in-shivamogga-for-wearing-headscarves-holding-protest-news-183162')
# Rank: 18 Relevant Document: ('hijab_284.json', 1.6183811080553885, '2022-02-19', 'bangalore, karnataka', 'https://www.sundayguardianlive.com/news/hijab-controversy-manufactured-create-anarchy')
# Rank: 19 Relevant Document: ('hijab_335.json', 1.0605895506602931, '2022-02-20', 'bangalore, karnataka', 'https://indianexpress.com/article/cities/bangalore/karnataka-bengaluru-live-updates-hijab-row-protests-court-hearing-covid-7765244/')
# Rank: 20 Relevant Document: ('hijab_289.json', 0.8936366711490651, '2022-02-19', 'karnataka', 'https://www.freepressjournal.in/india/karnataka-hijab-row-seen-to-be-soft-cm-basavaraj-bommaiturns-heat-on-hijab-protesters')
#
# 20
# Mean Average Precision Keyword YAKE Model (TF-IDF Log Normalization) : 0.9426130171428155
# 20
# Mean Average Recall Keyword YAKE Model (TF-IDF Log Normalization) : 0.48999999999999994
# nDCG Keyword YAKE Model (TF-IDF Log Normalization) : 0.9008610671963094

# %% [markdown]
# # Model with RAKE (TF-IDF Log Normalization)

# %%
relevant_docs_tfidf_log_normalization_rake = find_relevant_documents_tfidf_log_normalization(False, docs_preprocessed, tweet_keywords_rake)

for rank, doc in enumerate(relevant_docs_tfidf_log_normalization_rake):
  print('Rank: {} Relevant Document: {}'.format(rank+1,doc))

print()

mean_average_precision_hashtag_tfidf_log_normalization_rake = mean_average_precision(20, u_base_hashtag, u_time, relevant_docs_tfidf_log_normalization_rake, docs_preprocessed)
print('Mean Average Precision Keyword RAKE Model (TF-IDF Log Normalization) : {}'.format(mean_average_precision_hashtag_tfidf_log_normalization_rake))

mean_average_recall_hashtag_tfidf_log_normalization_rake = mean_average_recall(20, u_base_hashtag, u_time, relevant_docs_tfidf_log_normalization_rake, docs_preprocessed)
print('Mean Average Recall Keyword RAKE Model (TF-IDF Log Normalization) : {}'.format(mean_average_recall_hashtag_tfidf_log_normalization_rake))

nDCG_hashtag_tfidf_log_normalization_rake = nDCG(u_base_hashtag, u_time, relevant_docs_tfidf_log_normalization_rake, docs_preprocessed)
print('nDCG Keyword RAKE Model (TF-IDF Log Normalization) : {}'.format(nDCG_hashtag_tfidf_log_normalization_rake))
# Out:
# 100%|██████████| 17544/17544 [00:00<00:00, 652880.62it/s]
# Rank: 1 Relevant Document: ('PunjabElections2022_2360.json', 2.5634432717860833, '2022-02-20', 'punjab india', 'https://indianexpress.com/elections/assembly-elections-2022-live-updates-punjab-up-uttarakhand-manipur-goa-7783132/')
# Rank: 2 Relevant Document: ('hijab_285.json', 2.2511137483498738, '2022-02-19', 'new delhi, india', 'https://news.abplive.com/karnataka/karnataka-hijab-row-govt-order-dated-feb-5-does-not-ban-hijab-ag-tells-high-court-1514213')
# Rank: 3 Relevant Document: ('PunjabElections2022_2357.json', 1.8314735080460203, '2022-02-20', 'punjab india', 'https://www.tribuneindia.com/news/punjab/punjab-votes-polling-begins-for-117-constituencies-cm-channi-navjot-sidhu-sukhbir-badal-bhagwant-mann-capt-amarinder-in-fray-371448')
# Rank: 4 Relevant Document: ('hijab_338.json', 1.6421673454617007, '2022-02-20', 'new delhi, india', 'https://news.abplive.com/karnataka/hijab-row-conspiracy-of-bjp-against-muslim-girls-former-k-taka-cm-siddaramaiah-1514360')
# Rank: 5 Relevant Document: ('kejriwalvsall_1655.json', 1.5393164314862842, '2022-02-18', 'india', 'https://www.ndtv.com/opinion/it-could-be-kejriwal-vs-adityanath-in-2029-by-sagarika-ghose-2814030')
# Rank: 6 Relevant Document: ('hijab_283.json', 1.4491957154372395, '2022-02-19', 'new delhi, india', 'https://www.newindianexpress.com/nation/2022/feb/19/education-more-important-than-hijab-rss-linked-muslim-rashtriya-manch-to-community-2421449.html')
# Rank: 7 Relevant Document: ('hijab_286.json', 2.8296239281763977, '2022-02-19', 'bangalore, karnataka', 'https://thefederal.com/states/south/karnataka/uneasy-bjp-central-command-wants-to-wind-down-hijab-row-in-karnataka/')
# Rank: 8 Relevant Document: ('hijab_339.json', 2.469207712818906, '2022-02-20', 'aluva, kerala', 'https://thefederal.com/states/south/tamil-nadu/discrimination-violence-drove-40-dalits-in-tn-village-to-embrace-islam/')
# Rank: 9 Relevant Document: ('UkraineRussiaCrisis_319.json', 2.1038721203499247, '2022-02-20', 'new york, united states of america', 'https://www.bloomberg.com/news/articles/2022-04-16/ukraine-update-un-calls-for-unimpeded-access-to-besieged-cities')
# Rank: 10 Relevant Document: ('narendramodi_305.json', 2.0689410950513842, '2022-02-20', 'hardoi, uttar pradesh', 'https://www.indiatoday.in/elections/uttar-pradesh-assembly-polls-2022/story/pm-modi-addresses-rally-up-hardoi-1915489-2022-02-20')
# Rank: 11 Relevant Document: ('hijab_281.json', 1.975563462300111, '2022-02-19', 'bangalore, karnataka', 'https://www.thehindu.com/news/national/karnataka/hijab-row-polarises-classrooms-breaks-friendships/article65063188.ece')
# Rank: 12 Relevant Document: ('zeynep_1627.json', 1.8123481019170269, '2022-02-18', 'united states of america', 'https://www.nytimes.com/2022/03/11/opinion/covid-health-pandemic.html')
# Rank: 13 Relevant Document: ('UltimateDraft_1687.json', 1.796795585483583, '2022-02-19', 'united states of america', 'https://basketballforever.com/2022/02/20/nba-ultimate-draft-highlights-dominique-wilkins-shocks-panel-with-first-pick')
# Rank: 14 Relevant Document: ('BJPwinningUP_2524.json', 1.7479183586479268, '2022-02-18', 'banaras, up', 'https://theprint.in/opinion/bjps-2ab-factor-thats-missing-from-sp-bsp-congress-in-up-elections/836455/')
# Rank: 15 Relevant Document: ('QueenElizabeth_2388.json', 1.6907070304941039, '2022-02-20', 'united kingdom', 'https://www.republicworld.com/world-news/uk-news/uk-prince-andrew-met-mother-queen-elizabeth-ii-every-night-last-week-claims-report-articleshow.html')
# Rank: 16 Relevant Document: ('hijab_290.json', 1.6245896717856785, '2022-02-19', 'bangalore, karnataka', 'https://english.varthabharati.in/karnataka/hijab-row-feb-5-government-order-doesnt-ban-hijab-insists-ag-in-karnataka-hc')
# Rank: 17 Relevant Document: ('UkraineRussiaCrisis_315.json', 1.5289263764692478, '2022-02-20', 'london, united kingdom', 'https://fivebooks.com/best-books/russia-ukraine-serhii-plokhy/')
# Rank: 18 Relevant Document: ('hijab_282.json', 1.5207899894208787, '2022-02-19', 'bangalore, karnataka', 'https://www.hindustantimes.com/entertainment/bollywood/zaira-wasim-reacts-to-hijab-row-i-as-a-woman-who-wears-hijab-resent-this-entire-system-101645288361058.html')
# Rank: 19 Relevant Document: ('UkraineRussiaCrisis_314.json', 1.5135319953576511, '2022-02-20', 'washington, united states of america', 'https://edition.cnn.com/europe/live-news/ukraine-russia-news-02-20-22-intl/index.html')
# Rank: 20 Relevant Document: ('OperationDudula_999.json', 1.4529676238130464, '2022-02-20', 'johannesburg, south africa', 'https://www.dailymaverick.co.za/article/2022-02-21-xenophobia-accused-operation-dudula-returns-to-hillbrow/')
#
# 20
# Mean Average Precision Keyword RAKE Model (TF-IDF Log Normalization) : 0.44678218388938207
# 20
# Mean Average Recall Keyword RAKE Model (TF-IDF Log Normalization) : 0.24
# nDCG Keyword RAKE Model (TF-IDF Log Normalization) : 0.48494695992943054

# %% [markdown]
# # Model with TextRank (TF-IDF Log Normalization)

# %%
relevant_docs_tfidf_log_normalization_text_rank = find_relevant_documents_tfidf_log_normalization(False, docs_preprocessed, tweet_keywords_text_rank)

for rank, doc in enumerate(relevant_docs_tfidf_log_normalization_text_rank):
  print('Rank: {} Relevant Document: {}'.format(rank+1,doc))

print()

mean_average_precision_hashtag_tfidf_log_normalization_text_rank = mean_average_precision(20, u_base_hashtag, u_time, relevant_docs_tfidf_log_normalization_text_rank, docs_preprocessed)
print('Mean Average Precision Keyword TextRank Model (TF-IDF Log Normalization) : {}'.format(mean_average_precision_hashtag_tfidf_log_normalization_text_rank))

mean_average_recall_hashtag_tfidf_log_normalization_text_rank = mean_average_recall(20, u_base_hashtag, u_time, relevant_docs_tfidf_log_normalization_text_rank, docs_preprocessed)
print('Mean Average Recall Keyword TextRank Model (TF-IDF Log Normalization) : {}'.format(mean_average_recall_hashtag_tfidf_log_normalization_text_rank))

nDCG_hashtag_tfidf_log_normalization_text_rank = nDCG(u_base_hashtag, u_time, relevant_docs_tfidf_log_normalization_text_rank, docs_preprocessed)
print('nDCG Keyword TextRank Model (TF-IDF Log Normalization) : {}'.format(nDCG_hashtag_tfidf_log_normalization_text_rank))
# Out:
# 100%|██████████| 17544/17544 [00:00<00:00, 566098.42it/s]
# Rank: 1 Relevant Document: ('hijab_332.json', 2.3603154879642667, '2022-02-20', 'new delhi, india', 'https://thewire.in/communalism/karnataka-muslim-women-students-face-case-suspension-for-wearing-hijab-protesting')
# Rank: 2 Relevant Document: ('hijab_338.json', 2.184875457625381, '2022-02-20', 'new delhi, india', 'https://news.abplive.com/karnataka/hijab-row-conspiracy-of-bjp-against-muslim-girls-former-k-taka-cm-siddaramaiah-1514360')
# Rank: 3 Relevant Document: ('hijab_285.json', 2.0749682054723886, '2022-02-19', 'new delhi, india', 'https://news.abplive.com/karnataka/karnataka-hijab-row-govt-order-dated-feb-5-does-not-ban-hijab-ag-tells-high-court-1514213')
# Rank: 4 Relevant Document: ('hijab_340.json', 1.5279836824240418, '2022-02-20', 'hyderabad, india', 'https://www.siasat.com/hijab-row-bangladesh-stands-in-solidarity-with-muslim-women-2279139/')
# Rank: 5 Relevant Document: ('hijab_283.json', 1.5144582738710881, '2022-02-19', 'new delhi, india', 'https://www.newindianexpress.com/nation/2022/feb/19/education-more-important-than-hijab-rss-linked-muslim-rashtriya-manch-to-community-2421449.html')
# Rank: 6 Relevant Document: ('hijab_333.json', 0.8405354749815046, '2022-02-20', 'kerala, india', 'https://www.theweek.in/news/entertainment/2022/02/20/hijab-not-a-choice-but-an-obligation-in-islam-says-zaira-wasim.html')
# Rank: 7 Relevant Document: ('hijab_334.json', 3.3203359237508834, '2022-02-20', 'massachusetts, united states of america', 'https://scroll.in/article/1017784/why-urbane-educated-muslim-women-are-wearing-the-hijab-in-india')
# Rank: 8 Relevant Document: ('hijab_339.json', 2.5150901377809936, '2022-02-20', 'aluva, kerala', 'https://thefederal.com/states/south/tamil-nadu/discrimination-violence-drove-40-dalits-in-tn-village-to-embrace-islam/')
# Rank: 9 Relevant Document: ('hijab_284.json', 2.2876328207532803, '2022-02-19', 'bangalore, karnataka', 'https://www.sundayguardianlive.com/news/hijab-controversy-manufactured-create-anarchy')
# Rank: 10 Relevant Document: ('hijab_286.json', 2.057329367072633, '2022-02-19', 'bangalore, karnataka', 'https://thefederal.com/states/south/karnataka/uneasy-bjp-central-command-wants-to-wind-down-hijab-row-in-karnataka/')
# Rank: 11 Relevant Document: ('hijab_331.json', 1.8647529572926862, '2022-02-20', 'chennai, tamil nadu', 'https://www.thehindu.com/data/data-hijab-row-why-the-ban-is-a-double-blow-for-muslim-girl-students/article65066546.ece')
# Rank: 12 Relevant Document: ('hijab_281.json', 1.8203845632968365, '2022-02-19', 'bangalore, karnataka', 'https://www.thehindu.com/news/national/karnataka/hijab-row-polarises-classrooms-breaks-friendships/article65063188.ece')
# Rank: 13 Relevant Document: ('hijab_287.json', 1.5942551130206852, '2022-02-19', 'shivamogga', 'https://www.outlookindia.com/national/karnataka-hijab-row-58-students-suspended-in-shivamogga-for-wearing-headscarves-holding-protest-news-183162')
# Rank: 14 Relevant Document: ('hijab_288.json', 1.501950030621117, '2022-02-19', 'mysore', 'https://thekashmirwalla.com/mysuru-college-cancels-uniform-order-allows-students-to-wear-hijab/')
# Rank: 15 Relevant Document: ('hijab_290.json', 1.4664199249289664, '2022-02-19', 'bangalore, karnataka', 'https://english.varthabharati.in/karnataka/hijab-row-feb-5-government-order-doesnt-ban-hijab-insists-ag-in-karnataka-hc')
# Rank: 16 Relevant Document: ('hijab_282.json', 1.4337102567342965, '2022-02-19', 'bangalore, karnataka', 'https://www.hindustantimes.com/entertainment/bollywood/zaira-wasim-reacts-to-hijab-row-i-as-a-woman-who-wears-hijab-resent-this-entire-system-101645288361058.html')
# Rank: 17 Relevant Document: ('BJPwinningUP_2527.json', 1.1699908303523676, '2022-02-18', 'lucknow, uttar pradesh', 'https://www.ndtv.com/india-news/up-assembly-election-second-hate-speech-video-by-bjp-mla-emerges-amid-uttar-pradesh-election-2775119')
# Rank: 18 Relevant Document: ('hijab_289.json', 0.919640871898017, '2022-02-19', 'karnataka', 'https://www.freepressjournal.in/india/karnataka-hijab-row-seen-to-be-soft-cm-basavaraj-bommaiturns-heat-on-hijab-protesters')
# Rank: 19 Relevant Document: ('hijab_336.json', 0.9176828056315668, '2022-02-20', 'mumbai, maharashtra', 'https://www.indiatoday.in/movies/celebrities/story/hijab-isn-t-a-choice-but-an-obligation-in-islam-says-zaira-wasim-1915351-2022-02-20')
# Rank: 20 Relevant Document: ('TrudeauTyranny_1738.json', 0.7749915576594752, '2022-02-20', 'united states of america', 'https://www.mediaite.com/tv/fcking-liars-canadian-convoy-protesters-invade-msnbc-live-report-yelling-freedom-at-top-of-lungs/')
#
# 20
# Mean Average Precision Keyword TextRank Model (TF-IDF Log Normalization) : 0.9866494668042654
# 20
# Mean Average Recall Keyword TextRank Model (TF-IDF Log Normalization) : 0.5125
# nDCG Keyword TextRank Model (TF-IDF Log Normalization) : 0.8723514797065149

# %% [markdown]
# # Model with KeyBERT (TF-IDF Log Normalization)

# %%
relevant_docs_tfidf_log_normalization_keybert = find_relevant_documents_tfidf_log_normalization(False, docs_preprocessed, tweet_keywords_keybert)

for rank, doc in enumerate(relevant_docs_tfidf_log_normalization_keybert):
  print('Rank: {} Relevant Document: {}'.format(rank+1,doc))

print()

mean_average_precision_hashtag_tfidf_log_normalization_keybert = mean_average_precision(20, u_base_hashtag, u_time, relevant_docs_tfidf_log_normalization_keybert, docs_preprocessed)
print('Mean Average Precision Keyword KeyBERT Model (TF-IDF Log Normalization) : {}'.format(mean_average_precision_hashtag_tfidf_log_normalization_keybert))

mean_average_recall_hashtag_tfidf_log_normalization_keybert = mean_average_recall(20, u_base_hashtag, u_time, relevant_docs_tfidf_log_normalization_keybert, docs_preprocessed)
print('Mean Average Recall Keyword KeyBERT Model (TF-IDF Log Normalization) : {}'.format(mean_average_recall_hashtag_tfidf_log_normalization_keybert))

nDCG_hashtag_tfidf_log_normalization_keybert = nDCG(u_base_hashtag, u_time, relevant_docs_tfidf_log_normalization_keybert, docs_preprocessed)
print('nDCG Keyword KeyBERT Model (TF-IDF Log Normalization) : {}'.format(nDCG_hashtag_tfidf_log_normalization_keybert))
# Out:
# 100%|██████████| 17544/17544 [00:00<00:00, 352304.91it/s]
# Rank: 1 Relevant Document: ('hijab_332.json', 0.6735951139771488, '2022-02-20', 'new delhi, india', 'https://thewire.in/communalism/karnataka-muslim-women-students-face-case-suspension-for-wearing-hijab-protesting')
# Rank: 2 Relevant Document: ('hijab_338.json', 0.6380004898290687, '2022-02-20', 'new delhi, india', 'https://news.abplive.com/karnataka/hijab-row-conspiracy-of-bjp-against-muslim-girls-former-k-taka-cm-siddaramaiah-1514360')
# Rank: 3 Relevant Document: ('hijab_285.json', 0.6180908231705812, '2022-02-19', 'new delhi, india', 'https://news.abplive.com/karnataka/karnataka-hijab-row-govt-order-dated-feb-5-does-not-ban-hijab-ag-tells-high-court-1514213')
# Rank: 4 Relevant Document: ('hijab_340.json', 0.6180908231705812, '2022-02-20', 'hyderabad, india', 'https://www.siasat.com/hijab-row-bangladesh-stands-in-solidarity-with-muslim-women-2279139/')
# Rank: 5 Relevant Document: ('hijab_333.json', 0.5964477833270866, '2022-02-20', 'kerala, india', 'https://www.theweek.in/news/entertainment/2022/02/20/hijab-not-a-choice-but-an-obligation-in-islam-says-zaira-wasim.html')
# Rank: 6 Relevant Document: ('hijab_283.json', 0.4456787482754476, '2022-02-19', 'new delhi, india', 'https://www.newindianexpress.com/nation/2022/feb/19/education-more-important-than-hijab-rss-linked-muslim-rashtriya-manch-to-community-2421449.html')
# Rank: 7 Relevant Document: ('hijab_337.json', 0.17241207489513352, '2022-02-20', 'new delhi, india', 'https://www.hindustantimes.com/opinion/hijab-row-restriction-on-clothing-is-political-101645367225790.html')
# Rank: 8 Relevant Document: ('hijab_339.json', 0.7572885604593315, '2022-02-20', 'aluva, kerala', 'https://thefederal.com/states/south/tamil-nadu/discrimination-violence-drove-40-dalits-in-tn-village-to-embrace-islam/')
# Rank: 9 Relevant Document: ('hijab_334.json', 0.7323939965969337, '2022-02-20', 'massachusetts, united states of america', 'https://scroll.in/article/1017784/why-urbane-educated-muslim-women-are-wearing-the-hijab-in-india')
# Rank: 10 Relevant Document: ('hijab_336.json', 0.6735951139771488, '2022-02-20', 'mumbai, maharashtra', 'https://www.indiatoday.in/movies/celebrities/story/hijab-isn-t-a-choice-but-an-obligation-in-islam-says-zaira-wasim-1915351-2022-02-20')
# Rank: 11 Relevant Document: ('hijab_286.json', 0.6564339619741508, '2022-02-19', 'bangalore, karnataka', 'https://thefederal.com/states/south/karnataka/uneasy-bjp-central-command-wants-to-wind-down-hijab-row-in-karnataka/')
# Rank: 12 Relevant Document: ('hijab_282.json', 0.6380004898290687, '2022-02-19', 'bangalore, karnataka', 'https://www.hindustantimes.com/entertainment/bollywood/zaira-wasim-reacts-to-hijab-row-i-as-a-woman-who-wears-hijab-resent-this-entire-system-101645288361058.html')
# Rank: 13 Relevant Document: ('hijab_281.json', 0.6180908231705812, '2022-02-19', 'bangalore, karnataka', 'https://www.thehindu.com/news/national/karnataka/hijab-row-polarises-classrooms-breaks-friendships/article65063188.ece')
# Rank: 14 Relevant Document: ('hijab_287.json', 0.5964477833270866, '2022-02-19', 'shivamogga', 'https://www.outlookindia.com/national/karnataka-hijab-row-58-students-suspended-in-shivamogga-for-wearing-headscarves-holding-protest-news-183162')
# Rank: 15 Relevant Document: ('hijab_288.json', 0.5964477833270866, '2022-02-19', 'mysore', 'https://thekashmirwalla.com/mysuru-college-cancels-uniform-order-allows-students-to-wear-hijab/')
# Rank: 16 Relevant Document: ('hijab_289.json', 0.5727405154919681, '2022-02-19', 'karnataka', 'https://www.freepressjournal.in/india/karnataka-hijab-row-seen-to-be-soft-cm-basavaraj-bommaiturns-heat-on-hijab-protesters')
# Rank: 17 Relevant Document: ('hijab_290.json', 0.5727405154919681, '2022-02-19', 'bangalore, karnataka', 'https://english.varthabharati.in/karnataka/hijab-row-feb-5-government-order-doesnt-ban-hijab-insists-ag-in-karnataka-hc')
# Rank: 18 Relevant Document: ('hijab_331.json', 0.5172362246854005, '2022-02-20', 'chennai, tamil nadu', 'https://www.thehindu.com/data/data-hijab-row-why-the-ban-is-a-double-blow-for-muslim-girl-students/article65066546.ece')
# Rank: 19 Relevant Document: ('hijab_284.json', 0.4840218870790173, '2022-02-19', 'bangalore, karnataka', 'https://www.sundayguardianlive.com/news/hijab-controversy-manufactured-create-anarchy')
# Rank: 20 Relevant Document: ('hijab_335.json', 0.4456787482754476, '2022-02-20', 'bangalore, karnataka', 'https://indianexpress.com/article/cities/bangalore/karnataka-bengaluru-live-updates-hijab-row-protests-court-hearing-covid-7765244/')
#
# 20
# Mean Average Precision Keyword KeyBERT Model (TF-IDF Log Normalization) : 1.0
# 20
# Mean Average Recall Keyword KeyBERT Model (TF-IDF Log Normalization) : 0.5249999999999999
# nDCG Keyword KeyBERT Model (TF-IDF Log Normalization) : 0.9008203286974528

# %% [markdown]
# # All hashtags

# %%
# global_list =[['IPL', '2022-02-25', 'india'], ['IPL', '2022-02-16', 'india'], ['Drishyam2', '2022-02-17', 'india'], ['elections', '2022-02-27', 'imphal'], ['elections', '2022-02-27', 'new delhi'], ['elections', '2022-02-27', 'uttar pradesh'], ['nursesstrike', '2022-02-15', 'australia'], ['Djokovic', '2022-02-15', 'australia'],['hijab', '2022-02-19', 'india'], ['msdstrong', '2022-02-14', 'Florida'], ['ottawaoccupied', '2022-02-14', 'Ottawa'], ['Boycott_ChennaiSuperKings', '2022-02-14', 'chennai'], ['GlanceJio', '2022-02-14', 'New Delhi'], ['ArabicKuthu', '2022-02-14', 'CHENNAI'], ['Djokovic', '2022-02-15', 'AUSTRALIA'], ['Real Madrid', '2022-02-15', 'Madrid'], ['bighit', '2022-02-15', 'ASSAM'], ['Maxwell', '2022-02-15', 'india'], ['mafsau', '2022-02-16', 'australia'], ['channi', '2022-02-16', 'punjab'], ['ayalaan', '2022-02-16', 'tamil nadu'], ['jkbose', '2022-02-16', 'srinagar'], ['happybirthdayjhope', '2022-02-17', 'new delhi'], ['mohsinbaig', '2022-02-17', 'islamabad'],  ['ShivajiJayanti', '2022-02-18', 'maharashtra'], ['OperationDudula', '2022-02-20', 'South Africa'], ['UFCVegas48', '2022-02-20', 'india'], ['FCNPSG', '2022-02-20', 'PARIS'], ['shivamogga', '2022-02-21', 'KARNATAKA'],  ['StayAlive_CHAKHO', '2022-02-22', 'seoul'], ['KaranSinghGrover', '2022-02-22', 'india'], ['NationalMargaritaDay', '2022-02-22', 'United States of America'], ['dontsaygay', '2022-02-22', 'New York'], ['RIPRikyRick', '2022-02-23', 'South Africa'], ['budget2022', '2022-02-23', 'Cape Town'], ['CottonFest2022', '2022-02-23', 'nigeria'], ['NationalChiliDay', '2022-02-24', 'Ohio'], ['stockmarketcrash', '2022-02-24', 'mumbai'], ['BidenisaFailure', '2022-02-24', 'United States of America']]
# print(len(global_list))
# global_list = global_list[:30]
# Out:
# 39

# %%
# def get_keyword_keywordextractor(df_query):
#   keyword_dataset = df_query['tweet'].tolist()
#   tweet_query_keyword_extractor = keyword_extractor(keyword_dataset)
#   return tweet_query_keyword_extractor

# %%
# def get_yake_keywords(tweet_query):
#   tweet_keywords_yake = []
#   kw_extractor = yake.KeywordExtractor(top=20, stopwords=None)
#   keywords = kw_extractor.extract_keywords(' '.join(tweet_query))
#   #keywords = kw_extractor.extract_keywords(' '.join(df_query['tweet'].tolist()))
#   for kw, v in keywords:
#     # print("Keyphrase: ",kw, ": score", v)
#     for key in kw.split():
#       if(key.lower() not in tweet_keywords_yake):
#         tweet_keywords_yake.append(key.lower())
#   return tweet_keywords_yake

# %%
# def get_rake_keywords(tweet_query):
#   tweet_keywords_rake = []
#   rake = Rake()
#   rake_keywords = rake.apply(' '.join(tweet_query).encode('ascii', 'ignore').decode())
#   for kw,score in rake_keywords[:20]:
#     for key in kw.split():
#       if(key.lower() not in tweet_keywords_rake):
#         tweet_keywords_rake.append(key.lower())
#   # print(tweet_keywords_rake)
#   return tweet_keywords_rake

# %%
# def get_text_rank_keywords(tweet_query):
#   tweet_keywords_text_rank = []
#   TR_keywords = summa_keywords.keywords(' '.join(tweet_query), scores=True)
#   for kw,score in TR_keywords[:20]:
#     for key in kw.split():
#       if(key.lower() not in tweet_keywords_text_rank):
#         tweet_keywords_text_rank.append(key.lower())
#   # print(tweet_keywords_text_rank)
#   return tweet_keywords_text_rank

# %%
# def get_keybert_keywords(tweet_query):
#   # uncomment later
#   keybert_model = KeyBERT(model='all-mpnet-base-v2')
#   keybert_keywords = keybert_model.extract_keywords(' '.join(tweet_query), keyphrase_ngram_range=(1,1), stop_words='english', highlight=False, top_n=20)
#   tweet_keywords_keybert = list(dict(keybert_keywords).keys())
#   # print(tweet_keywords_keybert)
#   return tweet_keywords_keybert

# %%
# global_average_mean_average_precision_plain = []
# global_mean_average_recall_plain = []
# global_mean_average_ndcg_plain = []

# global_average_mean_average_precision_keyword_extractor = []
# global_mean_average_recall_keyword_extractor = []
# global_mean_average_ndcg_keyword_exractor = []

# global_average_mean_average_precision_rake = []
# global_mean_average_recall_rake = []
# global_mean_average_ndcg_rake = []

# global_average_mean_average_precision_yake = []
# global_mean_average_recall_yake = []
# global_mean_average_ndcg_yake = []

# global_average_mean_average_precision_text_rank = []
# global_mean_average_recall_text_rank = []
# global_mean_average_ndcg_text_rank = []


# global_average_mean_average_precision_keybert = []
# global_mean_average_recall_keybert = []
# global_mean_average_ndcg_keybert = []

# for iter in tqdm(range(len(global_list))):
#   u_base_hashtag = global_list[iter][0]
#   u_time = global_list[iter][1]
#   u_location = global_list[iter][2]
#   tweet_query = []
#   format = '%Y-%m-%d'
#   u_present_date = datetime.datetime.strptime(u_time, format)
#   u_prev_date = u_present_date - datetime.timedelta(days=1)
#   u_next_date = u_present_date + datetime.timedelta(days=1)
#   df_query = df.loc[df['hashtags'].str.contains(u_base_hashtag) & df['Date_Only'].isin([str(u_present_date.date()), str(u_prev_date.date()), str(u_next_date.date())])]

#   for tweet in df_query['Preprocessed_Data']:
#     tweet_query.extend(tweet)
  
#   tweet_keywords = []
#   kw_extractor = yake.KeywordExtractor(top=20, stopwords=None)
#   keywords = kw_extractor.extract_keywords(' '.join(tweet_query))
#   for kw, v in keywords:
#     #print("Keyphrase: ",kw, ": score", v)
#     for key in kw.split():
#       if(key not in tweet_keywords):
#         tweet_keywords.append(key)
  
#   docs_preprocessed = []

#   total_documents = 0
#   path = '/content/drive/MyDrive/Tweelink_Dataset/Tweelink_Articles_Processed'
#   for filename in glob(os.path.join(path, '*')):
#     with open(os.path.join(os.getcwd(), filename), 'r', encoding = 'utf-8',errors = 'ignore') as f:
#       filename = os.path.basename(f.name)
#       data = json.load(f)
#       d_date = data["Date"]
#       if(d_date=="" or d_date=="Date"):
#         continue
#       format = '%Y-%m-%d'
  
#       d_present_date = datetime.datetime.strptime(d_date, format)
  
#       if(str(d_present_date.date()) not in [str(u_present_date.date()), str(u_prev_date.date()), str(u_next_date.date())]):
#         continue
    
#       docs_preprocessed.append({'Name':filename, 'Data':data})
#       total_documents+=1
  
#   # Plain
#   relevant_articles_list_plain = find_relevant_documents_tfidf_double_normalization(True, docs_preprocessed, tweet_query)
#   mean_average_precision_hashtag_plain = mean_average_precision(20, u_base_hashtag, u_time, relevant_articles_list_plain, docs_preprocessed)
#   global_average_mean_average_precision_plain.append(mean_average_precision_hashtag_plain)
#   mean_average_recall_hashtag_plain = mean_average_recall(20, u_base_hashtag, u_time, relevant_articles_list_plain, docs_preprocessed)
#   global_mean_average_recall_plain.append(mean_average_recall_hashtag_plain)
#   nDCG_hashtag_plain = nDCG(u_base_hashtag, u_time, relevant_articles_list_plain, docs_preprocessed)
#   global_mean_average_ndcg_plain.append(nDCG_hashtag_plain)

#   # keyword extractor
#   tweet_query_keyword_extractor = get_keyword_keywordextractor(df_query)
#   relevant_articles_list_keyword_extractor = find_relevant_documents_tfidf_double_normalization(False, docs_preprocessed, tweet_query_keyword_extractor[:20])
#   mean_average_precision_hashtag_keyword_extractor = mean_average_precision(20, u_base_hashtag, u_time, relevant_articles_list_keyword_extractor, docs_preprocessed)
#   global_average_mean_average_precision_keyword_extractor.append(mean_average_precision_hashtag_keyword_extractor)
#   mean_average_recall_hashtag_keyword_extractor = mean_average_recall(20, u_base_hashtag, u_time, relevant_articles_list_keyword_extractor, docs_preprocessed)
#   global_mean_average_recall_keyword_extractor.append(mean_average_recall_hashtag_keyword_extractor)
#   nDCG_hashtag_keyword_extractor = nDCG(u_base_hashtag, u_time, relevant_articles_list_keyword_extractor, docs_preprocessed)
#   global_mean_average_ndcg_keyword_exractor.append(nDCG_hashtag_keyword_extractor)

#   # Rake
#   tweet_query_rake = get_rake_keywords(tweet_query)
#   relevant_articles_list_rake = find_relevant_documents_tfidf_double_normalization(False, docs_preprocessed, tweet_query_rake)
#   mean_average_precision_hashtag_rake = mean_average_precision(20, u_base_hashtag, u_time, relevant_articles_list_rake, docs_preprocessed)
#   global_average_mean_average_precision_rake.append(mean_average_precision_hashtag_rake)
#   mean_average_recall_hashtag_rake = mean_average_recall(20, u_base_hashtag, u_time, relevant_articles_list_rake, docs_preprocessed)
#   global_mean_average_recall_rake.append(mean_average_recall_hashtag_rake)
#   nDCG_hashtag_rake = nDCG(u_base_hashtag, u_time, relevant_articles_list_rake, docs_preprocessed)
#   global_mean_average_ndcg_rake.append(nDCG_hashtag_rake)


#    # Yake
#   tweet_query_yake = get_yake_keywords(tweet_query)
#   relevant_articles_list_yake = find_relevant_documents_tfidf_double_normalization(False, docs_preprocessed, tweet_query_yake)
#   mean_average_precision_hashtag_yake = mean_average_precision(20, u_base_hashtag, u_time, relevant_articles_list_yake, docs_preprocessed)
#   global_average_mean_average_precision_yake.append(mean_average_precision_hashtag_yake)
#   mean_average_recall_hashtag_yake = mean_average_recall(20, u_base_hashtag, u_time, relevant_articles_list_yake, docs_preprocessed)
#   global_mean_average_recall_yake.append(mean_average_recall_hashtag_yake)
#   nDCG_hashtag_yake = nDCG(u_base_hashtag, u_time, relevant_articles_list_yake, docs_preprocessed)
#   global_mean_average_ndcg_yake.append(nDCG_hashtag_yake)


#   # Text Rank
#   tweet_query_text_rank = get_text_rank_keywords(tweet_query)
#   relevant_articles_list_text_rank = find_relevant_documents_tfidf_double_normalization(False, docs_preprocessed, tweet_query_text_rank)
#   mean_average_precision_hashtag_text_rank = mean_average_precision(20, u_base_hashtag, u_time, relevant_articles_list_text_rank, docs_preprocessed)
#   global_average_mean_average_precision_text_rank.append(mean_average_precision_hashtag_text_rank)
#   mean_average_recall_hashtag_text_rank = mean_average_recall(20, u_base_hashtag, u_time, relevant_articles_list_text_rank, docs_preprocessed)
#   global_mean_average_recall_text_rank.append(mean_average_recall_hashtag_text_rank)
#   nDCG_hashtag_text_rank = nDCG(u_base_hashtag, u_time, relevant_articles_list_text_rank, docs_preprocessed)
#   global_mean_average_ndcg_text_rank.append(nDCG_hashtag_text_rank)


#   # Keybert
#   tweet_query_keybert = get_keybert_keywords(tweet_query)
#   relevant_articles_list_keybert = find_relevant_documents_tfidf_double_normalization(False, docs_preprocessed, tweet_query_keybert)
#   mean_average_precision_hashtag_keybert = mean_average_precision(20, u_base_hashtag, u_time, relevant_articles_list_text_rank, docs_preprocessed)
#   global_average_mean_average_precision_keybert.append(mean_average_precision_hashtag_keybert)
#   mean_average_recall_hashtag_keybert = mean_average_recall(20, u_base_hashtag, u_time, relevant_articles_list_keybert, docs_preprocessed)
#   global_mean_average_recall_keybert.append(mean_average_recall_hashtag_keybert)
#   nDCG_hashtag_keybert = nDCG(u_base_hashtag, u_time, relevant_articles_list_keybert, docs_preprocessed)
#   global_mean_average_ndcg_keybert.append(nDCG_hashtag_keybert)

# %%
# overall_average_mean_average_precision_plain = sum(global_average_mean_average_precision_plain)/len(global_average_mean_average_precision_plain)
# print("Overall precision plain: ", overall_average_mean_average_precision_plain)

# overall_mean_average_recall_plain = sum(global_mean_average_recall_plain)/len(global_mean_average_recall_plain)
# print("Overall recall plain: ",overall_mean_average_recall_plain)

# overall_mean_average_ndcg_plain = sum(global_mean_average_ndcg_plain)/len(global_mean_average_ndcg_plain)
# print("Overall ndcg plain: ",overall_mean_average_ndcg_plain)

# %%
# overall_average_mean_average_precision_keyword_extractor = sum(global_average_mean_average_precision_keyword_extractor)/len(global_average_mean_average_precision_keyword_extractor)
# print("Overall precision keyword_extractor: ",overall_average_mean_average_precision_keyword_extractor)

# overall_mean_average_recall_keyword_extractor = sum(global_mean_average_recall_keyword_extractor)/len(global_mean_average_recall_keyword_extractor)
# print("Overall recall keyword extractor: ",overall_mean_average_recall_keyword_extractor)

# overall_mean_average_ndcg_keyword_extractor = sum(global_mean_average_ndcg_keyword_exractor)/len(global_mean_average_ndcg_keyword_exractor)
# print("Overall ndcg keyword extractor: ",overall_mean_average_ndcg_keyword_extractor)

# %%
# overall_average_mean_average_precision_rake = sum(global_average_mean_average_precision_rake)/len(global_average_mean_average_precision_rake)
# print(overall_average_mean_average_precision_rake)

# overall_mean_average_recall_rake = sum(global_mean_average_recall_rake)/len(global_mean_average_recall_rake)
# print(overall_mean_average_recall_rake)

# overall_mean_average_ndcg_rake = sum(global_mean_average_ndcg_rake)/len(global_mean_average_ndcg_rake)
# print(overall_mean_average_ndcg_rake)

# %%
# overall_average_mean_average_precision_yake = sum(global_average_mean_average_precision_yake)/len(global_average_mean_average_precision_yake)
# print(overall_average_mean_average_precision_yake)

# overall_mean_average_recall_yake = sum(global_mean_average_recall_yake)/len(global_mean_average_recall_yake)
# print(overall_mean_average_recall_yake)

# overall_mean_average_ndcg_yake = sum(global_mean_average_ndcg_yake)/len(global_mean_average_ndcg_yake)
# print(overall_mean_average_ndcg_yake)

# %%
# overall_average_mean_average_precision_text_rank = sum(global_average_mean_average_precision_text_rank)/len(global_average_mean_average_precision_text_rank)
# print(overall_average_mean_average_precision_text_rank)

# overall_mean_average_recall_text_rank = sum(global_mean_average_recall_text_rank)/len(global_mean_average_recall_text_rank)
# print(overall_mean_average_recall_text_rank)

# overall_mean_average_ndcg_text_rank = sum(global_mean_average_ndcg_text_rank)/len(global_mean_average_ndcg_text_rank)
# print(overall_mean_average_ndcg_text_rank)

# %%
# overall_average_mean_average_precision_keybert = sum(global_average_mean_average_precision_keybert)/len(global_average_mean_average_precision_keybert)
# print(overall_average_mean_average_precision_keybert)

# overall_mean_average_recall_keybert = sum(global_mean_average_recall_keybert)/len(global_mean_average_recall_keybert)
# print(overall_mean_average_recall_keybert)

# overall_mean_average_ndcg_keybert = sum(global_mean_average_ndcg_keybert)/len(global_mean_average_ndcg_keybert)
# print(overall_mean_average_ndcg_keybert)
