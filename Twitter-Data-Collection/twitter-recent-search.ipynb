# %%
import requests
import os
import json

# %%
bearer_token = ''

# %%
def create_url():
    tweet_fields = "tweet.fields=lang,author_id"
    # Tweet fields are adjustable.
    # Options include:
    # attachments, author_id, context_annotations,
    # conversation_id, created_at, entities, geo, id,
    # in_reply_to_user_id, lang, non_public_metrics, organic_metrics,
    # possibly_sensitive, promoted_metrics, public_metrics, referenced_tweets,
    # source, text, and withheld
    ids = "ids=1493576285200666625"
    # You can adjust ids to include a single Tweets.
    # Or you can add to up to 100 comma-separated IDs
    url = "https://api.twitter.com/2/tweets?{}&{}".format(ids, tweet_fields)
    return url

# %%
# 'tweet.fields': 'attachments,author_id,context_annotations,conversation_id,created_at,entities,geo,id,in_reply_to_user_id,lang,public_metrics,possibly_sensitive,referenced_tweets,reply_settings,source,text,withheld'
# 'expansions': 'attachments.poll_ids,attachments.media_keys,author_id,entities.mentions.username,geo.place_id,in_reply_to_user_id,referenced_tweets.id,referenced_tweets.id.author_id'
# 'user.fields': 'created_at,description,entities,id,location,name,pinned_tweet_id,profile_image_url,protected,public_metrics,url,username,verified,withheld'
# 'media.fields': 'duration_ms,height,media_key,preview_image_url,type,url,width,public_metrics,alt_text'
# 'place.fields': 'contained_within,country,country_code,full_name,geo,id,name,place_type'
# 'poll.fields': 'duration_minutes,end_datetime,id,options,voting_status'

# %%
def custom_create_url():
  url = "https://api.twitter.com/2/tweets/search/recent"
  params = {
      'query': '#Canada lang:en',
      'start_time': '2022-02-09T00:00:00.000Z',
      'end_time': '2022-02-15T00:00:00.000Z',
      'max_results': 10,
      'sort_order': 'relevancy',
      'tweet.fields': 'attachments,author_id,context_annotations,conversation_id,created_at,entities,geo,id,in_reply_to_user_id,lang,public_metrics,possibly_sensitive,referenced_tweets,reply_settings,source,text,withheld',
      'expansions': 'attachments.poll_ids,attachments.media_keys,author_id,entities.mentions.username,geo.place_id,in_reply_to_user_id,referenced_tweets.id,referenced_tweets.id.author_id',
      'user.fields': 'created_at,description,entities,id,location,name,pinned_tweet_id,profile_image_url,protected,public_metrics,url,username,verified,withheld',
      'media.fields': 'duration_ms,height,media_key,preview_image_url,type,url,width,public_metrics,alt_text',
      'place.fields': 'contained_within,country,country_code,full_name,geo,id,name,place_type',
      'poll.fields': 'duration_minutes,end_datetime,id,options,voting_status'
  }
  return url, params

# %%
def bearer_oauth(r):
    """
    Method required by bearer token authentication.
    """

    r.headers["Authorization"] = f"Bearer {bearer_token}"
    r.headers["User-Agent"] = "v2TweetLookupPython"
    return r

# %%
def connect_to_endpoint(url):
    response = requests.request("GET", url, auth=bearer_oauth)
    print(response.status_code)
    if response.status_code != 200:
        raise Exception(
            "Request returned an error: {} {}".format(
                response.status_code, response.text
            )
        )
    return response.json()

# %%
def custom_connect_to_endpoint(custom_url, params):
    response = requests.request("GET", custom_url, auth=bearer_oauth, params=params)
    print(response.status_code)
    if response.status_code != 200:
        raise Exception(
            "Request returned an error: {} {}".format(
                response.status_code, response.text
            )
        )
    return response.json()

# %%
def main():
    # url = create_url()
    # json_response = connect_to_endpoint(url)
    custom_url, params = custom_create_url()
    custom_json_response = custom_connect_to_endpoint(custom_url, params)
    print(json.dumps(custom_json_response, indent=4, sort_keys=True))

# %%
if __name__ == "__main__":
    main()
# Out:
# 200
# {
#     "data": [
#         {
#             "author_id": "1489734902622920704",
#             "context_annotations": [
#                 {
#                     "domain": {
#                         "description": "A grouping of interests and hobbies entities, like Novelty Food or Destinations",
#                         "id": "66",
#                         "name": "Interests and Hobbies Category"
#                     },
#                     "entity": {
#                         "description": "Marketing",
#                         "id": "857879016971186177",
#                         "name": "Marketing"
#                     }
#                 }
#             ],
#             "conversation_id": "1492284697132556292",
#             "created_at": "2022-02-11T23:49:31.000Z",
#             "entities": {
#                 "hashtags": [
#                     {
#                         "end": 60,
#                         "start": 56,
#                         "tag": "Ads"
#                     },
#                     {
#                         "end": 178,
#                         "start": 168,
#                         "tag": "ecommerce"
#                     },
#                     {
#                         "end": 196,
#                         "start": 179,
#                         "tag": "affiliateprogram"
#                     },
#                     {
#                         "end": 201,
#                         "start": 197,
#                         "tag": "ads"
#                     },
#                     {
#                         "end": 207,
#                         "start": 202,
#                         "tag": "free"
#                     },
#                     {
#                         "end": 212,
#                         "start": 208,
#                         "tag": "USA"
#                     },
#                     {
#                         "end": 216,
#                         "start": 213,
#                         "tag": "uk"
#                     },
#                     {
#                         "end": 224,
#                         "start": 217,
#                         "tag": "canada"
#                     },
#                     {
#                         "end": 231,
#                         "start": 225,
#                         "tag": "sales"
#                     },
#                     {
#                         "end": 237,
#                         "start": 232,
#                         "tag": "sell"
#                     },
#                     {
#                         "end": 252,
#                         "start": 238,
#                         "tag": "marketingtips"
#                     },
#                     {
#                         "end": 263,
#                         "start": 253,
#                         "tag": "Marketing"
#                     }
#                 ],
#                 "urls": [
#                     {
#                         "display_url": "cutt.ly/tO5bep9",
#                         "end": 167,
#                         "expanded_url": "https://cutt.ly/tO5bep9",
#                         "start": 144,
#                         "status": 200,
#                         "unwound_url": "https://warriorplus.com/o2/a/zm437c/0",
#                         "url": "https://t.co/Spjw7AKByh"
#                     }
#                 ]
#             },
#             "id": "1492284697132556292",
#             "lang": "en",
#             "possibly_sensitive": false,
#             "public_metrics": {
#                 "like_count": 68,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 1
#             },
#             "reply_settings": "everyone",
#             "source": "Twitter Web App",
#             "text": "Looking for \nmore sales?\ntargeted customers?\nGuaranteed #Ads Results?\nquickly market your products?\nget your free sales machine using this link\ud83d\udc49https://t.co/Spjw7AKByh\n#ecommerce #affiliateprogram #ads #free #USA #uk #canada #sales #sell #marketingtips #Marketing"
#         },
#         {
#             "attachments": {
#                 "media_keys": [
#                     "3_1493230440152543243"
#                 ]
#             },
#             "author_id": "1427441851620020225",
#             "context_annotations": [
#                 {
#                     "domain": {
#                         "description": "Top level interests and hobbies groupings, like Food or Travel",
#                         "id": "65",
#                         "name": "Interests and Hobbies Vertical"
#                     },
#                     "entity": {
#                         "id": "781974596148793345",
#                         "name": "Business & finance"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "A grouping of interests and hobbies entities, like Novelty Food or Destinations",
#                         "id": "66",
#                         "name": "Interests and Hobbies Category"
#                     },
#                     "entity": {
#                         "description": "Personal finance",
#                         "id": "847888632711061504",
#                         "name": "Personal finance"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "A grouping of interests and hobbies entities, like Novelty Food or Destinations",
#                         "id": "66",
#                         "name": "Interests and Hobbies Category"
#                     },
#                     "entity": {
#                         "description": "Accounting",
#                         "id": "1047535852396507136",
#                         "name": "Accounting"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "Interests, opinions, and behaviors of individuals, groups, or cultures; like Speciality Cooking or Theme Parks",
#                         "id": "67",
#                         "name": "Interests and Hobbies"
#                     },
#                     "entity": {
#                         "description": "Investing",
#                         "id": "847894353708068864",
#                         "name": "Investing"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "Holidays like Christmas or Halloween",
#                         "id": "119",
#                         "name": "Holiday"
#                     },
#                     "entity": {
#                         "description": "this entity for all conversations for valentine's day all year ",
#                         "id": "1201528585682423809",
#                         "name": "Valentine's Day"
#                     }
#                 }
#             ],
#             "conversation_id": "1493230524936171526",
#             "created_at": "2022-02-14T14:27:54.000Z",
#             "entities": {
#                 "hashtags": [
#                     {
#                         "end": 34,
#                         "start": 23,
#                         "tag": "accounting"
#                     },
#                     {
#                         "end": 42,
#                         "start": 35,
#                         "tag": "canada"
#                     },
#                     {
#                         "end": 61,
#                         "start": 43,
#                         "tag": "ValentinesDay2022"
#                     }
#                 ],
#                 "urls": [
#                     {
#                         "display_url": "pic.twitter.com/jaHZLXrDPO",
#                         "end": 85,
#                         "expanded_url": "https://twitter.com/thecybercpa/status/1493230524936171526/photo/1",
#                         "start": 62,
#                         "url": "https://t.co/jaHZLXrDPO"
#                     }
#                 ]
#             },
#             "id": "1493230524936171526",
#             "lang": "en",
#             "possibly_sensitive": false,
#             "public_metrics": {
#                 "like_count": 1,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "reply_settings": "everyone",
#             "source": "Twitter Web App",
#             "text": "Happy Valentine's Day!\n#accounting #canada #ValentinesDay2022 https://t.co/jaHZLXrDPO"
#         },
#         {
#             "attachments": {
#                 "media_keys": [
#                     "16_1493241124395257858"
#                 ]
#             },
#             "author_id": "1325593916880510976",
#             "conversation_id": "1493238238860890115",
#             "created_at": "2022-02-14T15:10:04.000Z",
#             "entities": {
#                 "hashtags": [
#                     {
#                         "end": 240,
#                         "start": 233,
#                         "tag": "Canada"
#                     }
#                 ],
#                 "mentions": [
#                     {
#                         "end": 11,
#                         "id": "15392486",
#                         "start": 0,
#                         "username": "disclosetv"
#                     }
#                 ],
#                 "urls": [
#                     {
#                         "display_url": "pic.twitter.com/91iVVszhpe",
#                         "end": 264,
#                         "expanded_url": "https://twitter.com/Jack4America/status/1493241135061295108/photo/1",
#                         "start": 241,
#                         "url": "https://t.co/91iVVszhpe"
#                     }
#                 ]
#             },
#             "id": "1493241135061295108",
#             "in_reply_to_user_id": "15392486",
#             "lang": "en",
#             "possibly_sensitive": false,
#             "public_metrics": {
#                 "like_count": 5,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 4
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1493238238860890115",
#                     "type": "replied_to"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for iPhone",
#             "text": "@disclosetv Interesting that he didn\u2019t use these powers when  the Black Lives Matter idiots were burning and destroying.  Only gonna use these powers when the non-violent protestors are holding hands and singing the national anthem. #Canada https://t.co/91iVVszhpe"
#         },
#         {
#             "author_id": "1490764734605320193",
#             "context_annotations": [
#                 {
#                     "domain": {
#                         "description": "Named people in the world like Nelson Mandela",
#                         "id": "10",
#                         "name": "Person"
#                     },
#                     "entity": {
#                         "description": "Canadian Prime Minister Justin Trudeau",
#                         "id": "834164697880416257",
#                         "name": "Justin Trudeau"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "Politicians in the world, like Joe Biden",
#                         "id": "35",
#                         "name": "Politician"
#                     },
#                     "entity": {
#                         "description": "Canadian Prime Minister Justin Trudeau",
#                         "id": "834164697880416257",
#                         "name": "Justin Trudeau"
#                     }
#                 }
#             ],
#             "conversation_id": "1493215483235033089",
#             "created_at": "2022-02-14T13:28:08.000Z",
#             "entities": {
#                 "mentions": [
#                     {
#                         "end": 14,
#                         "id": "2200236457",
#                         "start": 3,
#                         "username": "BillNavari"
#                     },
#                     {
#                         "end": 32,
#                         "id": "14260960",
#                         "start": 18,
#                         "username": "JustinTrudeau"
#                     }
#                 ]
#             },
#             "id": "1493215483235033089",
#             "lang": "en",
#             "possibly_sensitive": false,
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 8
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1492890297738612742",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for Android",
#             "text": "RT @BillNavari: . @JustinTrudeau is a freaking Nazi. Literally. He can no longer hide it. The truckers have won. The true north strong and\u2026"
#         },
#         {
#             "attachments": {
#                 "media_keys": [
#                     "3_1492485333807624198"
#                 ]
#             },
#             "author_id": "141193278",
#             "context_annotations": [
#                 {
#                     "domain": {
#                         "id": "6",
#                         "name": "Sports Event"
#                     },
#                     "entity": {
#                         "id": "1237760060828213249",
#                         "name": "Olympics"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "id": "6",
#                         "name": "Sports Event"
#                     },
#                     "entity": {
#                         "id": "1284174028442230785",
#                         "name": "Winter Olympics"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "id": "6",
#                         "name": "Sports Event"
#                     },
#                     "entity": {
#                         "id": "1473298560514883593",
#                         "name": "2022 Beijing Winter Olympics"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "id": "6",
#                         "name": "Sports Event"
#                     },
#                     "entity": {
#                         "id": "1485616674237648898",
#                         "name": "2022 Beijing Winter Olympics - Canada Olympic Team"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "A sports team organization, like Arsenal and the Boston Celtics",
#                         "id": "12",
#                         "name": "Sports Team"
#                     },
#                     "entity": {
#                         "description": "A league for all teams for all sports for the country: Canada",
#                         "id": "765574763888513024",
#                         "name": "Canada"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "A sports team organization, like Arsenal and the Boston Celtics",
#                         "id": "12",
#                         "name": "Sports Team"
#                     },
#                     "entity": {
#                         "id": "1400530139130130433",
#                         "name": "Canada Olympic Team"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "",
#                         "id": "26",
#                         "name": "Sports League"
#                     },
#                     "entity": {
#                         "id": "1473298560514883593",
#                         "name": "2022 Beijing Winter Olympics"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "Franchises which span multiple forms of media like 'Harry Potter'",
#                         "id": "130",
#                         "name": "Multimedia Franchise"
#                     },
#                     "entity": {
#                         "id": "1319391064311033856",
#                         "name": "Hetalia"
#                     }
#                 }
#             ],
#             "conversation_id": "1492485353948999680",
#             "created_at": "2022-02-12T13:06:52.000Z",
#             "entities": {
#                 "hashtags": [
#                     {
#                         "end": 56,
#                         "start": 46,
#                         "tag": "hwscanada"
#                     },
#                     {
#                         "end": 67,
#                         "start": 57,
#                         "tag": "aphcanada"
#                     },
#                     {
#                         "end": 79,
#                         "start": 68,
#                         "tag": "teamcanada"
#                     },
#                     {
#                         "end": 87,
#                         "start": 80,
#                         "tag": "canada"
#                     },
#                     {
#                         "end": 97,
#                         "start": 89,
#                         "tag": "hetalia"
#                     },
#                     {
#                         "end": 113,
#                         "start": 98,
#                         "tag": "winterolympics"
#                     }
#                 ],
#                 "urls": [
#                     {
#                         "display_url": "pic.twitter.com/mRFzvfcOxg",
#                         "end": 137,
#                         "expanded_url": "https://twitter.com/kooroiwwa/status/1492485353948999680/photo/1",
#                         "start": 114,
#                         "url": "https://t.co/mRFzvfcOxg"
#                     }
#                 ]
#             },
#             "id": "1492485353948999680",
#             "lang": "en",
#             "possibly_sensitive": false,
#             "public_metrics": {
#                 "like_count": 18,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 6
#             },
#             "reply_settings": "everyone",
#             "source": "Twitter for iPad",
#             "text": "best costume winter olympics 2022!!\nbest boii #hwscanada #aphcanada #teamcanada #canada \n#hetalia #winterolympics https://t.co/mRFzvfcOxg"
#         },
#         {
#             "attachments": {
#                 "media_keys": [
#                     "7_1493245404263383040"
#                 ]
#             },
#             "author_id": "1245554806132891648",
#             "context_annotations": [
#                 {
#                     "domain": {
#                         "description": "Named people in the world like Nelson Mandela",
#                         "id": "10",
#                         "name": "Person"
#                     },
#                     "entity": {
#                         "description": "Canadian Prime Minister Justin Trudeau",
#                         "id": "834164697880416257",
#                         "name": "Justin Trudeau"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "Politicians in the world, like Joe Biden",
#                         "id": "35",
#                         "name": "Politician"
#                     },
#                     "entity": {
#                         "description": "Canadian Prime Minister Justin Trudeau",
#                         "id": "834164697880416257",
#                         "name": "Justin Trudeau"
#                     }
#                 }
#             ],
#             "conversation_id": "1493245885173551109",
#             "created_at": "2022-02-14T15:28:56.000Z",
#             "entities": {
#                 "annotations": [
#                     {
#                         "end": 43,
#                         "normalized_text": "Justin trudeau",
#                         "probability": 0.7883,
#                         "start": 30,
#                         "type": "Person"
#                     }
#                 ],
#                 "hashtags": [
#                     {
#                         "end": 67,
#                         "start": 48,
#                         "tag": "TruckersForFreedom"
#                     },
#                     {
#                         "end": 75,
#                         "start": 68,
#                         "tag": "Canada"
#                     }
#                 ],
#                 "mentions": [
#                     {
#                         "end": 17,
#                         "id": "920154616582377473",
#                         "start": 3,
#                         "username": "TyagiBharatOM"
#                     }
#                 ],
#                 "urls": [
#                     {
#                         "display_url": "pic.twitter.com/EkyNLaNdWF",
#                         "end": 99,
#                         "expanded_url": "https://twitter.com/TyagiBharatOM/status/1493245449645428736/video/1",
#                         "start": 76,
#                         "url": "https://t.co/EkyNLaNdWF"
#                     }
#                 ]
#             },
#             "id": "1493245885173551109",
#             "lang": "en",
#             "possibly_sensitive": false,
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 2
#             },
#             "referenced_tweets": [
#                 {
#                     "id": "1493245449645428736",
#                     "type": "retweeted"
#                 }
#             ],
#             "reply_settings": "everyone",
#             "source": "Twitter for Android",
#             "text": "RT @TyagiBharatOM: Indians to Justin trudeau \ud83e\udd23\ud83e\udd23\n#TruckersForFreedom #Canada https://t.co/EkyNLaNdWF"
#         },
#         {
#             "attachments": {
#                 "media_keys": [
#                     "7_1492714834579922948"
#                 ]
#             },
#             "author_id": "2891254635",
#             "context_annotations": [
#                 {
#                     "domain": {
#                         "description": "Ongoing News Stories like 'Brexit'",
#                         "id": "123",
#                         "name": "Ongoing News Story"
#                     },
#                     "entity": {
#                         "id": "1220701888179359745",
#                         "name": "COVID-19"
#                     }
#                 }
#             ],
#             "conversation_id": "1492714922408648708",
#             "created_at": "2022-02-13T04:19:05.000Z",
#             "entities": {
#                 "hashtags": [
#                     {
#                         "end": 105,
#                         "start": 87,
#                         "tag": "TrudeauMustResign"
#                     },
#                     {
#                         "end": 125,
#                         "start": 107,
#                         "tag": "EndTheMandatesNow"
#                     },
#                     {
#                         "end": 142,
#                         "start": 127,
#                         "tag": "EndTheMandates"
#                     },
#                     {
#                         "end": 169,
#                         "start": 144,
#                         "tag": "AmbassadorBridgeBlockade"
#                     },
#                     {
#                         "end": 178,
#                         "start": 171,
#                         "tag": "Canada"
#                     },
#                     {
#                         "end": 201,
#                         "start": 182,
#                         "tag": "TruckersForFreedom"
#                     }
#                 ],
#                 "urls": [
#                     {
#                         "display_url": "pic.twitter.com/aLm2UrgYmo",
#                         "end": 225,
#                         "expanded_url": "https://twitter.com/alienmagicman/status/1492714922408648708/video/1",
#                         "start": 202,
#                         "url": "https://t.co/aLm2UrgYmo"
#                     }
#                 ]
#             },
#             "id": "1492714922408648708",
#             "lang": "en",
#             "possibly_sensitive": false,
#             "public_metrics": {
#                 "like_count": 24,
#                 "quote_count": 2,
#                 "reply_count": 2,
#                 "retweet_count": 10
#             },
#             "reply_settings": "everyone",
#             "source": "Twitter for Android",
#             "text": "Replace the word \"barracades\" with \"vaccine mandates\" here and we can fix this mess \ud83c\udde8\ud83c\udde6\n#TrudeauMustResign \n#EndTheMandatesNow \n#EndTheMandates \n#AmbassadorBridgeBlockade \n#Canada \ud83c\udde8\ud83c\udde6 #TruckersForFreedom https://t.co/aLm2UrgYmo"
#         },
#         {
#             "author_id": "52585436",
#             "context_annotations": [
#                 {
#                     "domain": {
#                         "description": "Interests, opinions, and behaviors of individuals, groups, or cultures; like Speciality Cooking or Theme Parks",
#                         "id": "67",
#                         "name": "Interests and Hobbies"
#                     },
#                     "entity": {
#                         "description": "Traffic",
#                         "id": "1037076073719025664",
#                         "name": "Traffic"
#                     }
#                 }
#             ],
#             "conversation_id": "1492500842095824899",
#             "created_at": "2022-02-12T14:08:24.000Z",
#             "entities": {
#                 "hashtags": [
#                     {
#                         "end": 82,
#                         "start": 75,
#                         "tag": "Canada"
#                     },
#                     {
#                         "end": 87,
#                         "start": 83,
#                         "tag": "USA"
#                     }
#                 ]
#             },
#             "geo": {
#                 "place_id": "1d9a5370a355ab0c"
#             },
#             "id": "1492500842095824899",
#             "lang": "en",
#             "possibly_sensitive": false,
#             "public_metrics": {
#                 "like_count": 2863,
#                 "quote_count": 73,
#                 "reply_count": 617,
#                 "retweet_count": 207
#             },
#             "reply_settings": "everyone",
#             "source": "Twitter for iPhone",
#             "text": "Hopefully the Ambassador bridge will soon be cleared and open to traffic.  #Canada #USA \ud83c\udde8\ud83c\udde6\ud83c\uddfa\ud83c\uddf8"
#         },
#         {
#             "attachments": {
#                 "media_keys": [
#                     "7_1493031975904555008"
#                 ]
#             },
#             "author_id": "39311062",
#             "context_annotations": [
#                 {
#                     "domain": {
#                         "description": "Television shows from around the world",
#                         "id": "3",
#                         "name": "TV Shows"
#                     },
#                     "entity": {
#                         "description": "Football action from around the National Football League.",
#                         "id": "10000612773",
#                         "name": "NFL Football"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "Television shows from around the world",
#                         "id": "3",
#                         "name": "TV Shows"
#                     },
#                     "entity": {
#                         "id": "10033407327",
#                         "name": "Futebol NFL"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "Television shows from around the world",
#                         "id": "3",
#                         "name": "TV Shows"
#                     },
#                     "entity": {
#                         "id": "10042261464",
#                         "name": "F\u00fatbol Americano de la NFL"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "id": "6",
#                         "name": "Sports Event"
#                     },
#                     "entity": {
#                         "id": "1464277754489159682",
#                         "name": "NFL Playoffs 2022"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "id": "6",
#                         "name": "Sports Event"
#                     },
#                     "entity": {
#                         "description": "Don't use this event page. Seriously.",
#                         "id": "1479060636936007683",
#                         "name": "Super Bowl LVI"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "id": "6",
#                         "name": "Sports Event"
#                     },
#                     "entity": {
#                         "id": "1488249377437020160",
#                         "name": "Rams at Bengals"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "Types of sports, like soccer and basketball",
#                         "id": "11",
#                         "name": "Sport"
#                     },
#                     "entity": {
#                         "id": "689566306014617600",
#                         "name": "American football"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "",
#                         "id": "26",
#                         "name": "Sports League"
#                     },
#                     "entity": {
#                         "id": "689566314835259392",
#                         "name": "NFL"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "Sports Event specific to American Football, such as Notre Dame vs. Stanford",
#                         "id": "27",
#                         "name": "American Football Game"
#                     },
#                     "entity": {
#                         "description": "Don't use this event page. Seriously.",
#                         "id": "1479060636936007683",
#                         "name": "Super Bowl LVI"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "Sports Event specific to American Football, such as Notre Dame vs. Stanford",
#                         "id": "27",
#                         "name": "American Football Game"
#                     },
#                     "entity": {
#                         "id": "1488249377437020160",
#                         "name": "Rams at Bengals"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "Sports Event specific to NFL Football, such as Buffalo Bills vs. New England Patriots",
#                         "id": "28",
#                         "name": "NFL Football Game"
#                     },
#                     "entity": {
#                         "description": "Don't use this event page. Seriously.",
#                         "id": "1479060636936007683",
#                         "name": "Super Bowl LVI"
#                     }
#                 },
#                 {
#                     "domain": {
#                         "description": "Sports Event specific to NFL Football, such as Buffalo Bills vs. New England Patriots",
#                         "id": "28",
#                         "name": "NFL Football Game"
#                     },
#                     "entity": {
#                         "id": "1488249377437020160",
#                         "name": "Rams at Bengals"
#                     }
#                 }
#             ],
#             "conversation_id": "1493032042728239109",
#             "created_at": "2022-02-14T01:19:12.000Z",
#             "entities": {
#                 "hashtags": [
#                     {
#                         "end": 17,
#                         "start": 10,
#                         "tag": "Canada"
#                     },
#                     {
#                         "end": 149,
#                         "start": 139,
#                         "tag": "SuperBowl"
#                     },
#                     {
#                         "end": 171,
#                         "start": 152,
#                         "tag": "TruckersForFreedom"
#                     },
#                     {
#                         "end": 190,
#                         "start": 172,
#                         "tag": "FreedomConvoy2022"
#                     },
#                     {
#                         "end": 209,
#                         "start": 191,
#                         "tag": "EndTheMandatesNow"
#                     }
#                 ],
#                 "urls": [
#                     {
#                         "display_url": "pic.twitter.com/lOM6nYEiAc",
#                         "end": 233,
#                         "expanded_url": "https://twitter.com/shalom08/status/1493032042728239109/video/1",
#                         "start": 210,
#                         "url": "https://t.co/lOM6nYEiAc"
#                     }
#                 ]
#             },
#             "id": "1493032042728239109",
#             "lang": "en",
#             "possibly_sensitive": false,
#             "public_metrics": {
#                 "like_count": 4665,
#                 "quote_count": 234,
#                 "reply_count": 237,
#                 "retweet_count": 1933
#             },
#             "reply_settings": "everyone",
#             "source": "Twitter for iPhone",
#             "text": "Are we ok #Canada? Are we seriously going back to our regular lives and continue to mask, social distance, etc? After watching this video? #SuperBowl \n\n#TruckersForFreedom #FreedomConvoy2022 #EndTheMandatesNow https://t.co/lOM6nYEiAc"
#         },
#         {
#             "attachments": {
#                 "media_keys": [
#                     "7_1492474390159765510"
#                 ]
#             },
#             "author_id": "1492270474855866368",
#             "conversation_id": "1492474795371474947",
#             "created_at": "2022-02-12T12:24:54.000Z",
#             "entities": {
#                 "hashtags": [
#                     {
#                         "end": 50,
#                         "start": 43,
#                         "tag": "Ottawa"
#                     },
#                     {
#                         "end": 58,
#                         "start": 51,
#                         "tag": "Canada"
#                     }
#                 ],
#                 "mentions": [
#                     {
#                         "end": 117,
#                         "id": "950558867099824128",
#                         "start": 103,
#                         "username": "MarkFriesen08"
#                     },
#                     {
#                         "end": 132,
#                         "id": "2791988124",
#                         "start": 118,
#                         "username": "MaximeBernier"
#                     },
#                     {
#                         "end": 142,
#                         "id": "1166799265806503936",
#                         "start": 133,
#                         "username": "Kirky861"
#                     },
#                     {
#                         "end": 158,
#                         "id": "1365726233586257922",
#                         "start": 143,
#                         "username": "BrianESimpson1"
#                     }
#                 ],
#                 "urls": [
#                     {
#                         "display_url": "pic.twitter.com/EnTyXQYYQ5",
#                         "end": 182,
#                         "expanded_url": "https://twitter.com/FringeViews/status/1492474795371474947/video/1",
#                         "start": 159,
#                         "url": "https://t.co/EnTyXQYYQ5"
#                     }
#                 ]
#             },
#             "id": "1492474795371474947",
#             "lang": "en",
#             "possibly_sensitive": false,
#             "public_metrics": {
#                 "like_count": 2514,
#                 "quote_count": 182,
#                 "reply_count": 108,
#                 "retweet_count": 1360
#             },
#             "reply_settings": "everyone",
#             "source": "Twitter Web App",
#             "text": "Very moving man on the street interview in #Ottawa #Canada - here's what is motivating the protesters.\n@MarkFriesen08 @MaximeBernier @Kirky861 @BrianESimpson1 https://t.co/EnTyXQYYQ5"
#         }
#     ],
#     "includes": {
#         "media": [
#             {
#                 "height": 1080,
#                 "media_key": "3_1493230440152543243",
#                 "type": "photo",
#                 "url": "https://pbs.twimg.com/media/FLkFLIEXsAsOxzd.jpg",
#                 "width": 1080
#             },
#             {
#                 "height": 270,
#                 "media_key": "16_1493241124395257858",
#                 "preview_image_url": "https://pbs.twimg.com/tweet_video_thumb/FLkO5B-VkAIibdl.jpg",
#                 "type": "animated_gif",
#                 "width": 480
#             },
#             {
#                 "height": 1536,
#                 "media_key": "3_1492485333807624198",
#                 "type": "photo",
#                 "url": "https://pbs.twimg.com/media/FLZfgOoVcAY0M6P.jpg",
#                 "width": 1536
#             },
#             {
#                 "duration_ms": 1973,
#                 "height": 360,
#                 "media_key": "7_1493245404263383040",
#                 "preview_image_url": "https://pbs.twimg.com/ext_tw_video_thumb/1493245404263383040/pu/img/KxlqUBA2kJkjH4x-.jpg",
#                 "public_metrics": {
#                     "view_count": 94
#                 },
#                 "type": "video",
#                 "width": 640
#             },
#             {
#                 "duration_ms": 32949,
#                 "height": 1024,
#                 "media_key": "7_1492714834579922948",
#                 "preview_image_url": "https://pbs.twimg.com/ext_tw_video_thumb/1492714834579922948/pu/img/rAGDk1GwRds6SF-U.jpg",
#                 "public_metrics": {
#                     "view_count": 986
#                 },
#                 "type": "video",
#                 "width": 576
#             },
#             {
#                 "duration_ms": 15025,
#                 "height": 1280,
#                 "media_key": "7_1493031975904555008",
#                 "preview_image_url": "https://pbs.twimg.com/ext_tw_video_thumb/1493031975904555008/pu/img/l5KhdeeAyR6-jfmS.jpg",
#                 "public_metrics": {
#                     "view_count": 72222
#                 },
#                 "type": "video",
#                 "width": 720
#             },
#             {
#                 "duration_ms": 118200,
#                 "height": 720,
#                 "media_key": "7_1492474390159765510",
#                 "preview_image_url": "https://pbs.twimg.com/ext_tw_video_thumb/1492474390159765510/pu/img/Wg9CZhk__raV1bcm.jpg",
#                 "public_metrics": {
#                     "view_count": 32367
#                 },
#                 "type": "video",
#                 "width": 1272
#             }
#         ],
#         "places": [
#             {
#                 "country": "Verenigde Staten",
#                 "country_code": "US",
#                 "full_name": "Chicago, IL",
#                 "geo": {
#                     "bbox": [
#                         -87.940033,
#                         41.644102,
#                         -87.523993,
#                         42.0230669
#                     ],
#                     "properties": {},
#                     "type": "Feature"
#                 },
#                 "id": "1d9a5370a355ab0c",
#                 "name": "Chicago",
#                 "place_type": "city"
#             }
#         ],
#         "tweets": [
#             {
#                 "author_id": "15392486",
#                 "context_annotations": [
#                     {
#                         "domain": {
#                             "description": "Named people in the world like Nelson Mandela",
#                             "id": "10",
#                             "name": "Person"
#                         },
#                         "entity": {
#                             "description": "Canadian Prime Minister Justin Trudeau",
#                             "id": "834164697880416257",
#                             "name": "Justin Trudeau"
#                         }
#                     },
#                     {
#                         "domain": {
#                             "description": "Politicians in the world, like Joe Biden",
#                             "id": "35",
#                             "name": "Politician"
#                         },
#                         "entity": {
#                             "description": "Canadian Prime Minister Justin Trudeau",
#                             "id": "834164697880416257",
#                             "name": "Justin Trudeau"
#                         }
#                     }
#                 ],
#                 "conversation_id": "1493238238860890115",
#                 "created_at": "2022-02-14T14:58:33.000Z",
#                 "entities": {
#                     "annotations": [
#                         {
#                             "end": 15,
#                             "normalized_text": "Canada",
#                             "probability": 0.9774,
#                             "start": 10,
#                             "type": "Place"
#                         },
#                         {
#                             "end": 28,
#                             "normalized_text": "PM Trudeau",
#                             "probability": 0.37,
#                             "start": 19,
#                             "type": "Person"
#                         }
#                     ]
#                 },
#                 "id": "1493238238860890115",
#                 "lang": "en",
#                 "possibly_sensitive": false,
#                 "public_metrics": {
#                     "like_count": 20182,
#                     "quote_count": 2124,
#                     "reply_count": 2904,
#                     "retweet_count": 7375
#                 },
#                 "reply_settings": "everyone",
#                 "source": "Twitter Web App",
#                 "text": "JUST IN - Canada's PM Trudeau to invoke never-before-used federal emergency powers in response to nationwide protests, CBC reports."
#             },
#             {
#                 "author_id": "2200236457",
#                 "context_annotations": [
#                     {
#                         "domain": {
#                             "description": "Named people in the world like Nelson Mandela",
#                             "id": "10",
#                             "name": "Person"
#                         },
#                         "entity": {
#                             "description": "Canadian Prime Minister Justin Trudeau",
#                             "id": "834164697880416257",
#                             "name": "Justin Trudeau"
#                         }
#                     },
#                     {
#                         "domain": {
#                             "description": "Politicians in the world, like Joe Biden",
#                             "id": "35",
#                             "name": "Politician"
#                         },
#                         "entity": {
#                             "description": "Canadian Prime Minister Justin Trudeau",
#                             "id": "834164697880416257",
#                             "name": "Justin Trudeau"
#                         }
#                     }
#                 ],
#                 "conversation_id": "1492890297738612742",
#                 "created_at": "2022-02-13T15:55:58.000Z",
#                 "entities": {
#                     "hashtags": [
#                         {
#                             "end": 140,
#                             "start": 133,
#                             "tag": "Canada"
#                         },
#                         {
#                             "end": 184,
#                             "start": 170,
#                             "tag": "TrudeauMustGo"
#                         }
#                     ],
#                     "mentions": [
#                         {
#                             "end": 16,
#                             "id": "14260960",
#                             "start": 2,
#                             "username": "JustinTrudeau"
#                         }
#                     ],
#                     "urls": [
#                         {
#                             "display_url": "twitter.com/MAGAJew2/statu\u2026",
#                             "end": 208,
#                             "expanded_url": "https://twitter.com/MAGAJew2/status/1492865048993316864",
#                             "start": 185,
#                             "url": "https://t.co/5jomE9V9sH"
#                         }
#                     ]
#                 },
#                 "id": "1492890297738612742",
#                 "lang": "en",
#                 "possibly_sensitive": false,
#                 "public_metrics": {
#                     "like_count": 16,
#                     "quote_count": 0,
#                     "reply_count": 4,
#                     "retweet_count": 8
#                 },
#                 "referenced_tweets": [
#                     {
#                         "id": "1492865048993316864",
#                         "type": "quoted"
#                     }
#                 ],
#                 "reply_settings": "everyone",
#                 "source": "Twitter Web App",
#                 "text": ". @JustinTrudeau is a freaking Nazi. Literally. He can no longer hide it. The truckers have won. The true north strong and free, oh, #Canada, we stand on guard for thee!\n#TrudeauMustGo https://t.co/5jomE9V9sH"
#             },
#             {
#                 "attachments": {
#                     "media_keys": [
#                         "7_1493245404263383040"
#                     ]
#                 },
#                 "author_id": "920154616582377473",
#                 "context_annotations": [
#                     {
#                         "domain": {
#                             "description": "Named people in the world like Nelson Mandela",
#                             "id": "10",
#                             "name": "Person"
#                         },
#                         "entity": {
#                             "description": "Canadian Prime Minister Justin Trudeau",
#                             "id": "834164697880416257",
#                             "name": "Justin Trudeau"
#                         }
#                     },
#                     {
#                         "domain": {
#                             "description": "Politicians in the world, like Joe Biden",
#                             "id": "35",
#                             "name": "Politician"
#                         },
#                         "entity": {
#                             "description": "Canadian Prime Minister Justin Trudeau",
#                             "id": "834164697880416257",
#                             "name": "Justin Trudeau"
#                         }
#                     }
#                 ],
#                 "conversation_id": "1493245449645428736",
#                 "created_at": "2022-02-14T15:27:13.000Z",
#                 "entities": {
#                     "annotations": [
#                         {
#                             "end": 24,
#                             "normalized_text": "Justin trudeau",
#                             "probability": 0.7387,
#                             "start": 11,
#                             "type": "Person"
#                         }
#                     ],
#                     "hashtags": [
#                         {
#                             "end": 48,
#                             "start": 29,
#                             "tag": "TruckersForFreedom"
#                         },
#                         {
#                             "end": 56,
# ...
#                 "verified": true
#             },
#             {
#                 "created_at": "2010-05-07T12:08:17.000Z",
#                 "description": "adult only pls \ud83c\udf3d\ud83c\udf3d based in Palembang | my cats is my lyfe | 26y/o ~ DAINAMAITO hws Indo!!",
#                 "entities": {
#                     "url": {
#                         "urls": [
#                             {
#                                 "display_url": "dobe15.tumblr.com",
#                                 "end": 23,
#                                 "expanded_url": "http://dobe15.tumblr.com",
#                                 "start": 0,
#                                 "url": "https://t.co/goWNqdYFMB"
#                             }
#                         ]
#                     }
#                 },
#                 "id": "141193278",
#                 "location": "Palembang, South Sumatra",
#                 "name": "\ud83c\uddee\ud83c\udde9 \ud83c\uddee\ud83c\udde9 Indonesia",
#                 "pinned_tweet_id": "1492831917259239428",
#                 "profile_image_url": "https://pbs.twimg.com/profile_images/892837313926922240/Xuacz4tw_normal.jpg",
#                 "protected": false,
#                 "public_metrics": {
#                     "followers_count": 560,
#                     "following_count": 3032,
#                     "listed_count": 7,
#                     "tweet_count": 14433
#                 },
#                 "url": "https://t.co/goWNqdYFMB",
#                 "username": "kooroiwwa",
#                 "verified": false
#             },
#             {
#                 "created_at": "2020-04-02T03:33:26.000Z",
#                 "description": "Nationalist Proud Hindu",
#                 "id": "1245554806132891648",
#                 "location": "India ",
#                 "name": "Bhanu",
#                 "profile_image_url": "https://pbs.twimg.com/profile_images/1438716596264976385/81qGYUXI_normal.jpg",
#                 "protected": false,
#                 "public_metrics": {
#                     "followers_count": 7,
#                     "following_count": 18,
#                     "listed_count": 0,
#                     "tweet_count": 588
#                 },
#                 "url": "",
#                 "username": "BhanuTyagi99",
#                 "verified": false
#             },
#             {
#                 "created_at": "2017-10-17T05:08:51.000Z",
#                 "description": "Proud Nationalist - Proud BJP Member.                 Big Supporter of @narendramodi",
#                 "entities": {
#                     "description": {
#                         "mentions": [
#                             {
#                                 "end": 84,
#                                 "start": 71,
#                                 "username": "narendramodi"
#                             }
#                         ]
#                     }
#                 },
#                 "id": "920154616582377473",
#                 "location": "India",
#                 "name": "Bharat Tyagi",
#                 "profile_image_url": "https://pbs.twimg.com/profile_images/1469977214959579137/-JDGuqX3_normal.jpg",
#                 "protected": false,
#                 "public_metrics": {
#                     "followers_count": 1460,
#                     "following_count": 207,
#                     "listed_count": 0,
#                     "tweet_count": 4171
#                 },
#                 "url": "",
#                 "username": "TyagiBharatOM",
#                 "verified": false
#             },
#             {
#                 "created_at": "2014-11-24T20:37:46.000Z",
#                 "description": "I am not from here and neither are you. Truth will keep us free \ud83c\udde8\ud83c\udde6 #TrudeauMustGo",
#                 "entities": {
#                     "description": {
#                         "hashtags": [
#                             {
#                                 "end": 81,
#                                 "start": 67,
#                                 "tag": "TrudeauMustGo"
#                             }
#                         ]
#                     },
#                     "url": {
#                         "urls": [
#                             {
#                                 "display_url": "twitter.com/alienmagicman",
#                                 "end": 23,
#                                 "expanded_url": "https://twitter.com/alienmagicman",
#                                 "start": 0,
#                                 "url": "https://t.co/R7I3iuKH99"
#                             }
#                         ]
#                     }
#                 },
#                 "id": "2891254635",
#                 "location": "Planet Earth landing 2014",
#                 "name": "Alien Fringe Minority T \ud83c\udde8\ud83c\udde6\ud83d\udcab\ud83d\udc7d",
#                 "pinned_tweet_id": "1488605474144538627",
#                 "profile_image_url": "https://pbs.twimg.com/profile_images/1480934997502705664/rNmoPImS_normal.jpg",
#                 "protected": false,
#                 "public_metrics": {
#                     "followers_count": 3520,
#                     "following_count": 4216,
#                     "listed_count": 27,
#                     "tweet_count": 53733
#                 },
#                 "url": "https://t.co/R7I3iuKH99",
#                 "username": "alienmagicman",
#                 "verified": false
#             },
#             {
#                 "created_at": "2009-07-01T01:11:46.000Z",
#                 "description": "Citizen-enjoying all the privileges & embracing all the responsibilities that come with this title Former US Ambassador to Canada https://t.co/taEinZbo4l",
#                 "entities": {
#                     "description": {
#                         "urls": [
#                             {
#                                 "display_url": "unchartedllc.com/book/",
#                                 "end": 153,
#                                 "expanded_url": "https://unchartedllc.com/book/",
#                                 "start": 130,
#                                 "url": "https://t.co/taEinZbo4l"
#                             }
#                         ]
#                     },
#                     "url": {
#                         "urls": [
#                             {
#                                 "display_url": "facebook.com/AmbassadorBruc\u2026",
#                                 "end": 23,
#                                 "expanded_url": "https://www.facebook.com/AmbassadorBruceHeyman/",
#                                 "start": 0,
#                                 "url": "https://t.co/jiH0LmoRsk"
#                             }
#                         ]
#                     }
#                 },
#                 "id": "52585436",
#                 "location": "Chicago, IL",
#                 "name": "Bruce A. Heyman",
#                 "pinned_tweet_id": "1490158700941750274",
#                 "profile_image_url": "https://pbs.twimg.com/profile_images/1050023436955865088/E3qFnACk_normal.jpg",
#                 "protected": false,
#                 "public_metrics": {
#                     "followers_count": 29081,
#                     "following_count": 3432,
#                     "listed_count": 287,
#                     "tweet_count": 24342
#                 },
#                 "url": "https://t.co/jiH0LmoRsk",
#                 "username": "BruceAHeyman",
#                 "verified": true
#             },
#             {
#                 "created_at": "2009-05-11T18:43:27.000Z",
#                 "description": "#Christian | #Gay | #Torontonian Philippians 4:13",
#                 "entities": {
#                     "description": {
#                         "hashtags": [
#                             {
#                                 "end": 10,
#                                 "start": 0,
#                                 "tag": "Christian"
#                             },
#                             {
#                                 "end": 17,
#                                 "start": 13,
#                                 "tag": "Gay"
#                             },
#                             {
#                                 "end": 32,
#                                 "start": 20,
#                                 "tag": "Torontonian"
#                             }
#                         ]
#                     }
#                 },
#                 "id": "39311062",
#                 "location": "Toronto, Ontario",
#                 "name": "Honk Honk \ud83d\ude9b\ud83d\ude9a\ud83d\udefb!!!",
#                 "pinned_tweet_id": "699711667094102016",
#                 "profile_image_url": "https://pbs.twimg.com/profile_images/1468389513756135427/NvgYh9FL_normal.jpg",
#                 "protected": false,
#                 "public_metrics": {
#                     "followers_count": 2413,
#                     "following_count": 2172,
#                     "listed_count": 22,
#                     "tweet_count": 132020
#                 },
#                 "url": "",
#                 "username": "shalom08",
#                 "verified": false
#             },
#             {
#                 "created_at": "2022-02-11T22:53:30.000Z",
#                 "description": "Who me?",
#                 "id": "1492270474855866368",
#                 "name": "Mrs. Smith",
#                 "profile_image_url": "https://pbs.twimg.com/profile_images/1492271173127884809/kco65DZH_normal.jpg",
#                 "protected": false,
#                 "public_metrics": {
#                     "followers_count": 71,
#                     "following_count": 122,
#                     "listed_count": 0,
#                     "tweet_count": 121
#                 },
#                 "url": "",
#                 "username": "FringeViews",
#                 "verified": false
#             },
#             {
#                 "created_at": "2018-01-09T02:44:29.000Z",
#                 "description": "\ud83c\udde8\ud83c\udde6#UnityisStrength\ud83c\udde8\ud83c\udde6Advocate for Canadian Sovereignty\ud83c\udde8\ud83c\udde6Canadian Nationalist & Patriot\ud83c\udde8\ud83c\udde6 @MaximeBernier #PPC #Canada1st",
#                 "entities": {
#                     "description": {
#                         "hashtags": [
#                             {
#                                 "end": 18,
#                                 "start": 2,
#                                 "tag": "UnityisStrength"
#                             },
#                             {
#                                 "end": 107,
#                                 "start": 103,
#                                 "tag": "PPC"
#                             },
#                             {
#                                 "end": 118,
#                                 "start": 108,
#                                 "tag": "Canada1st"
#                             }
#                         ],
#                         "mentions": [
#                             {
#                                 "end": 102,
#                                 "start": 88,
#                                 "username": "MaximeBernier"
#                             }
#                         ]
#                     },
#                     "url": {
#                         "urls": [
#                             {
#                                 "display_url": "FFCS.info",
#                                 "end": 23,
#                                 "expanded_url": "http://www.FFCS.info",
#                                 "start": 0,
#                                 "url": "https://t.co/Gy7KvJiFNt"
#                             }
#                         ]
#                     }
#                 },
#                 "id": "950558867099824128",
#                 "location": "Saskatoon, Saskatchewan",
#                 "name": "\ud83c\udde8\ud83c\udde6MarkFriesen\ud83c\udde8\ud83c\udde6 Patriot & Proud Nationalist",
#                 "pinned_tweet_id": "1492641985210970114",
#                 "profile_image_url": "https://pbs.twimg.com/profile_images/1487571863207395332/Lp2hVeJT_normal.jpg",
#                 "protected": false,
#                 "public_metrics": {
#                     "followers_count": 33285,
#                     "following_count": 10555,
#                     "listed_count": 104,
#                     "tweet_count": 35600
#                 },
#                 "url": "https://t.co/Gy7KvJiFNt",
#                 "username": "MarkFriesen08",
#                 "verified": false
#             },
#             {
#                 "created_at": "2014-09-05T14:06:45.000Z",
#                 "description": "Chef du @ppopulaireca / Leader of the @peoplespca",
#                 "entities": {
#                     "description": {
#                         "mentions": [
#                             {
#                                 "end": 21,
#                                 "start": 8,
#                                 "username": "ppopulaireca"
#                             },
#                             {
#                                 "end": 49,
#                                 "start": 38,
#                                 "username": "peoplespca"
#                             }
#                         ]
#                     },
#                     "url": {
#                         "urls": [
#                             {
#                                 "display_url": "linktr.ee/maximebernier",
#                                 "end": 23,
#                                 "expanded_url": "https://linktr.ee/maximebernier",
#                                 "start": 0,
#                                 "url": "https://t.co/eyKmbob1U3"
#                             }
#                         ]
#                     }
#                 },
#                 "id": "2791988124",
#                 "location": "CANADA",
#                 "name": "Maxime Bernier",
#                 "profile_image_url": "https://pbs.twimg.com/profile_images/798544589019713537/4i1kOcoj_normal.jpg",
#                 "protected": false,
#                 "public_metrics": {
#                     "followers_count": 181483,
#                     "following_count": 6537,
#                     "listed_count": 932,
#                     "tweet_count": 27956
#                 },
#                 "url": "https://t.co/eyKmbob1U3",
#                 "username": "MaximeBernier",
#                 "verified": true
#             },
#             {
#                 "created_at": "2019-08-28T19:47:10.000Z",
#                 "description": "",
#                 "id": "1166799265806503936",
#                 "name": "Kirky86",
#                 "pinned_tweet_id": "1472109728788537348",
#                 "profile_image_url": "https://pbs.twimg.com/profile_images/1352315630356226048/Y3I5kKi7_normal.jpg",
#                 "protected": false,
#                 "public_metrics": {
#                     "followers_count": 3795,
#                     "following_count": 657,
#                     "listed_count": 31,
#                     "tweet_count": 125139
#                 },
#                 "url": "",
#                 "username": "Kirky861",
#                 "verified": false
#             },
#             {
#                 "created_at": "2021-02-27T18:12:10.000Z",
#                 "description": "Real eyes, realize real lies. The greatest crash in world history will happen in 2022 - 2023. Here to learn, here to watch. Max and the PPC are the future",
#                 "id": "1365726233586257922",
#                 "name": "Brian E Simpson",
#                 "pinned_tweet_id": "1492930416877228043",
#                 "profile_image_url": "https://pbs.twimg.com/profile_images/1383889819760091147/zykLVdeg_normal.jpg",
#                 "protected": false,
#                 "public_metrics": {
#                     "followers_count": 1657,
#                     "following_count": 1716,
#                     "listed_count": 4,
#                     "tweet_count": 5233
#                 },
#                 "url": "",
#                 "username": "BrianESimpson1",
#                 "verified": false
#             }
#         ]
#     },
#     "meta": {
#         "newest_id": "1493245885173551109",
#         "next_token": "b26v89c19zqg8o3fpe75q9joga4ikp9jf0rj7t4q1vibh",
#         "oldest_id": "1492284697132556292",
#         "result_count": 10
#     }
# }
