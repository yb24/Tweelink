# %%
# code credits: https://github.com/twitterdev/Twitter-API-v2-sample-code/blob/main/Sampled-Stream/sampled-stream.py

# %%
import requests
import os
import json

# %%
bearer_token = ''

# %%
def create_url():
    return "https://api.twitter.com/2/tweets/sample/stream"

# %%
def bearer_oauth(r):
    """
    Method required by bearer token authentication.
    """

    r.headers["Authorization"] = f"Bearer {bearer_token}"
    r.headers["User-Agent"] = "v2SampledStreamPython"
    return r

# %%
def connect_to_endpoint(url):
    response = requests.request("GET", url, auth=bearer_oauth, stream=True)
    print(response.status_code)
    for response_line in response.iter_lines():
        if response_line:
            json_response = json.loads(response_line)
            print(json.dumps(json_response, indent=4, sort_keys=True))
    if response.status_code != 200:
        raise Exception(
            "Request returned an error: {} {}".format(
                response.status_code, response.text
            )
        )

# %%
def main():
    url = create_url()
    timeout = 0
    while True:
        connect_to_endpoint(url)
        timeout += 1

# %%
if __name__ == "__main__":
    main()
# Out:
# Streaming output truncated to the last 5000 lines.
#     }
# }
# {
#     "data": {
#         "id": "1493638181836980225",
#         "text": "RT @Msuppasitstudio: \u0e17\u0e38\u0e01\u0e04\u0e19\u0e44\u0e07 \u0e27\u0e31\u0e22\u0e23\u0e38\u0e48\u0e19 90 \u0e21\u0e32\u0e40\u0e1b\u0e47\u0e19\u0e41\u0e02\u0e01\u0e43\u0e19\u0e04\u0e2d\u0e19 \u0e2d\u0e34\u0e2d\u0e34\ud83d\ude0e\n\n#MewSuppasit \n@MSuppasit \n#\u0e21\u0e34\u0e27\u0e28\u0e38\u0e20\u0e28\u0e34\u0e29\u0e0f\u0e4c \n#Before430\n#Made42Ticket"
#     }
# }
# {
#     "data": {
#         "id": "1493638186031099908",
#         "text": "@_CocaineMulaBih She scared somebody gone take her spot! You can literally look at her whole body language when nene talk she is madddddddd"
#     }
# }
# {
#     "data": {
#         "id": "1493638186010087424",
#         "text": "RT @RachelR22610982: #ye\u015filyurt #karabaglar #g\u00f6ztepe \u015fey saklamadanhayat\u0131m\u0131 https://t.co/lrxaDKZB0a"
#     }
# }
# {
#     "data": {
#         "id": "1493638186014326787",
#         "text": "RT @nayibbukele: Are these the people who like to give lessons to other countries about democracy and freedom?\n\nThis is one of the top rank\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1493638186030960640",
#         "text": "RT @WeraReynoso: Telemundo, un medio internacional, acaba de confirmar que no existe domicilio fiscal de la supuesta empresa en donde traba\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1493638186009968641",
#         "text": "\u56f3\u66f8\u9928\u30a8\u30b0\u30be\u3060\u3068\u601d\u3063\u3066\u305f\u304b\u3089\u5c1a\u306e\u3053\u3068\u30b7\u30e7\u30c3\u30af\u3060\u3063\u305f\u3000\u3042\u3001\u305d\u3046\u3044\u3046\u30c7\u30c3\u30ad\u3060\u3063\u305f\u3093\u3060\u3001\u307f\u305f\u3044\u306a\u3000\u3000\u3044\u3084\u7d61\u3081\u624b\u3063\u3066\u3044\u3046\u610f\u5473\u3067\u306f\u9762\u767d\u3044\u30c7\u30c3\u30ad\u3060\u3063\u305f\u3093\u3060\u3051\u3069\u3001\u5927\u9006\u8ee2\u30af\u30a4\u30ba\u3092\u305d\u3046\u3044\u3046\u4f7f\u3044\u304b\u305f\u3055\u308c\u308b\u3068\u51b7\u3081\u308b\u3063\u3066\u3044\u3046\u304b......"
#     }
# }
# {
#     "data": {
#         "id": "1493638181845352448",
#         "text": "Labor is prior to, and independent of, capital. Capital is only the fruit of labor, and could never have existed if labor had not first existed. Labor is the superior of capital, and deserves much the higher consideration.\nAbraham Lincoln"
#     }
# }
# {
#     "data": {
#         "id": "1493638181816004608",
#         "text": "RT @ENHYPEN_members: #ENHYPEN #JUNGWON #\ubc1c\ub80c\ud0c0\uc778\ub370\uc774\n\n\uc5d4\uc9c4\uc5ec\ub7ec\ubd84~ \uc624\ub298 \ubc1c\ub80c\ud0c0\uc778\ub370\uc774\ub124\uc694!!\n\ubc8c\uc368 \uace7 \uc800\ub141\uc2dc\uac04\uc774\uc9c0\ub9cc \ub0a8\uc740 \ud558\ub8e8 \ub2ec\ub2ec\ud558\uac8c \ubcf4\ub0b4\uc138\uc694~\u2661\u2661 https://t.co/4DoXe8aHUz"
#     }
# }
# {
#     "data": {
#         "id": "1493638186026901513",
#         "text": "@MihrThakar Upusi yako"
#     }
# }
# {
#     "data": {
#         "id": "1493638186031063040",
#         "text": "RT @JarjisPreeti: #izmir #gaziemir seninle, https://t.co/G71L5uXf0v"
#     }
# }
# {
#     "data": {
#         "id": "1493638186018668546",
#         "text": "AV\u306e\u30b5\u30f3\u30d7\u30eb\u3060\u3051\u3067\u304b\u306a\u308a\u629c\u3051\u308b\u306e\u6700\u8fd1\u591a\u304f\u3066\u6357\u308b"
#     }
# }
# {
#     "data": {
#         "id": "1493638186031251459",
#         "text": "RT @kaenakeng: \u0e0a\u0e48\u0e27\u0e07\u0e19\u0e35\u0e49\u0e40\u0e1b\u0e47\u0e19\u0e40\u0e19\u0e37\u0e2d\u0e22 \u0e46 \u0e22\u0e31\u0e07\u0e44\u0e07\u0e44\u0e21\u0e48\u0e23\u0e39\u0e49 \u0e44\u0e21\u0e48\u0e04\u0e48\u0e2d\u0e22\u0e21\u0e35\u0e04\u0e27\u0e32\u0e21\u0e2a\u0e38\u0e02\u0e01\u0e31\u0e1a\u0e2d\u0e30\u0e44\u0e23\u0e21\u0e32\u0e01\u0e40\u0e17\u0e48\u0e32\u0e44\u0e2b\u0e23\u0e48 \u0e2d\u0e22\u0e39\u0e48\u0e14\u0e35 \u0e46 \u0e01\u0e47\u0e21\u0e35\u0e04\u0e33\u0e16\u0e32\u0e21\u0e01\u0e31\u0e1a\u0e15\u0e31\u0e27\u0e40\u0e2d\u0e07\u0e02\u0e36\u0e49\u0e19\u0e21\u0e32\u0e27\u0e48\u0e32\u0e41\u0e17\u0e49\u0e08\u0e23\u0e34\u0e07\u0e41\u0e25\u0e49\u0e27 \u2018\u0e04\u0e27\u0e32\u0e21\u0e2a\u0e38\u0e02\u0e04\u0e37\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1493638181832790017",
#         "text": "RT @PawanismNetwork: Human Tsunami Arriving on Feb 25th \ud83d\udd25\ud83d\udd25\n\n#BheemlaNayakOn25thFeb https://t.co/bHTBnhazbc"
#     }
# }
# {
#     "data": {
#         "id": "1493638186031108108",
#         "text": "@CombatSportPhys @JackAChew I'd pay to see those words changed"
#     }
# }
# {
#     "data": {
#         "id": "1493638186014281729",
#         "text": "@VitoLops Inversione"
#     }
# }
# {
#     "data": {
#         "id": "1493638186014236674",
#         "text": "RT @saberucv: Repositorio Institucional de la Universidad Central de Venezuela Saber UCV: Acceso abierto a m\u00e1s de 40 mil documentos acad\u00e9mi\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1493638186043854848",
#         "text": "\u0e19\u0e48\u0e32\u0e23\u0e31\u0e01\u0e21\u0e32\u0e01\u0e04\u0e49\u0e32\u0e1a\u0e04\u0e19\u0e19\u0e35\u0e49\ud83e\udd0f\ud83c\udffb \u0e41\u0e1a\u0e1a\u0e07\u0e38\u0e49\u0e21\u0e46 #suo\u0287soq"
#     }
# }
# {
#     "data": {
#         "id": "1493638186039332865",
#         "text": "RT @meltyorheart: https://t.co/V8U9hBLowv"
#     }
# }
# {
#     "data": {
#         "id": "1493638186026868740",
#         "text": "RT @Stephan62638793: #bornova #alsancak ile bilgin olsak https://t.co/Hzkxfnv74Z"
#     }
# }
# {
#     "data": {
#         "id": "1493638181824217088",
#         "text": "RT @anilsaidso: Chrystia Freeland wrote this book in 2012. \n\nHere are some snippets. Strap in, folks! https://t.co/RvC2MubOTC"
#     }
# }
# {
#     "data": {
#         "id": "1493638186039316487",
#         "text": "RT @WealthyTree: Are you being CRUSHED by debt?\n\nAny debt payment from $500+/mo of debt can really be dragging down your net worth\u2019s growth\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1493638190216921092",
#         "text": "@3eyeswiiide @TheRealJQB @LateRoundCorner Everyone refuses to acknowledge this but i also dont like giving excuses. They made the most of the circumstances that were given."
#     }
# }
# {
#     "data": {
#         "id": "1493638190208626689",
#         "text": "RT @Le360ar: \u0643\u0627\u0631\u064a\u0643\u0627\u062a\u064a\u0631. \u0634\u0646\u0642\u0631\u064a\u062d\u0629 \"\u0627\u0644\u062d\u0627\u0643\u0645 \u0627\u0644\u0641\u0639\u0644\u064a\" \u0644\u0644\u062c\u0632\u0627\u0626\u0631 \u064a\u062e\u062a\u0641\u064a \u0639\u0646 \u0627\u0644\u0623\u0646\u0638\u0627\u0631\n\n\u0645\u0646 \u0637\u0631\u0641 : @GueddarKhalid https://t.co/F0EYJlgTmF"
#     }
# }
# {
#     "data": {
#         "id": "1493638190237839362",
#         "text": "@AgusAmicone ok"
#     }
# }
# {
#     "data": {
#         "id": "1493638190229426181",
#         "text": "RT @jda1BekUDve1ccx: \u4e00\u8272\u6b63\u6625\u6c0f\u304c\u300c\u6551\u6025\u8eca\u306e\u30b5\u30a4\u30ec\u30f3\u97f3\u304c\u3046\u308b\u3055\u3044\u3068\u304a\u56f0\u308a\u306e\u65b9\u3002\u826f\u3044\u65b9\u6cd5\u3092\u304a\u6559\u3048\u3057\u307e\u3057\u3087\u3046\u3002\u8033\u3092\u585e\u3052\u3002\u305d\u308c\u3067\u52a9\u304b\u308b\u547d\u304c\u3042\u308b\u300d\u3002\u3044\u3064\u3082\u7684\u78ba\u306a\u3054\u6307\u6458\u3001\u8cdb\u540c\u3057\u611f\u5fc3\u3057\u3066\u304a\u308a\u307e\u3059\u3002"
#     }
# }
# {
#     "data": {
#         "id": "1493638190204616704",
#         "text": "oh bakit kapa gising masamang mag puyat sa maling tao"
#     }
# }
# {
#     "data": {
#         "id": "1493638190204219392",
#         "text": "RT @sayo0692: the idea is already made but yes.\n\nLove yourself in valentine's day just as much Kronii loves herself \n\n#kronillust #drawMEI\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1493638190204399628",
#         "text": "RT @JB_Peeples: Even if McVay coaches for a 100 more years this clip will forever be his best https://t.co/BjIHYCLlSI"
#     }
# }
# {
#     "data": {
#         "id": "1493638190212788231",
#         "text": "YOU WILL FIND HERE...: Come See The Highest Paying Jobs in Finance and Accounting https://t.co/gQOjcixrBD"
#     }
# }
# {
#     "data": {
#         "id": "1493638190233976832",
#         "text": "RT @mimiinwza: #\u0e08\u0e30\u0e17\u0e31\u0e01\u0e40\u0e14\u0e21\u0e04\u0e19\u0e17\u0e35\u0e48\u0e21\u0e32\u0e23\u0e35\u0e17\u0e27\u0e34\u0e15"
#     }
# }
# {
#     "data": {
#         "id": "1493638190242177024",
#         "text": "I have to stop trying to make sense out of nonsense. \ud83e\udd23\ud83e\udd23"
#     }
# }
# {
#     "data": {
#         "id": "1493638190233960450",
#         "text": "@Sandeepmohi7 \u0939\u093e\u0902 \u0939\u093e\u0902 \u092c\u093f\u0932\u094d\u0915\u0941\u0932 \u0938\u0902\u091c\u092f \u0917\u093e\u0902\u0927\u0940, \u0913\u092a\u0940 \u091c\u093f\u0902\u0926\u0932, \u092e\u093e\u0927\u0935\u0930\u093e\u0935 \u0938\u093f\u0902\u0927\u093f\u092f\u093e, \u0930\u093e\u091c\u0947\u0936 \u092a\u093e\u092f\u0932\u091f, \u0914\u0930 \u092d\u0940 \u092c\u0939\u0941\u0924 \u0939\u0948\u0902\u0964"
#     }
# }
# {
#     "data": {
#         "id": "1493638190204264448",
#         "text": "@GBaby_GrayJo I was told anything under 50 meant it was considered fully suppressed"
#     }
# }
# {
#     "data": {
#         "id": "1493638190216978434",
#         "text": "iHerb (\u30a2\u30a4\u30cf\u30fc\u30d6)\n\n\u30d7\u30ed\u30e2\u30b3\u30fc\u30c9\n\u2705DJY9122\u2705\n\n\u30d7\u30ed\u30e2\u30fc\u30b7\u30e7\u30f3\u30b3\u30fc\u30c9\u3092\u5165\u529b\u3059\u308b\u3068\u3001\u5404\u88fd\u54c1\u304c5%\u5272\u5f15\n\u306b\u306a\u308a\u307e\u3059\u3002\n\ud83d\udc9aDJY9122\ud83d\udc9a\n\n\u514d\u75ab\u304a\u3088\u3073\u30a6\u30a4\u30eb\u30b9\u5bfe\u7b56\u30b5\u30d7\u30ea\u30e1\u30f3\u30c8\u3001\u30a2\u30b9\u30ec\u30c1\u30c3\u30af\u88fd\u54c1\u3001\n\u30aa\u30fc\u30ac\u30cb\u30c3\u30af\u88fd\u54c1\u3001\u30b0\u30eb\u30c6\u30f3\u30d5\u30ea\u30fc\u98df\u54c1\u3001\u30ec\u30c1\u30ce\u30fc\u30eb\u3001\u7f8e\u5bb9\u88fd\u54c1\u306a,vitamins,skin beauty,\u3069\u3002mds7"
#     }
# }
# {
#     "data": {
#         "id": "1493638186027069441",
#         "text": "@2PRmwIdLmzFnDs5 \u3053\u3061\u3089\u3053\u305d\u3067\u3059\u30fc\uff01(?)\ud83d\ude2d\u2764\ufe0f\u200d\ud83d\udd25\n\u9014\u4e2d\u64cd\u4f5c\u3057\u3066\u308b\u753b\u9762\u304c\u5165\u3063\u3061\u3083\u3063\u3066\u308b\u306e\u306f\u3059\u307f\u307e\u305b\u3093\ud83d\ude2d"
#     }
# }
# {
#     "data": {
#         "id": "1493638190242344960",
#         "text": "RT @TwoodTrolls: ee Sannasi gallu 5 years tenure lo pani chese athi koddhi instances lo okati feb 25th \ud83d\ude37\n\n#BheemlaNayak | #PawanKalyan \n#Bh\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1493638190221123588",
#         "text": "RT @realNDWalsch: Unless you get a little humor in your life, none of it is going to make any sense. Laugher is the best medicine. Joy is g\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1493638190242144270",
#         "text": "@DaddyZee14 Enjoyment kill you there bossman \ud83d\ude0b"
#     }
# }
# {
#     "data": {
#         "id": "1493638190225260549",
#         "text": "\ud83d\udccc \u0e1a\u0e32\u0e07\u0e17\u0e35\u0e01\u0e47\u0e2d\u0e22\u0e32\u0e01\u0e40\u0e1b\u0e47\u0e19\u0e1b\u0e39\u0e44\u0e17\u0e22 \u0e08\u0e30\u0e44\u0e14\u0e49\u0e2d\u0e23\u0e48\u0e2d\u0e22\u0e16\u0e39\u0e01\u0e43\u0e08\u0e40\u0e14\u0e47\u0e01\u0e44\u0e17\u0e22\u0e17\u0e38\u0e01\u0e04\u0e19 #\u0e04\u0e33\u0e04\u0e21 \ud83e\udd23"
#     }
# }
# {
#     "data": {
#         "id": "1493638190242189319",
#         "text": "#\u0639\u0635\u0641_\u0627\u0644\u0630\u0647\u0646_\u064a\u0633\u062a\u0647\u0632\u064a\u0621_\u0628\u0627\u0644\u0644\u0647 \ufd3f \u0623\u0641\u0623\u0645\u0646\u0648\u0627 \u0645\u0643\u0631 \u0627\u0644\u0644\u0647 \u0641\u0644\u0627 \u064a\u0623\u0645\u0646 \u0645\u0643\u0631 \u0627\u0644\u0644\u0647 \u0625\u0644\u0627 \u0627\u0644\u0642\u0648\u0645 \u0627\u0644\u062e\u0627\u0633\u0631\u0648\u0646\ufd3e"
#     }
# }
# {
#     "data": {
#         "id": "1493638190221037575",
#         "text": "RT @DANIWAhana: \u0e21\u0e32!! \u0e17\u0e35\u0e21\u0e22\u0e39\u0e17\u0e39\u0e1b\u0e01\u0e30\u0e14\u0e36\u0e01\u0e27\u0e31\u0e19\u0e1b\u0e25\u0e48\u0e2d\u0e22\u0e40\u0e1e\u0e25\u0e07 24 \u0e0a\u0e21.\u0e41\u0e23\u0e01 \u0e41\u0e04\u0e1b\u0e15\u0e31\u0e49\u0e07\u0e41\u0e15\u0e48 5 \u0e17\u0e38\u0e48\u0e21 15/2 \u0e16\u0e36\u0e07 \u0e15\u0e35 5 16/2\n\u0e40\u0e23\u0e32\u0e41\u0e08\u0e01\u0e01\u0e32\u0e23\u0e4c\u0e14\u0e19\u0e49\u0e2d\u0e07\u0e40\u0e17\u0e23\u0e40\u0e0a\u0e2d\u0e23\u0e4c\u0e1a\u0e31\u0e49\u0e21\u0e01\u0e48\u0e2d\u0e19\u0e2b\u0e19\u0e49\u0e32 5 \u0e23\u0e32\u0e07\u0e27\u0e31\u0e25\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1493638190229786625",
#         "text": "RT @jjjapcr: \u0e40\u0e23\u0e32\u0e44\u0e14\u0e49\u0e19\u0e30 \u0e2a\u0e41\u0e15\u0e19\u0e14\u0e35\u0e49\u0e13\u0e10 \u0e19\u0e30 \u0e19\u0e49\u0e2d\u0e07\u0e22\u0e31\u0e07\u0e2d\u0e22\u0e39\u0e48\u0e14\u0e35\u0e17\u0e31\u0e01\u0e17\u0e32\u0e22\u0e15\u0e2d\u0e19\u0e40\u0e0a\u0e49\u0e32\u0e01\u0e48\u0e2d\u0e19\u0e44\u0e1b\u0e17\u0e33\u0e07\u0e32\u0e19\u0e17\u0e38\u0e01\u0e27\u0e31\u0e19 555 #SpaceWithNat https://t.co/g198VBE21k"
#     }
# }
# {
#     "data": {
#         "id": "1493638190242086914",
#         "text": "RT @RachelR22610982: #ye\u015filyurt #karabaglar #g\u00f6ztepe \u015fey saklamadanhayat\u0131m\u0131 https://t.co/lrxaDKZB0a"
#     }
# }
# {
#     "data": {
#         "id": "1493638190212726785",
#         "text": "RT @jenny_the1975: dal disco nuovo di @iosonoariete tutto ok! https://t.co/9mgQJHo66Z"
#     }
# }
# {
#     "data": {
#         "id": "1493638190204604418",
#         "text": "RT @sfkkfs_: \u0e42\u0e2d\u0e40\u0e04\u0e19\u0e30 \u0e02\u0e2d\u0e43\u0e2b\u0e49\u0e40\u0e02\u0e49\u0e32\u0e43\u0e08\u0e15\u0e23\u0e07\u0e01\u0e31\u0e19 5555555555\n#\u0e17\u0e33\u0e17\u0e38\u0e01\u0e27\u0e31\u0e19\u0e02\u0e2d\u0e07\u0e0a\u0e35\u0e27\u0e34\u0e15\u0e43\u0e2b\u0e49\u0e2d\u0e23\u0e48\u0e2d\u0e22\u0e44\u0e1b\u0e14\u0e49\u0e27\u0e22\u0e01\u0e31\u0e19 https://t.co/Pf63F0FObz"
#     }
# }
# {
#     "data": {
#         "id": "1493638190237995011",
#         "text": "RT @JarjisPreeti: #izmir #gaziemir seninle, https://t.co/G71L5uXf0v"
#     }
# }
# {
#     "data": {
#         "id": "1493638190242013189",
#         "text": "RT @my_xanadu_: #\ubcbc\ub8e9 \uc790\ub77c \ud050\ube45 \ud504\ub9b0\uc9c0 \uc6d0\ud53c\uc2a4 \uc0c8\uc0c1\ud488 s\n\n\uc544\uc9c1 \uc785\uae30 \uc804\uc778 \uac70\ub77c \ud314\uae4c \ub9d0\uae4c \uace0\ubbfc\ud558\ub2e4 \uc62c\ub824 \ubd10\uc694 \ud83e\udd7a \uc694\uc998 \uc0b0 \uc637\ub4e4\uc774 \ub2e4 \ub290\ub08c\uc774 \ube44\uc2b7\ud574\uc11c! \uc138\uc77c \uc804\uc5d0 \uad6c\ub9e4\ud588\uc2b5\ub2c8\ub2f9\n\n\u20a952,000 https://t.co/EqvzWb0CJh"
#     }
# }
# {
#     "data": {
#         "id": "1493638190229757952",
#         "text": "RT @hamtaro______: hidup w seru banget pas 2019"
#     }
# }
# {
#     "data": {
#         "id": "1493638190217011203",
#         "text": "@granodpimienta Vale la correcci\u00f3n pero es corto y croto."
#     }
# }
# {
#     "data": {
#         "id": "1493638190229602305",
#         "text": "RT @AlexaJirez: Liebe Frau Raab, dieser Befund ist falsch positiv. Die \"Verbesserung\" hat folgende Gr\u00fcnde: M\u00e4nner haben im Krisenjahr schle\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1493638190208532486",
#         "text": "@Agenda2030_ \ud83d\udc4f\ud83d\udc4f\ud83d\udc4f\ud83d\udc4f\ud83d\udc4f bravo"
#     }
# }
# {
#     "data": {
#         "id": "1493638186018369541",
#         "text": "#BEdTET2011_\u0905\u0916\u093f\u0932\u0947\u0936_\u0915\u094b_\u091c\u093f\u0924\u093e\u090f\u0917\u093e\n@bstvlive \n@dimpleyadav \n@samajwadiparty \n@yadavakhilesh \n@proframgopalya1 \n@shivpalsinghyad \n@sunilyadv_unnao \n@oprajbhar \n@RajeevRai \n@Kaamboltahai 5 https://t.co/MwvILdamYv"
#     }
# }
# {
#     "data": {
#         "id": "1493638190229598221",
#         "text": "RT @collegemenfess: [cm] ayo semangat untuk kita. Udah berjalan sejauh ini. Ga nyangka ya? Tahan sedikit lagi. Kita pasti bisa melewati lik\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1493638186031013889",
#         "text": "\"Poes\u00eda dende a mi\u00f1a voz\", a voz de Antonio Garc\u00eda Teijeiro nas VIII Xornadas G\u00c1LIX. Poes\u00eda cargada de futuro para futuras xeraci\u00f3ns. @consellocultura @CAFIgalicia #xornadasg\u00e1lix #desfacendoaraia #poesia #poes\u00edainfantil #poes\u00edaengalego https://t.co/rtZ1Ni4sVl"
#     }
# }
# {
#     "data": {
#         "id": "1493638190221176832",
#         "text": "@touchitdior a goddess"
#     }
# }
# {
#     "data": {
#         "id": "1493638190204432384",
#         "text": "RT @Signorasinasce: Cifra da record destinata indubbiamente a crescere \ud83d\udc47\ud83c\udffb https://t.co/nYY8Wyd4kZ"
#     }
# }
# {
#     "data": {
#         "id": "1493638190212984834",
#         "text": "RT @mubai__jk: \u0e19\u0e2d\u0e01\u0e14\u0e49\u0e2d\u0e21\u0e40\u0e1b\u0e34\u0e14\u0e2a\u0e40\u0e1b\u0e0b\u0e2d\u0e27\u0e22\u0e40\u0e1e\u0e25\u0e07\u0e1a\u0e31\u0e07\u0e17\u0e31\u0e19\n\n\u0e2d\u0e32\u0e23\u0e4c\u0e21\u0e35\u0e48 : https://t.co/ehEFiuHsQw"
#     }
# }
# {
#     "data": {
#         "id": "1493638190229602314",
#         "text": "@Engineer_Musty Better for us to wait and see the politicians that has this characters as follows \n(1) HONESTY \n(2) SELF AWARENESS \n(3) DEFERENTIAL TO OTHER\n(4) ACTIVE LISTENING \n(5) WALKS THE TALK\ni think it will be good for us to have a leaders that has this but we should give ALLAH choice"
#     }
# }
# {
#     "data": {
#         "id": "1493638190242177025",
#         "text": "RT @BangedGuys: https://t.co/vYop3JtgGR"
#     }
# }
# {
#     "data": {
#         "id": "1493638190237990920",
#         "text": "@Giiit6 @TurkeyCelebs \u0627\u062d\u061f \u0644\u064a\u0634"
#     }
# }
# {
#     "data": {
#         "id": "1493638190204211200",
#         "text": "\ud2b8\uce5c\uc774 \ucd94\ucc9c\ud574\uc900 \ud31d\uc1a1 \ud50c\ub9ac\uac00 \ub108\ubb34 \uc88b\ub2e4....."
#     }
# }
# {
#     "data": {
#         "id": "1493638190241964032",
#         "text": "RT @Ek_Tha_Eagle: People Says:- One Of The Best Iconic Pose.\n\nBut Behind This Pose:- There's A Man #SidharthShukla, He Was ill But Not Weak\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1493638190212821003",
#         "text": "RT @MrsVivacia: Will never not repost this when I come across it https://t.co/W7Lq5TcyRf"
#     }
# }
# {
#     "data": {
#         "id": "1493638186031099906",
#         "text": "RT @gghhaykbdpgyze: Manal\u0131bak\u0131\u015fla,    #ankaratrave\ufb05i akl\u0131m\u0131\u00e7elip,  . https://t.co/tUTV01gmJP"
#     }
# }
# {
#     "data": {
#         "id": "1493638186043650048",
#         "text": "@JORGE_A_LARA https://t.co/ZYUGQXGhN5"
#     }
# }
# {
#     "data": {
#         "id": "1493638194406977541",
#         "text": "RT @AdultSharingXXX: Mood\n\n\ud83d\udd1e GET LAID TONIGHT https://t.co/xZ7uAxKV8N \ud83d\udd1e https://t.co/U7KsCSN7ru"
#     }
# }
# {
#     "data": {
#         "id": "1493638194415521792",
#         "text": "RT @BOROWSKIMIKE: Emmanuel Macron nomme le ministre Jacqueline Gourault au Conseil constitutionnel. Quelles sont ses qualit\u00e9s en tant que j\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1493638194424074240",
#         "text": "\u521d\u3081\u3066\u30eb\u30fc\u30e0\u30de\u30c3\u30c1\u306e\u90e8\u5c4b\u5165\u3063\u3066\u5bfe\u6226\u3057\u3066\u307f\u305f\u3051\u3069\u521d\u5fc3\u8005\u304c\u591a\u304f\u3066\u30d6\u30e9\u30de\u30b8\u30c7\u30c3\u30ad\u8a66\u3059\u306e\u306b\u3061\u3087\u3046\u3069\u826f\u304b\u3063\u305f"
#     }
# }
# {
#     "data": {
#         "id": "1493638194419712007",
#         "text": "Ah\u00ed aveces que dan ganas de desaparecer y hacer cosas malas"
#     }
# }
# {
#     "data": {
#         "id": "1493638194398597121",
#         "text": "RT @alittlegirlon: \u0e17\u0e38\u0e01\u0e04\u0e19\u0e0a\u0e48\u0e27\u0e22\u0e40\u0e23\u0e32\u0e23\u0e35\u0e17\u0e27\u0e34\u0e15\u0e19\u0e35\u0e49\u0e2b\u0e19\u0e48\u0e2d\u0e22\u0e44\u0e14\u0e49\u0e44\u0e2b\u0e21\u0e04\u0e30 \n\u0e40\u0e23\u0e32\u0e01\u0e33\u0e25\u0e31\u0e07\u0e40\u0e08\u0e2d\u0e1b\u0e31\u0e0d\u0e2b\u0e32\u0e43\u0e2b\u0e0d\u0e48\u0e21\u0e32\u0e01\u0e46 \u0e17\u0e35\u0e48\u0e44\u0e21\u0e48\u0e40\u0e04\u0e22\u0e16\u0e39\u0e01\u0e41\u0e01\u0e49\u0e44\u0e02\u0e08\u0e32\u0e01\u0e20\u0e32\u0e04\u0e23\u0e31\u0e10\u0e40\u0e25\u0e22 \u0e19\u0e49\u0e33\u0e1b\u0e23\u0e30\u0e1b\u0e32\u0e17\u0e35\u0e48\u0e2b\u0e21\u0e39\u0e48\u0e1a\u0e49\u0e32\u0e19\u0e40\u0e23\u0e32\u0e43\u0e0a\u0e49\u0e40\u0e1b\u0e47\u0e19\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1493638194432258049",
#         "text": "RT @Habagyal: 19 sale spots left on my site \ud83c\udf39"
#     }
# }
# {
#     "data": {
#         "id": "1493638194398650370",
#         "text": "RT @littlegiinge: If I do you the favor of following back please do me the favor of not immediately messaging me."
#     }
# }
# {
#     "data": {
#         "id": "1493638194402930689",
#         "text": "RT @ai_tyorvgrs: https://t.co/x1jxUKAQuF"
#     }
# }
# {
#     "data": {
#         "id": "1493638194432290816",
#         "text": "RT @elochima: We are celebrating the official ELO BAPES NFT artwork by giving away 50 WL spots. FOLLOW @elochima and @bapesclan + RT + TAG\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1493638194398580737",
#         "text": "RT @RNCResearch: Are you surprised? https://t.co/QCEqJxDG8U"
#     }
# }
# {
#     "data": {
#         "id": "1493638194419671045",
#         "text": "@ImManuVelez @cesornero \u00c9xitos comerciales jajajaja ok"
#     }
# }
# {
#     "data": {
#         "id": "1493638190225571840",
#         "text": "\u5b85\u914d\u30dc\u30c3\u30af\u30b9\u306b\u4f55\u304b\u5165\u3063\u3066\u3066\u3001\u4f55\u304b\u5c4a\u304f\u3088\u3046\u306a\u3082\u306e\u3042\u3063\u305f\u304b\u8b0e\u3060\u3063\u305f\u3051\u3069 \u305f\u3060\u306e\u5b9a\u671f\u4fbf\u306e\u67d4\u8edf\u5264\u3060\u3063\u305f\u2668\ufe0f"
#     }
# }
# {
#     "data": {
#         "id": "1493638190217195520",
#         "text": "RT @cjmajor_th: \u0e23\u0e2d\u0e22\u0e23\u0e49\u0e32\u0e27\u0e2b\u0e25\u0e31\u0e07\u0e20\u0e32\u0e1e \u0e42\u0e0a\u0e27\u0e4c\u0e28\u0e31\u0e01\u0e22\u0e20\u0e32\u0e1e\u0e19\u0e31\u0e01\u0e41\u0e2a\u0e14\u0e07\u0e17\u0e35\u0e48\u0e44\u0e21\u0e48\u0e40\u0e04\u0e22\u0e40\u0e2b\u0e47\u0e19! \n\u201c\u0e19\u0e34\u0e0a\u0e04\u0e38\u0e13\u201d \u0e41\u0e25\u0e30 \u201c\u0e41\u0e1e\u0e15 \u0e0a\u0e0d\u0e32\u0e19\u0e34\u0e29\u0e10\u0e4c\u201d \u0e09\u0e35\u0e01\u0e25\u0e38\u0e04 \u0e17\u0e38\u0e48\u0e21\u0e2a\u0e1b\u0e34\u0e23\u0e34\u0e15\u0e2a\u0e38\u0e14\u0e15\u0e31\u0e27 \n\u0e2b\u0e19\u0e35\u0e15\u0e32\u0e22\u0e2d\u0e32\u0e23\u0e23\u0e1e\u0e4c\u0e20\u0e32\u0e1e\u0e27\u0e32\u0e14\u0e17\u0e35\u0e48\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1493638194432290817",
#         "text": "2022 et c\u2019est toujours le son qui me correspond le plus depuis sa sortie !! https://t.co/PlZCtLVtae"
#     }
# }
# {
#     "data": {
#         "id": "1493638194427875329",
#         "text": "RT @krisster8: Justin Trudeau , Crystia Freeland, David Lametti, Marco Mendicino, Elizabeth May , Jagmeet Singh, Evan Solomon, Rosemary Bar\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1493638194403082241",
#         "text": "RT @DineshK35437626: #BEdTET2011_\u0905\u0916\u093f\u0932\u0947\u0936_\u0915\u094b_\u091c\u093f\u0924\u093e\u090f\u0917\u093e\n\u092c\u0940\u090f\u0921 \u091f\u0947\u091f2011 \u0928\u0947 \u0920\u093e\u0928\u093e \u0939\u0948 \u0905\u0916\u093f\u0932\u0947\u0936 \u092d\u0948\u092f\u093e \u0915\u094b \u0932\u093e\u0928\u093e \u0939\u0948\u0964 @yadavakhilesh @dimpleyadav @jayantrld @\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1493638190225190913",
#         "text": "RT @01Btsxarmy: Vote #Butter by @BTS_twt as this year's #BestMusicVideo at the #iHeartAwards 2022 \ud83c\udfc6"
#     }
# }
# {
#     "data": {
#         "id": "1493638194407092229",
#         "text": "@KateWilliamsme It stinks of guilt to me... \ud83e\udd14\ud83d\ude44"
#     }
# }
# {
#     "data": {
#         "id": "1493638194411229187",
#         "text": "RT @DM_Shirley: Ideal Virginia Tech schedule, instant-impact candidates, measuring Brent Pry\u2019s progress, more: Hokies mailbag, Part II @And\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1493638194411171840",
#         "text": "RT @NiteshA63684193: #BEdTET2011_\u0905\u0916\u093f\u0932\u0947\u0936_\u0915\u094b_\u091c\u093f\u0924\u093e\u090f\u0917\u093e\n\u091c\u0928 \u091c\u0928 \u0915\u0940 \u092f\u0939\u0940 \u092a\u0941\u0915\u093e\u0930 \u0905\u092c\u0915\u0940 \u092c\u093e\u0930 \u092f\u0942\u092a\u0940 \u092e\u0947\u0902 \u0938\u092a\u093e \u0938\u0930\u0915\u093e\u0930 \ud83d\udeb2\n@yadavakhilesh\n@MediaCellSP\n@dimpleyada\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1493638194419671041",
#         "text": "@ClaudiooGentile Fordi jeg sp\u00f8rger, neutralt, om vi mon f\u00e5r belyst historien i danske medier? Hvordan f\u00e5r du lavet det til noia, Dino Zoff?"
#     }
# }
# {
#     "data": {
#         "id": "1493638194402897924",
#         "text": "RT @ManOfNovember: \u0420\u043e\u0441\u0441\u0438\u0439\u0441\u043a\u0438\u0435 \u0438\u0441\u0442\u0440\u0435\u0431\u0438\u0442\u0435\u043b\u0438 \u041c\u0438\u0413-31\u041a \u0441 \u0433\u0438\u043f\u0435\u0440\u0437\u0432\u0443\u043a\u043e\u0432\u044b\u043c\u0438 \u0440\u0430\u043a\u0435\u0442\u0430\u043c\u0438 \"\u041a\u0438\u043d\u0436\u0430\u043b\" \u0438 \u0434\u0430\u043b\u044c\u043d\u0438\u0435 \u0431\u043e\u043c\u0431\u0430\u0440\u0434\u0438\u0440\u043e\u0432\u0449\u0438\u043a\u0438 \u0422\u0443-22\u041c3 \u043f\u0440\u0438\u0431\u044b\u043b\u0438 \u043d\u0430 \u0431\u0430\u0437\u0443 \u0425\u043c\u0435\u0439\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1493638194402893831",
#         "text": "@Racardx @81notz @Brasileirao @SantosFC @Flamengo @ChampionsLeague @neymarjr @vinijr Boa tarde vice"
#     }
# }
# {
#     "data": {
#         "id": "1493638194415423488",
#         "text": "RT @Lilwee23_: I\u2019m glad Bitches posted Their Boyfriends Today , Now 8ths $120"
#     }
# }
# {
#     "data": {
#         "id": "1493638194432204801",
#         "text": "La v\u00e9ritable question dont on doit se poser. Est ce que le fait que la CENI ait une autonomie adm et financi\u00e8re. Ne peux t elle pas \u00eatre contr\u00f4l\u00e9e ? Et si elle doit \u00eatre comment cela doit se faire ? Est ce a la BCECO de faire l'appel d'offre pr la CENI ? https://t.co/5AA6JyEI8A"
#     }
# }
# {
#     "data": {
#         "id": "1493638194411175938",
#         "text": "@vishalvhai fir to pakka murder hua hai"
#     }
# }
# {
#     "data": {
#         "id": "1493638190217175043",
#         "text": "@KimjunkyuThfan #JIKJIN\u00a0 #\uc9c1\uc9c4\u00a0  #THESECONDSTEP_CHAPTERONE\u00a0  #TREASURE\u00a0 #\ud2b8\ub808\uc800\u00a0 @treasuremembers https://t.co/MJ0O9q2wRV"
#     }
# }
# {
#     "data": {
#         "id": "1493638194424082433",
#         "text": "RT @cineasimetrico: Olivia Wilde https://t.co/f7wUZTnAAK"
#     }
# }
# {
#     "data": {
#         "id": "1493638194436444164",
#         "text": "RT @arelyfeminista: #BuenosYFeministasD\u00edas #NosotrasParaNosotras \ud83d\udc9a\u2640\ufe0f\ud83d\udc9c @MiriamHamdan @sof_j @worldwomanfund @LaClau @Mirelle_Mtz @_eloiseloi\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1493638194415521796",
#         "text": "@shitpostingMP4 t desparraman todo el agua \ud83d\ude21\ud83d\ude21\ud83d\ude21\ud83d\ude21"
#     }
# }
# {
#     "data": {
#         "id": "1493638190212653057",
#         "text": "RT @Coony_illust: \u301cCOMING SOON\u301c\n\n\u3010\u30cb\u30e3\u30f3\u30c6\u30a3\u30fc\u3011\u767a\u58f2\u3057\u307e\u3059\ud83e\uded6\u2728\n\n\u5609\u6c38\u4e09\u5e74\u5275\u696d\u306e\u8001\u8217\u88fd\u8336\u5e97\u300c\u3064\u307c\u5e02\u8056\u8336\u672c\u8217\u300d @TeaTsuboichi \u3055\u3093\u3068\u30b3\u30e9\u30dc\u3055\u305b\u3066\u3044\u305f\u3060\u304d\u3001\u4e16\u754c\u65c5\u884c\u3092\u30c6\u30fc\u30de\u306b\u3057\u305fNYAN TEA\u3092\u4f5c\u308a\u307e\u3057\u305f\ud83e\uddf3\n\n\u307b\u3046\u3058\u8336\u3001\u30b8\u30e3\u30b9\u30df\u30f3\u8336\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1493638190204604416",
#         "text": "https://t.co/H2lTOdSgxv\u5546\u54c1\u4e00\u89a7-2/jyajiparka.html\n\n\u2191\u306b\u3066\u30dd\u30c3\u30d4\u30f3\u30b7\u30e3\u30ef\u30fc\u98a8\u306e\u30b8\u30e3\u30fc\u30b8\u30d1\u30fc\u30ab\u30fc\u3092\u4f5c\u308a\u305f\u3044\u3068\u601d\u3063\u3066\u3044\u308b\u306e\u3067\u3059\u304c\u753b\u529b\u3082\u982d\u3082\u306a\u304f\u8ff7\u8d70\u3057\u3066\u3044\u307e\u3059\u3002\u8896\u306f\u51fa\u6765\u305f\u306e\u3067\u3059\u304c\u3001\u6b63\u9762\u3068\u88cf\u304c\u60a9\u3093\u3067\u307e\u3057\u305f\u3002\u306a\u3093\u304b\u30a2\u30a4\u30c7\u30a2\u304c\u3042\u308c\u3070\u305c\u3072\u307b\u3057\u3044\u3067\u3059\uff01\u8a18\u8f09\u6f0f\u308c\u3067\u3059\u304c\u30d5\u30fc\u30c9\u306f\u30d4\u30f3\u30af\u4e88\u5b9a\u3067\u3059 https://t.co/YluOM6cIKQ"
#     }
# }
# {
#     "data": {
#         "id": "1493638194407284736",
#         "text": "\u0e02\u0e2d\u0e2d\u0e19\u0e38\u0e0d\u0e32\u0e15\u0e16\u0e32\u0e21\u0e19\u0e30\u0e04\u0e30 \u0e1b\u0e01\u0e15\u0e34\u0e2a\u0e2d\u0e07\u0e43\u0e1a\u0e19\u0e35\u0e49\u0e40\u0e02\u0e32\u0e02\u0e32\u0e22\u0e01\u0e31\u0e19\u0e40\u0e17\u0e48\u0e32\u0e44\u0e2b\u0e23\u0e48\u0e04\u0e30\n\n #\u0e15\u0e25\u0e32\u0e14\u0e19\u0e31\u0e14ENHYPEN https://t.co/uR3mpFllVp"
#     }
# }
# {
#     "data": {
#         "id": "1493638194436489217",
#         "text": "RT @Hbamulinde: Keep your private life away from the office, what you think is a personal achievement may trigger an investigation and the\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1493638194432450560",
#         "text": "RT @sukironn: \u0e41\u0e01 \u0e04\u0e37\u0e2d\u0e09\u0e31\u0e19\u0e40\u0e1e\u0e34\u0e48\u0e07\u0e40\u0e25\u0e34\u0e01\u0e07\u0e32\u0e19\u0e21\u0e32 \u0e16\u0e36\u0e07\u0e2b\u0e49\u0e2d\u0e07\u0e01\u0e47\u0e16\u0e2d\u0e14\u0e40\u0e2a\u0e37\u0e49\u0e2d\u0e1c\u0e49\u0e32\u0e42\u0e14\u0e14\u0e02\u0e36\u0e49\u0e19\u0e40\u0e15\u0e35\u0e22\u0e07\u0e1b\u0e23\u0e30\u0e2a\u0e32\u0e04\u0e19\u0e0b\u0e01\u0e21\u0e01\u0e40\u0e27\u0e49\u0e22 \u0e25\u0e30\u0e15\u0e2d\u0e19\u0e40\u0e25\u0e48\u0e19\u0e21\u0e37\u0e2d\u0e16\u0e37\u0e2d\u0e01\u0e47\u0e2a\u0e31\u0e07\u0e40\u0e01\u0e15\u0e27\u0e48\u0e32\u0e21\u0e48\u0e32\u0e19\u0e21\u0e31\u0e19\u0e40\u0e1b\u0e34\u0e14\u0e40\u0e1c\u0e22\u0e2d\u0e2d\u0e2d\u0e01\u0e2b\u0e19\u0e48\u0e2d\u0e22\u0e19\u0e36\u0e07\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1493638194419703813",
#         "text": "RT @_RAMi20: - \u062c\u0627\u0628\u0643 \u0627\u0644\u0644\u0647 \u0648\u0623\u0645\u062a\u0644\u0649 \u0639\u064f\u0645\u0631\u064a \u0631\u0636\u0627 . ."
#     }
# }
# {
#     "data": {
#         "id": "1493638194415521803",
#         "text": "RT @Simone_Biles: WOKE UP A FIANC\u00c9E \ud83d\udc8d\ud83d\udc8d\ud83d\ude2d\n\nI can\u2019t wait to spend forever &amp; ever with you, you\u2019re everything I dreamed of and more! let\u2019s get\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1493638194402783233",
#         "text": "hah tot 3.5 gb \nhah twst music 8 gb"
#     }
# }
# {
#     "data": {
#         "id": "1493638194436341763",
#         "text": "@Sratkw @yaseralbahri \u0644\u0627 \u0641\u0636\u0649 \u0641\u064a\u0643 \u064a\u0627 \u0627\u062e \u064a\u0627\u0633\u0631 \u0627\u0628\u062f\u0639\u062a \u0641\u064a \u0627\u0644\u062a\u062d\u0644\u064a\u0644 \u0645\u0627 \u0634\u0627\u0621 \u0627\u0644\u0644\u0647 \u0639\u0644\u064a\u0643"
#     }
# }
# {
#     "data": {
#         "id": "1493638194432122888",
#         "text": "polygon is so fucking dogshit"
#     }
# }
# {
#     "data": {
#         "id": "1493638194411180035",
#         "text": "RT @pinkyfaye: @ALDubFTnQT @elaineRequina2x @GlianeMarienell @clarita_mate @OctNov_0503 @icanBestrong02 @NoraNoraCampos @Cassy1614 @momshie\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1493638194419703811",
#         "text": "RT @Suat_Denk: \ud83d\udcc8Sava\u015f d\u00f6nemleri #ALTIN hareketlenir ve y\u00fckseli\u015f e\u011filiminde seyreder.\n\nBuna en yak\u0131n \u00f6rnek d\u00fcn alm\u0131\u015f oldu\u011fumuz ALTIN i\u015flemin\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1493638194419617794",
#         "text": "RT @throatchakra_: A r t\ud83d\udc97 https://t.co/RhnXEWgA4f"
#     }
# }
# {
#     "data": {
#         "id": "1493638194436395016",
#         "text": "RT @noujouhaan: Kannie glo my ysterprins nou reg vir sy eerste tokse.....en dis klaar 'n no 12\ud83d\ude32\ud83d\ude32\ud83d\udcaa\ud83d\udcaa\ud83d\udcaa\ud83e\uddb6\ud83e\uddb6\ud83e\uddb6\ud83d\udc40 https://t.co/0xG5MpncN0"
#     }
# }
# {
#     "data": {
#         "id": "1493638194419613698",
#         "text": "RT @MistressxCherry: I post full titty and bush pics everyday on my OnlyFans and Fansly! \ud83d\udc96 links in the comments \u2b07\ufe0f https://t.co/lvsjeBnjKA"
#     }
# }
# {
#     "data": {
#         "id": "1493638194411491328",
#         "text": "\u30b9\u30b7\u30fb\u30ec\u30b9\u30c8\u30e9\u30f3\u306b\u6765\u305f\u3088\u3046\u3067\u3059\u306d\n\u3044\u3089\u3063\u3057\u3083\uff5e\u3044\n\n\u3058\u3083\u3042\u6842\u4e09\u679d\u306e\u30e2\u30ce\u30de\u30cd\u3092\u3057\u3066\u3044\u308bA\u8cc0\u8c37\u541b\uff5e\n(ry"
#     }
# }
# {
#     "data": {
#         "id": "1493638194415300608",
#         "text": "@kawanaing gg anjir w td udh frustasi"
#     }
# }
# {
#     "data": {
#         "id": "1493638194398588928",
#         "text": "@JamaicanJihadi https://t.co/AvO9M0jSgI"
#     }
# }
# {
#     "data": {
#         "id": "1493638194419716098",
#         "text": "@TheodoreTalk \ud83e\udd70"
#     }
# }
# {
#     "data": {
#         "id": "1493638194407092225",
#         "text": "@nakedvix What a little poet x"
#     }
# }
# {
#     "data": {
#         "id": "1493638194423816196",
#         "text": "everybody did they pregnancy announcement yesterday soooo cute"
#     }
# }
# {
#     "data": {
#         "id": "1493638190221115397",
#         "text": "RT @TheLastMohicans: @zombiemommy @CDCDirector There is no such thing as \"mild myocarditis.\"\n-Dr Peter McCullough"
#     }
# }
# {
#     "data": {
#         "id": "1493638198601388046",
#         "text": "RT @Nickrob: Insane Clown Posse is threatening to kill Bill Cosby. https://t.co/WALwH9MnNi"
#     }
# }
# {
#     "data": {
#         "id": "1493638198597242880",
#         "text": "RT @sweet_sixteeen: So sexy \u2764\nhttps://t.co/41AkFIeFbk"
#     }
# }
# {
#     "data": {
#         "id": "1493638198609780736",
#         "text": "RT @lmHkMOhveTKtvhO: .\n\u0635\u0644\u0651\u0648\u0627 \u0648\u0633\u0644\u0651\u0645\u0648\u0627 \u0639\u0644\u0649 \u062e\u064a\u0631 \u0627\u0644\u062e\u0644\u0642 \u062d\u0628\u064a\u0628 \u0627\u0644\u062d\u0642 \ufdfa\u2764"
#     }
# }
# {
#     "data": {
#         "id": "1493638198597197829",
#         "text": "@DiyaAR12 \ud83d\udc40\ud83d\udc40\ud83d\udc40\ud83d\udc40\ud83d\udc40\ud83d\udc40\ud83d\ude0e\ud83d\ude0e\ud83e\uddd0"
#     }
# }
# {
#     "data": {
#         "id": "1493638198622396417",
#         "text": "@najah_94 \u062a\u0645\u0645\u0645\u0645\n \u064a\u0640\u0640\u0640\u0640\u0640\u0640\u0640\u0640\u0627\u0627\u0627\u0627\u0627\u0631\u0628 \n\u064a\u0640\u0640\u0640\u0640\u0640\u0640\u0640\u0640\u0627\u0627\u0627\u0627\u0627\u0627\u0627\u0627\u0627\u0627\u0627\u0631\u0628 \n\u064a\u0640\u0640\u0640\u0640\u0640\u0640\u0640\u0640\u0627\u0627\u0627\u0627\u0627\u0627\u0627\u0627\u0627\u0627\u0627\u0627\u0627\u0627\u0631\u0628 \n\u064a\u0627\u0631\u0628 \u0627\u062c\u0639\u0644 \u0645\u0646 \u0646\u0635\u064a\u0628\u064a \u0627\u0644\u0641\u0648\u0632 \u0627\u0646 \u0634\u0627\u0621 \u0627\u0644\u0644\u0647 \uff9f  \n\u0627\u0644\u0644\u0647\u0645 \u0627\u0631\u0632\u0642\u0646\u064a \u0648\u0627\u0646\u062a \u062e\u064a\u0631 \u0627\u0644\u0631\u0627\u0632\u0642\u064a\u0646 \n\u064a\u0623\u062a \u0628\u0647\u0627 \u0627\u0644\u0644\u0647 \u0627\u0646 \u0627\u0644\u0644\u0647 \u0644\u0637\u064a\u0641 \u062e\u0628\u064a\u0631\n\uff65 \uff9f*\uff61\uff65\uff9f\u273f\uff61\n\n\u0627\u0644\u0644\u0647\u0645\u064e\u0651\ufdfa\u0635\u064e\u0644\u0650\u0651\ufdfa\u0648\u064e\u0633\u064e\u0640\u0640\u0640\u0644\u0650\u0651\u0645\u0652\ufdfa\u0648\u064e\u0628\u064e\u0627\u0631\u0650\u0643 \u0639\u0644\u0649 \u0633\u064a\u062f\u0646\u0627 \u0645\u062d\u0645\u062f \u0648\u0639\u0644\u0649 \u0627\u0644\u0647 \u0648\u0635\u062d\u0628\u0647"
#     }
# }
# {
#     "data": {
#         "id": "1493638198618120198",
#         "text": "RT @YasarKaba17: 6\u2019l\u0131 Ganyan\u2026 https://t.co/WQyVr8nfBZ"
#     }
# }
# {
#     "data": {
#         "id": "1493638198601396230",
#         "text": "RT @svecha62: \u0406\u0440\u0438\u043d\u0430 \u0413\u0435\u0440\u0430\u0449\u0435\u043d\u043a\u043e\n\n\u041d\u0430\u0439\u043a\u0440\u0430\u0449\u0438\u0439 \u0430\u0440\u0433\u0443\u043c\u0435\u043d\u0442 \u043d\u0435\u043c\u043e\u0436\u043b\u0438\u0432\u043e\u0441\u0442\u0456 \u043f\u0435\u0440\u0435\u0445\u043e\u0434\u0443 \u0434\u043e \u043e\u043d\u043b\u0430\u0439\u043d \u0433\u043e\u043b\u043e\u0441\u0443\u0432\u0430\u043d\u044c \u0443 \u0412\u0420 \u0456 \u043d\u0430 \u0432\u0438\u0431\u043e\u0440\u0430\u0445- \u0446\u0435 \u0441\u0430\u0439\u0442 \u041c\u041e \u0437\u0430\u0440\u0430\u0437, \u044f\u043a\u0438\u0439 \u043f\u0456\u0434\u0434\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1493638198618173440",
#         "text": "RT @Mikegrinjr1: There's always going to be someone who doesn't see your worth\n\nDON'T LET IT BE YOU!!!\ud83d\udccc"
#     }
# }
# {
#     "data": {
#         "id": "1493638198618112004",
#         "text": "@EFFSouthAfrica I'm really grateful for all the efforts you have render to me with my little investment of R5000 and with joy over me after withdrawing  R30,500 with your help @Leticia_Thomas7  thank you for everything you have done for me and my family @Leticia_Thomas7"
#     }
# }
# {
#     "data": {
#         "id": "1493638198613925894",
#         "text": "RT @RegularRuben: Any @smilesssvrs under 2 ETH is a gift. Go get a few while they are slightly down. There aren't many at that price."
#     }
# }
# {
#     "data": {
#         "id": "1493638198622228485",
#         "text": "RT @blueta9810: \u738b\u69d8\u30e9\u30f3\u30ad\u30f3\u30b05\u8a71\u307e\u3067\u4e00\u77ac\u3060\u3063\u305f\uff57\n\u7d9a\u304d\u306f\u307e\u305f\u4eca\u65e5\uff01\n\ud83d\udc51\ud83d\udc0f\ud83d\udca8\n\n#\u3064\u306e\u307e\u304d\u3042\u30fc\u3068\n#\u30c9\u30c9\u30c9\u30e9\u30a4\u30d6 https://t.co/q7KcX4mrWi"
#     }
# }
# {
#     "data": {
#         "id": "1493638198605533193",
#         "text": "RT @GilbertCollard: Apr\u00e8s le \u00ab\u00a0fid\u00e8le\u00a0\u00bb Jacques M\u00e9zard, la ministre Jacqueline Gourault est nomm\u00e9e au #ConseilConstitutionnel\u00a0: si on ajout\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1493638198626422784",
#         "text": "Cuando tenga que entrenar a la noche me voy a suicidar"
#     }
# }
# {
#     "data": {
#         "id": "1493638198626504704",
#         "text": "@VengaLaAlegria @ZelmaCh @samiauniversal @elcapiperez Me cae bien @elcapiperez y @Horacitu (Horacio te admiro mucho) #ParejaDeReyes"
#     }
# }
# {
#     "data": {
#         "id": "1493638198630703114",
#         "text": "@MR_JAMAL5 \u0627\u0633\u0627\u0633\u0627 \u0627\u0644\u0644\u0633\u0627\u0646 \u064a\u0637\u0648\u0644 \u0627\u0643\u062b\u0631 \u0628\u0639\u062f \u0642\u0637\u0639 \u0627\u0644\u0639\u0644\u0627\u0642\u0627\u062a!! \u0645\u0639 \u0627\u0644\u0628\u0639\u0636\ud83d\ude11"
#     }
# }
# {
#     "data": {
#         "id": "1493638198626603009",
#         "text": "@CallofDuty Developers have been playing more @PlayApex than their own game https://t.co/9aV98njErJ"
#     }
# }
# {
#     "data": {
#         "id": "1493638198592954379",
#         "text": "RT @ilaaminho: \u00ab\u00a0Salam dunk\u00a0\u00bb https://t.co/XCTebAmAPU"
#     }
# }
# {
#     "data": {
#         "id": "1493638198622306305",
#         "text": "RT @BLOSGUNS: https://t.co/DpvwYpraG3"
#     }
# }
# {
#     "data": {
#         "id": "1493638198593040384",
#         "text": "@SamuraiCeng https://t.co/PTWfaNxL7t"
#     }
# }
# {
#     "data": {
#         "id": "1493638198609776640",
#         "text": "@deadheadz4trump @ZubyMusic I said I was working on it! Jerk face! Grrrrrrrrr dang!"
#     }
# }
# {
#     "data": {
#         "id": "1493638198622359552",
#         "text": "RT @Ebrubebek18: tenemos m\u00e1s de cuatro etiquetas en tendencia quien es el mejor fandom NOSOTROS\n#Ebru\u015eahin \n#Destan #Destans\u0131Sevdalar"
#     }
# }
# {
#     "data": {
#         "id": "1493638198630793225",
#         "text": "@_lantteo \u0434\u0430"
#     }
# }
# {
#     "data": {
#         "id": "1493638194428063748",
#         "text": "@Atlan82 Hoffe es hilft! Wenigstens ein bisschen! \ud83e\udd17 https://t.co/9odbalRSIk"
#     }
# }
# {
#     "data": {
#         "id": "1493638198605463553",
#         "text": "RT @Ekta91715494: #BEdTET2011_\u0905\u0916\u093f\u0932\u0947\u0936_\u0915\u094b_\u091c\u093f\u0924\u093e\u090f\u0917\u093e\nUP will become a better state when educated CM Akhilesh will come.\nJai Akhilesh.\n@yadavakhi\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1493638198613868550",
#         "text": "RT @kradebii: \u300cIt's a good meal, isn't it?\u300d https://t.co/l8vvgCmx7x"
#     }
# }
# {
#     "data": {
#         "id": "1493638198630789124",
#         "text": "RT @DUALIPA: Mark the date! Friday 18th Feb. @lisadtaddeo the bestselling, award winning author of the ground-breaking Three Women and Anim\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1493638198605590534",
#         "text": "RT @Georg_Pazderski: Mal wieder nachgefragt, damit es nicht in Vergessenheit ger\u00e4t:\nWas ist eigentlich aus dem Wahlbetrug in Berlin geworde\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1493638198601388043",
#         "text": "@qtskyler @squalishere Me when uhhhhhhhhhhhhhhhhh\n\nBottom text https://t.co/cTdeovALrv"
#     }
# }
# {
#     "data": {
#         "id": "1493638198622408704",
#         "text": "RT @alhilal_q877: \u062f\u064a\u0627\u0632 \u0627\u0648\u0644 \u062a\u0645\u0631\u064a\u0646 \u0648\u0647\u0648 \u064a\u0634\u0648\u0641 \u0639\u0628\u062b \u062c\u0627\u0631\u062f\u064a\u0645 \u0641\u064a \u0627\u0644\u0641\u0631\u064a\u0642 https://t.co/og3DllyzCn"
#     }
# }
# {
#     "data": {
#         "id": "1493638198592999426",
#         "text": "RT @ThatekCom: \u0623\u062e\u0628\u0631\u0646\u0627 \u0639\u0646 \u0634\u0639\u0648\u0631\u0643 \u0648\u0645\u0627 \u064a\u062f\u0648\u0631 \u0641\u064a \u0630\u0647\u0646\u0643 \u0648\u0623\u0646\u062a \u062a\u062c\u0644\u0633 \u0645\u0639 \u0634\u062e\u0635 \u0643\u062b\u064a\u0631 \u0627\u0644\u0646\u0645\u064a\u0645\u0629."
#     }
# }
# {
#     "data": {
#         "id": "1493638198630703110",
#         "text": "RT @panako2557: \u9006\u30c1\u30e7\u30b3\u7684\u306a\u30a2\u30ec https://t.co/dlLguBDF49"
#     }
# }
# {
#     "data": {
#         "id": "1493638198618062848",
#         "text": "RT @vishalshandilya: @_garrywalia \u092d\u0948\u092f\u093e \u0916\u093e\u092e\u094b\u0936 \u0928\u0939\u0940 \u0939\u0948 \u092a\u094d\u0932\u093e\u0928\u093f\u0902\u0917 \u091a\u0932 \u0930\u0939\u0940 \u0939\u094b\u0917\u0940 \u0915\u0948\u0938\u0947 \u0915\u093e\u0902\u0917\u094d\u0930\u0947\u0938 \u0915\u094b \u0907\u0938\u092e\u0947\u0902 \u0907\u0928\u094d\u0935\u0949\u0932\u094d\u0935 \u0915\u0930\u093e \u091c\u093e\u090f\u0964"
#     }
# }
# {
#     "data": {
#         "id": "1493638198618058756",
#         "text": "RT @MM67612010: \u0e19\u0e32\u0e07\u0e23\u0e33\u0e23\u0e38\u0e48\u0e19\u0e1e\u0e35\u0e48                     \u0e19\u0e32\u0e07\u0e23\u0e33\u0e1d\u0e36\u0e01\u0e2b\u0e31\u0e14 https://t.co/EBYcAZE5wu"
#     }
# }
# {
#     "data": {
#         "id": "1493638198622363650",
#         "text": "RT @nobigdyl: God is good even on the bad days"
#     }
# }
# {
#     "data": {
#         "id": "1493638198593036290",
#         "text": "RT @FePaesLeme: Maria expulsa do #bbb22. Agress\u00e3o clara, puni\u00e7\u00e3o justa. Vida que segue e que ela possa rever e trabalhar a animosidade. Suc\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1493638198601428997",
#         "text": "need to stop hating on messi because he actually did nothing wrong except being annoying https://t.co/50gviPhH4N"
#     }
# }
# {
#     "data": {
#         "id": "1493638198618116096",
#         "text": "@FourFourths I'm an engineer, every terrible decision I have to make is because of business majors, not my lack of ethics. Most ABET accredited programs have ethics as part of the curriculum as well."
#     }
# }
# {
#     "data": {
#         "id": "1493638198605807616",
#         "text": "RT @darkswrld: $25 \u2022 210K \u2022 180 MINS \ud83e\ude90\n\n- RT + REPLY TO MY \ud83d\udccc"
#     }
# }
# {
#     "data": {
#         "id": "1493638198626590729",
#         "text": "...\n\nI swear every time I say I won't add more ideas to the WIP pile, I end up doing it anyway lksjfls\u00f1kf\u00f1lsd\n\nKara and Choro in this are my kink ngl https://t.co/8Hmy8eoZBD"
#     }
# }
# {
#     "data": {
#         "id": "1493638198601392130",
#         "text": "@ncorreyna Yeah but the ride down is fucking spectacular."
#     }
# }
# {
#     "data": {
#         "id": "1493638202820743169",
#         "text": "RT @Rashed72489352: \"Seasons will come and go  winners will come and go but there won't be any other winner like the most iconic winner of\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1493638198626746368",
#         "text": "\ud83d\udd1d\ud83d\udd1d\ud83d\udd1d\n\n\uae40\uc81c\ucd9c\uc7a5\uc548\u3141\u314f  \ucd94\ucc9c  \ucd9c\uc7a5\uc5c5\uc18c\n\n\ud83d\udc9f\n\ud83d\udc51\n\n\ucd9c\uc7a5\ucf5c\uac78\n\n\uae40\uc81c\ucf5c\uac78\n\n\u26e9\n\ud83d\udecf\nhttps://t.co/2xaVRRTjA7"
#     }
# }
# {
#     "data": {
#         "id": "1493638202825003010",
#         "text": "RT @Christi52204223: https://t.co/KEtCCcv41G #buca #kar\u015f\u0131yaka do\u011frulara has\u0131m,"
#     }
# }
# {
#     "data": {
#         "id": "1493638202808274953",
#         "text": "Glory! Glory!! @ManUtd"
#     }
# }
# {
#     "data": {
#         "id": "1493638202804117505",
#         "text": "RT @Christi52204223: https://t.co/KEtCCcv41G #buca #kar\u015f\u0131yaka do\u011frulara has\u0131m,"
#     }
# }
# {
#     "data": {
#         "id": "1493638202799894534",
#         "text": "RT @Christi52204223: https://t.co/KEtCCcv41G #buca #kar\u015f\u0131yaka do\u011frulara has\u0131m,"
#     }
# }
# {
#     "data": {
#         "id": "1493638202787254273",
#         "text": "RT @camilladelucas: A vida aqui fora deve seguir, fim de jogo! Muita luz na sua carreira aqui fora @eumaria. Voc\u00ea \u00e9 talentosa demais! Que a\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1493638202825277441",
#         "text": "RT @pbhushan1: In a joint operation the NCB &amp; the Indian Navy, seized over 760 kg narcotics, including hashish, methamphetamine &amp; heroin, w\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1493638202820726784",
#         "text": "RT @life_life_eyes: \u0645\u0627\u0630\u0627 \u0641\u0639\u0644\u062a\u064e \u0644\u062a\u062a\u0631\u0627\u0643\u0645 \u0628\u0647\u0630\u0627 \u0627\u0644\u0643\u0645\n\u0641\u064a \u062d\u0646\u0627\u064a\u0627 \u0631\u0648\u062d\u064a\n\u0637\u0648\u0642\u062a\u064e \u0628\u0643\u064e \u0643\u0644 \u0645\u0627 \u0628\u064a \u060c\u060c\n\u0623\u0643\u0627\u062f \u0644\u0627 \u0623\u0631\u0649 \u0641\u064a \u0647\u0630\u0627 \u0627\u0644\u0643\u0648\u0646\n\u0633\u0648\u0627\u0643 ...\n\u062c\u0645\u064a\u0639\u0647\u0645 \u062d\u0648\u0644\u064a\n\u0644\u0643\u0646 \u060c\u060c\n\u0643\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1493638202816872451",
#         "text": "RT @V_USA: NOT TAEHYUNG \ud83d\ude2d\n\n#GetWellSoonTaehyung\n#GetWellSoonV\nWE LOVE YOU TAEHYUNG"
#     }
# }
# {
#     "data": {
#         "id": "1493638202791321601",
#         "text": "#2022Feb15Coup \n#WhatsHappeningInMyanmar https://t.co/gWfiSkCuo7"
#     }
# }
# {
#     "data": {
#         "id": "1493638202808102915",
#         "text": "RT @jypesmina: they finally let chaeyoung's tattoos breathe without those tapes.. AND IF sleeveless chaeyoung showed up it'll be over for me"
#     }
# }
# {
#     "data": {
#         "id": "1493638202799894535",
#         "text": "1493638195468247049"
#     }
# }
# {
#     "data": {
#         "id": "1493638202804121612",
#         "text": "RT @CatoCrane: Display Case Of Approx. 32 #WW1 &amp; #WW2 Medals inc. Orders of St.John of Jerusalem - This &amp; Others from a Private Collection\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1493638202812661760",
#         "text": "RT @itz_Vidhan: Everyone kindly drop 200 comments in this post between 7 to 9 pm as it will massivley increase the engagement\n\nSend Ss in c\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1493638198630699012",
#         "text": "Me he pelado,ya tocaba"
#     }
# }
# {
#     "data": {
#         "id": "1493638202791501826",
#         "text": "@orahounbelnick Ipnosi collettiva !"
#     }
# }
# {
#     "data": {
#         "id": "1493638202795741194",
#         "text": "RT @Christi52204223: https://t.co/KEtCCcv41G #buca #kar\u015f\u0131yaka do\u011frulara has\u0131m,"
#     }
# }
# {
#     "data": {
#         "id": "1493638202812518400",
#         "text": "\u0639\u0644\u0649 \u0627\u0644\u0631\u063a\u0645 \u0645\u0646 \u0639\u062f\u062f \u0627\u062d\u0628\u0627\u0628\u064a \u0625\u0644\u0627 \u0623\u0646\u064a \u0623\u0634\u0639\u0631 \u0648\u0643\u0623\u0646\u064a \u0628\u0644\u0627 \u0631\u0648\u062d \u0628\u0644\u0627 \u0645\u0634\u0627\u0639\u0631"
#     }
# }
# {
#     "data": {
#         "id": "1493638202799886340",
# ...
#         "text": "RT @HodelIngrid: MOBILITY TRAINING!\nMove ya dang body streak DAY 238\n\nCLICK LINK in bio to workout with me! \ud83d\ude4c\ud83d\udc4d\ud83d\udc95\n\n#Ingrid100FitDays #fitness\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1493638253123358722",
#         "text": "\u30a8\u30ea\u30fc\u30c8\u96c6\u4f1a\u304a\u75b2\u308c\u3055\u307e\u3067\u3057\u305f\ud83c\udf4b\n\u7d50\u679c\u306f3\u4f4d\ud83c\udf89\n\u524d\u56de\u3068\u9055\u3046\u30e1\u30f3\u30d0\u30fc\u3067\u30ec\u30e2\u30f3\u30c1\u30fc\u30e0\u3068\u3057\u3066\u3084\u308b\u306e\u306f\u30c9\u30ad\u30c9\u30ad\u3060\u3063\u305f\u3051\u308c\u3069\u697d\u3057\u304b\u3063\u305f(*\u00b4\ua4b3`*) https://t.co/zBn62jtdNv"
#     }
# }
# {
#     "data": {
#         "id": "1493638257325662212",
#         "text": "@kagechi56 \u30ac\u30c1\u30e3\uff1f"
#     }
# }
# {
#     "data": {
#         "id": "1493638257313292293",
#         "text": "@childefest Pov I am gonna legalize arson"
#     }
# }
# {
#     "data": {
#         "id": "1493638253152546821",
#         "text": "Haftan\u0131n Yalanlar\u0131 2\n\n\u274cKemal K\u0131l\u0131\u00e7daro\u011flu, Bursa-Yeni\u015fehir-Osmaneli ve Band\u0131rma-Bursa-Yeni\u015fehir-Osmaneli Y\u00fcksek H\u0131zl\u0131 Tren Hatlar\u0131 ihalelerinde yolsuzluk oldu\u011funu s\u00f6yledi\n\n\u2705Ula\u015ft\u0131rma ve Altyap\u0131 Bakanl\u0131\u011f\u0131 K\u0131l\u0131\u00e7daro\u011flu\u2019nun yolsuzluk iddialar\u0131n\u0131 madde madde a\u00e7\u0131klayarak yalanlad\u0131 https://t.co/djHHG9WUnt"
#     }
# }
# {
#     "data": {
#         "id": "1493638257338376195",
#         "text": "@conflrry te conheci com essa pack"
#     }
# }
# {
#     "data": {
#         "id": "1493638257342836736",
#         "text": "RT @Paipaiztar: \u0e1e\u0e39\u0e14\u0e16\u0e36\u0e07\u0e40\u0e23\u0e37\u0e48\u0e2d\u0e07\u0e21\u0e21.\u0e40\u0e04\u0e2d\u0e41\u0e1e\u0e17\u0e17\u0e35\u0e48\u0e0a\u0e2d\u0e1a\u0e21\u0e32\u0e01\u0e31\u0e1a\u0e25\u0e34\u0e1f\u0e15\u0e4c\u0e41\u0e25\u0e30\u0e2b\u0e25\u0e31\u0e07\u0e40\u0e27\u0e17\u0e35 \u0e40\u0e04\u0e22\u0e40\u0e2b\u0e47\u0e19\u0e04\u0e19\u0e41\u0e0b\u0e27\u0e2d\u0e22\u0e39\u0e48\u0e27\u0e48\u0e32\u0e0a\u0e37\u0e48\u0e2d\u0e04\u0e39\u0e48\u0e19\u0e35\u0e49 \u53cc\u5b87\u7535\u53f0 \u0e2b\u0e23\u0e37\u0e2d sydt \u0e19\u0e31\u0e49\u0e19 \u0e08\u0e23\u0e34\u0e07\u0e46 dt \u0e43\u0e19\u0e17\u0e35\u0e48\u0e19\u0e35\u0e49\u0e17\u0e35\u0e48\u0e41\u0e1b\u0e25\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1493638253139873798",
#         "text": "MN tava jogando Minecraft e me reparo com isso, que seed \u00e9 essa: 1252440507\nAs cordenadas s\u00e3o : 1391,39,-298 https://t.co/NZ58790voL"
#     }
# }
# {
#     "data": {
#         "id": "1493638253119152128",
#         "text": "RT @aussiebarbie07: Welcome home baby \ud83d\ude09\n\nLink for nudes \u23ec\ufe0f https://t.co/ekDYo5NvIC"
#     }
# }
# {
#     "data": {
#         "id": "1493638253127225347",
#         "text": "#AAHxC | \ud83d\udc80\ud83d\udc4a\ud83c\udffb | Sigo sin parar, gracias a todos por estar cada d\u00eda. \ud83d\udc49\ud83c\udffb @crestametalica 16 a\u00f1os surfeando la cresta de la ola Continuamos surfeando la ola hoy 15 de febrero de 2022, celebrando los 16 a\u00f1os de Cresta Metalica Producciones, cargados de\u2026 https://t.co/VmlijWpxU1 https://t.co/RPyTiuhzlu"
#     }
# }
# {
#     "data": {
#         "id": "1493638257350897666",
#         "text": "@CoachMikeDeFaz"
#     }
# }
# {
#     "data": {
#         "id": "1493638253127561216",
#         "text": "Let's get theat 10M views ASAP!!!\nWE CAN DO THIS....\nLet's be consistent!!!\n\nIT'S OKAY JIKJIN\n#STREAM_JIKJIN\n#\ud2b8\uba54_\ub108\uc5d0\uac8c\ub85c_\uc9c1\uc9c4\n@treasuremembers https://t.co/eeFajDl7mc"
#     }
# }
# {
#     "data": {
#         "id": "1493638257342623753",
#         "text": "RT @innercitypress: As filed. \"Virginia Giuffre and Prince Andrew have reached an out of court settlement... (the sum of which is not being\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1493638257338462213",
#         "text": "\u064a\u0627 \u0647\u062f\u0648\u0631\u0647\ud83e\udd7a\u0627\u0646\u0627 \u0628\u062d\u0628\u0643\ud83d\udc8b\ud83d\udda4 https://t.co/P4zmBcvGxF"
#     }
# }
# {
#     "data": {
#         "id": "1493638257325789188",
#         "text": "RT @FoxNews: Reporter's Notebook: Why 2022 midterms could mirror 2010 bloodbath for Democrats \nhttps://t.co/UU5kzhoId2"
#     }
# }
# {
#     "data": {
#         "id": "1493638253140148225",
#         "text": "@VanKhanhDuy4 @ThaiMinhTan5 @VanManhTan2 https://t.co/h180a1fVOY"
#     }
# }
# {
#     "data": {
#         "id": "1493638257338421252",
#         "text": "@NicolasRiax @CallmeMariepal @HerbelPhilippe Ce \"chantage\" a d\u00e9j\u00e0 sauv\u00e9 4000 vies. Il n'est peut \u00eatre plus n\u00e9cessaire aujourd'hui (\u00e0 voir avec les epidemio) mais a fait du bien."
#     }
# }
# {
#     "data": {
#         "id": "1493638257317400583",
#         "text": "@Coraillye oui..mais l\u00e0 on atteint le sommet, c'est un truc de ouf"
#     }
# }
# {
#     "data": {
#         "id": "1493638257346809856",
#         "text": "RT @qudsn: \u0641\u064a \u0628\u064a\u0627\u0646 \u0635\u062d\u0641\u064a... \u0627\u0644\u0641\u0635\u0627\u0626\u0644 \u0641\u064a \u063a\u0632\u0629: \"\u0644\u0646 \u0646\u062a\u0648\u0627\u0646\u0649 \u0623\u0628\u062f\u0627\u064b \u0639\u0646 \u062d\u0645\u0627\u064a\u0629 \u0627\u0644\u0648\u062c\u0648\u062f \u0627\u0644\u0641\u0644\u0633\u0637\u064a\u0646\u064a \u0641\u0633\u064a\u0641 \u0627\u0644\u0642\u062f\u0633 \u0645\u0627 \u064a\u0632\u0627\u0644 \u0645\u0634\u0631\u0639\u0627\u064b\". https://t.co/7cRtc2Fn74"
#     }
# }
# {
#     "data": {
#         "id": "1493638257321680896",
#         "text": "RT @BRGoals: \ud83e\udd14 https://t.co/CUjOReTc9c"
#     }
# }
# {
#     "data": {
#         "id": "1493638257313202179",
#         "text": "@MOSS_Egypt #\u0645\u0627\u062c\u0633\u062a\u064a\u0631_\u064a\u0635\u0631\u062e\n#\u0627\u0631\u062d\u0645\u0648\u0627_\u062d\u0645\u0644\u0629_\u0627\u0644\u0645\u0627\u062c\u0633\u062a\u064a\u0631\n#\u0627\u063a\u064a\u062b\u0648\u0627_\u062d\u0645\u0644\u0629_\u0627\u0644\u062f\u0643\u062a\u0648\u0631\u0627\u0647\n#\u0661\u0669\u0667\u0664\u062a\u0639\u064a\u064a\u0646_\u0627\u0644\u0628\u0627\u062d\u062b\u064a\u0646"
#     }
# }
# {
#     "data": {
#         "id": "1493638257346711553",
#         "text": "RT @abhirajashekar: MUMBAI! It's Time To Recreate The #VikrantRonaSwag Now in @_PVRCinemas @OberoiMall \n\nComing soon to all major cities ac\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1493638257338642432",
#         "text": "RT @woehPR: \uc911\uac04\uc5d0 \uccd0\ub2e4\ubcf4\ub294 \uac70 \ub108\ubb34 \ud0b9\ubc1b\ub294\ub370 \uc65c \uadf8\ub807\uac8c\uae4c\uc9c0 \ub3cc\ub824\uc11c \uccd0\ub2e4\ubcf4\ub294\uac70\uc57c? https://t.co/gyqXMAAYdT"
#     }
# }
# {
#     "data": {
#         "id": "1493638253144014848",
#         "text": "I am willing to sign with larger news stations @BallySportsSD https://t.co/KpgX07gk5R"
#     }
# }
# {
#     "data": {
#         "id": "1493638257338322947",
#         "text": "@dinathanthi \u0baa\u0bc6\u0ba3\u0bcd\u0baa\u0bbf\u0bb3\u0bcd\u0bb3\u0bc8\u0b95\u0bb3\u0bbf\u0b9f\u0bae\u0bcd \u0bb9\u0bbf\u0b9c\u0bbe\u0baa\u0bcd\u0b8e\u0ba9\u0bcd\u0bb1\u0bc1 \u0bb5\u0ba9\u0bcd\u0bae\u0bc1\u0bb1\u0bc8\u0b9a\u0bc6\u0baf\u0bcd\u0b95\u0bbf\u0bb1\u0bbe\u0bb0\u0bcd\u0b95\u0bb3\u0bcd\n\n\u0bae\u0bbe\u0b9f\u0bcd\u0b9f\u0bbf\u0ba9\u0bcd\u0baa\u0bc6\u0baf\u0bb0\u0bbe\u0bb2\u0bcd \u0bae\u0ba9\u0bbf\u0ba4\u0bb0\u0bcd\u0b95\u0bb3\u0bc8 \u0b95\u0bca\u0bb2\u0bcd\u0b95\u0bbf\u0bb1\u0bbe\u0bb0\u0bcd\u0b95\u0bb3\u0bcd\n\n\u0baa\u0bbe\u0bb2\u0bbf\u0baf\u0bb2\u0bcd \u0bb5\u0ba9\u0bcd\u0bae\u0bc1\u0bb1\u0bc8\u0baf\u0bbe\u0bb2\u0bcd \u0baa\u0bbe\u0ba4\u0bbf\u0b95\u0bcd\u0b95\u0baa\u0bcd\u0baa\u0b9f\u0bcd\u0b9f \u0baa\u0bc6\u0ba3\u0bcd\u0b95\u0bb3\u0bc8 \u0b95\u0bc1\u0b9f\u0bc1\u0bae\u0bcd\u0baa\u0ba4\u0bcd\u0ba4\u0bbe\u0bb0\u0bc8 \u0bae\u0bbf\u0bb0\u0b9f\u0bcd\u0b9f\u0bc1\u0b95\u0bbf\u0bb1\u0bbe\u0bb0\u0bcd\u0b95\u0bb3\u0bcd\n\u0b95\u0bca\u0bb2\u0bcd\u0b95\u0bbf\u0bb1\u0bbe\u0bb0\u0bcd\u0b95\u0bb3\u0bcd\n\n\u0baa\u0bca\u0ba4\u0bc1\u0bb5\u0bc6\u0bb3\u0bbf\u0baf\u0bbf\u0bb2\u0bcd \u0b92\u0bb0\u0bc1\u0b95\u0bc1\u0bb1\u0bbf\u0baa\u0bcd\u0baa\u0bbf\u0b9f\u0bcd\u0b9f \u0bae\u0ba4\u0ba4\u0bcd\u0ba4\u0bb5\u0bb0\u0bcd\u0b95\u0bb3\u0bc8 \u0b95\u0bca\u0bb2\u0bcd\u0bb5\u0bcb\u0bae\u0bc6\u0ba9 \u0baa\u0bc7\u0b9a\u0bc1\u0b95\u0bbf\u0bb1\u0bbe\u0bb0\u0bcd\u0b95\u0bb3\u0bcd\n\n\u0bae\u0b95\u0bcd\u0b95\u0bb3\u0bc8 \u0bb5\u0ba3\u0bcd\u0b9f\u0bbf\u0baf\u0bc7\u0bb1\u0bcd\u0bb1\u0bbf \u0b95\u0bca\u0bb2\u0bcd\u0b95\u0bbf\u0bb1\u0bbe\u0bb0\u0bcd\u0b95\u0bb3\u0bcd\n??"
#     }
# }
# {
#     "data": {
#         "id": "1493638257346678784",
#         "text": "RT @pepi_nim_: \u0e04\u0e19\u0e40\u0e21\u0e49\u0e19\u0e40\u0e04\u0e49\u0e32\u0e27\u0e48\u0e32\u0e44\u0e21\u0e48\u0e40\u0e2b\u0e47\u0e19 \u0e40\u0e04\u0e49\u0e32\u0e40\u0e25\u0e22\u0e40\u0e2d\u0e37\u0e49\u0e2d\u0e21\u0e44\u0e1b\u0e40\u0e1b\u0e34\u0e14\u0e44\u0e1f \u0e04\u0e37\u0e2d\u0e41\u0e04\u0e48\u0e19\u0e35\u0e49\u0e40\u0e25\u0e22 \u0e41\u0e04\u0e48\u0e19\u0e35\u0e49\u0e41\u0e2b\u0e25\u0e30 \u0e40\u0e04\u0e49\u0e32\u0e01\u0e47\u0e2b\u0e25\u0e48\u0e2d\u0e41\u0e25\u0e49\u0e27 \u3160\u3160\u3160 \u0e2b\u0e25\u0e48\u0e2d \u0e23\u0e27\u0e22 \u0e40\u0e1b\u0e47\u0e19\u0e01\u0e31\u0e19\u0e40\u0e2d\u0e07 \u0e43\u0e08\u0e14\u0e35 \u0e21\u0e35\u0e19\u0e49\u0e33\u0e43\u0e08 \u0e2b\u0e23\u0e38\u0e01\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1493638257330040832",
#         "text": "Ven a ver al gamer hablamesocio\ud83c\udfaeTA  retransmitiendo en directo en #BIGOLIVE https://t.co/X0piRea7ZP https://t.co/nRpwBo3Luu"
#     }
# }
# {
#     "data": {
#         "id": "1493638257342513160",
#         "text": "RT @erigori04: \u307c\u3088\uff5e\u3093\ud83d\ude06 https://t.co/4FOXAGPOYt"
#     }
# }
# {
#     "data": {
#         "id": "1493638257346846723",
#         "text": "RT @ayedocc: black history month just keeps getting worse"
#     }
# }
# {
#     "data": {
#         "id": "1493638257351049217",
#         "text": "Got a lot of speaking going on for Feb OPEX...\ud83e\udd14 https://t.co/cIgiekaRd6"
#     }
# }
# {
#     "data": {
#         "id": "1493638257342664705",
#         "text": "RT @official_ONEUS: [#RAVN] \ud83c\udf39\ud83d\udd25 \ud83d\uddfd https://t.co/kP6qgrSOTH"
#     }
# }
# {
#     "data": {
#         "id": "1493638257346809862",
#         "text": "RT @preparafamilia: Hoy se conmemora el D\u00eda Internacional contra el C\u00e1ncer infantil, una fecha para recordar que los ni\u00f1os merecen tener a\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1493638257338368005",
#         "text": "RT @Barbara4NC: My name is Barbara Gaskins, I am a proud democrat, and I am running to be the first ever Black Congresswoman elected to Nor\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1493638257350950917",
#         "text": "@ActuFoot_ Compte la dessus et boit un coup..."
#     }
# }
# {
#     "data": {
#         "id": "1493638257347014656",
#         "text": "@rgmlk You're so funny and have always brought the best content to the TL!"
#     }
# }
# {
#     "data": {
#         "id": "1493638257351041032",
#         "text": "RT @Klakala4: \u300bhappy family trip\u300a\n. \n.\n.\n.\n.\n. \n.\n . \n#fnafgregory #glamrockfreddy #fnafvanessa #fivenightsatfreddyssecuritybreach #fnafsbf\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1493638257334177803",
#         "text": "@WErnst32 Die k\u00f6nnen nicht z\u00e4hlen \ud83d\ude02"
#     }
# }
# {
#     "data": {
#         "id": "1493638257325887493",
#         "text": "@modakasmir Vi\u015fne"
#     }
# }
# {
#     "data": {
#         "id": "1493638257334226957",
#         "text": "@V_Silva0 mo\u00e7o \u00e9 uma m\u00fasica do tiktok junto com a trend KKKKKKKKKKK"
#     }
# }
# {
#     "data": {
#         "id": "1493638257329983489",
#         "text": "@shitgenial @raphsgm"
#     }
# }
# {
#     "data": {
#         "id": "1493638257346703364",
#         "text": "RT @Royallity01: \ud83d\udca6 \u09ac\u09be\u0997\u09bf\u09af\u09bc\u09be\u09a8 https://t.co/UAaiLpEMnQ"
#     }
# }
# {
#     "data": {
#         "id": "1493638261536739332",
#         "text": "RT @ShopCrunchyroll: The Love Hashira, Mitsuri Kanroji, joins the POP UP PARADE figure series \ud83d\udc97\ud83d\udc9a \n\nGET: https://t.co/WZgnyqNKKc https://t.c\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1493638261524566016",
#         "text": "@kjkyuuu \u0e19\u0e49\u0e2d\u0e07\u0e27\u0e32\u0e19\u0e48\u0e32\u0e23\u0e31\u0e01\u0e2d\u0e35\u0e01\u0e41\u0e25\u0e49\u0e27\u0e27\u0e27 \u0e02\u0e2d\u0e1a\u0e04\u0e38\u0e13\u0e21\u0e32\u0e01\u0e46\u0e19\u0e30\u0e04\u0e30 \ud83e\udd7a\ud83d\udc95"
#     }
# }
# {
#     "data": {
#         "id": "1493638257338634240",
#         "text": "RT @limelightahgase: BamBam: comeback is sooner than you think\nYugyeom: we all make songs for GOT7 \nJinyoung: this album that we're talking\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1493638261532733441",
#         "text": "RT @FS_Yusuf_: Until we fix our institutions and build a formidable criminal justice system, so many Abba Kyari would continue to flourish\u2026"
#     }
# }
# {
#     "data": {
#         "id": "1493638261520097282",
#         "text": "Oh, mama... https://t.co/bty9tF3acU"
#     }
# }
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-972361fa1b80> in <module>()
#       1 if __name__ == "__main__":
# ----> 2     main()
#
# <ipython-input-6-753b87cff1d2> in main()
#       3     timeout = 0
#       4     while True:
# ----> 5         connect_to_endpoint(url)
#       6         timeout += 1
#
# <ipython-input-5-830756d6cb01> in connect_to_endpoint(url)
#       2     response = requests.request("GET", url, auth=bearer_oauth, stream=True)
#       3     print(response.status_code)
# ----> 4     for response_line in response.iter_lines():
#       5         if response_line:
#       6             json_response = json.loads(response_line)
#
# /usr/local/lib/python3.7/dist-packages/requests/models.py in iter_lines(self, chunk_size, decode_unicode, delimiter)
#     793         pending = None
#     794
# --> 795         for chunk in self.iter_content(chunk_size=chunk_size, decode_unicode=decode_unicode):
#     796
#     797             if pending is not None:
#
# /usr/local/lib/python3.7/dist-packages/requests/models.py in generate()
#     749             if hasattr(self.raw, 'stream'):
#     750                 try:
# --> 751                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     752                         yield chunk
#     753                 except ProtocolError as e:
#
# /usr/local/lib/python3.7/dist-packages/urllib3/response.py in stream(self, amt, decode_content)
#     490         """
#     491         if self.chunked and self.supports_chunked_reads():
# --> 492             for line in self.read_chunked(amt, decode_content=decode_content):
#     493                 yield line
#     494         else:
#
# /usr/local/lib/python3.7/dist-packages/urllib3/response.py in read_chunked(self, amt, decode_content)
#     666
#     667             while True:
# --> 668                 self._update_chunk_length()
#     669                 if self.chunk_left == 0:
#     670                     break
#
# /usr/local/lib/python3.7/dist-packages/urllib3/response.py in _update_chunk_length(self)
#     598         if self.chunk_left is not None:
#     599             return
# --> 600         line = self._fp.fp.readline()
#     601         line = line.split(b';', 1)[0]
#     602         try:
#
# /usr/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# /usr/lib/python3.7/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1069                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#    1073             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.7/ssl.py in read(self, len, buffer)
#     927         try:
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#     931                 return self._sslobj.read(len)
#
# KeyboardInterrupt:
