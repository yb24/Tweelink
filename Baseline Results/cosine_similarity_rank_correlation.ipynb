# %% [markdown]
# Import Statements

# %%
import pandas as pd
import numpy as np
import csv
import json
from itertools import islice
from collections import OrderedDict
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import nltk
from glob import glob
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from tqdm import tqdm
import pickle
import math
from sklearn.model_selection import train_test_split
import operator
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('corpus')
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from scipy import stats
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Error loading corpus: Package 'corpus' not found in index

# %%
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file1 = open("/content/drive/MyDrive/Tweelink_Dataset/twitter_base_preprocessed.pkl", "rb")
df = pickle.load(file1)
file1.close()

# %%
df.head()
# Out:
#                author id                 created_at geo country country_code  \
# 0           1952510090.0  2022-02-14 00:11:44+00:00
# 1             20453105.0  2022-02-14 00:04:56+00:00
# 2  1492660754998247424.0  2022-02-14 00:39:55+00:00
# 3            117812637.0  2022-02-14 00:20:05+00:00
# 4  1490044524604928000.0  2022-02-14 00:10:26+00:00
#
#   place_full_name place_name place_type                     id lang  ...  \
# 0                                        1493015060943454208.0   en  ...
# 1                                        1493013352938934272.0   en  ...
# 2                                        1493022155239534336.0   en  ...
# 3                                        1493017163485044736.0   en  ...
# 4                                        1493014734903382016.0   en  ...
#
#                 source                                              tweet  \
# 0  Twitter for Android  ð¥ð¥ð¥ð¥ð¥ð¥ð¥â¤µï¸â¤µï¸â¤µï¸...
# 1  Twitter for Android  It's too bad these guys are afraid of needles,...
# 2  Twitter for Android  Cowboy dressed as #Furries now available at th...
# 3   Twitter for iPhone  We blocked these trucks from entering the dntn...
# 4   Twitter for iPhone  Krista is very pleased with how the @RCMPONT r...
#
#                                             hashtags sensitive  \
# 0  CommonSenseGunLaws,GunControlNow,GunSafes,GunS...     False
# 1          ClownConvoy,FreeDumbConvoy,OttawaOccupied     False
# 2                    Furries,RamRanch,OttawaOccupied     False
# 3                           Riverside,OttawaOccupied     False
# 4  FluTruxKlanGoHome,OttawaOccupied,kkkonvoy,Otta...     False
#
#                       urls context_text context_probability context_type  \
# 0  https://t.co/LjkEup24Dk                              0.0
# 1  https://t.co/MmFzuFjIDR                              0.0
# 2  https://t.co/GBuBCUtpXe                              0.0
# 3  https://t.co/KzLkBZvjgD                              0.0
# 4  https://t.co/kAm5KNugdA                              0.0
#
#                                    Preprocessed_Data   Date_Only
# 0  [ð¥ð¥ð¥ð¥ð¥ð¥ð¥â¤µï¸â¤µï¸â¤µï¸...  2022-02-14
# 1  [bad, guy, afraid, needle, twinrix, would, pre...  2022-02-14
# 2  [cowboy, dressed, furries, available, ramranch...  2022-02-14
# 3  [blocked, truck, entering, dntn, core, riversi...  2022-02-14
# 4  [krista, pleased, rcmpont, responded, maskless...  2022-02-14
#
# [5 rows x 24 columns]

# %%
u_base_hashtag = input("Enter base hashtag: ")
u_time = input("Enter time: ")
u_location = input("Enter Location: ")
# Out:
# Enter base hashtag: TaylorSwift
# Enter time: 2022-02-18
# Enter Location: USA

# %%
import datetime
tweet_query = []
format = '%Y-%m-%d'
u_present_date = datetime.datetime.strptime(u_time, format)
u_prev_date = u_present_date - datetime.timedelta(days=1)
u_next_date = u_present_date + datetime.timedelta(days=1)
df_query = df.loc[df['hashtags'].str.contains(u_base_hashtag) & df['Date_Only'].isin([str(u_present_date.date()), str(u_prev_date.date()), str(u_next_date.date())])]

# %%
df_query.head()
# Out:
#                 author id                 created_at geo country country_code  \
# 6537             21449347  2022-02-17 00:05:19+00:00
# 6538  1494103377155923970  2022-02-17 00:46:41+00:00
# 6539  1024043374263844865  2022-02-17 00:01:30+00:00
# 6540   981670169289216000  2022-02-17 00:44:59+00:00
# 6541            182993199  2022-02-17 00:57:06+00:00
#
#      place_full_name place_name place_type                   id lang  ...  \
# 6537                                        1494100611293454338   en  ...
# 6538                                        1494111020369039362   en  ...
# 6539                                        1494099650009124866   en  ...
# 6540                                        1494110595657830403   en  ...
# 6541                                        1494113643046346755   en  ...
#
#                    source                                              tweet  \
# 6537   Twitter for iPhone  What is this. #TaylorSwift https://t.co/IFZ0uV...
# 6538      Twitter Web App  I am on a mission to capture the heart of Tayl...
# 6539  Twitter for Android  Speak Now (Taylor's Version) ððð conc...
# 6540      Twitter Web App  Bike Shorts @\nRolling Casual Collections\nhtt...
# 6541   Twitter for iPhone  Day 47 of me trying to get @taylorswift13 to h...
#
#                                                hashtags sensitive  \
# 6537                                        TaylorSwift     False
# 6538                                        TaylorSwift     False
# 6539  TaylorSwift,TaylorsVersion,speaknowtaylorsversion     False
# 6540  fashionstyle,beyoncÃ©,rihanna,iamcardib,JLo,Ta...     False
# 6541            TaylorSwift,TaylorsVersion,taylornation     False
#
#                                                    urls context_text  \
# 6537                            https://t.co/IFZ0uVvkLb
# 6538                            https://t.co/mn9nG548h4
# 6539                            https://t.co/UAA8KAaC9E
# 6540  https://t.co/5RKzpr8zRl,https://t.co/d6Tkhu6dn...
# 6541                            https://t.co/q5ztjLsMvQ
#
#      context_probability context_type  \
# 6537                 0.0
# 6538                 0.0
# 6539                 0.0
# 6540                 0.0
# 6541                 0.0
#
#                                       Preprocessed_Data   Date_Only
# 6537    [taylorswift, http, tcoifz0uvvklb, taylorswift]  2022-02-17
# 6538  [mission, capture, heart, taylor, swift, start...  2022-02-17
# 6539  [speak, taylor, s, version, ððð, conc...  2022-02-17
# 6540  [bike, short, rolling, casual, collection, htt...  2022-02-17
# 6541  [day, 47, trying, get, taylorswift13, hopefull...  2022-02-17
#
# [5 rows x 24 columns]

# %%
for tweet in df_query['Preprocessed_Data']:
  tweet_query.extend(tweet)

# %%
tweet_query
# Out:
# ['taylorswift',
#  'http',
#  'tcoifz0uvvklb',
#  'taylorswift',
#  'mission',
#  'capture',
#  'heart',
#  'taylor',
#  'swift',
#  'starting',
#  'car',
#  '623',
#  'dollar',
#  'bank',
#  'account',
#  'job',
#  'crew',
#  'member',
#  'pizza',
#  'joint',
#  '140',
#  'pound',
#  'overweight',
#  'taylorswift13',
#  'taylorswift',
#  'http',
#  'tcomn9ng548h4',
#  'taylorswift',
#  'speak',
#  'taylor',
#  's',
#  'version',
#  'ð\x9f\x92\x9cð\x9f\x92\x9cð\x9f\x92\x9c',
#  'concept',
#  'hope',
#  'u',
#  'like',
#  'ð\x9f\x92\x97',
#  'taylorswift',
#  'taylorsversion',
#  'speaknowtaylorsversion',
#  'http',
#  'tcouaa8kaac9e',
#  'taylorswift',
#  'taylorsversion',
#  'speaknowtaylorsversion',
#  'bike',
#  'short',
#  'rolling',
#  'casual',
#  'collection',
#  'http',
#  'tco5rkzpr8zrl',
#  'fashionstyle',
#  'beyoncã©',
#  'rihanna',
#  'iamcardib',
#  'jlo',
#  'taylorswift',
#  'missyelliott',
#  'ladygaga',
#  'kyliejenner',
#  'zendaya',
#  'kimkardashian',
#  'wnba',
#  'usweekly',
#  'http',
#  'tcod6tkhu6dnx',
#  'fashionstyle',
#  'beyoncã©',
#  'rihanna',
#  'iamcardib',
#  'jlo',
#  'taylorswift',
#  'missyelliott',
#  'ladygaga',
#  'kyliejenner',
#  'zendaya',
#  'kimkardashian',
#  'wnba',
#  'usweekly',
#  'day',
#  '47',
#  'trying',
#  'get',
#  'taylorswift13',
#  'hopefully',
#  'like',
#  'comment',
#  'tweet',
#  'taylornation13',
#  'taylorswift',
#  'taylorsversion',
#  'taylornation',
#  'http',
#  'tcoq5ztjlsmvq',
#  'taylorswift',
#  'taylorsversion',
#  'taylornation',
#  'check',
#  'taylor',
#  'swift',
#  'pamphlet',
#  'speak',
#  'tour',
#  '2011',
#  'booklet',
#  'http',
#  'tcobgap8nyj2u',
#  'via',
#  'ebay',
#  'taylorswift',
#  'pamphlet',
#  'speaknowtour2011',
#  'booklet',
#  'ebay',
#  'auction',
#  'lighthousebooksjapan',
#  'taylorswift',
#  'pamphlet',
#  'speaknowtour2011',
#  'booklet',
#  'ebay',
#  'auction',
#  'lighthousebooksjapan',
#  'find',
#  'starbucks',
#  'drivethru',
#  'listening',
#  'taylorswift13',
#  'every',
#  'morning',
#  'ð\x9f¤\x8dâ\x98\x95ï¸\x8fð\x9f\x8e¶',
#  'sweatshirt',
#  'available',
#  'swiftie',
#  'taylorswift',
#  'http',
#  'tcopgaxw8uc5t',
#  'http',
#  'tco73nypqtlep',
#  'swiftie',
#  'taylorswift',
#  'ok',
#  'people',
#  'taylor',
#  'swift',
#  'blanket',
#  'also',
#  'pet',
#  'use',
#  'iâ\x80\x99m',
#  'worried',
#  'cat',
#  'knead',
#  'pull',
#  'thread',
#  'itâ\x80\x99s',
#  'first',
#  'one',
#  'iâ\x80\x99ve',
#  'ever',
#  'want',
#  'protect',
#  'cost',
#  'also',
#  'want',
#  'use',
#  'itð\x9f¤·ð\x9f\x8f¼â\x80\x8dâ\x99\x80ï¸\x8fð\x9f¥´ð\x9f\x98\x82',
#  'taylorswift',
#  'taylorswift',
#  'anybody',
#  'want',
#  '2',
#  'comment',
#  'show',
#  'ur',
#  'swiftie',
#  'passport',
#  'charlieneff',
#  'kennedynation',
#  'enews',
#  'elleduncanespn',
#  'taylorswift',
#  'elvisduran',
#  'taylorsversion',
#  'jalenrose',
#  'fdrlst',
#  'dcexaminer',
#  'ainsleyearhardt',
#  'jrpsaki',
#  'nytimes',
#  'nytimes',
#  'pdoocy',
#  'tmz',
#  'tmzlive',
#  'dollyparton',
#  'cardinaldolan',
#  'http',
#  'tcolfquouotor',
#  'swiftie',
#  'taylorswift',
#  'taylorsversion',
#  'nytimes',
#  'tmz',
#  'day',
#  '103',
#  'taylorswift13',
#  'taylornation13',
#  'fiancã©',
#  'fan',
#  'since',
#  '1st',
#  'uk',
#  'show',
#  'seen',
#  'every',
#  'one',
#  'since',
#  'play',
#  'album',
#  'road',
#  'trip',
#  'would',
#  'mean',
#  'world',
#  'record',
#  'short',
#  'clip',
#  'play',
#  'weddingâ\x99¥ï¸\x8f',
#  'taylorswiftâ',
#  'â',
#  'â',
#  'â',
#  'â',
#  'â',
#  'swifties',
#  'taylorswift',
#  'taylorswift',
#  'swifties',
#  'taylorswift',
#  'hello',
#  'swiftie',
#  'twitter',
#  'anyone',
#  'recognize',
#  'autograph',
#  'pls',
#  'circulate',
#  'taylorswift',
#  'redtaylorsversion',
#  'thejokerandthequeen',
#  'taylornation13',
#  'taylorswift13',
#  'http',
#  'tcoicyydvjs05',
#  'taylorswift',
#  'redtaylorsversion',
#  'thejokerandthequeen',
#  'swifferupdates',
#  'taylorswift13',
#  'joker',
#  'queen',
#  'focused',
#  'playlist',
#  'spotify',
#  'ð\x9f\x91\x87',
#  'http',
#  'tcoibigm6cmn0',
#  'edsheeran',
#  'taylorswift',
#  'edandtaylor',
#  'thejokerandthequeen',
#  'jokerandthequeen',
#  'taylorswift13',
#  'edsheeran',
#  'taylorswift',
#  'edandtaylor',
#  'thejokerandthequeen',
#  'jokerandthequeen',
#  'spotify',
#  'hearing',
#  'tear',
#  'ricochet',
#  'folklore',
#  'long',
#  'pond',
#  'studio',
#  'whole',
#  'experience',
#  'song',
#  'good',
#  'ð\x9f\x98\xadð\x9f\x98\xadð\x9f\x98\xadð\x9f\x98\xadð\x9f\x98\xad',
#  'taylorswift',
#  'taylorsversion',
#  'folklore',
#  'mytearsricochet',
#  'taylorswift',
#  'taylorsversion',
#  'folklore',
#  'mytearsricochet',
#  'look',
#  'arrived',
#  'iâ\x80\x99m',
#  'love',
#  'ð\x9f\x98\x8d',
#  'redcardigan',
#  'taylorswift',
#  'redtaylorsversion',
#  'cardigan',
#  'nzswiftie',
#  'taylorswift13',
#  'taylornation13',
#  'http',
#  'tcojr2ohnz9cm',
#  'redcardigan',
#  'taylorswift',
#  'redtaylorsversion',
#  'cardigan',
#  'nzswiftie',
#  'taylorswift',
#  'dating',
#  'kimjongun',
#  'http',
#  'tcolwkc06xrdp',
#  'http',
#  'tcopzmbt3udpc',
#  'taylorswift',
#  'kimjongun',
#  'wordle',
#  'today',
#  'allowed',
#  'play',
#  'taylorswift',
#  'give',
#  'husband',
#  'hint',
#  'ð\x9f¥³',
#  'wordle',
#  'taylorswift',
#  'linzyp0068',
#  'amazing',
#  'taylorswift',
#  'taylornation',
#  'http',
#  'tcovakfcesijt',
#  'taylorswift',
#  'taylornation',
#  'vote',
#  'swifties',
#  'bestfanarmy',
#  'iheartawardsï¸\x8e',
#  'taylorswift',
#  'http',
#  'tcozkrgqa7pxx',
#  'swifties',
#  'bestfanarmy',
#  'iheartawardsï¸\x8e',
#  'taylorswift',
#  'joker',
#  'queen',
#  'ð\x9f\x8f\x86',
#  'anitta',
#  'bring',
#  'w',
#  'kisskombat',
#  'soniconair',
#  '900pm',
#  'tonight',
#  'edsheeran',
#  'x',
#  'taylorswift13',
#  'v',
#  'anitta',
#  'anitta',
#  'boysdontcry',
#  'taylorswift',
#  'edsheeran',
#  'thejokerandthequeen',
#  'kisskombat',
#  'anitta',
#  'boysdontcry',
#  'taylorswift',
#  'edsheeran',
#  'thejokerandthequeen',
#  'already',
#  'lake',
#  'vinyl',
#  'taylorswift',
#  'folklore',
#  'rsd',
#  'http',
#  'tconl4efegofp',
#  'taylorswift',
#  'folklore',
#  'rsd',
#  'swifties',
#  'taylorswift',
#  'dislike',
#  'http',
#  'tcocz08aqc8az',
#  'taylorswift',
#  'dislike',
#  'like',
#  'follow',
#  'share',
#  'miss',
#  '2000',
#  'nfts',
#  'ranging',
#  'rarity',
#  'collect',
#  'mint',
#  'date',
#  'amp',
#  'website',
#  'coming',
#  'soon',
#  'nft',
#  'nfts',
#  'nftart',
#  'nftcollectors',
#  'nftcommunity',
#  'nftcollector',
#  'nftdrop',
#  'nftartists',
#  'opensea',
#  'openseanft',
#  'taylorswift',
#  'drake',
#  'billgates',
#  'elonmusk',
#  'aoc',
#  'http',
#  'tcoerfexbprkv',
#  'nfts',
#  'rarity',
#  'nft',
#  'nfts',
#  'nftart',
#  'nftcollectors',
#  'nftcommunity',
#  'nftcollector',
#  'nftdrop',
#  'nftartists',
#  'opensea',
#  'openseanft',
#  'taylorswift',
#  'drake',
#  'billgates',
#  'elonmusk',
#  'aoc',
#  'make',
#  'happy',
#  'turn',
#  'back',
#  'sad',
#  'yeah',
#  'nothing',
#  'hate',
#  'guess',
#  'stumble',
#  'home',
#  'cat',
#  'ugh',
#  'alone',
#  'unless',
#  'wan',
#  'na',
#  'come',
#  'along',
#  'taylorswift',
#  'http',
#  'tco0xk50g55za',
#  'taylorswift',
#  'already',
#  'started',
#  'eating',
#  'healthy',
#  'lost',
#  '8',
#  'pound',
#  'since',
#  'decided',
#  'start',
#  'quest',
#  'tomorrow',
#  'take',
#  'picture',
#  'scale',
#  'get',
#  'documented',
#  'starting',
#  'point',
#  'tonight',
#  'going',
#  'quit',
#  'smoking',
#  'drinking',
#  'cheat',
#  'day',
#  'drinking',
#  'taylorswift13',
#  'taylorswift',
#  'taylorswift',
#  'looking',
#  'moot',
#  'lt',
#  '3',
#  'anime',
#  'manga',
#  'jjk',
#  'snk',
#  'kny',
#  'yuukoku',
#  'moriarty',
#  'blue',
#  'period',
#  'toradora',
#  'yakusoku',
#  'neverlandâ\x80¦',
#  'book',
#  'series',
#  'music',
#  'pinterest',
#  'youtube',
#  'journal',
#  'taylor',
#  'swift',
#  'taylorswift',
#  'animetwt',
#  'mangatwt',
#  'booktwt',
#  'gilmoregirls',
#  'rtlike',
#  'help',
#  'taylorswift',
#  'animetwt',
#  'mangatwt',
#  'booktwt',
#  'gilmoregirls',
#  'listening',
#  'taylor',
#  'swift',
#  'probably',
#  'listen',
#  'wip',
#  'playlist',
#  'get',
#  'zone',
#  'click',
#  'playlist',
#  'taylor',
#  'swift',
#  'start',
#  'playing',
#  'ahh',
#  'thatâ\x80\x99s',
#  'better',
#  'writer',
#  'amwriting',
#  'historicalfiction',
#  'writingcommunity',
#  'taylorswift',
#  'http',
#  'tcolduyhohn7w',
#  'wip',
#  'writer',
#  'amwriting',
#  'historicalfiction',
#  'writingcommunity',
#  'taylorswift',
#  'vote',
#  'alltoowelltenminuteversion',
#  'bestlyrics',
#  'iheartawardsï¸\x8e',
#  'taylorswift',
#  'http',
#  'tcomspygluu79',
#  'alltoowelltenminuteversion',
#  'bestlyrics',
#  'iheartawardsï¸\x8e',
#  'taylorswift',
#  'spotifydata',
#  'sanbenito',
#  'taylorswift13',
#  'theweeknd',
#  'eminem',
#  'drake',
#  'btstwt',
#  'edsheeran',
#  'justinbieber',
#  'kanyewest',
#  'juiceworlddd',
#  'taytay',
#  'well',
#  '31m',
#  'club',
#  'ð\x9f¥°ð\x9f\x98\xadð\x9f\x98\x8d',
#  'taylorswift',
#  'http',
#  'tcoj6mjxzr5vr',
#  'taylorswift',
#  'spotify',
#  'taylorswift13',
#  'everybody',
#  'taylorswift',
#  '1989era',
#  'speaknowera',
#  'reputationera',
#  'loverera',
#  'taylorswiftera',
#  'redera',
#  'folkloreera',
#  'evermoreera',
#  'fearlessera',
#  'taylornation13',
#  'http',
#  'tcohocoyiop2w',
#  'taylorswift1989era',
#  'speaknowera',
#  'reputationera',
#  'loverera',
#  'taylorswiftera',
#  'redera',
#  'folkloreera',
#  'evermoreera',
#  'fearlessera',
#  'y100michiana',
#  'leslieonair',
#  'hi',
#  'leslieonair',
#  'play',
#  'alltoowelltaylorsversion',
#  'taylorswift',
#  'y100michiana',
#  'y100top9at9',
#  'please',
#  'thank',
#  'leslie',
#  'ð\x9f\x99\x8f',
#  'http',
#  'tco6ngo0pb2an',
#  'alltoowelltaylorsversion',
#  'taylorswift',
#  'y100top9at9',
#  'spotifydata',
#  'taylorswift13',
#  'dojacat',
#  'billieeilish',
#  'arianagrande',
#  'dualipa',
#  'adele',
#  'karolg',
#  'oliviarodrigo',
#  'rihanna',
#  'lanadelrey',
#  'nice',
#  'taylorswift',
#  '31m',
#  'club',
#  'ð\x9f¥°',
#  'taylorswift',
#  'spotify',
#  'bet',
#  'november',
#  'army',
#  'happy',
#  'get',
#  'abba',
#  'edsheeran',
#  'tonesandi',
#  'harrystyles',
#  'glassanimals',
#  'bringmethehorizon',
#  'eltonjohn',
#  'oliviarodrigo',
#  'billieeilish',
#  'pink',
#  'bts',
#  'taylorswift',
#  'http',
#  'tco4xlcnwfhi0',
#  'army',
#  'abba',
#  'edsheeran',
#  'tonesandi',
#  'harrystyles',
#  'glassanimals',
#  'bringmethehorizon',
#  'eltonjohn',
#  'oliviarodrigo',
#  'billieeilish',
#  'pink',
#  'bts',
#  'taylorswift',
#  'hereâ\x80\x99s',
#  'collection',
#  'song',
#  'taylorswift13',
#  'composed',
#  'take',
#  'look',
#  'follow',
#  'u',
#  'iwmbuzz',
#  'hollywoodsinger',
#  'songscomposedbyher',
#  'taylorswift',
#  'http',
#  'tcongq8ovd0o9',
#  'hollywoodsinger',
#  'songscomposedbyher',
#  'taylorswift',
#  'thinking',
#  'someone',
#  'wondering',
#  'thinking',
#  'meâ\x80¦',
#  'â\x80\x9cwho',
#  'could',
#  'ever',
#  'leave',
#  'darlinâ\x80\x99',
#  'could',
#  'stay',
#  'â\x80\x9d',
#  'butterfly',
#  'idontwanttogethurt',
#  'againandagain',
#  'mamasayslookbeforeyouleap',
#  'taylorswift',
#  'butterfly',
#  'idontwanttogethurt',
#  'againandagain',
#  'mamasayslookbeforeyouleap',
#  'taylorswift',
#  'edsheeran',
#  'taylorswift',
#  'photo',
#  'collage',
#  'edsheeran',
#  'taylorswift13',
#  'â\x9d¤ï¸\x8fâ\x9d¤ï¸\x8fâ\x9d¤ï¸\x8fð\x9f¦\x8bð\x9f¦\x8bð\x9f¦\x8b',
#  'thejokerandthequeen',
#  'â\x80\x94â\x80\x94',
#  'sheerionim',
#  'edsheeranbrcom',
#  'shawnrobb72',
#  'littlebirdsusa',
#  'comfortedsheern',
#  'edsheeransfan4',
#  'shawnrobb72',
#  'edshivers',
#  'tlc0920',
#  'usnims',
#  'barbscr8v',
#  'ucntcmeeeee',
#  'http',
#  'tcoiodne7uxpb',
#  'edsheeran',
#  'taylorswift',
#  'thejokerandthequeen',
#  'joker',
#  'amp',
#  'queen',
#  'repeat',
#  'day',
#  'erâ\x80\x99day',
#  'taylorswift',
#  'edsheeran',
#  'http',
#  'tcovyowzuqvg0',
#  'taylorswift',
#  'edsheeran',
#  'â\x9d¤ï¸\x8fâ\x9d¤ï¸\x8fâ\x9d¤ï¸\x8fâ\x9d¤ï¸\x8f',
#  'walked',
#  'door',
#  'air',
#  'cold',
#  'somethin',
#  'bout',
#  'felt',
#  'like',
#  'home',
#  'somehow',
#  'left',
#  'scarf',
#  'sister',
#  's',
#  'house',
#  'still',
#  'got',
#  'drawer',
#  'even',
#  'taylorswift',
#  'redtaylorsversion',
#  'alltoowelltenminuteversion',
#  'http',
#  'tcotqfxezijlb',
#  'taylorswift',
#  'redtaylorsversion',
#  'alltoowelltenminuteversion',
#  'run',
#  'donâ\x80\x99t',
#  'walk',
#  'swifties',
#  'youâ\x80\x99re',
#  'welcome',
#  'folklore',
#  'taylorswift',
#  'cardigan',
#  'taylornation',
#  'http',
#  'tcono72ldazlc',
#  'folklore',
#  'taylorswift',
#  'cardigan',
#  'taylornation',
#  'better',
#  'ever',
#  'wascall',
#  'want',
#  'taylorswift',
#  'thanks',
#  'xo',
#  'taylorswift',
#  'something',
#  'big',
#  'coming',
#  'jacy',
#  'jacytoken',
#  'spacex',
#  'taylorswift',
#  'justinbieber',
#  'rocket',
#  'elonmusk',
#  'big',
#  'omg',
#  'http',
#  'tcolj7guzxfjc',
#  'jacy',
#  'jacytoken',
#  'spacex',
#  'taylorswift',
#  'justinbieber',
#  'rocket',
#  'elonmusk',
#  'big',
#  'omg',
#  'like',
#  'follow',
#  'share',
#  'miss',
#  '2000',
#  'nfts',
#  'ranging',
#  'rarity',
#  'collect',
#  'mint',
#  'date',
#  'amp',
#  'website',
#  'coming',
#  'soon',
#  'nft',
#  'nfts',
#  'nftart',
#  'nftcollectors',
#  'nftcommunity',
#  'nftcollector',
#  'nftdrop',
#  'nftartists',
#  'opensea',
#  'openseanft',
#  'taylorswift',
#  'drake',
#  'billgates',
#  'elonmusk',
#  'eminemkneel',
#  'http',
#  'tcohsgxm8sdjw',
#  'nfts',
#  'rarity',
#  'nft',
#  'nfts',
#  'nftart',
#  'nftcollectors',
#  'nftcommunity',
#  'nftcollector',
#  'nftdrop',
#  'nftartists',
#  'opensea',
#  'openseanft',
#  'taylorswift',
#  'drake',
#  'billgates',
#  'elonmusk',
#  'eminemkneel',
#  'iâ\x80\x99m',
#  'shining',
#  'like',
#  'firework',
#  'â\x9c¨',
#  'ð\x9f\x8e\x87',
#  'ð\x9f\x8e\x86',
#  'sad',
#  'ð\x9f\x8e\x87',
#  'empty',
#  'ð\x9f\x8e\x86',
#  'town',
#  'ð\x9f\x8e\x87',
#  'taylorswift',
#  'taylorswift',
#  'â\x80\x9ccause',
#  'darling',
#  'iâ\x80\x99m',
#  'nightmare',
#  'dressed',
#  'like',
#  'daydreamâ\x80\x9d',
#  'taylorswift',
#  'taylorswift',
#  'somehow',
#  'need',
#  'find',
#  'way',
#  'get',
#  'touch',
#  'taylorswift13',
#  'pretty',
#  'sure',
#  'going',
#  'want',
#  'join',
#  'wohstsclub',
#  'google',
#  'meet',
#  'one',
#  'meeting',
#  '6',
#  'degree',
#  'separation',
#  'hard',
#  'make',
#  'connection',
#  'taylorswift',
#  'taylorswift',
#  'à¸\x9eà¸£à¹\x89à¸\xadà¸¡à¸ªà¹\x88à¸\x87ð\x9f\x9a\x9a',
#  'evermore',
#  'target',
#  'exclusive',
#  'red',
#  'vinly',
#  '2lp',
#  '12',
#  'taylor',
#  'swift',
#  'à¹\x81à¸\x9cà¹\x88à¸\x99à¹\x83à¸',
#  '«',
#  'à¸¡à¹\x88à¸\x8bà¸µà¸¥',
#  '1490à¸¿',
#  'à¹\x81à¸\x9cà¹\x88à¸\x99à¹\x80à¸ªà¸µà¸¢à¸\x87',
#  'à¹\x84à¸§à¸\x99à¸´à¸¥',
#  'à¸\x8bà¸µà¸\x94à¸µ',
#  'taylorswift',
#  'à¸\x95à¸¥à¸²à¸\x94à¸\x99à¸±à¸\x94taylorswift',
#  'à¸\x95à¸¥à¸²à¸\x94à¸\x99à¸±à¸\x94à¸ªà¸§à¸´à¸\x9fà¸\x95à¸µà¹\x89',
#  'http',
#  'tcoi78d9hhe3k',
#  'à¹\x81à¸\x9cà¹\x88à¸\x99à¹\x80à¸ªà¸µà¸¢à¸\x87',
#  'à¹\x84à¸§à¸\x99à¸´à¸¥',
#  'à¸\x8bà¸µà¸\x94à¸µ',
#  'taylorswift',
#  'à¸\x95à¸¥à¸²à¸\x94à¸\x99à¸±à¸\x94taylorswift',
#  'à¸\x95à¸¥à¸²à¸\x94à¸\x99à¸±à¸\x94à¸ªà¸§à¸´à¸\x9fà¸\x95à¸µà¹\x89',
#  'transformer',
#  'beeotch',
#  'patriciacornwall',
#  'dukeofcornwall',
#  'taylorswift',
#  'queencharlotte',
#  'royalfamily',
#  'usnavy',
#  'jealous',
#  'liar',
#  'george',
#  'lion',
#  's',
#  'paw',
#  'bush',
#  'make',
#  'mankind',
#  'suffer',
#  'play',
#  'hero',
#  'every',
#  'lifetime',
#  'family',
#  ...]

# %%
docs_preprocessed = []

# %%
#Storing file name and data
total_documents = 0
path = '/content/drive/MyDrive/Tweelink_Dataset/Tweelink_Articles_Processed'
for filename in glob(os.path.join(path, '*')):
   with open(os.path.join(os.getcwd(), filename), 'r', encoding = 'utf-8',errors = 'ignore') as f:
     filename = os.path.basename(f.name)
     data = json.load(f)
     d_date = data["Date"]
     if(d_date=="" or d_date=="Date"):
       continue
     format = '%Y-%m-%d'
 
     d_present_date = datetime.datetime.strptime(d_date, format)
 
     if(str(d_present_date.date()) not in [str(u_present_date.date()), str(u_prev_date.date()), str(u_next_date.date())]):
       continue
   
     docs_preprocessed.append({'Name':filename, 'Data':data})
     total_documents+=1
print(total_documents)
# Out:
# 150

# %%
def find_relevant_documents_cosine_similarity_count_vectorizer(docs_preprocessed, processed_query):
  cosine_similarities_cv = {}
  for document in docs_preprocessed:
    query_sent = ' '.join(map(str, processed_query))
    doc_text_sent = ' '.join(map(str, document['Data']['Body_processed']))
    data = [query_sent, doc_text_sent]
    count_vectorizer = CountVectorizer(encoding='latin-1', decode_error='ignore', ngram_range=(1,2))
    vector_matrix = count_vectorizer.fit_transform(data)
    cosine_similarity_matrix = cosine_similarity(vector_matrix)
    cosine_similarities_cv[document['Name']] = cosine_similarity_matrix[0][1]
  relevant_docs = list( sorted(cosine_similarities_cv.items(), key=operator.itemgetter(1),reverse=True))[:20]
  for i in range(len(relevant_docs)):
    for j in range(len(docs_preprocessed)):
      if(relevant_docs[i][0] == docs_preprocessed[j]['Name']):
        relevant_docs[i] = (relevant_docs[i][0], relevant_docs[i][1], docs_preprocessed[j]['Data']['Date'] )

  return relevant_docs

# %%
find_relevant_documents_cosine_similarity_count_vectorizer(docs_preprocessed, tweet_query)
# Out:
# [('TaylorSwift_236.json', 0.1187068454956676, '2022-02-18'),
#  ('TaylorSwift_184.json', 0.10239537875040472, '2022-02-17'),
#  ('TaylorSwift_182.json', 0.10096803859626721, '2022-02-17'),
#  ('TaylorSwift_187.json', 0.09924123468108602, '2022-02-17'),
#  ('TaylorSwift_239.json', 0.09305179183376847, '2022-02-18'),
#  ('TaylorSwift_185.json', 0.09158661815182516, '2022-02-17'),
#  ('TaylorSwift_233.json', 0.08709663272556863, '2022-02-18'),
#  ('TaylorSwift_181.json', 0.08676431680707926, '2022-02-17'),
#  ('TaylorSwift_232.json', 0.08114167882976443, '2022-02-18'),
#  ('TaylorSwift_235.json', 0.07871799435110648, '2022-02-18'),
#  ('TaylorSwift_189.json', 0.07581474335216665, '2022-02-17'),
#  ('TaylorSwift_188.json', 0.07415927876254758, '2022-02-17'),
#  ('TaylorSwift_183.json', 0.07182863611466148, '2022-02-17'),
#  ('TaylorSwift_240.json', 0.07143392802278403, '2022-02-18'),
#  ('TaylorSwift_237.json', 0.0710224024763392, '2022-02-18'),
#  ('TaylorSwift_186.json', 0.06980614020886278, '2022-02-17'),
#  ('TaylorSwift_234.json', 0.06976958973787893, '2022-02-18'),
#  ('TaylorSwift_231.json', 0.06944942658585736, '2022-02-18'),
#  ('TaylorSwift_190.json', 0.06535026214323723, '2022-02-17'),
#  ('UkraineRussiaCrisis_264.json', 0.0510443519357415, '2022-02-19')]

# %%
def find_relevant_documents_cosine_similarity_tfidf_vectorizer(docs_preprocessed, processed_query):
  cosine_similarities_tfidf = {}
  for document in docs_preprocessed:
    query_sent = ' '.join(map(str, processed_query))
    doc_text_sent = ' '.join(map(str, document['Data']['Body_processed']))
    data = [query_sent, doc_text_sent]
    Tfidf_vect = TfidfVectorizer(encoding='latin-1', decode_error='ignore', ngram_range=(1,2))
    vector_matrix = Tfidf_vect.fit_transform(data)
    cosine_similarity_matrix = cosine_similarity(vector_matrix)
    cosine_similarities_tfidf[document['Name']] = cosine_similarity_matrix[0][1]
  relevant_docs = list( sorted(cosine_similarities_tfidf.items(), key=operator.itemgetter(1),reverse=True))[:20]
  for i in range(len(relevant_docs)):
    for j in range(len(docs_preprocessed)):
      if(relevant_docs[i][0] == docs_preprocessed[j]['Name']):
        relevant_docs[i] = (relevant_docs[i][0], relevant_docs[i][1], docs_preprocessed[j]['Data']['Date'] )

  return relevant_docs

# %%
find_relevant_documents_cosine_similarity_tfidf_vectorizer(docs_preprocessed, tweet_query)
# Out:
# [('TaylorSwift_236.json', 0.07304325057053494, '2022-02-18'),
#  ('TaylorSwift_182.json', 0.06174074040988692, '2022-02-17'),
#  ('TaylorSwift_184.json', 0.061319424366090974, '2022-02-17'),
#  ('TaylorSwift_187.json', 0.0587372408143478, '2022-02-17'),
#  ('TaylorSwift_185.json', 0.056406738442554755, '2022-02-17'),
#  ('TaylorSwift_239.json', 0.05561636414619976, '2022-02-18'),
#  ('TaylorSwift_181.json', 0.05233887782270552, '2022-02-17'),
#  ('TaylorSwift_233.json', 0.05204498025451339, '2022-02-18'),
#  ('TaylorSwift_232.json', 0.04825705980019822, '2022-02-18'),
#  ('TaylorSwift_235.json', 0.04767597324291153, '2022-02-18'),
#  ('TaylorSwift_189.json', 0.04462909857764501, '2022-02-17'),
#  ('TaylorSwift_188.json', 0.04311602142846356, '2022-02-17'),
#  ('TaylorSwift_183.json', 0.04219341892566283, '2022-02-17'),
#  ('TaylorSwift_186.json', 0.04126727630234539, '2022-02-17'),
#  ('TaylorSwift_231.json', 0.041138447400592554, '2022-02-18'),
#  ('TaylorSwift_237.json', 0.041055259029544475, '2022-02-18'),
#  ('TaylorSwift_240.json', 0.040796383234322456, '2022-02-18'),
#  ('TaylorSwift_234.json', 0.03866360163346691, '2022-02-18'),
#  ('TaylorSwift_190.json', 0.03680307354344191, '2022-02-17'),
#  ('UkraineRussiaCrisis_264.json', 0.028746618513347588, '2022-02-19')]

# %%
# def find_relevant_documents_spearman_rank_correlation_count_vectorizer(docs_preprocessed, processed_query):
#   spearman_rank_correlation_cv = {}
#   for document in docs_preprocessed:
#     query_sent = ' '.join(map(str, processed_query))
#     doc_text_sent = ' '.join(map(str, document['Data']['Body_processed']))
#     data = [query_sent, doc_text_sent]
#     count_vectorizer = CountVectorizer(encoding='latin-1', decode_error='ignore', ngram_range=(1,2))
#     vector_matrix = count_vectorizer.fit_transform(data)
#     VM = vector_matrix.toarray()
#     spearman_rc, pvalue = stats.spearmanr(VM[0], VM[1], nan_policy='omit')
#     if(math.isnan(spearman_rc)):
#       flag1=True
#       flag2=True
#       val = VM[0][0]
#       for x in VM[0]:
#         if(val!=x):
#           flag1=False
#       val2 = VM[1][0]
#       for y in VM[1]:
#         if(val2!=y):
#           flag2=False
#       if(flag1 | flag2):
#         print('hmm')
#     alpha = 0.05
#     if pvalue<alpha:
#       spearman_rank_correlation_cv[document['Name']] = 0
#     else:
#       spearman_rank_correlation_cv[document['Name']] = spearman_rc
#   relevant_docs = list( sorted(spearman_rank_correlation_cv.items(), key=operator.itemgetter(1),reverse=True))[:20]
#   for i in range(len(relevant_docs)):
#     for j in range(len(docs_preprocessed)):
#       if(relevant_docs[i][0] == docs_preprocessed[j]['Name']):
#         relevant_docs[i] = (relevant_docs[i][0], relevant_docs[i][1], docs_preprocessed[j]['Data']['Date'] )

#   return relevant_docs

# %%
# find_relevant_documents_spearman_rank_correlation_count_vectorizer(docs_preprocessed, tweet_query)

# %%
# def find_relevant_documents_spearman_rank_correlation_tfidf_vectorizer(docs_preprocessed, processed_query):
#   spearman_rank_correlation_tfidf = {}
#   for document in docs_preprocessed:
#     query_sent = ' '.join(map(str, processed_query))
#     doc_text_sent = ' '.join(map(str, document['Data']['Body_processed']))
#     data = [query_sent, doc_text_sent]
#     Tfidf_vect = TfidfVectorizer(encoding='latin-1', decode_error='ignore', ngram_range=(1,2))
#     vector_matrix = Tfidf_vect.fit_transform(data)
#     VM = vector_matrix.toarray()
#     spearman_rc, pvalue = stats.spearmanr(VM[0], VM[1], nan_policy='omit')
#     spearman_rank_correlation_tfidf[document['Name']] = spearman_rc
#   relevant_docs = list( sorted(spearman_rank_correlation_tfidf.items(), key=operator.itemgetter(1),reverse=True))[:20]
#   for i in range(len(relevant_docs)):
#     for j in range(len(docs_preprocessed)):
#       if(relevant_docs[i][0] == docs_preprocessed[j]['Name']):
#         relevant_docs[i] = (relevant_docs[i][0], relevant_docs[i][1], docs_preprocessed[j]['Data']['Date'] )

#   return relevant_docs

# %%
# find_relevant_documents_spearman_rank_correlation_tfidf_vectorizer(docs_preprocessed, tweet_query)
