# %% [markdown]
# Import Statements

# %%
import pandas as pd
import numpy as np
import csv
import json
from itertools import islice
from collections import OrderedDict
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import nltk
from glob import glob
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from tqdm import tqdm
import pickle
import math
from sklearn.model_selection import train_test_split
import operator
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('corpus')
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from scipy import stats
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Error loading corpus: Package 'corpus' not found in index

# %%
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file1 = open("/content/drive/MyDrive/Tweelink_Dataset/twitter_base_preprocessed.pkl", "rb")
df = pickle.load(file1)
file1.close()

# %%
df.head()
# Out:
#                author id                 created_at geo country country_code  \
# 0           1952510090.0  2022-02-14 00:11:44+00:00
# 1             20453105.0  2022-02-14 00:04:56+00:00
# 2  1492660754998247424.0  2022-02-14 00:39:55+00:00
# 3            117812637.0  2022-02-14 00:20:05+00:00
# 4  1490044524604928000.0  2022-02-14 00:10:26+00:00
#
#   place_full_name place_name place_type                     id lang  ...  \
# 0                                        1493015060943454208.0   en  ...
# 1                                        1493013352938934272.0   en  ...
# 2                                        1493022155239534336.0   en  ...
# 3                                        1493017163485044736.0   en  ...
# 4                                        1493014734903382016.0   en  ...
#
#                 source                                              tweet  \
# 0  Twitter for Android  ð¥ð¥ð¥ð¥ð¥ð¥ð¥â¤µï¸â¤µï¸â¤µï¸...
# 1  Twitter for Android  It's too bad these guys are afraid of needles,...
# 2  Twitter for Android  Cowboy dressed as #Furries now available at th...
# 3   Twitter for iPhone  We blocked these trucks from entering the dntn...
# 4   Twitter for iPhone  Krista is very pleased with how the @RCMPONT r...
#
#                                             hashtags sensitive  \
# 0  CommonSenseGunLaws,GunControlNow,GunSafes,GunS...     False
# 1          ClownConvoy,FreeDumbConvoy,OttawaOccupied     False
# 2                    Furries,RamRanch,OttawaOccupied     False
# 3                           Riverside,OttawaOccupied     False
# 4  FluTruxKlanGoHome,OttawaOccupied,kkkonvoy,Otta...     False
#
#                       urls context_text context_probability context_type  \
# 0  https://t.co/LjkEup24Dk                              0.0
# 1  https://t.co/MmFzuFjIDR                              0.0
# 2  https://t.co/GBuBCUtpXe                              0.0
# 3  https://t.co/KzLkBZvjgD                              0.0
# 4  https://t.co/kAm5KNugdA                              0.0
#
#                                    Preprocessed_Data   Date_Only
# 0  [ð¥ð¥ð¥ð¥ð¥ð¥ð¥â¤µï¸â¤µï¸â¤µï¸...  2022-02-14
# 1  [bad, guy, afraid, needle, twinrix, would, pre...  2022-02-14
# 2  [cowboy, dressed, furries, available, ramranch...  2022-02-14
# 3  [blocked, truck, entering, dntn, core, riversi...  2022-02-14
# 4  [krista, pleased, rcmpont, responded, maskless...  2022-02-14
#
# [5 rows x 24 columns]

# %%
u_base_hashtag = input("Enter base hashtag: ")
u_time = input("Enter time: ")
u_location = input("Enter Location: ")
# Out:
# Enter base hashtag: hijab
# Enter time: 2022-02-19
# Enter Location: india

# %%
import datetime
tweet_query = []
format = '%Y-%m-%d'
u_present_date = datetime.datetime.strptime(u_time, format)
u_prev_date = u_present_date - datetime.timedelta(days=1)
u_next_date = u_present_date + datetime.timedelta(days=1)
df_query = df.loc[df['hashtags'].str.contains(u_base_hashtag) & df['Date_Only'].isin([str(u_present_date.date()), str(u_prev_date.date()), str(u_next_date.date())])]

# %%
df_query.head()
# Out:
#                  author id                 created_at               geo  \
# 12546          123851279.0  2022-02-19 12:59:42+00:00
# 8192            3187630801  2022-02-20 00:55:03+00:00
# 8198            2443976946  2022-02-20 00:14:25+00:00
# 8278   1483569403425959939  2022-02-20 01:06:11+00:00  18810aa5b43e76c7
# 8280              18931596  2022-02-20 01:55:42+00:00
#
#                 country country_code place_full_name place_name place_type  \
# 12546
# 8192
# 8198
# 8278   Verenigde Staten           US      Dallas, TX     Dallas       city
# 8280
#
#                           id lang  ...               source  \
# 12546  1495020266862174208.0   en  ...   Twitter for iPhone
# 8192     1495200290210910209   en  ...  Twitter for Android
# 8198     1495190066112651265   en  ...      Twitter Web App
# 8278     1495203094224904192   en  ...   Twitter for iPhone
# 8280     1495215554508075011   en  ...      Twitter Web App
#
#                                                    tweet  \
# 12546  They are so desperate they have let loose #Yat...
# 8192   No Woman is Forced to wear and Not to wear Som...
# 8198   Protests in US cities against #Karnataka #hija...
# 8278   Protest by local Dallas Muslims at JFK square ...
# 8280   Feel sorry for #zahirawasim.  Religion must ma...
#
#                                                 hashtags sensitive  \
# 12546             YatiNarsinghanand,PlotToKillModi,hijab     False
# 8192   hijab,HijabIsOurPride,HijabIsFundamentalRight,...     False
# 8198                    Karnataka,hijab,Islamophobic,BJP     False
# 8278                                               hijab     False
# 8280                                   zahirawasim,hijab     False
#
#                                                     urls context_text  \
# 12546
# 8192
# 8198   https://t.co/957kBM8AJT,https://t.co/5gY741DZP...
# 8278                             https://t.co/KCm413Yb8N
# 8280
#
#       context_probability context_type  \
# 12546                 0.0
# 8192                  0.0
# 8198                  0.0
# 8278                  0.0
# 8280                  0.0
#
#                                        Preprocessed_Data   Date_Only
# 12546  [desperate, let, loose, yatinarsinghanand, vio...  2022-02-19
# 8192   [woman, forced, wear, wear, something, hijab, ...  2022-02-20
# 8198   [protest, u, city, karnataka, hijab, ban, indi...  2022-02-20
# 8278   [protest, local, dallas, muslim, jfk, square, ...  2022-02-20
# 8280   [feel, sorry, zahirawasim, religion, must, mak...  2022-02-20
#
# [5 rows x 24 columns]

# %%
for tweet in df_query['Preprocessed_Data']:
  tweet_query.extend(tweet)

# %%
tweet_query
# Out:
# ['desperate',
#  'let',
#  'loose',
#  'yatinarsinghanand',
#  'violent',
#  'rhetoric',
#  'plottokillmodi',
#  'hijab',
#  'hate',
#  'hateâ\x80¦',
#  'yatinarsinghanand',
#  'plottokillmodi',
#  'hijab',
#  'woman',
#  'forced',
#  'wear',
#  'wear',
#  'something',
#  'hijab',
#  'hijabisourpride',
#  'hijabisfundamentalright',
#  'hijaboruniform',
#  'hijabcontroversy',
#  'hijabcircular',
#  'hijabisindividualright',
#  'ð\x9f§\x95',
#  'hijab',
#  'hijabisourpride',
#  'hijabisfundamentalright',
#  'hijaboruniform',
#  'hijabcontroversy',
#  'hijabcircular',
#  'hijabisindividualright',
#  'protest',
#  'u',
#  'city',
#  'karnataka',
#  'hijab',
#  'ban',
#  'indian',
#  'american',
#  'ally',
#  'demonstrated',
#  'islamophobic',
#  'unconstitutional',
#  'ban',
#  'school',
#  'india',
#  's',
#  'nationalist',
#  'bjp',
#  'government',
#  'take',
#  'action',
#  'canadaâ\x9e¡ï¸\x8f',
#  'http',
#  'tco957kbm8ajt',
#  'take',
#  'action',
#  'globallyâ\x9e¡ï¸\x8f',
#  'http',
#  'tco5gy741dzp1',
#  'http',
#  'tcobvsjhjohkc',
#  'karnataka',
#  'hijab',
#  'islamophobic',
#  'bjp',
#  'protest',
#  'local',
#  'dallas',
#  'muslim',
#  'jfk',
#  'square',
#  'downtown',
#  'draconian',
#  'hijab',
#  'law',
#  'today',
#  'entire',
#  'u',
#  'listening',
#  'voice',
#  'muslim',
#  'woman',
#  'thelivetvnews',
#  'http',
#  'tcokcm413yb8n',
#  'hijab',
#  'dallas',
#  'tx',
#  'feel',
#  'sorry',
#  'zahirawasim',
#  'religion',
#  'must',
#  'make',
#  'ppl',
#  'grow',
#  'make',
#  'ppl',
#  'regressive',
#  'time',
#  'reform',
#  'dear',
#  'zahirawasim',
#  'aisha',
#  'fought',
#  'ali',
#  'war',
#  'wearing',
#  'hijab',
#  'u',
#  'think',
#  'u',
#  'know',
#  'religion',
#  'aisha',
#  'stop',
#  'spreading',
#  'myth',
#  'ur',
#  'faith',
#  'hijab',
#  'obligation',
#  'zahirawasim',
#  'hijab',
#  'good',
#  'sunday',
#  'ð\x9f\x98\x8e',
#  'tour',
#  'castle',
#  'click',
#  'link',
#  'bio',
#  'humairasquare',
#  'dropshipdiperlukan',
#  'dropshipmalaysia',
#  'hijab',
#  'love',
#  'bawalcottonvoile',
#  'tudungbawal',
#  'tudungbawalkayangan',
#  'ootd',
#  'http',
#  'tconjhzlywwvg',
#  'humairasquare',
#  'dropshipdiperlukan',
#  'dropshipmalaysia',
#  'hijab',
#  'love',
#  'bawalcottonvoile',
#  'tudungbawal',
#  'tudungbawalkayangan',
#  'ootd',
#  'illeberasim',
#  'school',
#  'uniform',
#  'fr',
#  'everyone',
#  'ban',
#  'anythingonly',
#  '5',
#  'girl',
#  'suddenly',
#  'wanted',
#  'hijabcanada',
#  'using',
#  'emergency',
#  '2',
#  'counter',
#  'canadafreedomconvoycan',
#  'anyone',
#  'dare',
#  'criticize',
#  'blm',
#  'amp',
#  'risk',
#  'loosing',
#  'job',
#  'kind',
#  'free',
#  'speech',
#  'liberalism',
#  'avatans',
#  'http',
#  'tcozrcptpnvip',
#  'hijab',
#  'canadafreedomconvoy',
#  'blm',
#  'hijab',
#  'woman',
#  'lead',
#  'way',
#  'raffia',
#  'arshad',
#  'appointment',
#  'judge',
#  'midland',
#  'circuit',
#  'see',
#  'personal',
#  'achievement',
#  'bigger',
#  'joint',
#  'head',
#  'st',
#  'mary',
#  's',
#  'chamber',
#  'said',
#  'led',
#  'way',
#  'muslim',
#  'woman',
#  'succeed',
#  'http',
#  'tcowgezqfoojz',
#  'hijab',
#  'ambreenzaidi',
#  'woman',
#  'hijab',
#  'lead',
#  'way',
#  'hijab',
#  'never',
#  'hijab',
#  'hijabisourpride',
#  'brahmin',
#  'dalitlivesmatter',
#  'http',
#  'tconszf9vzmjy',
#  'hijab',
#  'hijabisourpride',
#  'brahmin',
#  'dalitlivesmatter',
#  'kick',
#  'footballhelps',
#  'hijabclad',
#  'girl',
#  'mumbai',
#  'breaknewground',
#  'http',
#  'tcojzz8pg0wbq',
#  'via',
#  'timesofindia',
#  'coachzakirhussainansari',
#  'started',
#  'girl',
#  'team',
#  'group',
#  '20',
#  '2018',
#  'footballhelps',
#  'hijab',
#  'girl',
#  'breaknewground',
#  'coachzakirhussainansari',
#  'wish',
#  'great',
#  'shahid',
#  'palni',
#  'baba',
#  'alive',
#  'hijab',
#  'issue',
#  'ongoing',
#  'karnataka',
#  'ð\x9f\x98\x93ð\x9f\x98\x93',
#  'may',
#  'allah',
#  'pleased',
#  'give',
#  'higher',
#  'rank',
#  'jannah',
#  'hijab',
#  'zafarsareshwala',
#  'unfortunate',
#  'set',
#  'unpleasant',
#  'precedence',
#  'next',
#  'demand',
#  'hijab',
#  'police',
#  'military',
#  'airline',
#  'show',
#  'bunch',
#  'rogue',
#  'element',
#  'arm',
#  'twist',
#  'get',
#  'unreasonable',
#  'demand',
#  'hijab',
#  'â\x80\x9cfatâ\x80\x9d',
#  'girl',
#  'post',
#  'photo',
#  'wearing',
#  'booty',
#  'short',
#  'freefromhijab',
#  'â\x80\x9cskinnyâ\x80\x9d',
#  'girl',
#  'go',
#  'school',
#  'wearing',
#  'fitted',
#  'jean',
#  'â\x80\x9cpromoting',
#  'anorexiaâ\x80\x9d',
#  'start',
#  'wearing',
#  'loose',
#  'clothes',
#  'â\x80\x9cpromoting',
#  'hijabâ\x80\x9d',
#  'skinnyshaming',
#  'freefromhijab',
#  'hijab',
#  'skinnyshaming',
#  'mindset',
#  'congressif',
#  'muslim',
#  'allowed',
#  'wear',
#  'hijab',
#  'congress',
#  'sp',
#  'said',
#  'punjabies',
#  'allowed',
#  'wear',
#  'traditional',
#  'dress',
#  'incindia',
#  'bjp4india',
#  'http',
#  'tcoxwvwwaeqtl',
#  'hijab',
#  'à¤\x95à¥\x87à¤°à¤²',
#  'à¤\xadà¤¾à¤°à¤¤',
#  'educated',
#  'woman',
#  'progressive',
#  'family',
#  'freedom',
#  'education',
#  'dressing',
#  'lifestyle',
#  'want',
#  'young',
#  'girl',
#  'wear',
#  'hijab',
#  'burka',
#  'hijab',
#  'hijab',
#  'iamcouncil',
#  'khanabadosh0',
#  'huge',
#  'rally',
#  'dallas',
#  'protesting',
#  'nazi',
#  'inspired',
#  'hijab',
#  'ban',
#  'sister',
#  'clearly',
#  'made',
#  'clear',
#  'hijabisourright',
#  'http',
#  'tcobmyhvqsep4',
#  'hijab',
#  'hijabisourright',
#  'karnataka',
#  'critical',
#  'moment',
#  'wear',
#  'hijab',
#  'asked',
#  'remove',
#  'hijabisfundamentalright',
#  'hijab',
#  'hijabisfundamentalright',
#  'reposted',
#  'isabellapodesta',
#  'ð\x9f\x93¸',
#  'â\x80¢',
#  'â\x80¢',
#  'â\x80¢',
#  'â\x80¢',
#  'â\x80¢',
#  'â\x80¢',
#  'modestfashion',
#  'hijab',
#  'modestclothing',
#  'modest',
#  'revert',
#  'reverttings',
#  'fashion',
#  'hijabifashion',
#  'abaya',
#  'muslim',
#  'muslimah',
#  'http',
#  'tcocqcnehlaty',
#  'modestfashion',
#  'hijab',
#  'modestclothing',
#  'modest',
#  'revert',
#  'reverttings',
#  'fashion',
#  'hijabifashion',
#  'abaya',
#  'muslim',
#  'muslimah',
#  'woman',
#  'iran',
#  'deal',
#  'daily',
#  'basis',
#  'iran',
#  'womensrights',
#  'hijab',
#  'veil',
#  'islam',
#  'atheist',
#  'agnostic',
#  'discrimination',
#  'http',
#  'tcoksquzftfmp',
#  'iran',
#  'womensrights',
#  'hijab',
#  'veil',
#  'islam',
#  'atheist',
#  'agnostic',
#  'discrimination',
#  'yesterday',
#  'noticed',
#  'one',
#  'mobile',
#  'store',
#  'owned',
#  'pissfuls',
#  'mu',
#  'l',
#  'men',
#  'sale',
#  'executive',
#  'mu',
#  'l',
#  'woman',
#  'r',
#  'employed',
#  'pissfuls',
#  'anywhere',
#  'known',
#  'fact',
#  'reminder',
#  'want',
#  'hijab',
#  'education',
#  'bsbommai',
#  'bcnageshbjp',
#  'hijab',
#  'zairawasim',
#  'say',
#  'absolute',
#  'justice',
#  'woman',
#  'ask',
#  'give',
#  'either',
#  'education',
#  'hijab',
#  'citing',
#  'woman',
#  'empowerment',
#  'even',
#  'worst',
#  'read',
#  'full',
#  'post',
#  'hijab',
#  'row',
#  'hijab',
#  'hijabrow',
#  'http',
#  'tcomgovcwpjbr',
#  'zairawasim',
#  'hijab',
#  'hijabrow',
#  'cleaver',
#  'strategy',
#  'whole',
#  'hijab',
#  'issue',
#  'claim',
#  'want',
#  'hijab',
#  'actually',
#  'coming',
#  'burka',
#  'afghanistan',
#  'style',
#  'shah',
#  'bano',
#  '20',
#  'talibanisation',
#  'http',
#  'tcoysvcewmuig',
#  'hijab',
#  'hijabcontroversy',
#  'unveils',
#  'religious',
#  'political',
#  'faultlines',
#  'india',
#  'wearing',
#  'hijab',
#  'expression',
#  'protected',
#  'article19',
#  '1',
#  'constitution',
#  'guarantee',
#  'right',
#  'freedom',
#  'speech',
#  'expression',
#  'writes',
#  'ashokbhan2',
#  'http',
#  'tconrx75zpzt2',
#  'hijabcontroversy',
#  'faultlines',
#  'india',
#  'hijab',
#  'article19',
#  'constitution',
#  'guarantee',
#  'freedom',
#  'speech',
#  'expression',
#  'slogan',
#  'bharatmatakijai',
#  'vandemataram',
#  'raised',
#  'saffronclad',
#  'hijab',
#  'set',
#  'fire',
#  'aligarh',
#  'http',
#  'tcoynrfyh4n5j',
#  'bharatmatakijai',
#  'vandemataram',
#  'saffronclad',
#  'hijab',
#  'aligarh',
#  'hijab',
#  'protest',
#  'downtown',
#  'dallasmy',
#  'sister',
#  'also',
#  'thereð\x9f\x99\x82',
#  'thank',
#  'much',
#  'muslim',
#  'brother',
#  'sister',
#  'support',
#  'hijabisourright',
#  'hijabisourpride',
#  'hijabisfundamentalright',
#  'hijab',
#  'karnatakahijabrow',
#  'islamophobiainindia',
#  'http',
#  'tcoudanmcicea',
#  'hijabisourright',
#  'hijabisourpride',
#  'hijabisfundamentalright',
#  'hijab',
#  'karnatakahijabrow',
#  'islamophobiainindia',
#  'dmk',
#  'à®¤à®¿à®°à¯\x81à®\x9fà¯\x8dà®\x9fà¯\x81à®¤à®¿à®°à®¾à®µà®¿à®\x9fà®®à¯\x8d',
#  'abuse',
#  'hindu',
#  'hindu',
#  'god',
#  'heritage',
#  'tradition',
#  'normal',
#  'hindu',
#  'human',
#  'amp',
#  'stone',
#  'block',
#  'harmless',
#  'factual',
#  'opinion',
#  'hijab',
#  'wearing',
#  'voter',
#  'localbodyelection',
#  'hurt',
#  'muslim',
#  'ever',
#  'cm',
#  'biased',
#  'mkstalin',
#  'http',
#  'tcozdlhlodur4',
#  'dmk',
#  'à®¤à®¿à®°à¯\x81à®\x9fà¯\x8dà®\x9fà¯\x81à®¤à®¿à®°à®¾à®µà®¿à®\x9fà®®à¯\x8d',
#  'hindu',
#  'hijab',
#  'localbodyelection',
#  'mkstalin',
#  'karnatakahijabcontroversy',
#  '58',
#  'student',
#  'allegedly',
#  'suspended',
#  'college',
#  'removing',
#  'hijab',
#  'however',
#  'shivamogga',
#  'deputy',
#  'commissioner',
#  'claimed',
#  'principal',
#  'institution',
#  'threatened',
#  'suspension',
#  'order',
#  'issued',
#  'http',
#  'tcoll4n3rhgne',
#  'karnatakahijabcontroversy',
#  'hijab',
#  'radrama',
#  'rohinisgh',
#  'never',
#  'hijab',
#  'wanted',
#  'create',
#  'optic',
#  'uttarakhandelections2022',
#  'hijab',
#  'uttarakhandelections2022',
#  'bommai',
#  'priyaakulkarni2',
#  'currently',
#  'hijab',
#  'valentineday',
#  'point',
#  'achieve',
#  'attack',
#  'hindu',
#  'religious',
#  'festival',
#  'like',
#  'diwali',
#  'holi',
#  'bhai',
#  'duaj',
#  'durga',
#  'pooja',
#  'ganesh',
#  'chaturthi',
#  'many',
#  'banhijab',
#  'muslim',
#  'liveorleave',
#  'hijab',
#  'valentineday',
#  'banhijab',
#  'liveorleave',
#  'india',
#  'would',
#  'hijab',
#  'perfect',
#  'tool',
#  'transport',
#  'someone',
#  'hidden',
#  'plain',
#  'sight',
#  'hijab',
#  '3',
#  'phase',
#  'voting',
#  'suddenly',
#  'hijabrow',
#  'news',
#  'medium',
#  'reporting',
#  'drama',
#  'bring',
#  'bjp',
#  'election',
#  'amp',
#  'saturated',
#  'election',
#  'student',
#  'amp',
#  'relegion',
#  'used',
#  'puppet',
#  'political',
#  'people',
#  'yet',
#  'hijabcontroversy',
#  'hijab',
#  'hijabrow',
#  'hijabcontroversy',
#  'hijab',
#  'ktaka',
#  'minister',
#  'k',
#  'ishwarappa',
#  'said',
#  'saffron',
#  'flag',
#  'replace',
#  'tricolour',
#  'red',
#  'fort',
#  'day',
#  'bjp',
#  'never',
#  'fails',
#  'exhibit',
#  'disrespect',
#  'nation',
#  'pride',
#  'seditious',
#  'crime',
#  'tricolor',
#  'ishwarappa',
#  'redfort',
#  'saffronflag',
#  'saffron',
#  'hijab',
#  'tricolor',
#  'ishwarappa',
#  'redfort',
#  'saffronflag',
#  'saffron',
#  'hijab',
#  'frontlineindia',
#  'bharat4justice',
#  'yes',
#  'itâ\x80\x99s',
#  'hindutva',
#  'agenda',
#  'hater',
#  'hijab',
#  'excuse',
#  'hindutva',
#  'hater',
#  'hijab',
#  'shakibhaq',
#  'ð\x9f¤£ð\x9f¤£ð\x9f¤£',
#  'converted',
#  'duplicate',
#  'demand',
#  'anything',
#  'original',
#  'say',
#  'hijab',
#  'http',
#  'tcoqzxnsh8mkq',
#  'hijab',
#  'dhaka',
#  'ð\x9f\x87§ð\x9f\x87©',
#  'choose',
#  'wear',
#  'hijab',
#  'protect',
#  'choice',
#  'making',
#  'equally',
#  'sure',
#  'stand',
#  'choice',
#  'someone',
#  'turn',
#  'http',
#  'tcozmafaxxboe',
#  'hijab',
#  'bommai',
#  'busy',
#  'spreading',
#  'hatred',
#  'schoolcollege',
#  'going',
#  'hijab',
#  'wearing',
#  'muslim',
#  'girl',
#  'http',
#  'tcou4plmdbvqz',
#  'bommai',
#  'hijab',
#  'advaidism',
#  '1',
#  'support',
#  'hijab',
#  'burka',
#  'muslim',
#  'fellow',
#  'citizen',
#  'hijabburka',
#  'existence',
#  'prof',
#  'ultimate',
#  'expression',
#  'freedom',
#  'doesnâ\x80\x99t',
#  'need',
#  'logic',
#  'logic',
#  'patriarchal',
#  'tool',
#  'fool',
#  'rationally',
#  'marginalized',
#  'people',
#  'hijab',
#  'beyond',
#  'logic',
#  'hijab',
#  'burka',
#  'mysuru',
#  'anniezaidi',
#  'people',
#  'like',
#  'keep',
#  'muslim',
#  'backward',
#  'propoganda',
#  'changed',
#  '2022',
#  'suddenly',
#  'muslim',
#  'girl',
#  'want',
#  'hijab',
#  'hijab',
#  'false',
#  'propegenda',
#  'hijab',
#  'burqa',
#  'spreading',
#  'called',
#  'indian',
#  'muslim',
#  'woman',
#  's',
#  'actually',
#  'r',
#  'propengendist',
#  'practice',
#  'since',
#  '2030',
#  'year',
#  'india',
#  'true',
#  'hijab',
#  'practicing',
#  '1400',
#  'year',
#  'among',
#  'muslim',
#  'woman',
#  'either',
#  'form',
#  'burqa',
#  'hijab',
#  'burqa',
#  'karnataka',
#  'ð\x9f\x91\x89',
#  'http',
#  'tcoqnb5661ycy',
#  'à¤®à¤°à¤¾à¤',
#  'à¥\x80',
#  'à¤®à¤°à¤¾à¤',
#  'à¥\x80à¤¬à¤¾à¤¤à¤®à¥\x8dà¤¯à¤¾',
#  'marathi',
#  'marathinews',
#  'navarashtra',
#  'hijab',
#  'controversy',
#  'karnataka',
#  'à¤®à¤°à¤¾à¤',
#  'à¥\x80',
#  'à¤®à¤°à¤¾à¤',
#  'à¥\x80à¤¬à¤¾à¤¤à¤®à¥\x8dà¤¯à¤¾',
#  'marathi',
#  'marathinews',
#  'navarashtra',
#  'hijab',
#  'donâ\x80\x99t',
#  'know',
#  'headscarf',
#  'girl',
#  'think',
#  'men',
#  'taken',
#  'copyright',
#  'thought',
#  'thatâ\x80\x99s',
#  'religionâ\x80\x99s',
#  'worst',
#  'crime',
#  'writes',
#  'prasannara',
#  'hijab',
#  'orhanpamuk',
#  'snow',
#  'http',
#  'tcogojmyre0ba',
#  'http',
#  'tcoihxp4yn4jq',
#  'hijab',
#  'orhanpamuk',
#  'snow',
#  'tamilnadu',
#  'row',
#  'bjp',
#  'booth',
#  'agent',
#  'asks',
#  'woman',
#  'remove',
#  'hijab',
#  'http',
#  'tcosa6jmnmtzz',
#  'booth',
#  'agent',
#  'girirajan',
#  'created',
#  'ruckus',
#  'alameen',
#  'school',
#  'polling',
#  'booth',
#  '8th',
#  'ward',
#  'melur',
#  'municipality',
#  'handsoffmyhijab',
#  'tamilnadu',
#  'hijab',
#  'girirajan',
#  'handsoffmyhijab',
#  'wearing',
#  'hijab',
#  'personal',
#  'choice',
#  'governmentâ\x80\x99s',
#  'hijab',
#  'restriction',
#  'school',
#  'college',
#  'violate',
#  'indiaâ\x80\x99s',
#  'obligation',
#  'international',
#  'human',
#  'right',
#  'law',
#  'human',
#  'right',
#  'watch',
#  'hijabrow',
#  'hijab',
#  'hijabisindividualright',
#  'hijabrow',
#  'hijab',
#  'hijabisindividualright',
#  'view',
#  'follow',
#  'upscinsta',
#  ...]

# %%
docs_preprocessed = []

# %%
#Storing file name and data
total_documents = 0
path = '/content/drive/MyDrive/Tweelink_Dataset/Tweelink_Articles_Processed'
for filename in glob(os.path.join(path, '*')):
   with open(os.path.join(os.getcwd(), filename), 'r', encoding = 'utf-8',errors = 'ignore') as f:
     filename = os.path.basename(f.name)
     data = json.load(f)
     d_date = data["Date"]
     if(d_date=="" or d_date=="Date"):
       continue
     format = '%Y-%m-%d'
 
     d_present_date = datetime.datetime.strptime(d_date, format)
 
     if(str(d_present_date.date()) not in [str(u_present_date.date()), str(u_prev_date.date()), str(u_next_date.date())]):
       continue
   
     docs_preprocessed.append({'Name':filename, 'Data':data})
     total_documents+=1
print(total_documents)
# Out:
# 150

# %%
def get_relevant_docs_list_for_base_hashtag(base_hashtag, base_date, docs_preprocessed):
  relevant_docs_list = []
  for doc in docs_preprocessed:
    if doc['Data']['Base Hashtag']==base_hashtag:
      current_date = datetime.datetime.strptime(base_date, format)
      prev_date = current_date - datetime.timedelta(days=1)
      next_date = current_date + datetime.timedelta(days=1)
      if(doc['Data']['Date'] in [str(prev_date.date()), str(current_date.date()), str(next_date.date())]):
        relevant_docs_list.append(doc['Name'])
  return relevant_docs_list

# %%
def precision_at_k(k, base_hashtag, base_date, prediction_list, docs_preprocessed):
  relevant_docs_list = get_relevant_docs_list_for_base_hashtag(base_hashtag, base_date, docs_preprocessed)
  num_of_relevant_results=0
  for itr in range(k):
    if (prediction_list[itr][0] in relevant_docs_list):
      num_of_relevant_results+=1
  return num_of_relevant_results/k

# %%
def mean_average_precision(max_k, base_hashtag, base_date, relevant_docs, docs_preprocessed):
  average_precision=0
  ctr=0
  for k_val in range(1,max_k+1):
    ctr+=1
    precision_at_k_val = precision_at_k(k_val, base_hashtag, base_date, relevant_docs, docs_preprocessed)
    print('Hashtag: {}   Precision@{}: {}'.format(base_hashtag, k_val, precision_at_k_val))
    average_precision += precision_at_k_val
  return average_precision/ctr

# %%
def recall_at_k(k, base_hashtag, base_date, prediction_list, docs_preprocessed):
  relevant_docs_list = get_relevant_docs_list_for_base_hashtag(base_hashtag, base_date, docs_preprocessed)
  current_num_of_relevant_results=0
  for itr in range(k):
    if (prediction_list[itr][0] in relevant_docs_list):
      current_num_of_relevant_results+=1
  if(len(relevant_docs_list)==0):
    return 0
  return current_num_of_relevant_results/len(relevant_docs_list)

# %%
def mean_average_recall(max_k, base_hashtag, base_date, relevant_docs, docs_preprocessed):
  average_recall=0
  ctr=0
  for k_val in range(1,max_k+1):
    ctr+=1
    recall_at_k_val = recall_at_k(k_val, base_hashtag, base_date, relevant_docs, docs_preprocessed)
    print('Hashtag: {}   Recall@{}: {}'.format(base_hashtag, k_val, recall_at_k_val))
    average_recall += recall_at_k_val
  return average_recall/ctr

# %%
def find_relevant_documents_cosine_similarity_count_vectorizer(docs_preprocessed, processed_query):
  cosine_similarities_cv = {}
  for document in docs_preprocessed:
    query_sent = ' '.join(map(str, processed_query))
    doc_text_sent = ' '.join(map(str, document['Data']['Body_processed']))
    data = [query_sent, doc_text_sent]
    count_vectorizer = CountVectorizer(encoding='latin-1', decode_error='ignore', ngram_range=(1,2))
    vector_matrix = count_vectorizer.fit_transform(data)
    cosine_similarity_matrix = cosine_similarity(vector_matrix)
    cosine_similarities_cv[document['Name']] = cosine_similarity_matrix[0][1]
  relevant_docs = list( sorted(cosine_similarities_cv.items(), key=operator.itemgetter(1),reverse=True))[:20]
  for i in range(len(relevant_docs)):
    for j in range(len(docs_preprocessed)):
      if(relevant_docs[i][0] == docs_preprocessed[j]['Name']):
        relevant_docs[i] = (relevant_docs[i][0], relevant_docs[i][1], docs_preprocessed[j]['Data']['Date'] )

  return relevant_docs

# %%
relevant_docs_cs_cv = find_relevant_documents_cosine_similarity_count_vectorizer(docs_preprocessed, tweet_query)

# %%
mean_average_precision_hashtag = mean_average_precision(20, u_base_hashtag, u_time, relevant_docs_cs_cv, docs_preprocessed)
print(mean_average_precision_hashtag)
# Out:
# Hashtag: hijab   Precision@1: 1.0
# Hashtag: hijab   Precision@2: 1.0
# Hashtag: hijab   Precision@3: 1.0
# Hashtag: hijab   Precision@4: 1.0
# Hashtag: hijab   Precision@5: 1.0
# Hashtag: hijab   Precision@6: 1.0
# Hashtag: hijab   Precision@7: 1.0
# Hashtag: hijab   Precision@8: 1.0
# Hashtag: hijab   Precision@9: 1.0
# Hashtag: hijab   Precision@10: 1.0
# Hashtag: hijab   Precision@11: 0.9090909090909091
# Hashtag: hijab   Precision@12: 0.8333333333333334
# Hashtag: hijab   Precision@13: 0.7692307692307693
# Hashtag: hijab   Precision@14: 0.7142857142857143
# Hashtag: hijab   Precision@15: 0.6666666666666666
# Hashtag: hijab   Precision@16: 0.625
# Hashtag: hijab   Precision@17: 0.5882352941176471
# Hashtag: hijab   Precision@18: 0.5555555555555556
# Hashtag: hijab   Precision@19: 0.5263157894736842
# Hashtag: hijab   Precision@20: 0.5
# 0.834385701587714

# %%
def find_relevant_documents_cosine_similarity_tfidf_vectorizer(docs_preprocessed, processed_query):
  cosine_similarities_tfidf = {}
  for document in docs_preprocessed:
    query_sent = ' '.join(map(str, processed_query))
    doc_text_sent = ' '.join(map(str, document['Data']['Body_processed']))
    data = [query_sent, doc_text_sent]
    Tfidf_vect = TfidfVectorizer(encoding='latin-1', decode_error='ignore', ngram_range=(1,2))
    vector_matrix = Tfidf_vect.fit_transform(data)
    cosine_similarity_matrix = cosine_similarity(vector_matrix)
    cosine_similarities_tfidf[document['Name']] = cosine_similarity_matrix[0][1]
  relevant_docs = list( sorted(cosine_similarities_tfidf.items(), key=operator.itemgetter(1),reverse=True))[:20]
  for i in range(len(relevant_docs)):
    for j in range(len(docs_preprocessed)):
      if(relevant_docs[i][0] == docs_preprocessed[j]['Name']):
        relevant_docs[i] = (relevant_docs[i][0], relevant_docs[i][1], docs_preprocessed[j]['Data']['Date'] )

  return relevant_docs

# %%
relevant_docs_cs_tfidf = find_relevant_documents_cosine_similarity_tfidf_vectorizer(docs_preprocessed, tweet_query)

# %%
mean_average_recall_hashtag = mean_average_recall(20, u_base_hashtag, u_time, relevant_docs_cs_tfidf, docs_preprocessed)
print(mean_average_recall_hashtag)
# Out:
# Hashtag: hijab   Recall@1: 0.05
# Hashtag: hijab   Recall@2: 0.1
# Hashtag: hijab   Recall@3: 0.15
# Hashtag: hijab   Recall@4: 0.2
# Hashtag: hijab   Recall@5: 0.25
# Hashtag: hijab   Recall@6: 0.3
# Hashtag: hijab   Recall@7: 0.35
# Hashtag: hijab   Recall@8: 0.4
# Hashtag: hijab   Recall@9: 0.45
# Hashtag: hijab   Recall@10: 0.5
# Hashtag: hijab   Recall@11: 0.5
# Hashtag: hijab   Recall@12: 0.5
# Hashtag: hijab   Recall@13: 0.5
# Hashtag: hijab   Recall@14: 0.5
# Hashtag: hijab   Recall@15: 0.5
# Hashtag: hijab   Recall@16: 0.5
# Hashtag: hijab   Recall@17: 0.5
# Hashtag: hijab   Recall@18: 0.5
# Hashtag: hijab   Recall@19: 0.5
# Hashtag: hijab   Recall@20: 0.5
# 0.3875

# %%
# def find_relevant_documents_spearman_rank_correlation_count_vectorizer(docs_preprocessed, processed_query):
#   spearman_rank_correlation_cv = {}
#   for document in docs_preprocessed:
#     query_sent = ' '.join(map(str, processed_query))
#     doc_text_sent = ' '.join(map(str, document['Data']['Body_processed']))
#     data = [query_sent, doc_text_sent]
#     count_vectorizer = CountVectorizer(encoding='latin-1', decode_error='ignore', ngram_range=(1,2))
#     vector_matrix = count_vectorizer.fit_transform(data)
#     VM = vector_matrix.toarray()
#     spearman_rc, pvalue = stats.spearmanr(VM[0], VM[1], nan_policy='omit')
#     if(math.isnan(spearman_rc)):
#       flag1=True
#       flag2=True
#       val = VM[0][0]
#       for x in VM[0]:
#         if(val!=x):
#           flag1=False
#       val2 = VM[1][0]
#       for y in VM[1]:
#         if(val2!=y):
#           flag2=False
#       if(flag1 | flag2):
#         print('hmm')
#     alpha = 0.05
#     if pvalue<alpha:
#       spearman_rank_correlation_cv[document['Name']] = 0
#     else:
#       spearman_rank_correlation_cv[document['Name']] = spearman_rc
#   relevant_docs = list( sorted(spearman_rank_correlation_cv.items(), key=operator.itemgetter(1),reverse=True))[:20]
#   for i in range(len(relevant_docs)):
#     for j in range(len(docs_preprocessed)):
#       if(relevant_docs[i][0] == docs_preprocessed[j]['Name']):
#         relevant_docs[i] = (relevant_docs[i][0], relevant_docs[i][1], docs_preprocessed[j]['Data']['Date'] )

#   return relevant_docs

# %%
# find_relevant_documents_spearman_rank_correlation_count_vectorizer(docs_preprocessed, tweet_query)

# %%
# def find_relevant_documents_spearman_rank_correlation_tfidf_vectorizer(docs_preprocessed, processed_query):
#   spearman_rank_correlation_tfidf = {}
#   for document in docs_preprocessed:
#     query_sent = ' '.join(map(str, processed_query))
#     doc_text_sent = ' '.join(map(str, document['Data']['Body_processed']))
#     data = [query_sent, doc_text_sent]
#     Tfidf_vect = TfidfVectorizer(encoding='latin-1', decode_error='ignore', ngram_range=(1,2))
#     vector_matrix = Tfidf_vect.fit_transform(data)
#     VM = vector_matrix.toarray()
#     spearman_rc, pvalue = stats.spearmanr(VM[0], VM[1], nan_policy='omit')
#     spearman_rank_correlation_tfidf[document['Name']] = spearman_rc
#   relevant_docs = list( sorted(spearman_rank_correlation_tfidf.items(), key=operator.itemgetter(1),reverse=True))[:20]
#   for i in range(len(relevant_docs)):
#     for j in range(len(docs_preprocessed)):
#       if(relevant_docs[i][0] == docs_preprocessed[j]['Name']):
#         relevant_docs[i] = (relevant_docs[i][0], relevant_docs[i][1], docs_preprocessed[j]['Data']['Date'] )

#   return relevant_docs

# %%
# find_relevant_documents_spearman_rank_correlation_tfidf_vectorizer(docs_preprocessed, tweet_query)
